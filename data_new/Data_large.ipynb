# %%
import pandas as pd

# %%
# Load the Excel file into a DataFrame
df = pd.read_excel('train.xlsx', sheet_name=0)
df
# Out:
#          ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0      B291                         13.6          0.665119             1.0
# 1      B291                         13.6          0.665119             1.0
# 2      B291                         13.6          0.665119             1.0
# 3      B291                         13.6          0.665119             1.0
# 4      B291                         13.6          0.665119             1.0
# ...     ...                          ...               ...             ...
# 21595  B103                         30.7          0.181290             0.6
# 21596  B103                         30.7          0.181290             0.6
# 21597  B103                         30.7          0.181290             0.6
# 21598  B103                         30.7          0.181290             0.6
# 21599  B103                         30.7          0.181290             0.6
#
#        Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# ...

# %%
# Create a sample DataFrame
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})

# Duplicate the DataFrame 5 times
df_duplicates = [df.copy() for _ in range(5)]

# Concatenate the duplicates
df_combined = pd.concat(df_duplicates)

print(df_combined)
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6
# 0  1  4
# 1  2  5
# 2  3  6
# 0  1  4
# 1  2  5
# 2  3  6
# 0  1  4
# 1  2  5
# 2  3  6
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df_duplicates
# Out:
# [   A  B
#  0  1  4
#  1  2  5
#  2  3  6,
#     A  B
#  0  1  4
#  1  2  5
#  2  3  6,
#     A  B
#  0  1  4
#  1  2  5
#  2  3  6,
#     A  B
#  0  1  4
#  1  2  5
#  2  3  6,
#     A  B
#  0  1  4
#  1  2  5
#  2  3  6]
