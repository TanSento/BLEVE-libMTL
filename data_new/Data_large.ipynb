# %%
import pandas as pd

# %%
# Load the Excel file into a DataFrame
df = pd.read_excel('test.xlsx', sheet_name=0)
df
# Out:
#         ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0     P197                    11.559040          0.602823             3.0
# 1     P197                    11.559040          0.602823             3.0
# 2     P197                    11.559040          0.602823             3.0
# 3     P197                    11.559040          0.602823             3.0
# 4     P197                    11.559040          0.602823             3.0
# ...    ...                          ...               ...             ...
# 7195   P55                     5.970915          0.284706             0.6
# 7196   P55                     5.970915          0.284706             0.6
# 7197   P55                     5.970915          0.284706             0.6
# 7198   P55                     5.970915          0.284706             0.6
# 7199   P55                     5.970915          0.284706             0.6
#
#       Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# ...

# %%
# Duplicate the DataFrame 100 times
df_duplicates = [df.copy() for _ in range(100)]

# Concatenate the duplicates
df_combined = pd.concat(df_duplicates)

df_combined
# Out:
#         ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0     P197                    11.559040          0.602823             3.0
# 1     P197                    11.559040          0.602823             3.0
# 2     P197                    11.559040          0.602823             3.0
# 3     P197                    11.559040          0.602823             3.0
# 4     P197                    11.559040          0.602823             3.0
# ...    ...                          ...               ...             ...
# 7195   P55                     5.970915          0.284706             0.6
# 7196   P55                     5.970915          0.284706             0.6
# 7197   P55                     5.970915          0.284706             0.6
# 7198   P55                     5.970915          0.284706             0.6
# 7199   P55                     5.970915          0.284706             0.6
#
#       Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# ...

# %%
df.to_excel('check.xlsx', index=False, engine='xlsxwriter', sheet_name='random1')

# %% [markdown]
# ____

# %% [markdown]
# # Automated Scripts

# %%
writer = pd.ExcelWriter('large_validate.xlsx', engine='xlsxwriter')
target_name = ['positive_peak_time', 'negative_peak_time', 'arrival_time', 'positive_duration', 'negative_duration', 'positive_pressure', 'negative_pressure', 'positive_impulse']
for k in target_name:
    # Load the Excel file into a DataFrame
    df = pd.read_excel('test.xlsx', sheet_name=k)
    # Duplicate the DataFrame 100 times
    df_duplicates = [df.copy() for _ in range(140)]

    # Concatenate the duplicates
    df_combined = pd.concat(df_duplicates)
    df_combined.to_excel(writer,index=False, sheet_name=k)

writer.save()
