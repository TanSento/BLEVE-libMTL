# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import timeit
#import shap
from sklearn.metrics import r2_score, mean_absolute_percentage_error, mean_squared_error
from sklearn.model_selection import cross_val_score, GridSearchCV, KFold
from sklearn.model_selection import train_test_split

# %% [markdown]
# ___

# %% [markdown]
# # Read-in and One-Hot Encoding

# %%
df = pd.read_excel("data_new/train.xlsx", sheet_name="arrival_time")

dt = pd.read_excel("data_new/test.xlsx", sheet_name="arrival_time")

# %%
# Label encoding 'Status' feature into 0 and 1 
# 0 for Subcooled and 1 for Superheated

from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()

df['Status'] = LE.fit_transform(df['Status'])
dt['Status'] = LE.fit_transform(dt['Status'])

df
# Out:
#          ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0      B291                         13.6          0.665119             1.0
# 1      B291                         13.6          0.665119             1.0
# 2      B291                         13.6          0.665119             1.0
# 3      B291                         13.6          0.665119             1.0
# 4      B291                         13.6          0.665119             1.0
# ...     ...                          ...               ...             ...
# 21595  B103                         30.7          0.181290             0.6
# 21596  B103                         30.7          0.181290             0.6
# 21597  B103                         30.7          0.181290             0.6
# 21598  B103                         30.7          0.181290             0.6
# 21599  B103                         30.7          0.181290             0.6
#
#        Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 0                  4.0              0.8                  1.8
# 1                  4.0              0.8                  1.8
# 2                  4.0              0.8                  1.8
# 3                  4.0              0.8                  1.8
# 4                  4.0              0.8                  1.8
# ...                ...              ...                  ...
# 21595              2.0              2.8                  1.2
# 21596              2.0              2.8                  1.2
# 21597              2.0              2.8                  1.2
# 21598              2.0              2.8                  1.2
# 21599              2.0              2.8                  1.2
#
#        Tank Height with Gas (m)   Vapour Temerature (K)  \
# 0                           0.4                   435.0
# 1                           0.4                   435.0
# 2                           0.4                   435.0
# 3                           0.4                   435.0
# 4                           0.4                   435.0
# ...                         ...                     ...
# 21595                       2.2                   334.7
# 21596                       2.2                   334.7
# 21597                       2.2                   334.7
# 21598                       2.2                   334.7
# 21599                       2.2                   334.7
#
#         Liquid Temerature (K)  Status  Stand-off Distance    Target
# 0                       372.5       1                   5  0.010253
# 1                       372.5       1                   6  0.012442
# 2                       372.5       1                   7  0.014733
# 3                       372.5       1                   8  0.017102
# 4                       372.5       1                   9  0.019534
# ...                       ...     ...                 ...       ...
# 21595                   404.9       0                  36  0.088987
# 21596                   404.9       0                  37  0.091772
# 21597                   404.9       0                  38  0.094563
# 21598                   404.9       0                  39  0.097352
# 21599                   404.9       0                  40  0.100150
#
# [21600 rows x 13 columns]

# %%
dt.iloc[30:50,:]
# Out:
#       ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 30  P197                     11.55904          0.602823             3.0
# 31  P197                     11.55904          0.602823             3.0
# 32  P197                     11.55904          0.602823             3.0
# 33  P197                     11.55904          0.602823             3.0
# 34  P197                     11.55904          0.602823             3.0
# 35  P197                     11.55904          0.602823             3.0
# 36  P168                     12.72223          0.648320             1.8
# 37  P168                     12.72223          0.648320             1.8
# 38  P168                     12.72223          0.648320             1.8
# 39  P168                     12.72223          0.648320             1.8
# 40  P168                     12.72223          0.648320             1.8
# 41  P168                     12.72223          0.648320             1.8
# 42  P168                     12.72223          0.648320             1.8
# 43  P168                     12.72223          0.648320             1.8
# 44  P168                     12.72223          0.648320             1.8
# 45  P168                     12.72223          0.648320             1.8
# 46  P168                     12.72223          0.648320             1.8
# 47  P168                     12.72223          0.648320             1.8
# 48  P168                     12.72223          0.648320             1.8
# 49  P168                     12.72223          0.648320             1.8
#
#     Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 30              0.8              2.2                  0.2
# 31              0.8              2.2                  0.2
# 32              0.8              2.2                  0.2
# 33              0.8              2.2                  0.2
# 34              0.8              2.2                  0.2
# 35              0.8              2.2                  0.2
# 36              8.2              0.6                  1.8
# 37              8.2              0.6                  1.8
# 38              8.2              0.6                  1.8
# 39              8.2              0.6                  1.8
# 40              8.2              0.6                  1.8
# 41              8.2              0.6                  1.8
# 42              8.2              0.6                  1.8
# 43              8.2              0.6                  1.8
# 44              8.2              0.6                  1.8
# 45              8.2              0.6                  1.8
# 46              8.2              0.6                  1.8
# 47              8.2              0.6                  1.8
# 48              8.2              0.6                  1.8
# 49              8.2              0.6                  1.8
#
#     Tank Height with Gas (m)   Vapour Temerature (K)   Liquid Temerature (K)  \
# 30                       1.0                   296.7                   328.5
# 31                       1.0                   296.7                   328.5
# 32                       1.0                   296.7                   328.5
# 33                       1.0                   296.7                   328.5
# 34                       1.0                   296.7                   328.5
# 35                       1.0                   296.7                   328.5
# 36                       0.2                   389.7                   296.4
# 37                       0.2                   389.7                   296.4
# 38                       0.2                   389.7                   296.4
# 39                       0.2                   389.7                   296.4
# 40                       0.2                   389.7                   296.4
# 41                       0.2                   389.7                   296.4
# 42                       0.2                   389.7                   296.4
# 43                       0.2                   389.7                   296.4
# 44                       0.2                   389.7                   296.4
# 45                       0.2                   389.7                   296.4
# 46                       0.2                   389.7                   296.4
# 47                       0.2                   389.7                   296.4
# 48                       0.2                   389.7                   296.4
# 49                       0.2                   389.7                   296.4
#
#     Status  Stand-off Distance    Target
# 30       1                  35  0.091514
# 31       1                  36  0.094326
# 32       1                  37  0.097138
# 33       1                  38  0.099955
# 34       1                  39  0.102774
# 35       1                  40  0.105593
# 36       0                   5  0.011512
# 37       0                   6  0.013904
# 38       0                   7  0.016363
# 39       0                   8  0.018873
# 40       0                   9  0.021419
# 41       0                  10  0.023992
# 42       0                  11  0.026597
# 43       0                  12  0.029217
# 44       0                  13  0.031857
# 45       0                  14  0.034521
# 46       0                  15  0.037198
# 47       0                  16  0.039885
# 48       0                  17  0.042588
# 49       0                  18  0.045299

# %%
X_traindf = df.drop(['ID','Target'], axis=1)
X_testdf = dt.drop(['ID','Target'], axis=1)

X_traindf
# Out:
#        Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0                             13.6          0.665119             1.0
# 1                             13.6          0.665119             1.0
# 2                             13.6          0.665119             1.0
# 3                             13.6          0.665119             1.0
# 4                             13.6          0.665119             1.0
# ...                            ...               ...             ...
# 21595                         30.7          0.181290             0.6
# 21596                         30.7          0.181290             0.6
# 21597                         30.7          0.181290             0.6
# 21598                         30.7          0.181290             0.6
# 21599                         30.7          0.181290             0.6
#
#        Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 0                  4.0              0.8                  1.8
# 1                  4.0              0.8                  1.8
# 2                  4.0              0.8                  1.8
# 3                  4.0              0.8                  1.8
# 4                  4.0              0.8                  1.8
# ...                ...              ...                  ...
# 21595              2.0              2.8                  1.2
# 21596              2.0              2.8                  1.2
# 21597              2.0              2.8                  1.2
# 21598              2.0              2.8                  1.2
# 21599              2.0              2.8                  1.2
#
#        Tank Height with Gas (m)   Vapour Temerature (K)  \
# 0                           0.4                   435.0
# 1                           0.4                   435.0
# 2                           0.4                   435.0
# 3                           0.4                   435.0
# 4                           0.4                   435.0
# ...                         ...                     ...
# 21595                       2.2                   334.7
# 21596                       2.2                   334.7
# 21597                       2.2                   334.7
# 21598                       2.2                   334.7
# 21599                       2.2                   334.7
#
#         Liquid Temerature (K)  Status  Stand-off Distance
# 0                       372.5       1                   5
# 1                       372.5       1                   6
# 2                       372.5       1                   7
# 3                       372.5       1                   8
# 4                       372.5       1                   9
# ...                       ...     ...                 ...
# 21595                   404.9       0                  36
# 21596                   404.9       0                  37
# 21597                   404.9       0                  38
# 21598                   404.9       0                  39
# 21599                   404.9       0                  40
#
# [21600 rows x 11 columns]

# %%
y_train = df['Target']
y_train
# Out:
# 0        0.010253
# 1        0.012442
# 2        0.014733
# 3        0.017102
# 4        0.019534
#            ...
# 21595    0.088987
# 21596    0.091772
# 21597    0.094563
# 21598    0.097352
# 21599    0.100150
# Name: Target, Length: 21600, dtype: float64

# %%
y_test = dt['Target']

y_test
# Out:
# 0       0.009646
# 1       0.012093
# 2       0.014611
# 3       0.017177
# 4       0.019785
#           ...
# 7195    0.087402
# 7196    0.090136
# 7197    0.092877
# 7198    0.095618
# 7199    0.098365
# Name: Target, Length: 7200, dtype: float64

# %% [markdown]
# ___

# %% [markdown]
# # Standardization and Power Transform

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import QuantileTransformer

# %%
# Processing both X_train and X_test using standardization
scaler = StandardScaler()
X_train = scaler.fit_transform(X_traindf)
X_test = scaler.transform(X_testdf)

# %%
quantile = QuantileTransformer(output_distribution='normal', random_state=42)



y_train_normal = quantile.fit_transform(y_train.values.reshape(-1,1))
y_test_normal = quantile.transform(y_test.values.reshape(-1,1))

# %%
# Visualize the effect of power transformation
f = plt.figure(figsize=(15, 6))

ax = f.add_subplot(121)
sns.distplot(y_train, bins=50, color='r', ax=ax)
ax.set_title('Distribution before processing')

ax=f.add_subplot(122)
sns.distplot(y_train_normal, bins=50, color='b', ax=ax)
ax.set_title('Distribution after quantile processing')
print()
# Out:
# /home/tendou/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/tendou/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ___

# %% [markdown]
# # ANN

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt

torch.backends.cudnn.version() , torch.backends.cudnn.enabled
torch.manual_seed(0)

# %%
# convert data to torch.FloatTensor
X_train_torch = torch.from_numpy(X_train.astype(np.float32))
X_test_torch = torch.from_numpy(X_test.astype(np.float32))



y_train_torch = torch.from_numpy(y_train_normal.astype(np.float32))
y_test_torch = torch.from_numpy(y_test_normal.astype(np.float32))

print(X_train_torch)
# Out:
# tensor([[-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.6846],
#         [-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.5883],
#         [-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.4921],
#         ...,
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.4921],
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.5883],
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.6846]])

# %%
train_data = []
for i in range(len(X_train_torch)):
   train_data.append([X_train_torch[i],
                      y_train_torch[i]
                     ])

test_data = []
for i in range(len(X_test_torch)):
   test_data.append([X_test_torch[i], 
                     y_test_torch[i]
                     ])
   
# prepare data loaders
train_loader = torch.utils.data.DataLoader(train_data, batch_size=512,               # batch_size could be smaller
    num_workers=0, shuffle =True)                                                                   # Increasing num_workers slow down the training because it does not use GPU at all
test_loader = torch.utils.data.DataLoader(test_data, batch_size=512,
    num_workers=0)

# %%
## Define the NN architecture
## NN with 3 hidden layer, s=[11, 256, 256, 256, 1]

class BleveNet(nn.Module):
    def __init__(self):
        super(BleveNet, self).__init__()
        # The first hidden layer has 256 neurons
        self.fc1 = nn.Linear(X_train_torch.shape[1], 256)
        # The second hidden layer has 256 neurons
        self.fc2 = nn.Linear(256, 256)
        # The third hidden layer has 256 neurons
        self.fc3 = nn.Linear(256, 256)
        # The final layer has 1 output neuron
        self.fc4 = nn.Linear(256, 1)


        # Define proportion or neurons to dropout
        self.dropout = nn.Dropout(0.1)

        # Mish activation
        self.mish = nn.Mish()


    def forward(self, x):
        # add first fully connected layer
        x = self.fc1(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add second fully connected layer
        x = self.fc2(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add third fully connected layer
        x = self.fc3(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add final output layers:
        output = self.fc4(x)
       
        return output

# initialize the NN
model = BleveNet()
print(model)
# Out:
# BleveNet(
#   (fc1): Linear(in_features=11, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=256, bias=True)
#   (fc4): Linear(in_features=256, out_features=1, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (mish): Mish()
# )

# %%
criterion = nn.HuberLoss()        # This is the best loss function for my model
# criterion = nn.MSELoss()


optimizer = torch.optim.Adam(model.parameters(), lr=0.005, weight_decay=1e-5)     # This is the best optimizer for my model 

# Check for GPU
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
startTime = timeit.default_timer() 

n_epochs = 500 

model.to(device)    # bring the model to gpu

train_losses = []
lowest_mape = 100
for epoch in range(n_epochs):

    model.train()       

    # monitor training loss
    train_loss = 0.0
    
    ###################
    # train the model #
    ###################
    for data, target in train_loader:
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        #bring data and target to gpu
        data, target = data.to(device), target.to(device)
        
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update running training loss
        train_loss += loss.item()*data.size(0)
        
    # print training statistics 
    # calculate average loss over an epoch
    train_loss = train_loss/len(train_loader.dataset)
    train_losses.append(train_loss)

    print('Epoch: {}/{} \tTraining Loss: {:.6f}'.format(
        epoch+1,
        n_epochs, 
        train_loss
        ))
    

    ############################
    # Evaluate the lowest MAPE #
    ############################
    model.eval()
    with torch.no_grad():  # turn off gradient to save memory
        y_predNN_torch = model(X_test_torch.to(device))

    y_predNN = quantile.inverse_transform(y_predNN_torch.cpu().numpy())
    MAPE = mean_absolute_percentage_error(y_test, y_predNN)

    if MAPE < lowest_mape:
        lowest_mape = MAPE
        print(f'Lowest MAPE: {lowest_mape}')
        torch.save(model.state_dict(), 'PyTorch_Model/Single_ArrivalTime_lowest.pt')
    print()

endTime = timeit.default_timer()
runningTotal = (endTime - startTime)
print(f"Time taken: {runningTotal}")
# Out:
# Epoch: 1/500 	Training Loss: 0.056068
# Lowest MAPE: 0.08630672500172644
#
# Epoch: 2/500 	Training Loss: 0.016303
# Lowest MAPE: 0.034854937876237405
#
# Epoch: 3/500 	Training Loss: 0.011561
#
# Epoch: 4/500 	Training Loss: 0.010181
#
# Epoch: 5/500 	Training Loss: 0.010958
# Lowest MAPE: 0.03195736294401379
#
# Epoch: 6/500 	Training Loss: 0.010320
#
# Epoch: 7/500 	Training Loss: 0.008589
#
# Epoch: 8/500 	Training Loss: 0.007653
#
# Epoch: 9/500 	Training Loss: 0.006724
# Lowest MAPE: 0.025276272883798714
#
# Epoch: 10/500 	Training Loss: 0.007005
#
# Epoch: 11/500 	Training Loss: 0.007156
#
# Epoch: 12/500 	Training Loss: 0.005930
# Lowest MAPE: 0.020012047576942783
#
# Epoch: 13/500 	Training Loss: 0.005718
#
# Epoch: 14/500 	Training Loss: 0.006219
#
# Epoch: 15/500 	Training Loss: 0.006951
# Lowest MAPE: 0.016652060697276976
#
# Epoch: 16/500 	Training Loss: 0.006146
#
# Epoch: 17/500 	Training Loss: 0.004892
# Lowest MAPE: 0.016575615479801593
#
# Epoch: 18/500 	Training Loss: 0.005544
#
# Epoch: 19/500 	Training Loss: 0.005404
#
# Epoch: 20/500 	Training Loss: 0.004645
#
# Epoch: 21/500 	Training Loss: 0.004277
#
# Epoch: 22/500 	Training Loss: 0.004368
#
# Epoch: 23/500 	Training Loss: 0.004572
#
# Epoch: 24/500 	Training Loss: 0.003874
#
# Epoch: 25/500 	Training Loss: 0.004886
#
# Epoch: 26/500 	Training Loss: 0.004953
#
# Epoch: 27/500 	Training Loss: 0.006031
#
# Epoch: 28/500 	Training Loss: 0.004298
#
# Epoch: 29/500 	Training Loss: 0.005005
#
# Epoch: 30/500 	Training Loss: 0.004264
#
# Epoch: 31/500 	Training Loss: 0.005240
#
# Epoch: 32/500 	Training Loss: 0.003990
#
# Epoch: 33/500 	Training Loss: 0.003718
#
# Epoch: 34/500 	Training Loss: 0.004271
#
# Epoch: 35/500 	Training Loss: 0.003759
#
# Epoch: 36/500 	Training Loss: 0.003486
#
# Epoch: 37/500 	Training Loss: 0.004187
#
# Epoch: 38/500 	Training Loss: 0.003729
#
# Epoch: 39/500 	Training Loss: 0.004565
#
# Epoch: 40/500 	Training Loss: 0.004458
# Lowest MAPE: 0.01576324425329114
#
# Epoch: 41/500 	Training Loss: 0.004013
#
# Epoch: 42/500 	Training Loss: 0.003464
#
# Epoch: 43/500 	Training Loss: 0.003866
#
# Epoch: 44/500 	Training Loss: 0.004499
# Lowest MAPE: 0.015140343768392203
#
# Epoch: 45/500 	Training Loss: 0.004984
#
# Epoch: 46/500 	Training Loss: 0.003728
# Lowest MAPE: 0.012246799526253273
#
# Epoch: 47/500 	Training Loss: 0.003498
#
# Epoch: 48/500 	Training Loss: 0.005049
#
# Epoch: 49/500 	Training Loss: 0.003472
#
# Epoch: 50/500 	Training Loss: 0.003999
#
# Epoch: 51/500 	Training Loss: 0.004116
#
# Epoch: 52/500 	Training Loss: 0.003734
#
# Epoch: 53/500 	Training Loss: 0.003737
#
# Epoch: 54/500 	Training Loss: 0.004440
#
# Epoch: 55/500 	Training Loss: 0.004265
#
# Epoch: 56/500 	Training Loss: 0.003710
#
# Epoch: 57/500 	Training Loss: 0.003427
#
# Epoch: 58/500 	Training Loss: 0.003354
#
# Epoch: 59/500 	Training Loss: 0.003324
#
# Epoch: 60/500 	Training Loss: 0.003788
#
# Epoch: 61/500 	Training Loss: 0.004830
#
# Epoch: 62/500 	Training Loss: 0.004161
#
# Epoch: 63/500 	Training Loss: 0.003669
#
# Epoch: 64/500 	Training Loss: 0.003654
#
# Epoch: 65/500 	Training Loss: 0.005038
#
# Epoch: 66/500 	Training Loss: 0.003472
#
# Epoch: 67/500 	Training Loss: 0.003643
#
# Epoch: 68/500 	Training Loss: 0.003680
#
# Epoch: 69/500 	Training Loss: 0.003236
#
# Epoch: 70/500 	Training Loss: 0.005584
#
# Epoch: 71/500 	Training Loss: 0.003394
#
# Epoch: 72/500 	Training Loss: 0.003380
#
# Epoch: 73/500 	Training Loss: 0.003717
#
# Epoch: 74/500 	Training Loss: 0.003590
#
# Epoch: 75/500 	Training Loss: 0.004413
#
# Epoch: 76/500 	Training Loss: 0.003342
#
# Epoch: 77/500 	Training Loss: 0.003800
#
# Epoch: 78/500 	Training Loss: 0.005074
#
# Epoch: 79/500 	Training Loss: 0.003163
#
# Epoch: 80/500 	Training Loss: 0.003243
#
# Epoch: 81/500 	Training Loss: 0.003442
#
# Epoch: 82/500 	Training Loss: 0.004681
#
# Epoch: 83/500 	Training Loss: 0.004046
#
# Epoch: 84/500 	Training Loss: 0.003457
#
# Epoch: 85/500 	Training Loss: 0.004329
#
# Epoch: 86/500 	Training Loss: 0.003315
#
# Epoch: 87/500 	Training Loss: 0.003290
#
# Epoch: 88/500 	Training Loss: 0.003341
#
# Epoch: 89/500 	Training Loss: 0.003876
#
# Epoch: 90/500 	Training Loss: 0.003560
#
# Epoch: 91/500 	Training Loss: 0.003623
#
# Epoch: 92/500 	Training Loss: 0.003600
#
# Epoch: 93/500 	Training Loss: 0.003204
#
# Epoch: 94/500 	Training Loss: 0.003993
#
# Epoch: 95/500 	Training Loss: 0.003577
#
# Epoch: 96/500 	Training Loss: 0.003431
#
# Epoch: 97/500 	Training Loss: 0.004461
#
# Epoch: 98/500 	Training Loss: 0.003697
#
# Epoch: 99/500 	Training Loss: 0.003671
#
# Epoch: 100/500 	Training Loss: 0.003678
#
# Epoch: 101/500 	Training Loss: 0.004075
#
# Epoch: 102/500 	Training Loss: 0.004705
#
# Epoch: 103/500 	Training Loss: 0.003892
#
# Epoch: 104/500 	Training Loss: 0.003558
#
# Epoch: 105/500 	Training Loss: 0.002975
#
# Epoch: 106/500 	Training Loss: 0.003570
#
# Epoch: 107/500 	Training Loss: 0.003459
#
# Epoch: 108/500 	Training Loss: 0.003963
#
# Epoch: 109/500 	Training Loss: 0.003864
#
# Epoch: 110/500 	Training Loss: 0.004050
#
# Epoch: 111/500 	Training Loss: 0.002880
#
# Epoch: 112/500 	Training Loss: 0.003422
#
# Epoch: 113/500 	Training Loss: 0.003333
#
# Epoch: 114/500 	Training Loss: 0.003629
#
# Epoch: 115/500 	Training Loss: 0.003619
#
# Epoch: 116/500 	Training Loss: 0.003706
#
# Epoch: 117/500 	Training Loss: 0.003127
#
# Epoch: 118/500 	Training Loss: 0.004003
#
# Epoch: 119/500 	Training Loss: 0.003039
#
# Epoch: 120/500 	Training Loss: 0.003441
#
# Epoch: 121/500 	Training Loss: 0.003203
#
# Epoch: 122/500 	Training Loss: 0.003144
#
# Epoch: 123/500 	Training Loss: 0.004033
#
# Epoch: 124/500 	Training Loss: 0.003824
#
# Epoch: 125/500 	Training Loss: 0.003307
#
# Epoch: 126/500 	Training Loss: 0.002911
#
# Epoch: 127/500 	Training Loss: 0.003460
#
# Epoch: 128/500 	Training Loss: 0.003399
#
# Epoch: 129/500 	Training Loss: 0.003198
#
# Epoch: 130/500 	Training Loss: 0.003620
#
# Epoch: 131/500 	Training Loss: 0.002998
#
# Epoch: 132/500 	Training Loss: 0.003019
#
# Epoch: 133/500 	Training Loss: 0.005070
#
# Epoch: 134/500 	Training Loss: 0.003339
#
# Epoch: 135/500 	Training Loss: 0.003758
#
# Epoch: 136/500 	Training Loss: 0.003320
#
# Epoch: 137/500 	Training Loss: 0.002959
#
# Epoch: 138/500 	Training Loss: 0.003300
#
# Epoch: 139/500 	Training Loss: 0.003000
#
# Epoch: 140/500 	Training Loss: 0.004110
#
# Epoch: 141/500 	Training Loss: 0.003998
#
# Epoch: 142/500 	Training Loss: 0.003459
#
# Epoch: 143/500 	Training Loss: 0.003013
#
# Epoch: 144/500 	Training Loss: 0.003481
#
# Epoch: 145/500 	Training Loss: 0.004396
#
# Epoch: 146/500 	Training Loss: 0.003800
#
# Epoch: 147/500 	Training Loss: 0.004587
#
# Epoch: 148/500 	Training Loss: 0.003406
#
# Epoch: 149/500 	Training Loss: 0.004828
#
# Epoch: 150/500 	Training Loss: 0.002788
#
# Epoch: 151/500 	Training Loss: 0.003595
#
# Epoch: 152/500 	Training Loss: 0.004343
#
# Epoch: 153/500 	Training Loss: 0.004133
#
# Epoch: 154/500 	Training Loss: 0.002843
#
# Epoch: 155/500 	Training Loss: 0.003447
#
# Epoch: 156/500 	Training Loss: 0.003195
#
# Epoch: 157/500 	Training Loss: 0.003305
#
# Epoch: 158/500 	Training Loss: 0.002955
#
# Epoch: 159/500 	Training Loss: 0.003484
#
# Epoch: 160/500 	Training Loss: 0.003039
#
# Epoch: 161/500 	Training Loss: 0.003522
#
# Epoch: 162/500 	Training Loss: 0.002902
#
# Epoch: 163/500 	Training Loss: 0.003334
#
# Epoch: 164/500 	Training Loss: 0.003321
#
# Epoch: 165/500 	Training Loss: 0.002811
#
# Epoch: 166/500 	Training Loss: 0.003983
#
# Epoch: 167/500 	Training Loss: 0.003832
#
# Epoch: 168/500 	Training Loss: 0.003892
#
# Epoch: 169/500 	Training Loss: 0.004115
#
# Epoch: 170/500 	Training Loss: 0.002615
#
# Epoch: 171/500 	Training Loss: 0.002678
#
# Epoch: 172/500 	Training Loss: 0.003662
#
# Epoch: 173/500 	Training Loss: 0.003623
#
# Epoch: 174/500 	Training Loss: 0.003151
#
# Epoch: 175/500 	Training Loss: 0.003111
#
# Epoch: 176/500 	Training Loss: 0.003778
#
# Epoch: 177/500 	Training Loss: 0.003354
#
# Epoch: 178/500 	Training Loss: 0.003035
#
# Epoch: 179/500 	Training Loss: 0.002936
#
# Epoch: 180/500 	Training Loss: 0.003056
#
# Epoch: 181/500 	Training Loss: 0.002961
#
# Epoch: 182/500 	Training Loss: 0.003223
#
# Epoch: 183/500 	Training Loss: 0.137144
#
# Epoch: 184/500 	Training Loss: 0.061990
#
# Epoch: 185/500 	Training Loss: 0.010128
#
# Epoch: 186/500 	Training Loss: 0.006961
#
# Epoch: 187/500 	Training Loss: 0.005865
#
# Epoch: 188/500 	Training Loss: 0.005629
#
# Epoch: 189/500 	Training Loss: 0.004933
#
# Epoch: 190/500 	Training Loss: 0.004782
#
# Epoch: 191/500 	Training Loss: 0.004786
#
# Epoch: 192/500 	Training Loss: 0.004375
#
# Epoch: 193/500 	Training Loss: 0.004620
#
# Epoch: 194/500 	Training Loss: 0.003910
#
# Epoch: 195/500 	Training Loss: 0.003913
#
# Epoch: 196/500 	Training Loss: 0.003353
#
# Epoch: 197/500 	Training Loss: 0.003696
#
# Epoch: 198/500 	Training Loss: 0.003608
#
# Epoch: 199/500 	Training Loss: 0.003898
#
# Epoch: 200/500 	Training Loss: 0.003404
#
# Epoch: 201/500 	Training Loss: 0.003519
#
# Epoch: 202/500 	Training Loss: 0.003188
# Lowest MAPE: 0.01085779417774422
#
# Epoch: 203/500 	Training Loss: 0.003170
#
# Epoch: 204/500 	Training Loss: 0.003249
#
# Epoch: 205/500 	Training Loss: 0.003051
#
# Epoch: 206/500 	Training Loss: 0.002953
#
# Epoch: 207/500 	Training Loss: 0.003010
#
# Epoch: 208/500 	Training Loss: 0.003266
#
# Epoch: 209/500 	Training Loss: 0.003066
#
# Epoch: 210/500 	Training Loss: 0.003079
#
# Epoch: 211/500 	Training Loss: 0.003216
#
# Epoch: 212/500 	Training Loss: 0.003067
#
# Epoch: 213/500 	Training Loss: 0.003068
#
# Epoch: 214/500 	Training Loss: 0.003067
#
# Epoch: 215/500 	Training Loss: 0.002931
#
# Epoch: 216/500 	Training Loss: 0.003064
#
# Epoch: 217/500 	Training Loss: 0.003287
#
# Epoch: 218/500 	Training Loss: 0.003128
#
# Epoch: 219/500 	Training Loss: 0.003060
#
# Epoch: 220/500 	Training Loss: 0.002935
#
# Epoch: 221/500 	Training Loss: 0.003326
#
# Epoch: 222/500 	Training Loss: 0.003281
#
# Epoch: 223/500 	Training Loss: 0.004079
#
# Epoch: 224/500 	Training Loss: 0.003135
#
# Epoch: 225/500 	Training Loss: 0.002969
#
# Epoch: 226/500 	Training Loss: 0.003220
#
# Epoch: 227/500 	Training Loss: 0.003534
#
# Epoch: 228/500 	Training Loss: 0.003345
#
# Epoch: 229/500 	Training Loss: 0.003465
#
# Epoch: 230/500 	Training Loss: 0.003271
#
# Epoch: 231/500 	Training Loss: 0.003199
#
# Epoch: 232/500 	Training Loss: 0.003238
#
# Epoch: 233/500 	Training Loss: 0.002953
#
# Epoch: 234/500 	Training Loss: 0.002712
#
# Epoch: 235/500 	Training Loss: 0.002879
#
# Epoch: 236/500 	Training Loss: 0.003275
#
# Epoch: 237/500 	Training Loss: 0.003846
#
# Epoch: 238/500 	Training Loss: 0.003336
#
# Epoch: 239/500 	Training Loss: 0.002979
#
# Epoch: 240/500 	Training Loss: 0.003237
#
# Epoch: 241/500 	Training Loss: 0.002726
#
# Epoch: 242/500 	Training Loss: 0.002919
#
# Epoch: 243/500 	Training Loss: 0.002825
#
# Epoch: 244/500 	Training Loss: 0.003430
#
# Epoch: 245/500 	Training Loss: 0.004304
#
# Epoch: 246/500 	Training Loss: 0.003321
#
# Epoch: 247/500 	Training Loss: 0.002819
#
# Epoch: 248/500 	Training Loss: 0.003214
#
# Epoch: 249/500 	Training Loss: 0.003778
#
# Epoch: 250/500 	Training Loss: 0.003142
#
# Epoch: 251/500 	Training Loss: 0.003505
#
# Epoch: 252/500 	Training Loss: 0.003030
#
# Epoch: 253/500 	Training Loss: 0.002903
#
# Epoch: 254/500 	Training Loss: 0.003515
#
# Epoch: 255/500 	Training Loss: 0.002779
#
# Epoch: 256/500 	Training Loss: 0.002993
#
# Epoch: 257/500 	Training Loss: 0.003535
#
# Epoch: 258/500 	Training Loss: 0.003240
#
# Epoch: 259/500 	Training Loss: 0.002873
#
# Epoch: 260/500 	Training Loss: 0.003579
#
# Epoch: 261/500 	Training Loss: 0.002849
#
# Epoch: 262/500 	Training Loss: 0.003251
#
# Epoch: 263/500 	Training Loss: 0.003023
#
# Epoch: 264/500 	Training Loss: 0.002846
#
# Epoch: 265/500 	Training Loss: 0.003796
#
# Epoch: 266/500 	Training Loss: 0.002781
#
# Epoch: 267/500 	Training Loss: 0.003090
#
# Epoch: 268/500 	Training Loss: 0.003007
#
# Epoch: 269/500 	Training Loss: 0.003379
#
# Epoch: 270/500 	Training Loss: 0.003021
#
# Epoch: 271/500 	Training Loss: 0.003017
#
# Epoch: 272/500 	Training Loss: 0.002940
#
# Epoch: 273/500 	Training Loss: 0.003308
#
# Epoch: 274/500 	Training Loss: 0.003447
#
# Epoch: 275/500 	Training Loss: 0.002997
#
# Epoch: 276/500 	Training Loss: 0.003625
#
# Epoch: 277/500 	Training Loss: 0.002840
#
# Epoch: 278/500 	Training Loss: 0.002960
#
# Epoch: 279/500 	Training Loss: 0.003452
#
# Epoch: 280/500 	Training Loss: 0.003439
#
# Epoch: 281/500 	Training Loss: 0.002924
#
# Epoch: 282/500 	Training Loss: 0.003094
#
# Epoch: 283/500 	Training Loss: 0.002635
#
# Epoch: 284/500 	Training Loss: 0.002832
#
# Epoch: 285/500 	Training Loss: 0.003625
#
# Epoch: 286/500 	Training Loss: 0.003315
#
# Epoch: 287/500 	Training Loss: 0.002849
#
# Epoch: 288/500 	Training Loss: 0.003089
#
# Epoch: 289/500 	Training Loss: 0.003259
#
# Epoch: 290/500 	Training Loss: 0.003050
#
# Epoch: 291/500 	Training Loss: 0.003278
#
# Epoch: 292/500 	Training Loss: 0.003281
#
# Epoch: 293/500 	Training Loss: 0.003162
#
# Epoch: 294/500 	Training Loss: 0.002921
#
# Epoch: 295/500 	Training Loss: 0.003452
#
# Epoch: 296/500 	Training Loss: 0.003004
#
# Epoch: 297/500 	Training Loss: 0.003116
#
# Epoch: 298/500 	Training Loss: 0.002661
#
# Epoch: 299/500 	Training Loss: 0.002822
#
# Epoch: 300/500 	Training Loss: 0.003627
#
# Epoch: 301/500 	Training Loss: 0.003160
#
# Epoch: 302/500 	Training Loss: 0.002951
#
# Epoch: 303/500 	Training Loss: 0.003006
#
# Epoch: 304/500 	Training Loss: 0.002767
#
# Epoch: 305/500 	Training Loss: 0.003032
#
# Epoch: 306/500 	Training Loss: 0.003015
#
# Epoch: 307/500 	Training Loss: 0.003068
#
# Epoch: 308/500 	Training Loss: 0.003157
#
# Epoch: 309/500 	Training Loss: 0.003291
#
# Epoch: 310/500 	Training Loss: 0.004870
#
# Epoch: 311/500 	Training Loss: 0.002585
#
# Epoch: 312/500 	Training Loss: 0.003521
#
# Epoch: 313/500 	Training Loss: 0.003309
#
# Epoch: 314/500 	Training Loss: 0.003169
#
# Epoch: 315/500 	Training Loss: 0.002742
#
# Epoch: 316/500 	Training Loss: 0.002826
#
# Epoch: 317/500 	Training Loss: 0.003108
#
# Epoch: 318/500 	Training Loss: 0.003344
#
# Epoch: 319/500 	Training Loss: 0.002836
#
# Epoch: 320/500 	Training Loss: 0.002943
#
# Epoch: 321/500 	Training Loss: 0.003042
#
# Epoch: 322/500 	Training Loss: 0.003060
#
# Epoch: 323/500 	Training Loss: 0.002537
#
# Epoch: 324/500 	Training Loss: 0.004359
#
# Epoch: 325/500 	Training Loss: 0.002800
#
# Epoch: 326/500 	Training Loss: 0.002896
#
# Epoch: 327/500 	Training Loss: 0.003359
#
# Epoch: 328/500 	Training Loss: 0.003641
#
# Epoch: 329/500 	Training Loss: 0.003237
#
# Epoch: 330/500 	Training Loss: 0.003339
#
# Epoch: 331/500 	Training Loss: 0.002936
#
# Epoch: 332/500 	Training Loss: 0.003225
#
# Epoch: 333/500 	Training Loss: 0.002962
#
# Epoch: 334/500 	Training Loss: 0.003435
#
# Epoch: 335/500 	Training Loss: 0.002757
#
# Epoch: 336/500 	Training Loss: 0.003215
#
# Epoch: 337/500 	Training Loss: 0.003795
#
# Epoch: 338/500 	Training Loss: 0.002648
#
# Epoch: 339/500 	Training Loss: 0.003053
#
# Epoch: 340/500 	Training Loss: 0.003452
#
# Epoch: 341/500 	Training Loss: 0.002875
#
# Epoch: 342/500 	Training Loss: 0.002825
#
# Epoch: 343/500 	Training Loss: 0.003874
#
# Epoch: 344/500 	Training Loss: 0.003010
#
# Epoch: 345/500 	Training Loss: 0.003238
#
# Epoch: 346/500 	Training Loss: 0.002940
#
# Epoch: 347/500 	Training Loss: 0.003001
#
# Epoch: 348/500 	Training Loss: 0.002866
#
# Epoch: 349/500 	Training Loss: 0.003274
#
# Epoch: 350/500 	Training Loss: 0.003565
#
# Epoch: 351/500 	Training Loss: 0.002842
#
# Epoch: 352/500 	Training Loss: 0.003705
#
# Epoch: 353/500 	Training Loss: 0.003574
#
# Epoch: 354/500 	Training Loss: 0.003440
#
# Epoch: 355/500 	Training Loss: 0.003245
#
# Epoch: 356/500 	Training Loss: 0.003053
#
# Epoch: 357/500 	Training Loss: 0.002681
#
# Epoch: 358/500 	Training Loss: 0.002871
#
# Epoch: 359/500 	Training Loss: 0.002835
#
# Epoch: 360/500 	Training Loss: 0.003395
#
# Epoch: 361/500 	Training Loss: 0.003319
#
# Epoch: 362/500 	Training Loss: 0.003081
#
# Epoch: 363/500 	Training Loss: 0.002975
#
# Epoch: 364/500 	Training Loss: 0.002962
#
# Epoch: 365/500 	Training Loss: 0.003090
#
# Epoch: 366/500 	Training Loss: 0.003040
#
# Epoch: 367/500 	Training Loss: 0.003067
#
# Epoch: 368/500 	Training Loss: 0.003132
#
# Epoch: 369/500 	Training Loss: 0.003095
#
# Epoch: 370/500 	Training Loss: 0.003605
#
# Epoch: 371/500 	Training Loss: 0.003027
#
# Epoch: 372/500 	Training Loss: 0.003388
#
# Epoch: 373/500 	Training Loss: 0.002938
#
# Epoch: 374/500 	Training Loss: 0.003991
#
# Epoch: 375/500 	Training Loss: 0.003095
#
# Epoch: 376/500 	Training Loss: 0.002935
#
# Epoch: 377/500 	Training Loss: 0.003246
#
# Epoch: 378/500 	Training Loss: 0.002696
#
# Epoch: 379/500 	Training Loss: 0.002632
#
# Epoch: 380/500 	Training Loss: 0.003048
#
# Epoch: 381/500 	Training Loss: 0.002929
#
# Epoch: 382/500 	Training Loss: 0.002885
#
# Epoch: 383/500 	Training Loss: 0.002892
#
# Epoch: 384/500 	Training Loss: 0.002839
#
# Epoch: 385/500 	Training Loss: 0.003607
#
# Epoch: 386/500 	Training Loss: 0.002884
#
# Epoch: 387/500 	Training Loss: 0.002797
#
# Epoch: 388/500 	Training Loss: 0.003327
#
# Epoch: 389/500 	Training Loss: 0.003059
#
# Epoch: 390/500 	Training Loss: 0.003239
#
# Epoch: 391/500 	Training Loss: 0.002731
#
# Epoch: 392/500 	Training Loss: 0.002907
#
# Epoch: 393/500 	Training Loss: 0.003182
#
# Epoch: 394/500 	Training Loss: 0.003068
#
# Epoch: 395/500 	Training Loss: 0.002878
#
# Epoch: 396/500 	Training Loss: 0.002933
#
# Epoch: 397/500 	Training Loss: 0.002926
#
# Epoch: 398/500 	Training Loss: 0.002668
#
# Epoch: 399/500 	Training Loss: 0.002870
#
# Epoch: 400/500 	Training Loss: 0.003988
#
# Epoch: 401/500 	Training Loss: 0.002823
#
# Epoch: 402/500 	Training Loss: 0.003726
#
# Epoch: 403/500 	Training Loss: 0.003202
#
# Epoch: 404/500 	Training Loss: 0.003123
#
# Epoch: 405/500 	Training Loss: 0.002934
#
# Epoch: 406/500 	Training Loss: 0.002943
#
# Epoch: 407/500 	Training Loss: 0.003403
#
# Epoch: 408/500 	Training Loss: 0.003256
#
# Epoch: 409/500 	Training Loss: 0.003211
#
# Epoch: 410/500 	Training Loss: 0.002944
#
# Epoch: 411/500 	Training Loss: 0.003072
#
# Epoch: 412/500 	Training Loss: 0.003671
#
# Epoch: 413/500 	Training Loss: 0.002833
#
# Epoch: 414/500 	Training Loss: 0.002931
#
# Epoch: 415/500 	Training Loss: 0.002897
#
# Epoch: 416/500 	Training Loss: 0.003054
#
# Epoch: 417/500 	Training Loss: 0.002846
#
# Epoch: 418/500 	Training Loss: 0.003765
#
# Epoch: 419/500 	Training Loss: 0.003519
#
# Epoch: 420/500 	Training Loss: 0.002818
#
# Epoch: 421/500 	Training Loss: 0.002905
#
# Epoch: 422/500 	Training Loss: 0.002884
#
# Epoch: 423/500 	Training Loss: 0.002442
#
# Epoch: 424/500 	Training Loss: 0.002821
#
# Epoch: 425/500 	Training Loss: 0.002845
#
# Epoch: 426/500 	Training Loss: 0.003497
#
# Epoch: 427/500 	Training Loss: 0.002827
#
# Epoch: 428/500 	Training Loss: 0.003003
#
# Epoch: 429/500 	Training Loss: 0.002682
#
# Epoch: 430/500 	Training Loss: 0.003107
#
# Epoch: 431/500 	Training Loss: 0.003107
#
# Epoch: 432/500 	Training Loss: 0.003403
#
# Epoch: 433/500 	Training Loss: 0.003098
#
# Epoch: 434/500 	Training Loss: 0.003189
#
# Epoch: 435/500 	Training Loss: 0.002906
#
# Epoch: 436/500 	Training Loss: 0.003296
#
# Epoch: 437/500 	Training Loss: 0.003029
#
# Epoch: 438/500 	Training Loss: 0.002867
#
# Epoch: 439/500 	Training Loss: 0.002944
#
# Epoch: 440/500 	Training Loss: 0.002750
#
# Epoch: 441/500 	Training Loss: 0.003493
#
# Epoch: 442/500 	Training Loss: 0.003005
#
# Epoch: 443/500 	Training Loss: 0.002856
#
# Epoch: 444/500 	Training Loss: 0.003142
#
# Epoch: 445/500 	Training Loss: 0.002908
#
# Epoch: 446/500 	Training Loss: 0.003002
#
# Epoch: 447/500 	Training Loss: 0.002589
#
# Epoch: 448/500 	Training Loss: 0.002929
#
# Epoch: 449/500 	Training Loss: 0.003359
#
# Epoch: 450/500 	Training Loss: 0.002801
#
# Epoch: 451/500 	Training Loss: 0.002926
#
# Epoch: 452/500 	Training Loss: 0.003432
#
# Epoch: 453/500 	Training Loss: 0.003386
#
# Epoch: 454/500 	Training Loss: 0.003696
#
# Epoch: 455/500 	Training Loss: 0.002996
#
# Epoch: 456/500 	Training Loss: 0.003074
#
# Epoch: 457/500 	Training Loss: 0.003654
#
# Epoch: 458/500 	Training Loss: 0.002679
#
# Epoch: 459/500 	Training Loss: 0.002933
#
# Epoch: 460/500 	Training Loss: 0.003116
#
# Epoch: 461/500 	Training Loss: 0.003095
#
# Epoch: 462/500 	Training Loss: 0.002753
#
# Epoch: 463/500 	Training Loss: 0.003020
#
# Epoch: 464/500 	Training Loss: 0.004159
#
# Epoch: 465/500 	Training Loss: 0.002897
#
# Epoch: 466/500 	Training Loss: 0.003113
#
# Epoch: 467/500 	Training Loss: 0.003366
#
# Epoch: 468/500 	Training Loss: 0.003112
#
# Epoch: 469/500 	Training Loss: 0.002788
#
# Epoch: 470/500 	Training Loss: 0.003603
#
# Epoch: 471/500 	Training Loss: 0.002943
#
# Epoch: 472/500 	Training Loss: 0.003027
#
# Epoch: 473/500 	Training Loss: 0.003071
#
# Epoch: 474/500 	Training Loss: 0.002562
#
# Epoch: 475/500 	Training Loss: 0.002811
#
# Epoch: 476/500 	Training Loss: 0.002682
#
# Epoch: 477/500 	Training Loss: 0.003132
#
# Epoch: 478/500 	Training Loss: 0.003640
#
# Epoch: 479/500 	Training Loss: 0.002993
#
# Epoch: 480/500 	Training Loss: 0.002686
#
# Epoch: 481/500 	Training Loss: 0.005347
#
# Epoch: 482/500 	Training Loss: 0.003168
#
# Epoch: 483/500 	Training Loss: 0.002667
#
# Epoch: 484/500 	Training Loss: 0.002841
#
# Epoch: 485/500 	Training Loss: 0.002666
#
# Epoch: 486/500 	Training Loss: 0.002996
#
# Epoch: 487/500 	Training Loss: 0.002666
#
# Epoch: 488/500 	Training Loss: 0.003013
#
# Epoch: 489/500 	Training Loss: 0.002655
#
# Epoch: 490/500 	Training Loss: 0.003012
#
# Epoch: 491/500 	Training Loss: 0.002784
#
# Epoch: 492/500 	Training Loss: 0.002908
#
# Epoch: 493/500 	Training Loss: 0.003040
#
# Epoch: 494/500 	Training Loss: 0.002752
#
# Epoch: 495/500 	Training Loss: 0.003244
#
# Epoch: 496/500 	Training Loss: 0.002870
#
# Epoch: 497/500 	Training Loss: 0.003011
#
# Epoch: 498/500 	Training Loss: 0.002995
#
# Epoch: 499/500 	Training Loss: 0.003152
#
# Epoch: 500/500 	Training Loss: 0.002879
#
# Time taken: 101.8600761000016

# %%
plt.plot(train_losses)

# %%
model.load_state_dict(torch.load('PyTorch_Model/Single_ArrivalTime_lowest.pt', map_location=torch.device('cpu')))

model.eval()           # prep model for *evaluation*
model.to(device)
with torch.no_grad():  # turn off gradient to save memory
    y_predNN_torch = model(X_test_torch.to(device))

y_predNN_normal = y_predNN_torch.cpu().numpy()     # convert to numpy array
y_test_normal = y_test_torch.cpu().numpy()


print(y_predNN_normal)
# Out:
# [[-1.9635701]
#  [-1.5943279]
#  [-1.3605516]
#  ...
#  [ 1.1925952]
#  [ 1.341753 ]
#  [ 1.5137942]]

# %%
mape = mean_absolute_percentage_error(y_test_normal, y_predNN_normal)
r2 = r2_score(y_test_normal, y_predNN_normal)
rmse = np.sqrt(mean_squared_error(y_test_normal, y_predNN_normal))
print(f"Scores in normal distribution: r2 = {r2*100}, mape = {mape*100}, rmse = {rmse}")
# Out:
# Scores in normal distribution: r2 = 99.8637698650486, mape = 9.322019666433334, rmse = 0.036697614938020706

# %%
y_predNN = quantile.inverse_transform(y_predNN_normal)
mape = mean_absolute_percentage_error(y_test, y_predNN)
r2 = r2_score(y_test, y_predNN)
rmse = np.sqrt(mean_squared_error(y_test, y_predNN))


print(f"Scores in actual distribution for arrival time")
print('r2:', r2*100)
print('mape:', mape*100)
print('rmse:', rmse)
print()
# Out:
# Scores in actual distribution for arrival time
# r2: 99.94100485072121
# mape: 1.085779417774422
# rmse: 0.0006733432111972926
