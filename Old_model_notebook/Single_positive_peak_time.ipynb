# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import timeit
#import shap
from sklearn.metrics import r2_score, mean_absolute_percentage_error, mean_squared_error
from sklearn.model_selection import cross_val_score, GridSearchCV, KFold
from sklearn.model_selection import train_test_split

# %% [markdown]
# ___

# %% [markdown]
# # Read-in and One-Hot Encoding

# %%
df = pd.read_excel("data_new/train.xlsx", sheet_name="positive_peak_time")

dt = pd.read_excel("data_new/test.xlsx", sheet_name="positive_peak_time")

# %%
# Label encoding 'Status' feature into 0 and 1 
# 0 for Subcooled and 1 for Superheated

from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()

df['Status'] = LE.fit_transform(df['Status'])
dt['Status'] = LE.fit_transform(dt['Status'])

df
# Out:
#          ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0      B291                         13.6          0.665119             1.0
# 1      B291                         13.6          0.665119             1.0
# 2      B291                         13.6          0.665119             1.0
# 3      B291                         13.6          0.665119             1.0
# 4      B291                         13.6          0.665119             1.0
# ...     ...                          ...               ...             ...
# 21595  B103                         30.7          0.181290             0.6
# 21596  B103                         30.7          0.181290             0.6
# 21597  B103                         30.7          0.181290             0.6
# 21598  B103                         30.7          0.181290             0.6
# 21599  B103                         30.7          0.181290             0.6
#
#        Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 0                  4.0              0.8                  1.8
# 1                  4.0              0.8                  1.8
# 2                  4.0              0.8                  1.8
# 3                  4.0              0.8                  1.8
# 4                  4.0              0.8                  1.8
# ...                ...              ...                  ...
# 21595              2.0              2.8                  1.2
# 21596              2.0              2.8                  1.2
# 21597              2.0              2.8                  1.2
# 21598              2.0              2.8                  1.2
# 21599              2.0              2.8                  1.2
#
#        Tank Height with Gas (m)   Vapour Temerature (K)  \
# 0                           0.4                   435.0
# 1                           0.4                   435.0
# 2                           0.4                   435.0
# 3                           0.4                   435.0
# 4                           0.4                   435.0
# ...                         ...                     ...
# 21595                       2.2                   334.7
# 21596                       2.2                   334.7
# 21597                       2.2                   334.7
# 21598                       2.2                   334.7
# 21599                       2.2                   334.7
#
#         Liquid Temerature (K)  Status  Stand-off Distance    Target
# 0                       372.5       1                   5  0.012166
# 1                       372.5       1                   6  0.014556
# 2                       372.5       1                   7  0.017034
# 3                       372.5       1                   8  0.019576
# 4                       372.5       1                   9  0.022172
# ...                       ...     ...                 ...       ...
# 21595                   404.9       0                  36  0.093782
# 21596                   404.9       0                  37  0.096635
# 21597                   404.9       0                  38  0.099487
# 21598                   404.9       0                  39  0.102341
# 21599                   404.9       0                  40  0.105201
#
# [21600 rows x 13 columns]

# %%
dt.iloc[30:50,:]
# Out:
#       ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 30  P197                     11.55904          0.602823             3.0
# 31  P197                     11.55904          0.602823             3.0
# 32  P197                     11.55904          0.602823             3.0
# 33  P197                     11.55904          0.602823             3.0
# 34  P197                     11.55904          0.602823             3.0
# 35  P197                     11.55904          0.602823             3.0
# 36  P168                     12.72223          0.648320             1.8
# 37  P168                     12.72223          0.648320             1.8
# 38  P168                     12.72223          0.648320             1.8
# 39  P168                     12.72223          0.648320             1.8
# 40  P168                     12.72223          0.648320             1.8
# 41  P168                     12.72223          0.648320             1.8
# 42  P168                     12.72223          0.648320             1.8
# 43  P168                     12.72223          0.648320             1.8
# 44  P168                     12.72223          0.648320             1.8
# 45  P168                     12.72223          0.648320             1.8
# 46  P168                     12.72223          0.648320             1.8
# 47  P168                     12.72223          0.648320             1.8
# 48  P168                     12.72223          0.648320             1.8
# 49  P168                     12.72223          0.648320             1.8
#
#     Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 30              0.8              2.2                  0.2
# 31              0.8              2.2                  0.2
# 32              0.8              2.2                  0.2
# 33              0.8              2.2                  0.2
# 34              0.8              2.2                  0.2
# 35              0.8              2.2                  0.2
# 36              8.2              0.6                  1.8
# 37              8.2              0.6                  1.8
# 38              8.2              0.6                  1.8
# 39              8.2              0.6                  1.8
# 40              8.2              0.6                  1.8
# 41              8.2              0.6                  1.8
# 42              8.2              0.6                  1.8
# 43              8.2              0.6                  1.8
# 44              8.2              0.6                  1.8
# 45              8.2              0.6                  1.8
# 46              8.2              0.6                  1.8
# 47              8.2              0.6                  1.8
# 48              8.2              0.6                  1.8
# 49              8.2              0.6                  1.8
#
#     Tank Height with Gas (m)   Vapour Temerature (K)   Liquid Temerature (K)  \
# 30                       1.0                   296.7                   328.5
# 31                       1.0                   296.7                   328.5
# 32                       1.0                   296.7                   328.5
# 33                       1.0                   296.7                   328.5
# 34                       1.0                   296.7                   328.5
# 35                       1.0                   296.7                   328.5
# 36                       0.2                   389.7                   296.4
# 37                       0.2                   389.7                   296.4
# 38                       0.2                   389.7                   296.4
# 39                       0.2                   389.7                   296.4
# 40                       0.2                   389.7                   296.4
# 41                       0.2                   389.7                   296.4
# 42                       0.2                   389.7                   296.4
# 43                       0.2                   389.7                   296.4
# 44                       0.2                   389.7                   296.4
# 45                       0.2                   389.7                   296.4
# 46                       0.2                   389.7                   296.4
# 47                       0.2                   389.7                   296.4
# 48                       0.2                   389.7                   296.4
# 49                       0.2                   389.7                   296.4
#
#     Status  Stand-off Distance    Target
# 30       1                  35  0.097314
# 31       1                  36  0.100188
# 32       1                  37  0.103059
# 33       1                  38  0.105934
# 34       1                  39  0.108809
# 35       1                  40  0.111685
# 36       0                   5  0.013986
# 37       0                   6  0.016534
# 38       0                   7  0.019128
# 39       0                   8  0.021753
# 40       0                   9  0.024412
# 41       0                  10  0.027099
# 42       0                  11  0.029815
# 43       0                  12  0.032545
# 44       0                  13  0.035298
# 45       0                  14  0.038060
# 46       0                  15  0.040841
# 47       0                  16  0.043633
# 48       0                  17  0.046439
# 49       0                  18  0.049246

# %%
X_traindf = df.drop(['ID','Target'], axis=1)
X_testdf = dt.drop(['ID','Target'], axis=1)

X_traindf
# Out:
#        Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0                             13.6          0.665119             1.0
# 1                             13.6          0.665119             1.0
# 2                             13.6          0.665119             1.0
# 3                             13.6          0.665119             1.0
# 4                             13.6          0.665119             1.0
# ...                            ...               ...             ...
# 21595                         30.7          0.181290             0.6
# 21596                         30.7          0.181290             0.6
# 21597                         30.7          0.181290             0.6
# 21598                         30.7          0.181290             0.6
# 21599                         30.7          0.181290             0.6
#
#        Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 0                  4.0              0.8                  1.8
# 1                  4.0              0.8                  1.8
# 2                  4.0              0.8                  1.8
# 3                  4.0              0.8                  1.8
# 4                  4.0              0.8                  1.8
# ...                ...              ...                  ...
# 21595              2.0              2.8                  1.2
# 21596              2.0              2.8                  1.2
# 21597              2.0              2.8                  1.2
# 21598              2.0              2.8                  1.2
# 21599              2.0              2.8                  1.2
#
#        Tank Height with Gas (m)   Vapour Temerature (K)  \
# 0                           0.4                   435.0
# 1                           0.4                   435.0
# 2                           0.4                   435.0
# 3                           0.4                   435.0
# 4                           0.4                   435.0
# ...                         ...                     ...
# 21595                       2.2                   334.7
# 21596                       2.2                   334.7
# 21597                       2.2                   334.7
# 21598                       2.2                   334.7
# 21599                       2.2                   334.7
#
#         Liquid Temerature (K)  Status  Stand-off Distance
# 0                       372.5       1                   5
# 1                       372.5       1                   6
# 2                       372.5       1                   7
# 3                       372.5       1                   8
# 4                       372.5       1                   9
# ...                       ...     ...                 ...
# 21595                   404.9       0                  36
# 21596                   404.9       0                  37
# 21597                   404.9       0                  38
# 21598                   404.9       0                  39
# 21599                   404.9       0                  40
#
# [21600 rows x 11 columns]

# %%
y_train = df['Target']
y_train
# Out:
# 0        0.012166
# 1        0.014556
# 2        0.017034
# 3        0.019576
# 4        0.022172
#            ...
# 21595    0.093782
# 21596    0.096635
# 21597    0.099487
# 21598    0.102341
# 21599    0.105201
# Name: Target, Length: 21600, dtype: float64

# %%
y_test = dt['Target']

y_test
# Out:
# 0       0.012114
# 1       0.014798
# 2       0.017533
# 3       0.020293
# 4       0.023077
#           ...
# 7195    0.091819
# 7196    0.094618
# 7197    0.097421
# 7198    0.100227
# 7199    0.103035
# Name: Target, Length: 7200, dtype: float64

# %% [markdown]
# ___

# %% [markdown]
# # Standardization and Power Transform

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import QuantileTransformer

# %%
# Processing both X_train and X_test using standardization
scaler = StandardScaler()
X_train = scaler.fit_transform(X_traindf)
X_test = scaler.transform(X_testdf)

# %%
quantile = QuantileTransformer(output_distribution='normal', random_state=42)



y_train_normal = quantile.fit_transform(y_train.values.reshape(-1,1))
y_test_normal = quantile.transform(y_test.values.reshape(-1,1))

# %%
# Visualize the effect of power transformation
f = plt.figure(figsize=(15, 6))

ax = f.add_subplot(121)
sns.distplot(y_train, bins=50, color='r', ax=ax)
ax.set_title('Distribution before processing')

ax=f.add_subplot(122)
sns.distplot(y_train_normal, bins=50, color='b', ax=ax)
ax.set_title('Distribution after quantile processing')
print()
# Out:
# /home/tendou/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/tendou/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ___

# %% [markdown]
# # ANN

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt

torch.backends.cudnn.version() , torch.backends.cudnn.enabled
torch.manual_seed(0)

# %%
# convert data to torch.FloatTensor
X_train_torch = torch.from_numpy(X_train.astype(np.float32))
X_test_torch = torch.from_numpy(X_test.astype(np.float32))



y_train_torch = torch.from_numpy(y_train_normal.astype(np.float32))
y_test_torch = torch.from_numpy(y_test_normal.astype(np.float32))

print(X_train_torch)
# Out:
# tensor([[-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.6846],
#         [-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.5883],
#         [-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.4921],
#         ...,
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.4921],
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.5883],
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.6846]])

# %%
train_data = []
for i in range(len(X_train_torch)):
   train_data.append([X_train_torch[i],
                      y_train_torch[i]
                     ])

test_data = []
for i in range(len(X_test_torch)):
   test_data.append([X_test_torch[i], 
                     y_test_torch[i]
                     ])
   
# prepare data loaders
train_loader = torch.utils.data.DataLoader(train_data, batch_size=512,               # batch_size could be smaller
    num_workers=0, shuffle=True)                                                                   # Increasing num_workers slow down the training because it does not use GPU at all
test_loader = torch.utils.data.DataLoader(test_data, batch_size=512,
    num_workers=0)

# %%
for data, target in train_loader:
    print(data.shape[0] == data.size(0))
    break
# Out:
# True

# %%
## Define the NN architecture
## NN with 3 hidden layer, s=[11, 256, 256, 256, 1]

class BleveNet(nn.Module):
    def __init__(self):
        super(BleveNet, self).__init__()
        # The first hidden layer has 256 neurons
        self.fc1 = nn.Linear(X_train_torch.shape[1], 256)
        # The second hidden layer has 256 neurons
        self.fc2 = nn.Linear(256, 256)
        # The third hidden layer has 256 neurons
        self.fc3 = nn.Linear(256, 256)
        # The final layer has 1 output neuron
        self.fc4 = nn.Linear(256, 1)


        # Define proportion or neurons to dropout
        self.dropout = nn.Dropout(0.1)

        # Mish activation
        self.mish = nn.Mish()


    def forward(self, x):
        # add first fully connected layer
        x = self.fc1(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add second fully connected layer
        x = self.fc2(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add third fully connected layer
        x = self.fc3(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add final output layers:
        output = self.fc4(x)
       
        return output

# initialize the NN
model = BleveNet()
print(model)
# Out:
# BleveNet(
#   (fc1): Linear(in_features=11, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=256, bias=True)
#   (fc4): Linear(in_features=256, out_features=1, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (mish): Mish()
# )

# %%
criterion = nn.HuberLoss()        # This is the best loss function for my model
# criterion = nn.MSELoss()


optimizer = torch.optim.Adam(model.parameters(), lr=0.005, weight_decay=1e-5)     # This is the best optimizer for my model 

# Check for GPU
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
startTime = timeit.default_timer() 

n_epochs = 500 

model.to(device)    # bring the model to gpu

train_losses = []
lowest_mape = 100
for epoch in range(n_epochs):

    model.train()       

    # monitor training loss
    train_loss = 0.0
    
    ###################
    # train the model #
    ###################
    for data, target in train_loader:
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        #bring data and target to gpu
        data, target = data.to(device), target.to(device)
        
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update running training loss
        train_loss += loss.item()*data.size(0)
        
    # print training statistics 
    # calculate average loss over an epoch
    train_loss = train_loss/len(train_loader.dataset)
    train_losses.append(train_loss)

    print('Epoch: {}/{} \tTraining Loss: {:.6f}'.format(
        epoch+1,
        n_epochs, 
        train_loss
        ))
    

    ############################
    # Evaluate the lowest MAPE #
    ############################
    model.eval()
    with torch.no_grad():  # turn off gradient to save memory
        y_predNN_torch = model(X_test_torch.to(device))

    y_predNN = quantile.inverse_transform(y_predNN_torch.cpu().numpy())
    MAPE = mean_absolute_percentage_error(y_test, y_predNN)

    if MAPE < lowest_mape:
        lowest_mape = MAPE
        print(f'Lowest MAPE: {lowest_mape}')
        torch.save(model.state_dict(), 'PyTorch_Model/Single_PositivePeakTime_lowest.pt')
    print()

endTime = timeit.default_timer()
runningTotal = (endTime - startTime)
print(f"Time taken: {runningTotal}")
# Out:
# Epoch: 1/500 	Training Loss: 0.049271
# Lowest MAPE: 0.0475669806632448
#
# Epoch: 2/500 	Training Loss: 0.013155
#
# Epoch: 3/500 	Training Loss: 0.014129
#
# Epoch: 4/500 	Training Loss: 0.011569
# Lowest MAPE: 0.03687856206678478
#
# Epoch: 5/500 	Training Loss: 0.010075
# Lowest MAPE: 0.03434207384488324
#
# Epoch: 6/500 	Training Loss: 0.008732
# Lowest MAPE: 0.031834877793868545
#
# Epoch: 7/500 	Training Loss: 0.007637
# Lowest MAPE: 0.028405328035760614
#
# Epoch: 8/500 	Training Loss: 0.007546
#
# Epoch: 9/500 	Training Loss: 0.007088
#
# Epoch: 10/500 	Training Loss: 0.006552
# Lowest MAPE: 0.02428402776035817
#
# Epoch: 11/500 	Training Loss: 0.005993
#
# Epoch: 12/500 	Training Loss: 0.006188
# Lowest MAPE: 0.022369327211160906
#
# Epoch: 13/500 	Training Loss: 0.006150
#
# Epoch: 14/500 	Training Loss: 0.007460
# Lowest MAPE: 0.019385840481141812
#
# Epoch: 15/500 	Training Loss: 0.006042
# Lowest MAPE: 0.017200926438706222
#
# Epoch: 16/500 	Training Loss: 0.004908
#
# Epoch: 17/500 	Training Loss: 0.005486
#
# Epoch: 18/500 	Training Loss: 0.005097
#
# Epoch: 19/500 	Training Loss: 0.005459
#
# Epoch: 20/500 	Training Loss: 0.004669
#
# Epoch: 21/500 	Training Loss: 0.005112
#
# Epoch: 22/500 	Training Loss: 0.004186
#
# Epoch: 23/500 	Training Loss: 0.004548
#
# Epoch: 24/500 	Training Loss: 0.005310
# Lowest MAPE: 0.01685848108289619
#
# Epoch: 25/500 	Training Loss: 0.004345
#
# Epoch: 26/500 	Training Loss: 0.007256
#
# Epoch: 27/500 	Training Loss: 0.004266
#
# Epoch: 28/500 	Training Loss: 0.003976
#
# Epoch: 29/500 	Training Loss: 0.003635
#
# Epoch: 30/500 	Training Loss: 0.004092
#
# Epoch: 31/500 	Training Loss: 0.004378
#
# Epoch: 32/500 	Training Loss: 0.005938
#
# Epoch: 33/500 	Training Loss: 0.004550
#
# Epoch: 34/500 	Training Loss: 0.004252
#
# Epoch: 35/500 	Training Loss: 0.003811
#
# Epoch: 36/500 	Training Loss: 0.004957
# Lowest MAPE: 0.016689282385906494
#
# Epoch: 37/500 	Training Loss: 0.003869
#
# Epoch: 38/500 	Training Loss: 0.004496
#
# Epoch: 39/500 	Training Loss: 0.004874
#
# Epoch: 40/500 	Training Loss: 0.003578
#
# Epoch: 41/500 	Training Loss: 0.003187
#
# Epoch: 42/500 	Training Loss: 0.004150
#
# Epoch: 43/500 	Training Loss: 0.004906
# Lowest MAPE: 0.016658235893840443
#
# Epoch: 44/500 	Training Loss: 0.003598
#
# Epoch: 45/500 	Training Loss: 0.003953
# Lowest MAPE: 0.014912302379001277
#
# Epoch: 46/500 	Training Loss: 0.003288
#
# Epoch: 47/500 	Training Loss: 0.006579
#
# Epoch: 48/500 	Training Loss: 0.004053
#
# Epoch: 49/500 	Training Loss: 0.005355
#
# Epoch: 50/500 	Training Loss: 0.003413
#
# Epoch: 51/500 	Training Loss: 0.005050
#
# Epoch: 52/500 	Training Loss: 0.003413
#
# Epoch: 53/500 	Training Loss: 0.004103
#
# Epoch: 54/500 	Training Loss: 0.004762
#
# Epoch: 55/500 	Training Loss: 0.004340
#
# Epoch: 56/500 	Training Loss: 0.003810
#
# Epoch: 57/500 	Training Loss: 0.003572
#
# Epoch: 58/500 	Training Loss: 0.003345
#
# Epoch: 59/500 	Training Loss: 0.003814
#
# Epoch: 60/500 	Training Loss: 0.004011
#
# Epoch: 61/500 	Training Loss: 0.004999
#
# Epoch: 62/500 	Training Loss: 0.003405
#
# Epoch: 63/500 	Training Loss: 0.004026
#
# Epoch: 64/500 	Training Loss: 0.006261
#
# Epoch: 65/500 	Training Loss: 0.003746
# Lowest MAPE: 0.01242196860495542
#
# Epoch: 66/500 	Training Loss: 0.003493
#
# Epoch: 67/500 	Training Loss: 0.003550
#
# Epoch: 68/500 	Training Loss: 0.003733
#
# Epoch: 69/500 	Training Loss: 0.003942
#
# Epoch: 70/500 	Training Loss: 0.003546
#
# Epoch: 71/500 	Training Loss: 0.004227
#
# Epoch: 72/500 	Training Loss: 0.003302
#
# Epoch: 73/500 	Training Loss: 0.003273
#
# Epoch: 74/500 	Training Loss: 0.004719
#
# Epoch: 75/500 	Training Loss: 0.003548
#
# Epoch: 76/500 	Training Loss: 0.003816
#
# Epoch: 77/500 	Training Loss: 0.003520
#
# Epoch: 78/500 	Training Loss: 0.004975
#
# Epoch: 79/500 	Training Loss: 0.004386
#
# Epoch: 80/500 	Training Loss: 0.003522
#
# Epoch: 81/500 	Training Loss: 0.003829
#
# Epoch: 82/500 	Training Loss: 0.004132
#
# Epoch: 83/500 	Training Loss: 0.003628
#
# Epoch: 84/500 	Training Loss: 0.003028
#
# Epoch: 85/500 	Training Loss: 0.003852
#
# Epoch: 86/500 	Training Loss: 0.003850
#
# Epoch: 87/500 	Training Loss: 0.003690
#
# Epoch: 88/500 	Training Loss: 0.003869
#
# Epoch: 89/500 	Training Loss: 0.003673
#
# Epoch: 90/500 	Training Loss: 0.003615
#
# Epoch: 91/500 	Training Loss: 0.003160
#
# Epoch: 92/500 	Training Loss: 0.003951
#
# Epoch: 93/500 	Training Loss: 0.003599
#
# Epoch: 94/500 	Training Loss: 0.003315
#
# Epoch: 95/500 	Training Loss: 0.003963
#
# Epoch: 96/500 	Training Loss: 0.003277
#
# Epoch: 97/500 	Training Loss: 0.003119
#
# Epoch: 98/500 	Training Loss: 0.005195
#
# Epoch: 99/500 	Training Loss: 0.003031
#
# Epoch: 100/500 	Training Loss: 0.003948
#
# Epoch: 101/500 	Training Loss: 0.003960
#
# Epoch: 102/500 	Training Loss: 0.004206
#
# Epoch: 103/500 	Training Loss: 0.004243
#
# Epoch: 104/500 	Training Loss: 0.003344
#
# Epoch: 105/500 	Training Loss: 0.003125
#
# Epoch: 106/500 	Training Loss: 0.005100
#
# Epoch: 107/500 	Training Loss: 0.004462
#
# Epoch: 108/500 	Training Loss: 0.003978
#
# Epoch: 109/500 	Training Loss: 0.004579
#
# Epoch: 110/500 	Training Loss: 0.003352
#
# Epoch: 111/500 	Training Loss: 0.002876
#
# Epoch: 112/500 	Training Loss: 0.003413
#
# Epoch: 113/500 	Training Loss: 0.003610
#
# Epoch: 114/500 	Training Loss: 0.003643
#
# Epoch: 115/500 	Training Loss: 0.003012
#
# Epoch: 116/500 	Training Loss: 0.004449
#
# Epoch: 117/500 	Training Loss: 0.003712
#
# Epoch: 118/500 	Training Loss: 0.003545
#
# Epoch: 119/500 	Training Loss: 0.003220
# Lowest MAPE: 0.011954962167126635
#
# Epoch: 120/500 	Training Loss: 0.002775
#
# Epoch: 121/500 	Training Loss: 0.004084
#
# Epoch: 122/500 	Training Loss: 0.003249
#
# Epoch: 123/500 	Training Loss: 0.003370
#
# Epoch: 124/500 	Training Loss: 0.003137
# Lowest MAPE: 0.010576321561368016
#
# Epoch: 125/500 	Training Loss: 0.002886
#
# Epoch: 126/500 	Training Loss: 0.003737
#
# Epoch: 127/500 	Training Loss: 0.003662
#
# Epoch: 128/500 	Training Loss: 0.003214
#
# Epoch: 129/500 	Training Loss: 0.003114
#
# Epoch: 130/500 	Training Loss: 0.003739
#
# Epoch: 131/500 	Training Loss: 0.003042
#
# Epoch: 132/500 	Training Loss: 0.003110
#
# Epoch: 133/500 	Training Loss: 0.003488
#
# Epoch: 134/500 	Training Loss: 0.002835
#
# Epoch: 135/500 	Training Loss: 0.003512
#
# Epoch: 136/500 	Training Loss: 0.004903
#
# Epoch: 137/500 	Training Loss: 0.004059
#
# Epoch: 138/500 	Training Loss: 0.004059
#
# Epoch: 139/500 	Training Loss: 0.003207
#
# Epoch: 140/500 	Training Loss: 0.003342
#
# Epoch: 141/500 	Training Loss: 0.002833
#
# Epoch: 142/500 	Training Loss: 0.003920
#
# Epoch: 143/500 	Training Loss: 0.004102
#
# Epoch: 144/500 	Training Loss: 0.003266
#
# Epoch: 145/500 	Training Loss: 0.002689
#
# Epoch: 146/500 	Training Loss: 0.004282
#
# Epoch: 147/500 	Training Loss: 0.003421
#
# Epoch: 148/500 	Training Loss: 0.008012
#
# Epoch: 149/500 	Training Loss: 0.004363
#
# Epoch: 150/500 	Training Loss: 0.003114
#
# Epoch: 151/500 	Training Loss: 0.004832
#
# Epoch: 152/500 	Training Loss: 0.003747
#
# Epoch: 153/500 	Training Loss: 0.003265
#
# Epoch: 154/500 	Training Loss: 0.003418
#
# Epoch: 155/500 	Training Loss: 0.003409
#
# Epoch: 156/500 	Training Loss: 0.002943
#
# Epoch: 157/500 	Training Loss: 0.003025
#
# Epoch: 158/500 	Training Loss: 0.003202
#
# Epoch: 159/500 	Training Loss: 0.003382
#
# Epoch: 160/500 	Training Loss: 0.003525
#
# Epoch: 161/500 	Training Loss: 0.002975
#
# Epoch: 162/500 	Training Loss: 0.003112
#
# Epoch: 163/500 	Training Loss: 0.003071
#
# Epoch: 164/500 	Training Loss: 0.002990
#
# Epoch: 165/500 	Training Loss: 0.002744
#
# Epoch: 166/500 	Training Loss: 0.002891
#
# Epoch: 167/500 	Training Loss: 0.004326
#
# Epoch: 168/500 	Training Loss: 0.003980
#
# Epoch: 169/500 	Training Loss: 0.002805
#
# Epoch: 170/500 	Training Loss: 0.004516
#
# Epoch: 171/500 	Training Loss: 0.003086
#
# Epoch: 172/500 	Training Loss: 0.003982
#
# Epoch: 173/500 	Training Loss: 0.003534
#
# Epoch: 174/500 	Training Loss: 0.002898
#
# Epoch: 175/500 	Training Loss: 0.003573
#
# Epoch: 176/500 	Training Loss: 0.002976
#
# Epoch: 177/500 	Training Loss: 0.003243
#
# Epoch: 178/500 	Training Loss: 0.003014
#
# Epoch: 179/500 	Training Loss: 0.004207
#
# Epoch: 180/500 	Training Loss: 0.003386
#
# Epoch: 181/500 	Training Loss: 0.002855
#
# Epoch: 182/500 	Training Loss: 0.003161
#
# Epoch: 183/500 	Training Loss: 0.002604
#
# Epoch: 184/500 	Training Loss: 0.002783
#
# Epoch: 185/500 	Training Loss: 0.003153
#
# Epoch: 186/500 	Training Loss: 0.003353
#
# Epoch: 187/500 	Training Loss: 0.004318
#
# Epoch: 188/500 	Training Loss: 0.003757
#
# Epoch: 189/500 	Training Loss: 0.003076
#
# Epoch: 190/500 	Training Loss: 0.002892
#
# Epoch: 191/500 	Training Loss: 0.003502
#
# Epoch: 192/500 	Training Loss: 0.002805
#
# Epoch: 193/500 	Training Loss: 0.003581
#
# Epoch: 194/500 	Training Loss: 0.003670
#
# Epoch: 195/500 	Training Loss: 0.002768
#
# Epoch: 196/500 	Training Loss: 0.004531
#
# Epoch: 197/500 	Training Loss: 0.003045
#
# Epoch: 198/500 	Training Loss: 0.003087
#
# Epoch: 199/500 	Training Loss: 0.003058
#
# Epoch: 200/500 	Training Loss: 0.003283
#
# Epoch: 201/500 	Training Loss: 0.003090
#
# Epoch: 202/500 	Training Loss: 0.003184
#
# Epoch: 203/500 	Training Loss: 0.003446
#
# Epoch: 204/500 	Training Loss: 0.003593
#
# Epoch: 205/500 	Training Loss: 0.003793
#
# Epoch: 206/500 	Training Loss: 0.003515
#
# Epoch: 207/500 	Training Loss: 0.003079
#
# Epoch: 208/500 	Training Loss: 0.003969
#
# Epoch: 209/500 	Training Loss: 0.002887
#
# Epoch: 210/500 	Training Loss: 0.003468
#
# Epoch: 211/500 	Training Loss: 0.003247
#
# Epoch: 212/500 	Training Loss: 0.002909
#
# Epoch: 213/500 	Training Loss: 0.003191
#
# Epoch: 214/500 	Training Loss: 0.003234
#
# Epoch: 215/500 	Training Loss: 0.003141
#
# Epoch: 216/500 	Training Loss: 0.004242
#
# Epoch: 217/500 	Training Loss: 0.003263
#
# Epoch: 218/500 	Training Loss: 0.003531
#
# Epoch: 219/500 	Training Loss: 0.003689
#
# Epoch: 220/500 	Training Loss: 0.002941
#
# Epoch: 221/500 	Training Loss: 0.003554
#
# Epoch: 222/500 	Training Loss: 0.003470
#
# Epoch: 223/500 	Training Loss: 0.002948
#
# Epoch: 224/500 	Training Loss: 0.002935
#
# Epoch: 225/500 	Training Loss: 0.002848
#
# Epoch: 226/500 	Training Loss: 0.003738
#
# Epoch: 227/500 	Training Loss: 0.003001
#
# Epoch: 228/500 	Training Loss: 0.003167
#
# Epoch: 229/500 	Training Loss: 0.003387
#
# Epoch: 230/500 	Training Loss: 0.002856
#
# Epoch: 231/500 	Training Loss: 0.002729
#
# Epoch: 232/500 	Training Loss: 0.003551
#
# Epoch: 233/500 	Training Loss: 0.002952
#
# Epoch: 234/500 	Training Loss: 0.003602
#
# Epoch: 235/500 	Training Loss: 0.003572
#
# Epoch: 236/500 	Training Loss: 0.003856
#
# Epoch: 237/500 	Training Loss: 0.003383
#
# Epoch: 238/500 	Training Loss: 0.002725
#
# Epoch: 239/500 	Training Loss: 0.003562
#
# Epoch: 240/500 	Training Loss: 0.003225
#
# Epoch: 241/500 	Training Loss: 0.003351
#
# Epoch: 242/500 	Training Loss: 0.002720
#
# Epoch: 243/500 	Training Loss: 0.003430
#
# Epoch: 244/500 	Training Loss: 0.004043
#
# Epoch: 245/500 	Training Loss: 0.003033
#
# Epoch: 246/500 	Training Loss: 0.003037
#
# Epoch: 247/500 	Training Loss: 0.003153
#
# Epoch: 248/500 	Training Loss: 0.003071
#
# Epoch: 249/500 	Training Loss: 0.003657
#
# Epoch: 250/500 	Training Loss: 0.003920
#
# Epoch: 251/500 	Training Loss: 0.003386
#
# Epoch: 252/500 	Training Loss: 0.002655
#
# Epoch: 253/500 	Training Loss: 0.002970
#
# Epoch: 254/500 	Training Loss: 0.002883
#
# Epoch: 255/500 	Training Loss: 0.002782
#
# Epoch: 256/500 	Training Loss: 0.003086
#
# Epoch: 257/500 	Training Loss: 0.003753
#
# Epoch: 258/500 	Training Loss: 0.003055
#
# Epoch: 259/500 	Training Loss: 0.003029
#
# Epoch: 260/500 	Training Loss: 0.003397
#
# Epoch: 261/500 	Training Loss: 0.003149
#
# Epoch: 262/500 	Training Loss: 0.002534
#
# Epoch: 263/500 	Training Loss: 0.002793
#
# Epoch: 264/500 	Training Loss: 0.002809
#
# Epoch: 265/500 	Training Loss: 0.003966
#
# Epoch: 266/500 	Training Loss: 0.003243
#
# Epoch: 267/500 	Training Loss: 0.003605
#
# Epoch: 268/500 	Training Loss: 0.002967
#
# Epoch: 269/500 	Training Loss: 0.003445
#
# Epoch: 270/500 	Training Loss: 0.002846
#
# Epoch: 271/500 	Training Loss: 0.002741
#
# Epoch: 272/500 	Training Loss: 0.002872
#
# Epoch: 273/500 	Training Loss: 0.002751
#
# Epoch: 274/500 	Training Loss: 0.003415
#
# Epoch: 275/500 	Training Loss: 0.002870
#
# Epoch: 276/500 	Training Loss: 0.003689
#
# Epoch: 277/500 	Training Loss: 0.002673
#
# Epoch: 278/500 	Training Loss: 0.003339
#
# Epoch: 279/500 	Training Loss: 0.002861
#
# Epoch: 280/500 	Training Loss: 0.003179
#
# Epoch: 281/500 	Training Loss: 0.003195
#
# Epoch: 282/500 	Training Loss: 0.003259
#
# Epoch: 283/500 	Training Loss: 0.003138
#
# Epoch: 284/500 	Training Loss: 0.003188
#
# Epoch: 285/500 	Training Loss: 0.002769
#
# Epoch: 286/500 	Training Loss: 0.003821
#
# Epoch: 287/500 	Training Loss: 0.003121
#
# Epoch: 288/500 	Training Loss: 0.003141
#
# Epoch: 289/500 	Training Loss: 0.004762
#
# Epoch: 290/500 	Training Loss: 0.003631
#
# Epoch: 291/500 	Training Loss: 0.002628
#
# Epoch: 292/500 	Training Loss: 0.003020
#
# Epoch: 293/500 	Training Loss: 0.003462
#
# Epoch: 294/500 	Training Loss: 0.002584
#
# Epoch: 295/500 	Training Loss: 0.002723
#
# Epoch: 296/500 	Training Loss: 0.003116
#
# Epoch: 297/500 	Training Loss: 0.002672
#
# Epoch: 298/500 	Training Loss: 0.003204
#
# Epoch: 299/500 	Training Loss: 0.002918
#
# Epoch: 300/500 	Training Loss: 0.004141
#
# Epoch: 301/500 	Training Loss: 0.004515
#
# Epoch: 302/500 	Training Loss: 0.003657
#
# Epoch: 303/500 	Training Loss: 0.003015
#
# Epoch: 304/500 	Training Loss: 0.002634
#
# Epoch: 305/500 	Training Loss: 0.002725
#
# Epoch: 306/500 	Training Loss: 0.003622
#
# Epoch: 307/500 	Training Loss: 0.004269
#
# Epoch: 308/500 	Training Loss: 0.003290
#
# Epoch: 309/500 	Training Loss: 0.002958
#
# Epoch: 310/500 	Training Loss: 0.003779
#
# Epoch: 311/500 	Training Loss: 0.003170
#
# Epoch: 312/500 	Training Loss: 0.003011
#
# Epoch: 313/500 	Training Loss: 0.003742
#
# Epoch: 314/500 	Training Loss: 0.002862
#
# Epoch: 315/500 	Training Loss: 0.002760
#
# Epoch: 316/500 	Training Loss: 0.003954
#
# Epoch: 317/500 	Training Loss: 0.002903
#
# Epoch: 318/500 	Training Loss: 0.002960
#
# Epoch: 319/500 	Training Loss: 0.002527
#
# Epoch: 320/500 	Training Loss: 0.002715
#
# Epoch: 321/500 	Training Loss: 0.003063
#
# Epoch: 322/500 	Training Loss: 0.002722
#
# Epoch: 323/500 	Training Loss: 0.003574
#
# Epoch: 324/500 	Training Loss: 0.002561
#
# Epoch: 325/500 	Training Loss: 0.003390
#
# Epoch: 326/500 	Training Loss: 0.003397
#
# Epoch: 327/500 	Training Loss: 0.002767
#
# Epoch: 328/500 	Training Loss: 0.004268
#
# Epoch: 329/500 	Training Loss: 0.003891
#
# Epoch: 330/500 	Training Loss: 0.003125
#
# Epoch: 331/500 	Training Loss: 0.003548
#
# Epoch: 332/500 	Training Loss: 0.003014
#
# Epoch: 333/500 	Training Loss: 0.002843
#
# Epoch: 334/500 	Training Loss: 0.002791
#
# Epoch: 335/500 	Training Loss: 0.003015
#
# Epoch: 336/500 	Training Loss: 0.003037
#
# Epoch: 337/500 	Training Loss: 0.002531
#
# Epoch: 338/500 	Training Loss: 0.002891
#
# Epoch: 339/500 	Training Loss: 0.003597
#
# Epoch: 340/500 	Training Loss: 0.003739
#
# Epoch: 341/500 	Training Loss: 0.003970
#
# Epoch: 342/500 	Training Loss: 0.002849
#
# Epoch: 343/500 	Training Loss: 0.002903
#
# Epoch: 344/500 	Training Loss: 0.002766
#
# Epoch: 345/500 	Training Loss: 0.003324
#
# Epoch: 346/500 	Training Loss: 0.003157
#
# Epoch: 347/500 	Training Loss: 0.002992
#
# Epoch: 348/500 	Training Loss: 0.002737
#
# Epoch: 349/500 	Training Loss: 0.004349
#
# Epoch: 350/500 	Training Loss: 0.003185
#
# Epoch: 351/500 	Training Loss: 0.002948
#
# Epoch: 352/500 	Training Loss: 0.003161
#
# Epoch: 353/500 	Training Loss: 0.002867
#
# Epoch: 354/500 	Training Loss: 0.003157
#
# Epoch: 355/500 	Training Loss: 0.003037
#
# Epoch: 356/500 	Training Loss: 0.003290
#
# Epoch: 357/500 	Training Loss: 0.003601
#
# Epoch: 358/500 	Training Loss: 0.002864
#
# Epoch: 359/500 	Training Loss: 0.002893
#
# Epoch: 360/500 	Training Loss: 0.002485
#
# Epoch: 361/500 	Training Loss: 0.003106
#
# Epoch: 362/500 	Training Loss: 0.002850
#
# Epoch: 363/500 	Training Loss: 0.003154
#
# Epoch: 364/500 	Training Loss: 0.003186
#
# Epoch: 365/500 	Training Loss: 0.002567
#
# Epoch: 366/500 	Training Loss: 0.003110
#
# Epoch: 367/500 	Training Loss: 0.002867
#
# Epoch: 368/500 	Training Loss: 0.002950
#
# Epoch: 369/500 	Training Loss: 0.003145
#
# Epoch: 370/500 	Training Loss: 0.003268
#
# Epoch: 371/500 	Training Loss: 0.003492
#
# Epoch: 372/500 	Training Loss: 0.002762
#
# Epoch: 373/500 	Training Loss: 0.002533
#
# Epoch: 374/500 	Training Loss: 0.002628
#
# Epoch: 375/500 	Training Loss: 0.005498
#
# Epoch: 376/500 	Training Loss: 0.027104
#
# Epoch: 377/500 	Training Loss: 0.004231
#
# Epoch: 378/500 	Training Loss: 0.002815
#
# Epoch: 379/500 	Training Loss: 0.002768
#
# Epoch: 380/500 	Training Loss: 0.002794
#
# Epoch: 381/500 	Training Loss: 0.002882
#
# Epoch: 382/500 	Training Loss: 0.003135
#
# Epoch: 383/500 	Training Loss: 0.002500
#
# Epoch: 384/500 	Training Loss: 0.002805
#
# Epoch: 385/500 	Training Loss: 0.002529
#
# Epoch: 386/500 	Training Loss: 0.002720
#
# Epoch: 387/500 	Training Loss: 0.002986
#
# Epoch: 388/500 	Training Loss: 0.003094
#
# Epoch: 389/500 	Training Loss: 0.003183
#
# Epoch: 390/500 	Training Loss: 0.003063
#
# Epoch: 391/500 	Training Loss: 0.002629
#
# Epoch: 392/500 	Training Loss: 0.002425
#
# Epoch: 393/500 	Training Loss: 0.003214
#
# Epoch: 394/500 	Training Loss: 0.002847
#
# Epoch: 395/500 	Training Loss: 0.002933
#
# Epoch: 396/500 	Training Loss: 0.002834
#
# Epoch: 397/500 	Training Loss: 0.002688
#
# Epoch: 398/500 	Training Loss: 0.002883
#
# Epoch: 399/500 	Training Loss: 0.002772
#
# Epoch: 400/500 	Training Loss: 0.003003
#
# Epoch: 401/500 	Training Loss: 0.003642
#
# Epoch: 402/500 	Training Loss: 0.003436
#
# Epoch: 403/500 	Training Loss: 0.004282
#
# Epoch: 404/500 	Training Loss: 0.003052
#
# Epoch: 405/500 	Training Loss: 0.002682
#
# Epoch: 406/500 	Training Loss: 0.003494
#
# Epoch: 407/500 	Training Loss: 0.003296
#
# Epoch: 408/500 	Training Loss: 0.003241
#
# Epoch: 409/500 	Training Loss: 0.002496
#
# Epoch: 410/500 	Training Loss: 0.002734
#
# Epoch: 411/500 	Training Loss: 0.002447
#
# Epoch: 412/500 	Training Loss: 0.002738
#
# Epoch: 413/500 	Training Loss: 0.002780
#
# Epoch: 414/500 	Training Loss: 0.003183
#
# Epoch: 415/500 	Training Loss: 0.003304
#
# Epoch: 416/500 	Training Loss: 0.003321
#
# Epoch: 417/500 	Training Loss: 0.002893
#
# Epoch: 418/500 	Training Loss: 0.003349
#
# Epoch: 419/500 	Training Loss: 0.002936
#
# Epoch: 420/500 	Training Loss: 0.003058
#
# Epoch: 421/500 	Training Loss: 0.003001
#
# Epoch: 422/500 	Training Loss: 0.002997
#
# Epoch: 423/500 	Training Loss: 0.002683
#
# Epoch: 424/500 	Training Loss: 0.002880
#
# Epoch: 425/500 	Training Loss: 0.002877
#
# Epoch: 426/500 	Training Loss: 0.004698
#
# Epoch: 427/500 	Training Loss: 0.003586
#
# Epoch: 428/500 	Training Loss: 0.002752
#
# Epoch: 429/500 	Training Loss: 0.003157
#
# Epoch: 430/500 	Training Loss: 0.003323
#
# Epoch: 431/500 	Training Loss: 0.003542
#
# Epoch: 432/500 	Training Loss: 0.003042
#
# Epoch: 433/500 	Training Loss: 0.002633
#
# Epoch: 434/500 	Training Loss: 0.002717
#
# Epoch: 435/500 	Training Loss: 0.004430
#
# Epoch: 436/500 	Training Loss: 0.002752
#
# Epoch: 437/500 	Training Loss: 0.002764
#
# Epoch: 438/500 	Training Loss: 0.002697
#
# Epoch: 439/500 	Training Loss: 0.003001
#
# Epoch: 440/500 	Training Loss: 0.003129
#
# Epoch: 441/500 	Training Loss: 0.003377
#
# Epoch: 442/500 	Training Loss: 0.002834
#
# Epoch: 443/500 	Training Loss: 0.002968
#
# Epoch: 444/500 	Training Loss: 0.002726
#
# Epoch: 445/500 	Training Loss: 0.003494
#
# Epoch: 446/500 	Training Loss: 0.002964
#
# Epoch: 447/500 	Training Loss: 0.003524
#
# Epoch: 448/500 	Training Loss: 0.002873
#
# Epoch: 449/500 	Training Loss: 0.002580
#
# Epoch: 450/500 	Training Loss: 0.003282
#
# Epoch: 451/500 	Training Loss: 0.003528
#
# Epoch: 452/500 	Training Loss: 0.003451
#
# Epoch: 453/500 	Training Loss: 0.005995
#
# Epoch: 454/500 	Training Loss: 0.003109
#
# Epoch: 455/500 	Training Loss: 0.003312
#
# Epoch: 456/500 	Training Loss: 0.003563
#
# Epoch: 457/500 	Training Loss: 0.002518
#
# Epoch: 458/500 	Training Loss: 0.002931
#
# Epoch: 459/500 	Training Loss: 0.002320
#
# Epoch: 460/500 	Training Loss: 0.003272
#
# Epoch: 461/500 	Training Loss: 0.003061
#
# Epoch: 462/500 	Training Loss: 0.003074
#
# Epoch: 463/500 	Training Loss: 0.002904
#
# Epoch: 464/500 	Training Loss: 0.002939
#
# Epoch: 465/500 	Training Loss: 0.002656
#
# Epoch: 466/500 	Training Loss: 0.002861
#
# Epoch: 467/500 	Training Loss: 0.002592
#
# Epoch: 468/500 	Training Loss: 0.002891
#
# Epoch: 469/500 	Training Loss: 0.003374
#
# Epoch: 470/500 	Training Loss: 0.004123
#
# Epoch: 471/500 	Training Loss: 0.003515
#
# Epoch: 472/500 	Training Loss: 0.003403
#
# Epoch: 473/500 	Training Loss: 0.003541
#
# Epoch: 474/500 	Training Loss: 0.002791
#
# Epoch: 475/500 	Training Loss: 0.002475
#
# Epoch: 476/500 	Training Loss: 0.002746
#
# Epoch: 477/500 	Training Loss: 0.002454
#
# Epoch: 478/500 	Training Loss: 0.004262
#
# Epoch: 479/500 	Training Loss: 0.003342
#
# Epoch: 480/500 	Training Loss: 0.005816
#
# Epoch: 481/500 	Training Loss: 0.003819
#
# Epoch: 482/500 	Training Loss: 0.003391
#
# Epoch: 483/500 	Training Loss: 0.003442
#
# Epoch: 484/500 	Training Loss: 0.003678
#
# Epoch: 485/500 	Training Loss: 0.002832
#
# Epoch: 486/500 	Training Loss: 0.002420
#
# Epoch: 487/500 	Training Loss: 0.002721
#
# Epoch: 488/500 	Training Loss: 0.002544
# Lowest MAPE: 0.009538757512848613
#
# Epoch: 489/500 	Training Loss: 0.002327
#
# Epoch: 490/500 	Training Loss: 0.003252
#
# Epoch: 491/500 	Training Loss: 0.002739
#
# Epoch: 492/500 	Training Loss: 0.002706
#
# Epoch: 493/500 	Training Loss: 0.003237
#
# Epoch: 494/500 	Training Loss: 0.002845
#
# Epoch: 495/500 	Training Loss: 0.002680
#
# Epoch: 496/500 	Training Loss: 0.002466
#
# Epoch: 497/500 	Training Loss: 0.003539
#
# Epoch: 498/500 	Training Loss: 0.002919
#
# Epoch: 499/500 	Training Loss: 0.002919
#
# Epoch: 500/500 	Training Loss: 0.002932
#
# Time taken: 105.19667479999953

# %%
plt.plot(train_losses)

# %%
model.load_state_dict(torch.load('PyTorch_Model/Single_PositivePeakTime_lowest.pt', map_location=torch.device('cpu')))

model.eval()           # prep model for *evaluation*
model.to(device)
with torch.no_grad():  # turn off gradient to save memory
    y_predNN_torch = model(X_test_torch.to(device))

y_predNN_normal = y_predNN_torch.cpu().numpy()     # convert to numpy array
y_test_normal = y_test_torch.cpu().numpy()



print(y_predNN_normal)
# Out:
# [[-1.8884778]
#  [-1.5386695]
#  [-1.3075135]
#  ...
#  [ 1.2601558]
#  [ 1.4073944]
#  [ 1.5768234]]

# %%
mape = mean_absolute_percentage_error(y_test_normal, y_predNN_normal)
r2 = r2_score(y_test_normal, y_predNN_normal)
rmse = np.sqrt(mean_squared_error(y_test_normal, y_predNN_normal))
print(f"Scores in normal distribution: r2 = {r2}, mape = {mape}, rmse = {rmse}")
# Out:
# Scores in normal distribution: r2 = 0.9989765772692869, mape = 0.17218919098377228, rmse = 0.031819842755794525

# %%
y_predNN = quantile.inverse_transform(y_predNN_normal)
mape = mean_absolute_percentage_error(y_test, y_predNN)
r2 = r2_score(y_test, y_predNN)
rmse = np.sqrt(mean_squared_error(y_test, y_predNN))


print(f"Scores in actual distribution for positive peak time")
print('r2:', r2*100)
print('mape:', mape*100)
print('rmse:', rmse)
print()
# Out:
# Scores in actual distribution for positive peak time
# r2: 99.95239792783744
# mape: 0.9538757512848612
# rmse: 0.0006266152581780299
