# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import timeit
#import shap
from sklearn.metrics import r2_score, mean_absolute_percentage_error, mean_squared_error
from sklearn.model_selection import cross_val_score, GridSearchCV, KFold
from sklearn.model_selection import train_test_split

# %% [markdown]
# ___

# %% [markdown]
# # Read-in and One-Hot Encoding

# %%
df = pd.read_excel("data_new/train.xlsx", sheet_name="negative_peak_time")

dt = pd.read_excel("data_new/test.xlsx", sheet_name="negative_peak_time")

# %%
# Label encoding 'Status' feature into 0 and 1 
# 0 for Subcooled and 1 for Superheated

from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()

df['Status'] = LE.fit_transform(df['Status'])
dt['Status'] = LE.fit_transform(dt['Status'])

df
# Out:
#          ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0      B291                         13.6          0.665119             1.0
# 1      B291                         13.6          0.665119             1.0
# 2      B291                         13.6          0.665119             1.0
# 3      B291                         13.6          0.665119             1.0
# 4      B291                         13.6          0.665119             1.0
# ...     ...                          ...               ...             ...
# 21595  B103                         30.7          0.181290             0.6
# 21596  B103                         30.7          0.181290             0.6
# 21597  B103                         30.7          0.181290             0.6
# 21598  B103                         30.7          0.181290             0.6
# 21599  B103                         30.7          0.181290             0.6
#
#        Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 0                  4.0              0.8                  1.8
# 1                  4.0              0.8                  1.8
# 2                  4.0              0.8                  1.8
# 3                  4.0              0.8                  1.8
# 4                  4.0              0.8                  1.8
# ...                ...              ...                  ...
# 21595              2.0              2.8                  1.2
# 21596              2.0              2.8                  1.2
# 21597              2.0              2.8                  1.2
# 21598              2.0              2.8                  1.2
# 21599              2.0              2.8                  1.2
#
#        Tank Height with Gas (m)   Vapour Temerature (K)  \
# 0                           0.4                   435.0
# 1                           0.4                   435.0
# 2                           0.4                   435.0
# 3                           0.4                   435.0
# 4                           0.4                   435.0
# ...                         ...                     ...
# 21595                       2.2                   334.7
# 21596                       2.2                   334.7
# 21597                       2.2                   334.7
# 21598                       2.2                   334.7
# 21599                       2.2                   334.7
#
#         Liquid Temerature (K)  Status  Stand-off Distance    Target
# 0                       372.5       1                   5  0.019227
# 1                       372.5       1                   6  0.021948
# 2                       372.5       1                   7  0.024735
# 3                       372.5       1                   8  0.027562
# 4                       372.5       1                   9  0.030378
# ...                       ...     ...                 ...       ...
# 21595                   404.9       0                  36  0.108070
# 21596                   404.9       0                  37  0.110886
# 21597                   404.9       0                  38  0.113699
# 21598                   404.9       0                  39  0.116520
# 21599                   404.9       0                  40  0.119344
#
# [21600 rows x 13 columns]

# %%
dt.iloc[30:50,:]
# Out:
#       ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 30  P197                     11.55904          0.602823             3.0
# 31  P197                     11.55904          0.602823             3.0
# 32  P197                     11.55904          0.602823             3.0
# 33  P197                     11.55904          0.602823             3.0
# 34  P197                     11.55904          0.602823             3.0
# 35  P197                     11.55904          0.602823             3.0
# 36  P168                     12.72223          0.648320             1.8
# 37  P168                     12.72223          0.648320             1.8
# 38  P168                     12.72223          0.648320             1.8
# 39  P168                     12.72223          0.648320             1.8
# 40  P168                     12.72223          0.648320             1.8
# 41  P168                     12.72223          0.648320             1.8
# 42  P168                     12.72223          0.648320             1.8
# 43  P168                     12.72223          0.648320             1.8
# 44  P168                     12.72223          0.648320             1.8
# 45  P168                     12.72223          0.648320             1.8
# 46  P168                     12.72223          0.648320             1.8
# 47  P168                     12.72223          0.648320             1.8
# 48  P168                     12.72223          0.648320             1.8
# 49  P168                     12.72223          0.648320             1.8
#
#     Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 30              0.8              2.2                  0.2
# 31              0.8              2.2                  0.2
# 32              0.8              2.2                  0.2
# 33              0.8              2.2                  0.2
# 34              0.8              2.2                  0.2
# 35              0.8              2.2                  0.2
# 36              8.2              0.6                  1.8
# 37              8.2              0.6                  1.8
# 38              8.2              0.6                  1.8
# 39              8.2              0.6                  1.8
# 40              8.2              0.6                  1.8
# 41              8.2              0.6                  1.8
# 42              8.2              0.6                  1.8
# 43              8.2              0.6                  1.8
# 44              8.2              0.6                  1.8
# 45              8.2              0.6                  1.8
# 46              8.2              0.6                  1.8
# 47              8.2              0.6                  1.8
# 48              8.2              0.6                  1.8
# 49              8.2              0.6                  1.8
#
#     Tank Height with Gas (m)   Vapour Temerature (K)   Liquid Temerature (K)  \
# 30                       1.0                   296.7                   328.5
# 31                       1.0                   296.7                   328.5
# 32                       1.0                   296.7                   328.5
# 33                       1.0                   296.7                   328.5
# 34                       1.0                   296.7                   328.5
# 35                       1.0                   296.7                   328.5
# 36                       0.2                   389.7                   296.4
# 37                       0.2                   389.7                   296.4
# 38                       0.2                   389.7                   296.4
# 39                       0.2                   389.7                   296.4
# 40                       0.2                   389.7                   296.4
# 41                       0.2                   389.7                   296.4
# 42                       0.2                   389.7                   296.4
# 43                       0.2                   389.7                   296.4
# 44                       0.2                   389.7                   296.4
# 45                       0.2                   389.7                   296.4
# 46                       0.2                   389.7                   296.4
# 47                       0.2                   389.7                   296.4
# 48                       0.2                   389.7                   296.4
# 49                       0.2                   389.7                   296.4
#
#     Status  Stand-off Distance    Target
# 30       1                  35  0.111052
# 31       1                  36  0.113937
# 32       1                  37  0.116823
# 33       1                  38  0.119718
# 34       1                  39  0.122621
# 35       1                  40  0.125527
# 36       0                   5  0.021506
# 37       0                   6  0.024231
# 38       0                   7  0.026958
# 39       0                   8  0.029773
# 40       0                   9  0.032650
# 41       0                  10  0.035531
# 42       0                  11  0.038390
# 43       0                  12  0.041319
# 44       0                  13  0.044313
# 45       0                  14  0.047236
# 46       0                  15  0.050147
# 47       0                  16  0.051528
# 48       0                  17  0.054235
# 49       0                  18  0.057064

# %%
X_traindf = df.drop(['ID','Target'], axis=1)
X_testdf = dt.drop(['ID','Target'], axis=1)

X_traindf
# Out:
#        Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0                             13.6          0.665119             1.0
# 1                             13.6          0.665119             1.0
# 2                             13.6          0.665119             1.0
# 3                             13.6          0.665119             1.0
# 4                             13.6          0.665119             1.0
# ...                            ...               ...             ...
# 21595                         30.7          0.181290             0.6
# 21596                         30.7          0.181290             0.6
# 21597                         30.7          0.181290             0.6
# 21598                         30.7          0.181290             0.6
# 21599                         30.7          0.181290             0.6
#
#        Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 0                  4.0              0.8                  1.8
# 1                  4.0              0.8                  1.8
# 2                  4.0              0.8                  1.8
# 3                  4.0              0.8                  1.8
# 4                  4.0              0.8                  1.8
# ...                ...              ...                  ...
# 21595              2.0              2.8                  1.2
# 21596              2.0              2.8                  1.2
# 21597              2.0              2.8                  1.2
# 21598              2.0              2.8                  1.2
# 21599              2.0              2.8                  1.2
#
#        Tank Height with Gas (m)   Vapour Temerature (K)  \
# 0                           0.4                   435.0
# 1                           0.4                   435.0
# 2                           0.4                   435.0
# 3                           0.4                   435.0
# 4                           0.4                   435.0
# ...                         ...                     ...
# 21595                       2.2                   334.7
# 21596                       2.2                   334.7
# 21597                       2.2                   334.7
# 21598                       2.2                   334.7
# 21599                       2.2                   334.7
#
#         Liquid Temerature (K)  Status  Stand-off Distance
# 0                       372.5       1                   5
# 1                       372.5       1                   6
# 2                       372.5       1                   7
# 3                       372.5       1                   8
# 4                       372.5       1                   9
# ...                       ...     ...                 ...
# 21595                   404.9       0                  36
# 21596                   404.9       0                  37
# 21597                   404.9       0                  38
# 21598                   404.9       0                  39
# 21599                   404.9       0                  40
#
# [21600 rows x 11 columns]

# %%
y_train = df['Target']
y_train
# Out:
# 0        0.019227
# 1        0.021948
# 2        0.024735
# 3        0.027562
# 4        0.030378
#            ...
# 21595    0.108070
# 21596    0.110886
# 21597    0.113699
# 21598    0.116520
# 21599    0.119344
# Name: Target, Length: 21600, dtype: float64

# %%
y_test = dt['Target']

y_test
# Out:
# 0       0.023626
# 1       0.026637
# 2       0.029588
# 3       0.032553
# 4       0.035477
#           ...
# 7195    0.105469
# 7196    0.108324
# 7197    0.111183
# 7198    0.114052
# 7199    0.116930
# Name: Target, Length: 7200, dtype: float64

# %% [markdown]
# ___

# %% [markdown]
# # Standardization and Power Transform

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import QuantileTransformer

# %%
# Processing both X_train and X_test using standardization
scaler = StandardScaler()
X_train = scaler.fit_transform(X_traindf)
X_test = scaler.transform(X_testdf)

# %%
quantile = QuantileTransformer(output_distribution='normal', random_state=42)



y_train_normal = quantile.fit_transform(y_train.values.reshape(-1,1))
y_test_normal = quantile.transform(y_test.values.reshape(-1,1))

# %%
# Visualize the effect of power transformation
f = plt.figure(figsize=(15, 6))

ax = f.add_subplot(121)
sns.distplot(y_train, bins=50, color='r', ax=ax)
ax.set_title('Distribution before processing')

ax=f.add_subplot(122)
sns.distplot(y_train_normal, bins=50, color='b', ax=ax)
ax.set_title('Distribution after quantile processing')
print()
# Out:
# /home/tendou/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/tendou/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ___

# %% [markdown]
# # ANN

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt

torch.backends.cudnn.version() , torch.backends.cudnn.enabled
torch.manual_seed(0)

# %%
# convert data to torch.FloatTensor
X_train_torch = torch.from_numpy(X_train.astype(np.float32))
X_test_torch = torch.from_numpy(X_test.astype(np.float32))



y_train_torch = torch.from_numpy(y_train_normal.astype(np.float32))
y_test_torch = torch.from_numpy(y_test_normal.astype(np.float32))

print(X_train_torch)
# Out:
# tensor([[-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.6846],
#         [-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.5883],
#         [-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.4921],
#         ...,
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.4921],
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.5883],
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.6846]])

# %%
train_data = []
for i in range(len(X_train_torch)):
   train_data.append([X_train_torch[i],
                      y_train_torch[i]
                     ])

test_data = []
for i in range(len(X_test_torch)):
   test_data.append([X_test_torch[i], 
                     y_test_torch[i]
                     ])
   
# prepare data loaders
train_loader = torch.utils.data.DataLoader(train_data, batch_size=512,               # batch_size could be smaller
    num_workers=0, shuffle=True)                                                                   # Increasing num_workers slow down the training because it does not use GPU at all
test_loader = torch.utils.data.DataLoader(test_data, batch_size=512,
    num_workers=0)

# %%
for data, target in train_loader:
    print(data.shape[0] == data.size(0))
    break
# Out:
# True

# %%
## Define the NN architecture
## NN with 3 hidden layer, s=[11, 256, 256, 256, 1]

class BleveNet(nn.Module):
    def __init__(self):
        super(BleveNet, self).__init__()
        # The first hidden layer has 256 neurons
        self.fc1 = nn.Linear(X_train_torch.shape[1], 256)
        # The second hidden layer has 256 neurons
        self.fc2 = nn.Linear(256, 256)
        # The third hidden layer has 256 neurons
        self.fc3 = nn.Linear(256, 256)
        # The final layer has 1 output neuron
        self.fc4 = nn.Linear(256, 1)


        # Define proportion or neurons to dropout
        self.dropout = nn.Dropout(0.1)

        # Mish activation
        self.mish = nn.Mish()


    def forward(self, x):
        # add first fully connected layer
        x = self.fc1(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add second fully connected layer
        x = self.fc2(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add third fully connected layer
        x = self.fc3(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add final output layers:
        output = self.fc4(x)
       
        return output

# initialize the NN
model = BleveNet()
print(model)
# Out:
# BleveNet(
#   (fc1): Linear(in_features=11, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=256, bias=True)
#   (fc4): Linear(in_features=256, out_features=1, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (mish): Mish()
# )

# %%
criterion = nn.HuberLoss()        # This is the best loss function for my model
# criterion = nn.MSELoss()


optimizer = torch.optim.Adam(model.parameters(), lr=0.005, weight_decay=1e-5)     # This is the best optimizer for my model 

# Check for GPU
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
startTime = timeit.default_timer() 

n_epochs = 500 

model.to(device)    # bring the model to gpu

train_losses = []
lowest_mape = 100
for epoch in range(n_epochs):

    model.train()       

    # monitor training loss
    train_loss = 0.0
    
    ###################
    # train the model #
    ###################
    for data, target in train_loader:
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        #bring data and target to gpu
        data, target = data.to(device), target.to(device)
        
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update running training loss
        train_loss += loss.item()*data.size(0)
        
    # print training statistics 
    # calculate average loss over an epoch
    train_loss = train_loss/len(train_loader.dataset)
    train_losses.append(train_loss)

    print('Epoch: {}/{} \tTraining Loss: {:.6f}'.format(
        epoch+1,
        n_epochs, 
        train_loss
        ))
    

    ############################
    # Evaluate the lowest MAPE #
    ############################
    model.eval()
    with torch.no_grad():  # turn off gradient to save memory
        y_predNN_torch = model(X_test_torch.to(device))

    y_predNN = quantile.inverse_transform(y_predNN_torch.cpu().numpy())
    MAPE = mean_absolute_percentage_error(y_test, y_predNN)

    if MAPE < lowest_mape:
        lowest_mape = MAPE
        print(f'Lowest MAPE: {lowest_mape}')
        torch.save(model.state_dict(), 'PyTorch_Model/Single_NegativePeakTime_lowest.pt')
    print()

endTime = timeit.default_timer()
runningTotal = (endTime - startTime)
print(f"Time taken: {runningTotal}")
# Out:
# Epoch: 1/500 	Training Loss: 0.047991
# Lowest MAPE: 0.03574302861736696
#
# Epoch: 2/500 	Training Loss: 0.015908
# Lowest MAPE: 0.02709624546235117
#
# Epoch: 3/500 	Training Loss: 0.012136
#
# Epoch: 4/500 	Training Loss: 0.010472
# Lowest MAPE: 0.026466587671858183
#
# Epoch: 5/500 	Training Loss: 0.011029
# Lowest MAPE: 0.02527246581921776
#
# Epoch: 6/500 	Training Loss: 0.010532
# Lowest MAPE: 0.022963447432565672
#
# Epoch: 7/500 	Training Loss: 0.008585
#
# Epoch: 8/500 	Training Loss: 0.008652
#
# Epoch: 9/500 	Training Loss: 0.007188
#
# Epoch: 10/500 	Training Loss: 0.007145
#
# Epoch: 11/500 	Training Loss: 0.006835
# Lowest MAPE: 0.013981622194845526
#
# Epoch: 12/500 	Training Loss: 0.005115
#
# Epoch: 13/500 	Training Loss: 0.005634
#
# Epoch: 14/500 	Training Loss: 0.006560
#
# Epoch: 15/500 	Training Loss: 0.005406
#
# Epoch: 16/500 	Training Loss: 0.005283
#
# Epoch: 17/500 	Training Loss: 0.005343
#
# Epoch: 18/500 	Training Loss: 0.005107
#
# Epoch: 19/500 	Training Loss: 0.004925
#
# Epoch: 20/500 	Training Loss: 0.004743
#
# Epoch: 21/500 	Training Loss: 0.007070
#
# Epoch: 22/500 	Training Loss: 0.004877
#
# Epoch: 23/500 	Training Loss: 0.005305
#
# Epoch: 24/500 	Training Loss: 0.005758
#
# Epoch: 25/500 	Training Loss: 0.004996
#
# Epoch: 26/500 	Training Loss: 0.004406
#
# Epoch: 27/500 	Training Loss: 0.003941
# Lowest MAPE: 0.012212234613634314
#
# Epoch: 28/500 	Training Loss: 0.003933
#
# Epoch: 29/500 	Training Loss: 0.006793
#
# Epoch: 30/500 	Training Loss: 0.005968
#
# Epoch: 31/500 	Training Loss: 0.004672
#
# Epoch: 32/500 	Training Loss: 0.004780
#
# Epoch: 33/500 	Training Loss: 0.004299
#
# Epoch: 34/500 	Training Loss: 0.003606
#
# Epoch: 35/500 	Training Loss: 0.005413
#
# Epoch: 36/500 	Training Loss: 0.005268
# Lowest MAPE: 0.01165941416317807
#
# Epoch: 37/500 	Training Loss: 0.004130
#
# Epoch: 38/500 	Training Loss: 0.004239
#
# Epoch: 39/500 	Training Loss: 0.004242
#
# Epoch: 40/500 	Training Loss: 0.004328
#
# Epoch: 41/500 	Training Loss: 0.004642
#
# Epoch: 42/500 	Training Loss: 0.003887
#
# Epoch: 43/500 	Training Loss: 0.003962
#
# Epoch: 44/500 	Training Loss: 0.003851
#
# Epoch: 45/500 	Training Loss: 0.004741
#
# Epoch: 46/500 	Training Loss: 0.006773
#
# Epoch: 47/500 	Training Loss: 0.005485
#
# Epoch: 48/500 	Training Loss: 0.003504
#
# Epoch: 49/500 	Training Loss: 0.004370
#
# Epoch: 50/500 	Training Loss: 0.004582
#
# Epoch: 51/500 	Training Loss: 0.004038
#
# Epoch: 52/500 	Training Loss: 0.003513
#
# Epoch: 53/500 	Training Loss: 0.004087
#
# Epoch: 54/500 	Training Loss: 0.004000
#
# Epoch: 55/500 	Training Loss: 0.003642
#
# Epoch: 56/500 	Training Loss: 0.004701
#
# Epoch: 57/500 	Training Loss: 0.004014
#
# Epoch: 58/500 	Training Loss: 0.003628
#
# Epoch: 59/500 	Training Loss: 0.004058
#
# Epoch: 60/500 	Training Loss: 0.003707
#
# Epoch: 61/500 	Training Loss: 0.005094
#
# Epoch: 62/500 	Training Loss: 0.004309
#
# Epoch: 63/500 	Training Loss: 0.003341
#
# Epoch: 64/500 	Training Loss: 0.004170
#
# Epoch: 65/500 	Training Loss: 0.003483
#
# Epoch: 66/500 	Training Loss: 0.003947
#
# Epoch: 67/500 	Training Loss: 0.004486
#
# Epoch: 68/500 	Training Loss: 0.004317
#
# Epoch: 69/500 	Training Loss: 0.003894
# Lowest MAPE: 0.011637149705801583
#
# Epoch: 70/500 	Training Loss: 0.003608
#
# Epoch: 71/500 	Training Loss: 0.004240
#
# Epoch: 72/500 	Training Loss: 0.004143
#
# Epoch: 73/500 	Training Loss: 0.003516
#
# Epoch: 74/500 	Training Loss: 0.004510
#
# Epoch: 75/500 	Training Loss: 0.004515
#
# Epoch: 76/500 	Training Loss: 0.003407
#
# Epoch: 77/500 	Training Loss: 0.004898
#
# Epoch: 78/500 	Training Loss: 0.005032
#
# Epoch: 79/500 	Training Loss: 0.004080
#
# Epoch: 80/500 	Training Loss: 0.005015
#
# Epoch: 81/500 	Training Loss: 0.004190
#
# Epoch: 82/500 	Training Loss: 0.003244
#
# Epoch: 83/500 	Training Loss: 0.004217
#
# Epoch: 84/500 	Training Loss: 0.003902
#
# Epoch: 85/500 	Training Loss: 0.003994
#
# Epoch: 86/500 	Training Loss: 0.004944
#
# Epoch: 87/500 	Training Loss: 0.004981
#
# Epoch: 88/500 	Training Loss: 0.003765
#
# Epoch: 89/500 	Training Loss: 0.004435
#
# Epoch: 90/500 	Training Loss: 0.005840
#
# Epoch: 91/500 	Training Loss: 0.004593
#
# Epoch: 92/500 	Training Loss: 0.004468
#
# Epoch: 93/500 	Training Loss: 0.003975
#
# Epoch: 94/500 	Training Loss: 0.004065
#
# Epoch: 95/500 	Training Loss: 0.003780
#
# Epoch: 96/500 	Training Loss: 0.004388
#
# Epoch: 97/500 	Training Loss: 0.003744
#
# Epoch: 98/500 	Training Loss: 0.004555
#
# Epoch: 99/500 	Training Loss: 0.008086
#
# Epoch: 100/500 	Training Loss: 0.003701
#
# Epoch: 101/500 	Training Loss: 0.004460
#
# Epoch: 102/500 	Training Loss: 0.004563
#
# Epoch: 103/500 	Training Loss: 0.004339
#
# Epoch: 104/500 	Training Loss: 0.003950
#
# Epoch: 105/500 	Training Loss: 0.003632
#
# Epoch: 106/500 	Training Loss: 0.003626
#
# Epoch: 107/500 	Training Loss: 0.003228
#
# Epoch: 108/500 	Training Loss: 0.004327
#
# Epoch: 109/500 	Training Loss: 0.004021
#
# Epoch: 110/500 	Training Loss: 0.003257
#
# Epoch: 111/500 	Training Loss: 0.004403
#
# Epoch: 112/500 	Training Loss: 0.003840
#
# Epoch: 113/500 	Training Loss: 0.004164
#
# Epoch: 114/500 	Training Loss: 0.003879
#
# Epoch: 115/500 	Training Loss: 0.004585
#
# Epoch: 116/500 	Training Loss: 0.003557
#
# Epoch: 117/500 	Training Loss: 0.003897
#
# Epoch: 118/500 	Training Loss: 0.004299
# Lowest MAPE: 0.011354671600594054
#
# Epoch: 119/500 	Training Loss: 0.003385
#
# Epoch: 120/500 	Training Loss: 0.004610
#
# Epoch: 121/500 	Training Loss: 0.003871
#
# Epoch: 122/500 	Training Loss: 0.003258
#
# Epoch: 123/500 	Training Loss: 0.003798
#
# Epoch: 124/500 	Training Loss: 0.003725
#
# Epoch: 125/500 	Training Loss: 0.003696
#
# Epoch: 126/500 	Training Loss: 0.004952
#
# Epoch: 127/500 	Training Loss: 0.004594
#
# Epoch: 128/500 	Training Loss: 0.005348
#
# Epoch: 129/500 	Training Loss: 0.003429
#
# Epoch: 130/500 	Training Loss: 0.003748
#
# Epoch: 131/500 	Training Loss: 0.003424
#
# Epoch: 132/500 	Training Loss: 0.004287
#
# Epoch: 133/500 	Training Loss: 0.004535
#
# Epoch: 134/500 	Training Loss: 0.003294
#
# Epoch: 135/500 	Training Loss: 0.004299
#
# Epoch: 136/500 	Training Loss: 0.003690
#
# Epoch: 137/500 	Training Loss: 0.004613
#
# Epoch: 138/500 	Training Loss: 0.003491
#
# Epoch: 139/500 	Training Loss: 0.003811
#
# Epoch: 140/500 	Training Loss: 0.003461
#
# Epoch: 141/500 	Training Loss: 0.003468
#
# Epoch: 142/500 	Training Loss: 0.003660
#
# Epoch: 143/500 	Training Loss: 0.003568
#
# Epoch: 144/500 	Training Loss: 0.003469
#
# Epoch: 145/500 	Training Loss: 0.003460
#
# Epoch: 146/500 	Training Loss: 0.004095
#
# Epoch: 147/500 	Training Loss: 0.003412
#
# Epoch: 148/500 	Training Loss: 0.005474
#
# Epoch: 149/500 	Training Loss: 0.003984
#
# Epoch: 150/500 	Training Loss: 0.003828
#
# Epoch: 151/500 	Training Loss: 0.003656
#
# Epoch: 152/500 	Training Loss: 0.003736
#
# Epoch: 153/500 	Training Loss: 0.003762
#
# Epoch: 154/500 	Training Loss: 0.003396
#
# Epoch: 155/500 	Training Loss: 0.004012
#
# Epoch: 156/500 	Training Loss: 0.005428
#
# Epoch: 157/500 	Training Loss: 0.004366
#
# Epoch: 158/500 	Training Loss: 0.004230
#
# Epoch: 159/500 	Training Loss: 0.003295
# Lowest MAPE: 0.011010734216458285
#
# Epoch: 160/500 	Training Loss: 0.003590
#
# Epoch: 161/500 	Training Loss: 0.003431
#
# Epoch: 162/500 	Training Loss: 0.003807
#
# Epoch: 163/500 	Training Loss: 0.003918
#
# Epoch: 164/500 	Training Loss: 0.003378
#
# Epoch: 165/500 	Training Loss: 0.003245
#
# Epoch: 166/500 	Training Loss: 0.003570
#
# Epoch: 167/500 	Training Loss: 0.003235
#
# Epoch: 168/500 	Training Loss: 0.003072
#
# Epoch: 169/500 	Training Loss: 0.003862
#
# Epoch: 170/500 	Training Loss: 0.004279
#
# Epoch: 171/500 	Training Loss: 0.003628
#
# Epoch: 172/500 	Training Loss: 0.003863
#
# Epoch: 173/500 	Training Loss: 0.003456
#
# Epoch: 174/500 	Training Loss: 0.003254
#
# Epoch: 175/500 	Training Loss: 0.003806
#
# Epoch: 176/500 	Training Loss: 0.003847
#
# Epoch: 177/500 	Training Loss: 0.004434
#
# Epoch: 178/500 	Training Loss: 0.003439
#
# Epoch: 179/500 	Training Loss: 0.003423
#
# Epoch: 180/500 	Training Loss: 0.002797
#
# Epoch: 181/500 	Training Loss: 0.003538
#
# Epoch: 182/500 	Training Loss: 0.003678
#
# Epoch: 183/500 	Training Loss: 0.004703
#
# Epoch: 184/500 	Training Loss: 0.003884
#
# Epoch: 185/500 	Training Loss: 0.003864
#
# Epoch: 186/500 	Training Loss: 0.003820
#
# Epoch: 187/500 	Training Loss: 0.003960
#
# Epoch: 188/500 	Training Loss: 0.004157
#
# Epoch: 189/500 	Training Loss: 0.003659
#
# Epoch: 190/500 	Training Loss: 0.003476
#
# Epoch: 191/500 	Training Loss: 0.003628
#
# Epoch: 192/500 	Training Loss: 0.003777
#
# Epoch: 193/500 	Training Loss: 0.003684
#
# Epoch: 194/500 	Training Loss: 0.004068
#
# Epoch: 195/500 	Training Loss: 0.004138
#
# Epoch: 196/500 	Training Loss: 0.004390
#
# Epoch: 197/500 	Training Loss: 0.004188
#
# Epoch: 198/500 	Training Loss: 0.003326
#
# Epoch: 199/500 	Training Loss: 0.003179
#
# Epoch: 200/500 	Training Loss: 0.003888
#
# Epoch: 201/500 	Training Loss: 0.003293
#
# Epoch: 202/500 	Training Loss: 0.003235
#
# Epoch: 203/500 	Training Loss: 0.004402
#
# Epoch: 204/500 	Training Loss: 0.097111
#
# Epoch: 205/500 	Training Loss: 0.009866
#
# Epoch: 206/500 	Training Loss: 0.006236
#
# Epoch: 207/500 	Training Loss: 0.005534
#
# Epoch: 208/500 	Training Loss: 0.004312
#
# Epoch: 209/500 	Training Loss: 0.004144
#
# Epoch: 210/500 	Training Loss: 0.004255
#
# Epoch: 211/500 	Training Loss: 0.003856
#
# Epoch: 212/500 	Training Loss: 0.004706
#
# Epoch: 213/500 	Training Loss: 0.003783
#
# Epoch: 214/500 	Training Loss: 0.003305
#
# Epoch: 215/500 	Training Loss: 0.004072
#
# Epoch: 216/500 	Training Loss: 0.003998
#
# Epoch: 217/500 	Training Loss: 0.003760
#
# Epoch: 218/500 	Training Loss: 0.003653
#
# Epoch: 219/500 	Training Loss: 0.003137
#
# Epoch: 220/500 	Training Loss: 0.003232
#
# Epoch: 221/500 	Training Loss: 0.003166
# Lowest MAPE: 0.0106447530751019
#
# Epoch: 222/500 	Training Loss: 0.003482
#
# Epoch: 223/500 	Training Loss: 0.003373
#
# Epoch: 224/500 	Training Loss: 0.003457
#
# Epoch: 225/500 	Training Loss: 0.003172
#
# Epoch: 226/500 	Training Loss: 0.003978
#
# Epoch: 227/500 	Training Loss: 0.003390
#
# Epoch: 228/500 	Training Loss: 0.003629
#
# Epoch: 229/500 	Training Loss: 0.003260
#
# Epoch: 230/500 	Training Loss: 0.003992
#
# Epoch: 231/500 	Training Loss: 0.003336
#
# Epoch: 232/500 	Training Loss: 0.003643
#
# Epoch: 233/500 	Training Loss: 0.003247
#
# Epoch: 234/500 	Training Loss: 0.003876
#
# Epoch: 235/500 	Training Loss: 0.003485
#
# Epoch: 236/500 	Training Loss: 0.003490
#
# Epoch: 237/500 	Training Loss: 0.003029
#
# Epoch: 238/500 	Training Loss: 0.003153
#
# Epoch: 239/500 	Training Loss: 0.003077
#
# Epoch: 240/500 	Training Loss: 0.003026
#
# Epoch: 241/500 	Training Loss: 0.002984
#
# Epoch: 242/500 	Training Loss: 0.003029
#
# Epoch: 243/500 	Training Loss: 0.003410
#
# Epoch: 244/500 	Training Loss: 0.004024
#
# Epoch: 245/500 	Training Loss: 0.003559
#
# Epoch: 246/500 	Training Loss: 0.003496
#
# Epoch: 247/500 	Training Loss: 0.002950
#
# Epoch: 248/500 	Training Loss: 0.003702
#
# Epoch: 249/500 	Training Loss: 0.003850
#
# Epoch: 250/500 	Training Loss: 0.003680
#
# Epoch: 251/500 	Training Loss: 0.004038
#
# Epoch: 252/500 	Training Loss: 0.003448
#
# Epoch: 253/500 	Training Loss: 0.003431
#
# Epoch: 254/500 	Training Loss: 0.003084
#
# Epoch: 255/500 	Training Loss: 0.002919
#
# Epoch: 256/500 	Training Loss: 0.003364
#
# Epoch: 257/500 	Training Loss: 0.003137
#
# Epoch: 258/500 	Training Loss: 0.003355
#
# Epoch: 259/500 	Training Loss: 0.003027
#
# Epoch: 260/500 	Training Loss: 0.003438
#
# Epoch: 261/500 	Training Loss: 0.004075
#
# Epoch: 262/500 	Training Loss: 0.003684
#
# Epoch: 263/500 	Training Loss: 0.003165
#
# Epoch: 264/500 	Training Loss: 0.004086
#
# Epoch: 265/500 	Training Loss: 0.004098
#
# Epoch: 266/500 	Training Loss: 0.003856
#
# Epoch: 267/500 	Training Loss: 0.005608
#
# Epoch: 268/500 	Training Loss: 0.003037
#
# Epoch: 269/500 	Training Loss: 0.003816
#
# Epoch: 270/500 	Training Loss: 0.003087
#
# Epoch: 271/500 	Training Loss: 0.003065
#
# Epoch: 272/500 	Training Loss: 0.003148
#
# Epoch: 273/500 	Training Loss: 0.003139
#
# Epoch: 274/500 	Training Loss: 0.003201
#
# Epoch: 275/500 	Training Loss: 0.004045
#
# Epoch: 276/500 	Training Loss: 0.003744
#
# Epoch: 277/500 	Training Loss: 0.004126
#
# Epoch: 278/500 	Training Loss: 0.003393
#
# Epoch: 279/500 	Training Loss: 0.003423
#
# Epoch: 280/500 	Training Loss: 0.003324
#
# Epoch: 281/500 	Training Loss: 0.003484
#
# Epoch: 282/500 	Training Loss: 0.003300
#
# Epoch: 283/500 	Training Loss: 0.003081
#
# Epoch: 284/500 	Training Loss: 0.002713
#
# Epoch: 285/500 	Training Loss: 0.003431
#
# Epoch: 286/500 	Training Loss: 0.003881
#
# Epoch: 287/500 	Training Loss: 0.003035
# Lowest MAPE: 0.010612417380274047
#
# Epoch: 288/500 	Training Loss: 0.003280
#
# Epoch: 289/500 	Training Loss: 0.003848
#
# Epoch: 290/500 	Training Loss: 0.003319
#
# Epoch: 291/500 	Training Loss: 0.003278
#
# Epoch: 292/500 	Training Loss: 0.003147
#
# Epoch: 293/500 	Training Loss: 0.003573
#
# Epoch: 294/500 	Training Loss: 0.003434
#
# Epoch: 295/500 	Training Loss: 0.003345
#
# Epoch: 296/500 	Training Loss: 0.003184
#
# Epoch: 297/500 	Training Loss: 0.003730
#
# Epoch: 298/500 	Training Loss: 0.003280
#
# Epoch: 299/500 	Training Loss: 0.003231
#
# Epoch: 300/500 	Training Loss: 0.003721
#
# Epoch: 301/500 	Training Loss: 0.003572
#
# Epoch: 302/500 	Training Loss: 0.003051
#
# Epoch: 303/500 	Training Loss: 0.003689
#
# Epoch: 304/500 	Training Loss: 0.003349
#
# Epoch: 305/500 	Training Loss: 0.003985
#
# Epoch: 306/500 	Training Loss: 0.003130
#
# Epoch: 307/500 	Training Loss: 0.004074
#
# Epoch: 308/500 	Training Loss: 0.004047
#
# Epoch: 309/500 	Training Loss: 0.003590
#
# Epoch: 310/500 	Training Loss: 0.003780
#
# Epoch: 311/500 	Training Loss: 0.004102
#
# Epoch: 312/500 	Training Loss: 0.003539
#
# Epoch: 313/500 	Training Loss: 0.003305
#
# Epoch: 314/500 	Training Loss: 0.003087
#
# Epoch: 315/500 	Training Loss: 0.003056
#
# Epoch: 316/500 	Training Loss: 0.003164
#
# Epoch: 317/500 	Training Loss: 0.003793
#
# Epoch: 318/500 	Training Loss: 0.003414
#
# Epoch: 319/500 	Training Loss: 0.003252
#
# Epoch: 320/500 	Training Loss: 0.003118
#
# Epoch: 321/500 	Training Loss: 0.003576
#
# Epoch: 322/500 	Training Loss: 0.003959
#
# Epoch: 323/500 	Training Loss: 0.003938
#
# Epoch: 324/500 	Training Loss: 0.003465
#
# Epoch: 325/500 	Training Loss: 0.002871
#
# Epoch: 326/500 	Training Loss: 0.003110
#
# Epoch: 327/500 	Training Loss: 0.003399
#
# Epoch: 328/500 	Training Loss: 0.003476
#
# Epoch: 329/500 	Training Loss: 0.003865
#
# Epoch: 330/500 	Training Loss: 0.004121
#
# Epoch: 331/500 	Training Loss: 0.003890
#
# Epoch: 332/500 	Training Loss: 0.003580
#
# Epoch: 333/500 	Training Loss: 0.004581
#
# Epoch: 334/500 	Training Loss: 0.003054
#
# Epoch: 335/500 	Training Loss: 0.003012
#
# Epoch: 336/500 	Training Loss: 0.003301
#
# Epoch: 337/500 	Training Loss: 0.003261
#
# Epoch: 338/500 	Training Loss: 0.002795
#
# Epoch: 339/500 	Training Loss: 0.002933
#
# Epoch: 340/500 	Training Loss: 0.003618
#
# Epoch: 341/500 	Training Loss: 0.003439
#
# Epoch: 342/500 	Training Loss: 0.003844
#
# Epoch: 343/500 	Training Loss: 0.003603
#
# Epoch: 344/500 	Training Loss: 0.003595
#
# Epoch: 345/500 	Training Loss: 0.003197
#
# Epoch: 346/500 	Training Loss: 0.004390
#
# Epoch: 347/500 	Training Loss: 0.003200
#
# Epoch: 348/500 	Training Loss: 0.003336
#
# Epoch: 349/500 	Training Loss: 0.003036
#
# Epoch: 350/500 	Training Loss: 0.003299
#
# Epoch: 351/500 	Training Loss: 0.003371
#
# Epoch: 352/500 	Training Loss: 0.003200
#
# Epoch: 353/500 	Training Loss: 0.003736
#
# Epoch: 354/500 	Training Loss: 0.003146
#
# Epoch: 355/500 	Training Loss: 0.004275
#
# Epoch: 356/500 	Training Loss: 0.003581
#
# Epoch: 357/500 	Training Loss: 0.003917
#
# Epoch: 358/500 	Training Loss: 0.003699
#
# Epoch: 359/500 	Training Loss: 0.003511
#
# Epoch: 360/500 	Training Loss: 0.003747
#
# Epoch: 361/500 	Training Loss: 0.003232
#
# Epoch: 362/500 	Training Loss: 0.003093
#
# Epoch: 363/500 	Training Loss: 0.002805
#
# Epoch: 364/500 	Training Loss: 0.003395
#
# Epoch: 365/500 	Training Loss: 0.003365
#
# Epoch: 366/500 	Training Loss: 0.003036
#
# Epoch: 367/500 	Training Loss: 0.003290
#
# Epoch: 368/500 	Training Loss: 0.003408
#
# Epoch: 369/500 	Training Loss: 0.002870
#
# Epoch: 370/500 	Training Loss: 0.002845
#
# Epoch: 371/500 	Training Loss: 0.004508
#
# Epoch: 372/500 	Training Loss: 0.003453
#
# Epoch: 373/500 	Training Loss: 0.003441
#
# Epoch: 374/500 	Training Loss: 0.004337
#
# Epoch: 375/500 	Training Loss: 0.003499
#
# Epoch: 376/500 	Training Loss: 0.003573
#
# Epoch: 377/500 	Training Loss: 0.003622
#
# Epoch: 378/500 	Training Loss: 0.002943
#
# Epoch: 379/500 	Training Loss: 0.003150
#
# Epoch: 380/500 	Training Loss: 0.003560
#
# Epoch: 381/500 	Training Loss: 0.003008
#
# Epoch: 382/500 	Training Loss: 0.003170
#
# Epoch: 383/500 	Training Loss: 0.003655
#
# Epoch: 384/500 	Training Loss: 0.004002
#
# Epoch: 385/500 	Training Loss: 0.002892
#
# Epoch: 386/500 	Training Loss: 0.003611
#
# Epoch: 387/500 	Training Loss: 0.003432
#
# Epoch: 388/500 	Training Loss: 0.003405
#
# Epoch: 389/500 	Training Loss: 0.003686
#
# Epoch: 390/500 	Training Loss: 0.003348
#
# Epoch: 391/500 	Training Loss: 0.003683
#
# Epoch: 392/500 	Training Loss: 0.005088
#
# Epoch: 393/500 	Training Loss: 0.003157
#
# Epoch: 394/500 	Training Loss: 0.003646
#
# Epoch: 395/500 	Training Loss: 0.003160
#
# Epoch: 396/500 	Training Loss: 0.003870
#
# Epoch: 397/500 	Training Loss: 0.003400
#
# Epoch: 398/500 	Training Loss: 0.003106
#
# Epoch: 399/500 	Training Loss: 0.003087
#
# Epoch: 400/500 	Training Loss: 0.003061
#
# Epoch: 401/500 	Training Loss: 0.003498
#
# Epoch: 402/500 	Training Loss: 0.003885
#
# Epoch: 403/500 	Training Loss: 0.003685
#
# Epoch: 404/500 	Training Loss: 0.003073
#
# Epoch: 405/500 	Training Loss: 0.003302
#
# Epoch: 406/500 	Training Loss: 0.003425
# Lowest MAPE: 0.010328615424919434
#
# Epoch: 407/500 	Training Loss: 0.003421
#
# Epoch: 408/500 	Training Loss: 0.003373
#
# Epoch: 409/500 	Training Loss: 0.003025
#
# Epoch: 410/500 	Training Loss: 0.003289
#
# Epoch: 411/500 	Training Loss: 0.003059
#
# Epoch: 412/500 	Training Loss: 0.003065
#
# Epoch: 413/500 	Training Loss: 0.002953
#
# Epoch: 414/500 	Training Loss: 0.003438
#
# Epoch: 415/500 	Training Loss: 0.003410
#
# Epoch: 416/500 	Training Loss: 0.003412
#
# Epoch: 417/500 	Training Loss: 0.003198
#
# Epoch: 418/500 	Training Loss: 0.002750
#
# Epoch: 419/500 	Training Loss: 0.003014
#
# Epoch: 420/500 	Training Loss: 0.003606
#
# Epoch: 421/500 	Training Loss: 0.003220
#
# Epoch: 422/500 	Training Loss: 0.003274
#
# Epoch: 423/500 	Training Loss: 0.003523
#
# Epoch: 424/500 	Training Loss: 0.003280
#
# Epoch: 425/500 	Training Loss: 0.003279
#
# Epoch: 426/500 	Training Loss: 0.003438
#
# Epoch: 427/500 	Training Loss: 0.003431
#
# Epoch: 428/500 	Training Loss: 0.003743
#
# Epoch: 429/500 	Training Loss: 0.003462
#
# Epoch: 430/500 	Training Loss: 0.003681
#
# Epoch: 431/500 	Training Loss: 0.003821
#
# Epoch: 432/500 	Training Loss: 0.003767
#
# Epoch: 433/500 	Training Loss: 0.003414
#
# Epoch: 434/500 	Training Loss: 0.002884
#
# Epoch: 435/500 	Training Loss: 0.003196
#
# Epoch: 436/500 	Training Loss: 0.003801
#
# Epoch: 437/500 	Training Loss: 0.002835
#
# Epoch: 438/500 	Training Loss: 0.003135
#
# Epoch: 439/500 	Training Loss: 0.004469
#
# Epoch: 440/500 	Training Loss: 0.003134
#
# Epoch: 441/500 	Training Loss: 0.003061
#
# Epoch: 442/500 	Training Loss: 0.003270
#
# Epoch: 443/500 	Training Loss: 0.003932
#
# Epoch: 444/500 	Training Loss: 0.002723
#
# Epoch: 445/500 	Training Loss: 0.003692
#
# Epoch: 446/500 	Training Loss: 0.003036
#
# Epoch: 447/500 	Training Loss: 0.003011
#
# Epoch: 448/500 	Training Loss: 0.003071
#
# Epoch: 449/500 	Training Loss: 0.003279
#
# Epoch: 450/500 	Training Loss: 0.003272
#
# Epoch: 451/500 	Training Loss: 0.003222
#
# Epoch: 452/500 	Training Loss: 0.003051
#
# Epoch: 453/500 	Training Loss: 0.003981
#
# Epoch: 454/500 	Training Loss: 0.003285
#
# Epoch: 455/500 	Training Loss: 0.004345
#
# Epoch: 456/500 	Training Loss: 0.003585
#
# Epoch: 457/500 	Training Loss: 0.003512
#
# Epoch: 458/500 	Training Loss: 0.003054
#
# Epoch: 459/500 	Training Loss: 0.003074
#
# Epoch: 460/500 	Training Loss: 0.004825
#
# Epoch: 461/500 	Training Loss: 0.003087
#
# Epoch: 462/500 	Training Loss: 0.002990
#
# Epoch: 463/500 	Training Loss: 0.002856
#
# Epoch: 464/500 	Training Loss: 0.003632
#
# Epoch: 465/500 	Training Loss: 0.003038
#
# Epoch: 466/500 	Training Loss: 0.003359
#
# Epoch: 467/500 	Training Loss: 0.003508
#
# Epoch: 468/500 	Training Loss: 0.003158
#
# Epoch: 469/500 	Training Loss: 0.003742
#
# Epoch: 470/500 	Training Loss: 0.003451
#
# Epoch: 471/500 	Training Loss: 0.003172
#
# Epoch: 472/500 	Training Loss: 0.003686
#
# Epoch: 473/500 	Training Loss: 0.003140
#
# Epoch: 474/500 	Training Loss: 0.003431
#
# Epoch: 475/500 	Training Loss: 0.003223
#
# Epoch: 476/500 	Training Loss: 0.003330
#
# Epoch: 477/500 	Training Loss: 0.003662
#
# Epoch: 478/500 	Training Loss: 0.003472
#
# Epoch: 479/500 	Training Loss: 0.003164
#
# Epoch: 480/500 	Training Loss: 0.002853
#
# Epoch: 481/500 	Training Loss: 0.003396
#
# Epoch: 482/500 	Training Loss: 0.003966
#
# Epoch: 483/500 	Training Loss: 0.003016
#
# Epoch: 484/500 	Training Loss: 0.003440
#
# Epoch: 485/500 	Training Loss: 0.003434
#
# Epoch: 486/500 	Training Loss: 0.003281
#
# Epoch: 487/500 	Training Loss: 0.003439
#
# Epoch: 488/500 	Training Loss: 0.003194
#
# Epoch: 489/500 	Training Loss: 0.003694
#
# Epoch: 490/500 	Training Loss: 0.003314
#
# Epoch: 491/500 	Training Loss: 0.003254
#
# Epoch: 492/500 	Training Loss: 0.003624
#
# Epoch: 493/500 	Training Loss: 0.004597
#
# Epoch: 494/500 	Training Loss: 0.003622
#
# Epoch: 495/500 	Training Loss: 0.003297
#
# Epoch: 496/500 	Training Loss: 0.003524
#
# Epoch: 497/500 	Training Loss: 0.002843
#
# Epoch: 498/500 	Training Loss: 0.003446
#
# Epoch: 499/500 	Training Loss: 0.003170
#
# Epoch: 500/500 	Training Loss: 0.003336
#
# Time taken: 94.82120190000023

# %%
plt.plot(train_losses)

# %%
model.load_state_dict(torch.load('PyTorch_Model/Single_NegativePeakTime_lowest.pt', map_location=torch.device('cpu')))

model.eval()           # prep model for *evaluation*
model.to(device)
with torch.no_grad():  # turn off gradient to save memory
    y_predNN_torch = model(X_test_torch.to(device))

y_predNN_normal = y_predNN_torch.cpu().numpy()     # convert to numpy array
y_test_normal = y_test_torch.cpu().numpy()



print(y_predNN_normal)
# Out:
# [[-1.9567536]
#  [-1.6439282]
#  [-1.398924 ]
#  ...
#  [ 1.1136768]
#  [ 1.2568415]
#  [ 1.4322617]]

# %%
mape = mean_absolute_percentage_error(y_test_normal, y_predNN_normal)
r2 = r2_score(y_test_normal, y_predNN_normal)
rmse = np.sqrt(mean_squared_error(y_test_normal, y_predNN_normal))
print(f"Scores in normal distribution: r2 = {r2}, mape = {mape}, rmse = {rmse}")
# Out:
# Scores in normal distribution: r2 = 0.9968914737482236, mape = 0.11405181139707565, rmse = 0.05582112818956375

# %%
y_predNN = quantile.inverse_transform(y_predNN_normal)
mape = mean_absolute_percentage_error(y_test, y_predNN)
r2 = r2_score(y_test, y_predNN)
rmse = np.sqrt(mean_squared_error(y_test, y_predNN))


print(f"Scores in actual distribution for negative peak time")
print('r2:', r2*100)
print('mape:', mape*100)
print('rmse:', rmse)
print()
# Out:
# Scores in actual distribution for negative duration
# r2: 99.93444258594218
# mape: 1.0328615424919434
# rmse: 0.0007643796897068917
