# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import timeit
#import shap
from sklearn.metrics import r2_score, mean_absolute_percentage_error, mean_squared_error
from sklearn.model_selection import cross_val_score, GridSearchCV, KFold
from sklearn.model_selection import train_test_split

# %% [markdown]
# ___

# %% [markdown]
# # Read-in and One-Hot Encoding

# %%
df = pd.read_excel("data_new/train.xlsx", sheet_name="positive_impulse")

dt = pd.read_excel("data_new/test.xlsx", sheet_name="positive_impulse")

# %%
# Label encoding 'Status' feature into 0 and 1 
# 0 for Subcooled and 1 for Superheated

from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()

df['Status'] = LE.fit_transform(df['Status'])
dt['Status'] = LE.fit_transform(dt['Status'])

df
# Out:
#          ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0      B291                         13.6          0.665119             1.0
# 1      B291                         13.6          0.665119             1.0
# 2      B291                         13.6          0.665119             1.0
# 3      B291                         13.6          0.665119             1.0
# 4      B291                         13.6          0.665119             1.0
# ...     ...                          ...               ...             ...
# 21595  B103                         30.7          0.181290             0.6
# 21596  B103                         30.7          0.181290             0.6
# 21597  B103                         30.7          0.181290             0.6
# 21598  B103                         30.7          0.181290             0.6
# 21599  B103                         30.7          0.181290             0.6
#
#        Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 0                  4.0              0.8                  1.8
# 1                  4.0              0.8                  1.8
# 2                  4.0              0.8                  1.8
# 3                  4.0              0.8                  1.8
# 4                  4.0              0.8                  1.8
# ...                ...              ...                  ...
# 21595              2.0              2.8                  1.2
# 21596              2.0              2.8                  1.2
# 21597              2.0              2.8                  1.2
# 21598              2.0              2.8                  1.2
# 21599              2.0              2.8                  1.2
#
#        Tank Height with Gas (m)   Vapour Temerature (K)  \
# 0                           0.4                   435.0
# 1                           0.4                   435.0
# 2                           0.4                   435.0
# 3                           0.4                   435.0
# 4                           0.4                   435.0
# ...                         ...                     ...
# 21595                       2.2                   334.7
# 21596                       2.2                   334.7
# 21597                       2.2                   334.7
# 21598                       2.2                   334.7
# 21599                       2.2                   334.7
#
#         Liquid Temerature (K)  Status  Stand-off Distance      Target
# 0                       372.5       1                   5  105.453270
# 1                       372.5       1                   6   89.190781
# 2                       372.5       1                   7   77.237755
# 3                       372.5       1                   8   68.085800
# 4                       372.5       1                   9   60.845432
# ...                       ...     ...                 ...         ...
# 21595                   404.9       0                  36   29.048307
# 21596                   404.9       0                  37   28.231998
# 21597                   404.9       0                  38   27.460642
# 21598                   404.9       0                  39   26.729723
# 21599                   404.9       0                  40   26.035421
#
# [21600 rows x 13 columns]

# %%
dt.iloc[30:50,:]
# Out:
#       ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 30  P197                     11.55904          0.602823             3.0
# 31  P197                     11.55904          0.602823             3.0
# 32  P197                     11.55904          0.602823             3.0
# 33  P197                     11.55904          0.602823             3.0
# 34  P197                     11.55904          0.602823             3.0
# 35  P197                     11.55904          0.602823             3.0
# 36  P168                     12.72223          0.648320             1.8
# 37  P168                     12.72223          0.648320             1.8
# 38  P168                     12.72223          0.648320             1.8
# 39  P168                     12.72223          0.648320             1.8
# 40  P168                     12.72223          0.648320             1.8
# 41  P168                     12.72223          0.648320             1.8
# 42  P168                     12.72223          0.648320             1.8
# 43  P168                     12.72223          0.648320             1.8
# 44  P168                     12.72223          0.648320             1.8
# 45  P168                     12.72223          0.648320             1.8
# 46  P168                     12.72223          0.648320             1.8
# 47  P168                     12.72223          0.648320             1.8
# 48  P168                     12.72223          0.648320             1.8
# 49  P168                     12.72223          0.648320             1.8
#
#     Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 30              0.8              2.2                  0.2
# 31              0.8              2.2                  0.2
# 32              0.8              2.2                  0.2
# 33              0.8              2.2                  0.2
# 34              0.8              2.2                  0.2
# 35              0.8              2.2                  0.2
# 36              8.2              0.6                  1.8
# 37              8.2              0.6                  1.8
# 38              8.2              0.6                  1.8
# 39              8.2              0.6                  1.8
# 40              8.2              0.6                  1.8
# 41              8.2              0.6                  1.8
# 42              8.2              0.6                  1.8
# 43              8.2              0.6                  1.8
# 44              8.2              0.6                  1.8
# 45              8.2              0.6                  1.8
# 46              8.2              0.6                  1.8
# 47              8.2              0.6                  1.8
# 48              8.2              0.6                  1.8
# 49              8.2              0.6                  1.8
#
#     Tank Height with Gas (m)   Vapour Temerature (K)   Liquid Temerature (K)  \
# 30                       1.0                   296.7                   328.5
# 31                       1.0                   296.7                   328.5
# 32                       1.0                   296.7                   328.5
# 33                       1.0                   296.7                   328.5
# 34                       1.0                   296.7                   328.5
# 35                       1.0                   296.7                   328.5
# 36                       0.2                   389.7                   296.4
# 37                       0.2                   389.7                   296.4
# 38                       0.2                   389.7                   296.4
# 39                       0.2                   389.7                   296.4
# 40                       0.2                   389.7                   296.4
# 41                       0.2                   389.7                   296.4
# 42                       0.2                   389.7                   296.4
# 43                       0.2                   389.7                   296.4
# 44                       0.2                   389.7                   296.4
# 45                       0.2                   389.7                   296.4
# 46                       0.2                   389.7                   296.4
# 47                       0.2                   389.7                   296.4
# 48                       0.2                   389.7                   296.4
# 49                       0.2                   389.7                   296.4
#
#     Status  Stand-off Distance     Target
# 30       1                  35  11.898917
# 31       1                  36  11.622511
# 32       1                  37  11.358176
# 33       1                  38  11.105268
# 34       1                  39  10.863276
# 35       1                  40  10.631696
# 36       0                   5  83.744408
# 37       0                   6  73.629570
# 38       0                   7  65.149193
# 39       0                   8  58.173275
# 40       0                   9  52.403481
# 41       0                  10  47.589138
# 42       0                  11  43.535988
# 43       0                  12  40.098892
# 44       0                  13  37.164490
# 45       0                  14  34.629341
# 46       0                  15  32.415222
# 47       0                  16  29.546595
# 48       0                  17  27.957481
# 49       0                  18  26.551182

# %%
X_traindf = df.drop(['ID','Target'], axis=1)
X_testdf = dt.drop(['ID','Target'], axis=1)

X_traindf
# Out:
#        Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0                             13.6          0.665119             1.0
# 1                             13.6          0.665119             1.0
# 2                             13.6          0.665119             1.0
# 3                             13.6          0.665119             1.0
# 4                             13.6          0.665119             1.0
# ...                            ...               ...             ...
# 21595                         30.7          0.181290             0.6
# 21596                         30.7          0.181290             0.6
# 21597                         30.7          0.181290             0.6
# 21598                         30.7          0.181290             0.6
# 21599                         30.7          0.181290             0.6
#
#        Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 0                  4.0              0.8                  1.8
# 1                  4.0              0.8                  1.8
# 2                  4.0              0.8                  1.8
# 3                  4.0              0.8                  1.8
# 4                  4.0              0.8                  1.8
# ...                ...              ...                  ...
# 21595              2.0              2.8                  1.2
# 21596              2.0              2.8                  1.2
# 21597              2.0              2.8                  1.2
# 21598              2.0              2.8                  1.2
# 21599              2.0              2.8                  1.2
#
#        Tank Height with Gas (m)   Vapour Temerature (K)  \
# 0                           0.4                   435.0
# 1                           0.4                   435.0
# 2                           0.4                   435.0
# 3                           0.4                   435.0
# 4                           0.4                   435.0
# ...                         ...                     ...
# 21595                       2.2                   334.7
# 21596                       2.2                   334.7
# 21597                       2.2                   334.7
# 21598                       2.2                   334.7
# 21599                       2.2                   334.7
#
#         Liquid Temerature (K)  Status  Stand-off Distance
# 0                       372.5       1                   5
# 1                       372.5       1                   6
# 2                       372.5       1                   7
# 3                       372.5       1                   8
# 4                       372.5       1                   9
# ...                       ...     ...                 ...
# 21595                   404.9       0                  36
# 21596                   404.9       0                  37
# 21597                   404.9       0                  38
# 21598                   404.9       0                  39
# 21599                   404.9       0                  40
#
# [21600 rows x 11 columns]

# %%
y_train = df['Target']
y_train
# Out:
# 0        105.453270
# 1         89.190781
# 2         77.237755
# 3         68.085800
# 4         60.845432
#             ...
# 21595     29.048307
# 21596     28.231998
# 21597     27.460642
# 21598     26.729723
# 21599     26.035421
# Name: Target, Length: 21600, dtype: float64

# %%
y_test = dt['Target']

y_test
# Out:
# 0       52.619038
# 1       46.055485
# 2       41.131420
# 3       37.347630
# 4       34.215847
#           ...
# 7195    37.768711
# 7196    36.680138
# 7197    35.652153
# 7198    34.679951
# 7199    33.759022
# Name: Target, Length: 7200, dtype: float64

# %% [markdown]
# ___

# %% [markdown]
# # Standardization and Power Transform

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import QuantileTransformer

# %%
# Processing both X_train and X_test using standardization
scaler = StandardScaler()
X_train = scaler.fit_transform(X_traindf)
X_test = scaler.transform(X_testdf)

# %%
quantile = QuantileTransformer(output_distribution='normal', random_state=42)



y_train_normal = quantile.fit_transform(y_train.values.reshape(-1,1))
y_test_normal = quantile.transform(y_test.values.reshape(-1,1))

# %%
# Visualize the effect of power transformation
f = plt.figure(figsize=(15, 6))

ax = f.add_subplot(121)
sns.distplot(y_train, bins=50, color='r', ax=ax)
ax.set_title('Distribution before processing')

ax=f.add_subplot(122)
sns.distplot(y_train_normal, bins=50, color='b', ax=ax)
ax.set_title('Distribution after quantile processing')
print()
# Out:
# /home/tendou/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/tendou/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ___

# %% [markdown]
# # ANN

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt

torch.backends.cudnn.version() , torch.backends.cudnn.enabled
torch.manual_seed(0)

# %%
# convert data to torch.FloatTensor
X_train_torch = torch.from_numpy(X_train.astype(np.float32))
X_test_torch = torch.from_numpy(X_test.astype(np.float32))



y_train_torch = torch.from_numpy(y_train_normal.astype(np.float32))
y_test_torch = torch.from_numpy(y_test_normal.astype(np.float32))

print(X_train_torch)
print()
print(y_train_torch)
# Out:
# tensor([[-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.6846],
#         [-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.5883],
#         [-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.4921],
#         ...,
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.4921],
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.5883],
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.6846]])
#
# tensor([[ 0.6927],
#         [ 0.5174],
#         [ 0.3689],
#         ...,
#         [-0.6441],
#         [-0.6733],
#         [-0.6979]])

# %%
train_data = []
for i in range(len(X_train_torch)):
   train_data.append([X_train_torch[i],
                      y_train_torch[i]
                     ])

test_data = []
for i in range(len(X_test_torch)):
   test_data.append([X_test_torch[i], 
                     y_test_torch[i]
                     ])
   
# prepare data loaders
train_loader = torch.utils.data.DataLoader(train_data, batch_size=512,               # batch_size could be smaller
    num_workers=0, shuffle=True)                                                                   # Increasing num_workers slow down the training because it does not use GPU at all
test_loader = torch.utils.data.DataLoader(test_data, batch_size=512,
    num_workers=0)

# %%
for data, target in train_loader:
    print(data.shape[0] == data.size(0))
    break
# Out:
# True

# %%
## Define the NN architecture
## NN with 3 hidden layer, s=[11, 256, 256, 256, 1]

class BleveNet(nn.Module):
    def __init__(self):
        super(BleveNet, self).__init__()
        # The first hidden layer has 256 neurons
        self.fc1 = nn.Linear(X_train_torch.shape[1], 256)
        # The second hidden layer has 256 neurons
        self.fc2 = nn.Linear(256, 256)
        # The third hidden layer has 256 neurons
        self.fc3 = nn.Linear(256, 256)
        # The final layer has 1 output neuron
        self.fc4 = nn.Linear(256, 1)


        # Define proportion or neurons to dropout
        self.dropout = nn.Dropout(0.1)

        # Mish activation
        self.mish = nn.Mish()


    def forward(self, x):
        # add first fully connected layer
        x = self.fc1(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add second fully connected layer
        x = self.fc2(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add third fully connected layer
        x = self.fc3(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add final output layers:
        output = self.fc4(x)
       
        return output

# initialize the NN
model = BleveNet()
print(model)
# Out:
# BleveNet(
#   (fc1): Linear(in_features=11, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=256, bias=True)
#   (fc4): Linear(in_features=256, out_features=1, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (mish): Mish()
# )

# %%
criterion = nn.HuberLoss()        # This is the best loss function for my model
# criterion = nn.MSELoss()


optimizer = torch.optim.Adam(model.parameters(), lr=0.005, weight_decay=1e-5)     # This is the best optimizer for my model 

# Check for GPU
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
startTime = timeit.default_timer() 

n_epochs = 500 

model.to(device)    # bring the model to gpu

train_losses = []
lowest_mape = 100
for epoch in range(n_epochs):

    model.train()       

    # monitor training loss
    train_loss = 0.0
    
    ###################
    # train the model #
    ###################
    for data, target in train_loader:
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        #bring data and target to gpu
        data, target = data.to(device), target.to(device)
        
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update running training loss
        train_loss += loss.item()*data.size(0)
        
    # print training statistics 
    # calculate average loss over an epoch
    train_loss = train_loss/len(train_loader.dataset)
    train_losses.append(train_loss)

    print('Epoch: {}/{} \tTraining Loss: {:.6f}'.format(
        epoch+1,
        n_epochs, 
        train_loss
        ))
    

    ############################
    # Evaluate the lowest MAPE #
    ############################
    model.eval()
    with torch.no_grad():  # turn off gradient to save memory
        y_predNN_torch = model(X_test_torch.to(device))

    y_predNN = quantile.inverse_transform(y_predNN_torch.cpu().numpy())
    MAPE = mean_absolute_percentage_error(y_test, y_predNN)

    if MAPE < lowest_mape:
        lowest_mape = MAPE
        print(f'Lowest MAPE: {lowest_mape}')
        torch.save(model.state_dict(), 'PyTorch_Model/Single_PositiveImpulse_lowest.pt')
    print()

endTime = timeit.default_timer()
runningTotal = (endTime - startTime)
print(f"Time taken: {runningTotal}")
# Out:
# Epoch: 1/500 	Training Loss: 0.052605
# Lowest MAPE: 0.11380957862675833
#
# Epoch: 2/500 	Training Loss: 0.014198
# Lowest MAPE: 0.10097719927909733
#
# Epoch: 3/500 	Training Loss: 0.010741
# Lowest MAPE: 0.08570422392903743
#
# Epoch: 4/500 	Training Loss: 0.009468
# Lowest MAPE: 0.08494048043776359
#
# Epoch: 5/500 	Training Loss: 0.008929
# Lowest MAPE: 0.0801828492492284
#
# Epoch: 6/500 	Training Loss: 0.007598
#
# Epoch: 7/500 	Training Loss: 0.009159
#
# Epoch: 8/500 	Training Loss: 0.008290
#
# Epoch: 9/500 	Training Loss: 0.006951
# Lowest MAPE: 0.07216251354882808
#
# Epoch: 10/500 	Training Loss: 0.006310
# Lowest MAPE: 0.07087690505856246
#
# Epoch: 11/500 	Training Loss: 0.005951
# Lowest MAPE: 0.06671986365402016
#
# Epoch: 12/500 	Training Loss: 0.005962
#
# Epoch: 13/500 	Training Loss: 0.006410
# Lowest MAPE: 0.06249467195480837
#
# Epoch: 14/500 	Training Loss: 0.005698
#
# Epoch: 15/500 	Training Loss: 0.006048
#
# Epoch: 16/500 	Training Loss: 0.005239
#
# Epoch: 17/500 	Training Loss: 0.005187
#
# Epoch: 18/500 	Training Loss: 0.005425
#
# Epoch: 19/500 	Training Loss: 0.005132
#
# Epoch: 20/500 	Training Loss: 0.005064
#
# Epoch: 21/500 	Training Loss: 0.005250
#
# Epoch: 22/500 	Training Loss: 0.005352
#
# Epoch: 23/500 	Training Loss: 0.005522
#
# Epoch: 24/500 	Training Loss: 0.005178
#
# Epoch: 25/500 	Training Loss: 0.006709
#
# Epoch: 26/500 	Training Loss: 0.004509
#
# Epoch: 27/500 	Training Loss: 0.004853
# Lowest MAPE: 0.060787456085603556
#
# Epoch: 28/500 	Training Loss: 0.004704
#
# Epoch: 29/500 	Training Loss: 0.004813
#
# Epoch: 30/500 	Training Loss: 0.004364
#
# Epoch: 31/500 	Training Loss: 0.004503
#
# Epoch: 32/500 	Training Loss: 0.004739
#
# Epoch: 33/500 	Training Loss: 0.005583
#
# Epoch: 34/500 	Training Loss: 0.004146
# Lowest MAPE: 0.05909485215169582
#
# Epoch: 35/500 	Training Loss: 0.004246
#
# Epoch: 36/500 	Training Loss: 0.004651
#
# Epoch: 37/500 	Training Loss: 0.005074
#
# Epoch: 38/500 	Training Loss: 0.004943
#
# Epoch: 39/500 	Training Loss: 0.003955
#
# Epoch: 40/500 	Training Loss: 0.004882
#
# Epoch: 41/500 	Training Loss: 0.003917
#
# Epoch: 42/500 	Training Loss: 0.004157
#
# Epoch: 43/500 	Training Loss: 0.004581
#
# Epoch: 44/500 	Training Loss: 0.004568
#
# Epoch: 45/500 	Training Loss: 0.005855
#
# Epoch: 46/500 	Training Loss: 0.004501
#
# Epoch: 47/500 	Training Loss: 0.004907
#
# Epoch: 48/500 	Training Loss: 0.004503
#
# Epoch: 49/500 	Training Loss: 0.005336
#
# Epoch: 50/500 	Training Loss: 0.003883
#
# Epoch: 51/500 	Training Loss: 0.004953
# Lowest MAPE: 0.05759493394873077
#
# Epoch: 52/500 	Training Loss: 0.004100
#
# Epoch: 53/500 	Training Loss: 0.004397
#
# Epoch: 54/500 	Training Loss: 0.004266
#
# Epoch: 55/500 	Training Loss: 0.003737
#
# Epoch: 56/500 	Training Loss: 0.003990
#
# Epoch: 57/500 	Training Loss: 0.004128
# Lowest MAPE: 0.05648927500018503
#
# Epoch: 58/500 	Training Loss: 0.004563
#
# Epoch: 59/500 	Training Loss: 0.004295
#
# Epoch: 60/500 	Training Loss: 0.004017
#
# Epoch: 61/500 	Training Loss: 0.004681
#
# Epoch: 62/500 	Training Loss: 0.004333
#
# Epoch: 63/500 	Training Loss: 0.004728
#
# Epoch: 64/500 	Training Loss: 0.003997
#
# Epoch: 65/500 	Training Loss: 0.003750
#
# Epoch: 66/500 	Training Loss: 0.004068
#
# Epoch: 67/500 	Training Loss: 0.004422
#
# Epoch: 68/500 	Training Loss: 0.004434
#
# Epoch: 69/500 	Training Loss: 0.004092
#
# Epoch: 70/500 	Training Loss: 0.004009
#
# Epoch: 71/500 	Training Loss: 0.003726
#
# Epoch: 72/500 	Training Loss: 0.003609
#
# Epoch: 73/500 	Training Loss: 0.004756
#
# Epoch: 74/500 	Training Loss: 0.004822
#
# Epoch: 75/500 	Training Loss: 0.004288
#
# Epoch: 76/500 	Training Loss: 0.003723
#
# Epoch: 77/500 	Training Loss: 0.004140
#
# Epoch: 78/500 	Training Loss: 0.004014
#
# Epoch: 79/500 	Training Loss: 0.003759
#
# Epoch: 80/500 	Training Loss: 0.003882
#
# Epoch: 81/500 	Training Loss: 0.003922
# Lowest MAPE: 0.055686787279028385
#
# Epoch: 82/500 	Training Loss: 0.003561
#
# Epoch: 83/500 	Training Loss: 0.004010
#
# Epoch: 84/500 	Training Loss: 0.003973
#
# Epoch: 85/500 	Training Loss: 0.003740
#
# Epoch: 86/500 	Training Loss: 0.003670
#
# Epoch: 87/500 	Training Loss: 0.007109
#
# Epoch: 88/500 	Training Loss: 0.105025
#
# Epoch: 89/500 	Training Loss: 0.011696
#
# Epoch: 90/500 	Training Loss: 0.006787
#
# Epoch: 91/500 	Training Loss: 0.006203
#
# Epoch: 92/500 	Training Loss: 0.005249
#
# Epoch: 93/500 	Training Loss: 0.005643
#
# Epoch: 94/500 	Training Loss: 0.004580
#
# Epoch: 95/500 	Training Loss: 0.005592
#
# Epoch: 96/500 	Training Loss: 0.004422
#
# Epoch: 97/500 	Training Loss: 0.004559
#
# Epoch: 98/500 	Training Loss: 0.005132
#
# Epoch: 99/500 	Training Loss: 0.004157
#
# Epoch: 100/500 	Training Loss: 0.004085
#
# Epoch: 101/500 	Training Loss: 0.004272
#
# Epoch: 102/500 	Training Loss: 0.004187
#
# Epoch: 103/500 	Training Loss: 0.004123
#
# Epoch: 104/500 	Training Loss: 0.004235
# Lowest MAPE: 0.05546964504711958
#
# Epoch: 105/500 	Training Loss: 0.003690
#
# Epoch: 106/500 	Training Loss: 0.004248
#
# Epoch: 107/500 	Training Loss: 0.003674
#
# Epoch: 108/500 	Training Loss: 0.003535
#
# Epoch: 109/500 	Training Loss: 0.004136
#
# Epoch: 110/500 	Training Loss: 0.004202
#
# Epoch: 111/500 	Training Loss: 0.004248
#
# Epoch: 112/500 	Training Loss: 0.004019
#
# Epoch: 113/500 	Training Loss: 0.003872
#
# Epoch: 114/500 	Training Loss: 0.004006
#
# Epoch: 115/500 	Training Loss: 0.004170
# Lowest MAPE: 0.05454509416171818
#
# Epoch: 116/500 	Training Loss: 0.003607
#
# Epoch: 117/500 	Training Loss: 0.003774
#
# Epoch: 118/500 	Training Loss: 0.003694
#
# Epoch: 119/500 	Training Loss: 0.003760
#
# Epoch: 120/500 	Training Loss: 0.004858
#
# Epoch: 121/500 	Training Loss: 0.003851
#
# Epoch: 122/500 	Training Loss: 0.003430
#
# Epoch: 123/500 	Training Loss: 0.004240
#
# Epoch: 124/500 	Training Loss: 0.003607
#
# Epoch: 125/500 	Training Loss: 0.003430
#
# Epoch: 126/500 	Training Loss: 0.003517
#
# Epoch: 127/500 	Training Loss: 0.004334
#
# Epoch: 128/500 	Training Loss: 0.004159
#
# Epoch: 129/500 	Training Loss: 0.004115
#
# Epoch: 130/500 	Training Loss: 0.003940
#
# Epoch: 131/500 	Training Loss: 0.003475
#
# Epoch: 132/500 	Training Loss: 0.003517
#
# Epoch: 133/500 	Training Loss: 0.004695
#
# Epoch: 134/500 	Training Loss: 0.003519
#
# Epoch: 135/500 	Training Loss: 0.003853
#
# Epoch: 136/500 	Training Loss: 0.004873
#
# Epoch: 137/500 	Training Loss: 0.003610
#
# Epoch: 138/500 	Training Loss: 0.003817
#
# Epoch: 139/500 	Training Loss: 0.003112
#
# Epoch: 140/500 	Training Loss: 0.003717
#
# Epoch: 141/500 	Training Loss: 0.003259
#
# Epoch: 142/500 	Training Loss: 0.003333
#
# Epoch: 143/500 	Training Loss: 0.004054
#
# Epoch: 144/500 	Training Loss: 0.010539
#
# Epoch: 145/500 	Training Loss: 0.003823
#
# Epoch: 146/500 	Training Loss: 0.004614
#
# Epoch: 147/500 	Training Loss: 0.003848
#
# Epoch: 148/500 	Training Loss: 0.003716
#
# Epoch: 149/500 	Training Loss: 0.004021
#
# Epoch: 150/500 	Training Loss: 0.003678
#
# Epoch: 151/500 	Training Loss: 0.003589
#
# Epoch: 152/500 	Training Loss: 0.004166
#
# Epoch: 153/500 	Training Loss: 0.003185
#
# Epoch: 154/500 	Training Loss: 0.003527
#
# Epoch: 155/500 	Training Loss: 0.003294
#
# Epoch: 156/500 	Training Loss: 0.004381
#
# Epoch: 157/500 	Training Loss: 0.003474
#
# Epoch: 158/500 	Training Loss: 0.003220
#
# Epoch: 159/500 	Training Loss: 0.004286
#
# Epoch: 160/500 	Training Loss: 0.003615
#
# Epoch: 161/500 	Training Loss: 0.004091
#
# Epoch: 162/500 	Training Loss: 0.003252
#
# Epoch: 163/500 	Training Loss: 0.003889
#
# Epoch: 164/500 	Training Loss: 0.003684
#
# Epoch: 165/500 	Training Loss: 0.003942
#
# Epoch: 166/500 	Training Loss: 0.003883
#
# Epoch: 167/500 	Training Loss: 0.004084
#
# Epoch: 168/500 	Training Loss: 0.003318
#
# Epoch: 169/500 	Training Loss: 0.004142
#
# Epoch: 170/500 	Training Loss: 0.004250
#
# Epoch: 171/500 	Training Loss: 0.003251
#
# Epoch: 172/500 	Training Loss: 0.003811
#
# Epoch: 173/500 	Training Loss: 0.003437
#
# Epoch: 174/500 	Training Loss: 0.003617
#
# Epoch: 175/500 	Training Loss: 0.004386
#
# Epoch: 176/500 	Training Loss: 0.003899
#
# Epoch: 177/500 	Training Loss: 0.003324
#
# Epoch: 178/500 	Training Loss: 0.003953
#
# Epoch: 179/500 	Training Loss: 0.003373
#
# Epoch: 180/500 	Training Loss: 0.003349
#
# Epoch: 181/500 	Training Loss: 0.004034
#
# Epoch: 182/500 	Training Loss: 0.003916
#
# Epoch: 183/500 	Training Loss: 0.003695
#
# Epoch: 184/500 	Training Loss: 0.004131
#
# Epoch: 185/500 	Training Loss: 0.003935
#
# Epoch: 186/500 	Training Loss: 0.003519
#
# Epoch: 187/500 	Training Loss: 0.003582
#
# Epoch: 188/500 	Training Loss: 0.003798
#
# Epoch: 189/500 	Training Loss: 0.003525
#
# Epoch: 190/500 	Training Loss: 0.003238
#
# Epoch: 191/500 	Training Loss: 0.005197
#
# Epoch: 192/500 	Training Loss: 0.003993
#
# Epoch: 193/500 	Training Loss: 0.004788
#
# Epoch: 194/500 	Training Loss: 0.004140
#
# Epoch: 195/500 	Training Loss: 0.003442
#
# Epoch: 196/500 	Training Loss: 0.004047
#
# Epoch: 197/500 	Training Loss: 0.003697
#
# Epoch: 198/500 	Training Loss: 0.003895
#
# Epoch: 199/500 	Training Loss: 0.004258
#
# Epoch: 200/500 	Training Loss: 0.003766
#
# Epoch: 201/500 	Training Loss: 0.003423
#
# Epoch: 202/500 	Training Loss: 0.003352
#
# Epoch: 203/500 	Training Loss: 0.003326
#
# Epoch: 204/500 	Training Loss: 0.003585
#
# Epoch: 205/500 	Training Loss: 0.003539
#
# Epoch: 206/500 	Training Loss: 0.003820
#
# Epoch: 207/500 	Training Loss: 0.004254
#
# Epoch: 208/500 	Training Loss: 0.003662
# Lowest MAPE: 0.05423319513551315
#
# Epoch: 209/500 	Training Loss: 0.004730
#
# Epoch: 210/500 	Training Loss: 0.007683
#
# Epoch: 211/500 	Training Loss: 0.004121
#
# Epoch: 212/500 	Training Loss: 0.003303
#
# Epoch: 213/500 	Training Loss: 0.003959
#
# Epoch: 214/500 	Training Loss: 0.003517
#
# Epoch: 215/500 	Training Loss: 0.003420
#
# Epoch: 216/500 	Training Loss: 0.003934
#
# Epoch: 217/500 	Training Loss: 0.003919
#
# Epoch: 218/500 	Training Loss: 0.003466
#
# Epoch: 219/500 	Training Loss: 0.003790
#
# Epoch: 220/500 	Training Loss: 0.003344
#
# Epoch: 221/500 	Training Loss: 0.003395
#
# Epoch: 222/500 	Training Loss: 0.003160
#
# Epoch: 223/500 	Training Loss: 0.003320
#
# Epoch: 224/500 	Training Loss: 0.003814
#
# Epoch: 225/500 	Training Loss: 0.003708
#
# Epoch: 226/500 	Training Loss: 0.003834
#
# Epoch: 227/500 	Training Loss: 0.003186
#
# Epoch: 228/500 	Training Loss: 0.007203
#
# Epoch: 229/500 	Training Loss: 0.004521
#
# Epoch: 230/500 	Training Loss: 0.003135
#
# Epoch: 231/500 	Training Loss: 0.003076
#
# Epoch: 232/500 	Training Loss: 0.004118
#
# Epoch: 233/500 	Training Loss: 0.003501
#
# Epoch: 234/500 	Training Loss: 0.003994
# Lowest MAPE: 0.05412578642151287
#
# Epoch: 235/500 	Training Loss: 0.003423
#
# Epoch: 236/500 	Training Loss: 0.003644
#
# Epoch: 237/500 	Training Loss: 0.003687
#
# Epoch: 238/500 	Training Loss: 0.003284
#
# Epoch: 239/500 	Training Loss: 0.003722
#
# Epoch: 240/500 	Training Loss: 0.003474
#
# Epoch: 241/500 	Training Loss: 0.003372
#
# Epoch: 242/500 	Training Loss: 0.003569
#
# Epoch: 243/500 	Training Loss: 0.003118
#
# Epoch: 244/500 	Training Loss: 0.003487
#
# Epoch: 245/500 	Training Loss: 0.003440
#
# Epoch: 246/500 	Training Loss: 0.003377
#
# Epoch: 247/500 	Training Loss: 0.004053
#
# Epoch: 248/500 	Training Loss: 0.004729
#
# Epoch: 249/500 	Training Loss: 0.005166
#
# Epoch: 250/500 	Training Loss: 0.004272
#
# Epoch: 251/500 	Training Loss: 0.003727
#
# Epoch: 252/500 	Training Loss: 0.004136
#
# Epoch: 253/500 	Training Loss: 0.003937
#
# Epoch: 254/500 	Training Loss: 0.003577
#
# Epoch: 255/500 	Training Loss: 0.003840
#
# Epoch: 256/500 	Training Loss: 0.003467
#
# Epoch: 257/500 	Training Loss: 0.003914
#
# Epoch: 258/500 	Training Loss: 0.003361
#
# Epoch: 259/500 	Training Loss: 0.003000
#
# Epoch: 260/500 	Training Loss: 0.003295
#
# Epoch: 261/500 	Training Loss: 0.003841
#
# Epoch: 262/500 	Training Loss: 0.003278
#
# Epoch: 263/500 	Training Loss: 0.003461
#
# Epoch: 264/500 	Training Loss: 0.003902
#
# Epoch: 265/500 	Training Loss: 0.003611
#
# Epoch: 266/500 	Training Loss: 0.003269
# Lowest MAPE: 0.053983710144493116
#
# Epoch: 267/500 	Training Loss: 0.003163
#
# Epoch: 268/500 	Training Loss: 0.004049
#
# Epoch: 269/500 	Training Loss: 0.003383
#
# Epoch: 270/500 	Training Loss: 0.003662
#
# Epoch: 271/500 	Training Loss: 0.004229
#
# Epoch: 272/500 	Training Loss: 0.003098
#
# Epoch: 273/500 	Training Loss: 0.003239
#
# Epoch: 274/500 	Training Loss: 0.003662
#
# Epoch: 275/500 	Training Loss: 0.003087
#
# Epoch: 276/500 	Training Loss: 0.003768
#
# Epoch: 277/500 	Training Loss: 0.004905
#
# Epoch: 278/500 	Training Loss: 0.003419
#
# Epoch: 279/500 	Training Loss: 0.004257
#
# Epoch: 280/500 	Training Loss: 0.004421
#
# Epoch: 281/500 	Training Loss: 0.005319
#
# Epoch: 282/500 	Training Loss: 0.004216
#
# Epoch: 283/500 	Training Loss: 0.003605
#
# Epoch: 284/500 	Training Loss: 0.003566
#
# Epoch: 285/500 	Training Loss: 0.003365
#
# Epoch: 286/500 	Training Loss: 0.003334
#
# Epoch: 287/500 	Training Loss: 0.003797
#
# Epoch: 288/500 	Training Loss: 0.003171
#
# Epoch: 289/500 	Training Loss: 0.003651
#
# Epoch: 290/500 	Training Loss: 0.003757
#
# Epoch: 291/500 	Training Loss: 0.003388
#
# Epoch: 292/500 	Training Loss: 0.004228
#
# Epoch: 293/500 	Training Loss: 0.003683
#
# Epoch: 294/500 	Training Loss: 0.004101
#
# Epoch: 295/500 	Training Loss: 0.003646
#
# Epoch: 296/500 	Training Loss: 0.004284
#
# Epoch: 297/500 	Training Loss: 0.004077
#
# Epoch: 298/500 	Training Loss: 0.003350
#
# Epoch: 299/500 	Training Loss: 0.003263
#
# Epoch: 300/500 	Training Loss: 0.003467
#
# Epoch: 301/500 	Training Loss: 0.003383
#
# Epoch: 302/500 	Training Loss: 0.003627
#
# Epoch: 303/500 	Training Loss: 0.003655
#
# Epoch: 304/500 	Training Loss: 0.003201
#
# Epoch: 305/500 	Training Loss: 0.003460
#
# Epoch: 306/500 	Training Loss: 0.003675
#
# Epoch: 307/500 	Training Loss: 0.003405
#
# Epoch: 308/500 	Training Loss: 0.003173
#
# Epoch: 309/500 	Training Loss: 0.004814
#
# Epoch: 310/500 	Training Loss: 0.007126
#
# Epoch: 311/500 	Training Loss: 0.004405
#
# Epoch: 312/500 	Training Loss: 0.004101
#
# Epoch: 313/500 	Training Loss: 0.003401
#
# Epoch: 314/500 	Training Loss: 0.004057
#
# Epoch: 315/500 	Training Loss: 0.003121
#
# Epoch: 316/500 	Training Loss: 0.003693
#
# Epoch: 317/500 	Training Loss: 0.003353
#
# Epoch: 318/500 	Training Loss: 0.003455
#
# Epoch: 319/500 	Training Loss: 0.003098
#
# Epoch: 320/500 	Training Loss: 0.003085
#
# Epoch: 321/500 	Training Loss: 0.003323
#
# Epoch: 322/500 	Training Loss: 0.003632
#
# Epoch: 323/500 	Training Loss: 0.004126
#
# Epoch: 324/500 	Training Loss: 0.003276
#
# Epoch: 325/500 	Training Loss: 0.003055
#
# Epoch: 326/500 	Training Loss: 0.003365
#
# Epoch: 327/500 	Training Loss: 0.003680
#
# Epoch: 328/500 	Training Loss: 0.005596
#
# Epoch: 329/500 	Training Loss: 0.003305
#
# Epoch: 330/500 	Training Loss: 0.003800
#
# Epoch: 331/500 	Training Loss: 0.003259
#
# Epoch: 332/500 	Training Loss: 0.003130
#
# Epoch: 333/500 	Training Loss: 0.003775
#
# Epoch: 334/500 	Training Loss: 0.003253
#
# Epoch: 335/500 	Training Loss: 0.003831
#
# Epoch: 336/500 	Training Loss: 0.003083
#
# Epoch: 337/500 	Training Loss: 0.003173
#
# Epoch: 338/500 	Training Loss: 0.003723
#
# Epoch: 339/500 	Training Loss: 0.003655
#
# Epoch: 340/500 	Training Loss: 0.003063
#
# Epoch: 341/500 	Training Loss: 0.003885
#
# Epoch: 342/500 	Training Loss: 0.003412
#
# Epoch: 343/500 	Training Loss: 0.004055
#
# Epoch: 344/500 	Training Loss: 0.004564
#
# Epoch: 345/500 	Training Loss: 0.004107
#
# Epoch: 346/500 	Training Loss: 0.003959
#
# Epoch: 347/500 	Training Loss: 0.003391
#
# Epoch: 348/500 	Training Loss: 0.003271
#
# Epoch: 349/500 	Training Loss: 0.003709
#
# Epoch: 350/500 	Training Loss: 0.005305
#
# Epoch: 351/500 	Training Loss: 0.003403
#
# Epoch: 352/500 	Training Loss: 0.004212
#
# Epoch: 353/500 	Training Loss: 0.003222
#
# Epoch: 354/500 	Training Loss: 0.003989
#
# Epoch: 355/500 	Training Loss: 0.003140
#
# Epoch: 356/500 	Training Loss: 0.003990
#
# Epoch: 357/500 	Training Loss: 0.003671
#
# Epoch: 358/500 	Training Loss: 0.003665
#
# Epoch: 359/500 	Training Loss: 0.003350
#
# Epoch: 360/500 	Training Loss: 0.003460
#
# Epoch: 361/500 	Training Loss: 0.003742
#
# Epoch: 362/500 	Training Loss: 0.003760
#
# Epoch: 363/500 	Training Loss: 0.006963
#
# Epoch: 364/500 	Training Loss: 0.003540
#
# Epoch: 365/500 	Training Loss: 0.003467
#
# Epoch: 366/500 	Training Loss: 0.003548
#
# Epoch: 367/500 	Training Loss: 0.003642
#
# Epoch: 368/500 	Training Loss: 0.003814
#
# Epoch: 369/500 	Training Loss: 0.003954
#
# Epoch: 370/500 	Training Loss: 0.003596
#
# Epoch: 371/500 	Training Loss: 0.003106
#
# Epoch: 372/500 	Training Loss: 0.003468
#
# Epoch: 373/500 	Training Loss: 0.003332
#
# Epoch: 374/500 	Training Loss: 0.003617
#
# Epoch: 375/500 	Training Loss: 0.003678
#
# Epoch: 376/500 	Training Loss: 0.003874
#
# Epoch: 377/500 	Training Loss: 0.004058
#
# Epoch: 378/500 	Training Loss: 0.003408
#
# Epoch: 379/500 	Training Loss: 0.002958
#
# Epoch: 380/500 	Training Loss: 0.003208
#
# Epoch: 381/500 	Training Loss: 0.003492
#
# Epoch: 382/500 	Training Loss: 0.003860
#
# Epoch: 383/500 	Training Loss: 0.004016
#
# Epoch: 384/500 	Training Loss: 0.003698
#
# Epoch: 385/500 	Training Loss: 0.003817
#
# Epoch: 386/500 	Training Loss: 0.003947
#
# Epoch: 387/500 	Training Loss: 0.003707
#
# Epoch: 388/500 	Training Loss: 0.003545
#
# Epoch: 389/500 	Training Loss: 0.003723
#
# Epoch: 390/500 	Training Loss: 0.003793
#
# Epoch: 391/500 	Training Loss: 0.003290
#
# Epoch: 392/500 	Training Loss: 0.003670
#
# Epoch: 393/500 	Training Loss: 0.003229
#
# Epoch: 394/500 	Training Loss: 0.003099
#
# Epoch: 395/500 	Training Loss: 0.003243
#
# Epoch: 396/500 	Training Loss: 0.003339
#
# Epoch: 397/500 	Training Loss: 0.132316
#
# Epoch: 398/500 	Training Loss: 0.013638
#
# Epoch: 399/500 	Training Loss: 0.007274
#
# Epoch: 400/500 	Training Loss: 0.006422
# Lowest MAPE: 0.053553627834161156
#
# Epoch: 401/500 	Training Loss: 0.005577
#
# Epoch: 402/500 	Training Loss: 0.005375
#
# Epoch: 403/500 	Training Loss: 0.005796
#
# Epoch: 404/500 	Training Loss: 0.004736
#
# Epoch: 405/500 	Training Loss: 0.004865
#
# Epoch: 406/500 	Training Loss: 0.004261
# Lowest MAPE: 0.05349643392379273
#
# Epoch: 407/500 	Training Loss: 0.004259
#
# Epoch: 408/500 	Training Loss: 0.004210
#
# Epoch: 409/500 	Training Loss: 0.004237
#
# Epoch: 410/500 	Training Loss: 0.003958
#
# Epoch: 411/500 	Training Loss: 0.004380
#
# Epoch: 412/500 	Training Loss: 0.004149
#
# Epoch: 413/500 	Training Loss: 0.003834
#
# Epoch: 414/500 	Training Loss: 0.003868
#
# Epoch: 415/500 	Training Loss: 0.003666
#
# Epoch: 416/500 	Training Loss: 0.003959
#
# Epoch: 417/500 	Training Loss: 0.003934
#
# Epoch: 418/500 	Training Loss: 0.004431
# Lowest MAPE: 0.05295990196190726
#
# Epoch: 419/500 	Training Loss: 0.003731
#
# Epoch: 420/500 	Training Loss: 0.003649
#
# Epoch: 421/500 	Training Loss: 0.004010
#
# Epoch: 422/500 	Training Loss: 0.003722
#
# Epoch: 423/500 	Training Loss: 0.003571
#
# Epoch: 424/500 	Training Loss: 0.003706
#
# Epoch: 425/500 	Training Loss: 0.003793
#
# Epoch: 426/500 	Training Loss: 0.003945
#
# Epoch: 427/500 	Training Loss: 0.004061
#
# Epoch: 428/500 	Training Loss: 0.004027
#
# Epoch: 429/500 	Training Loss: 0.003628
#
# Epoch: 430/500 	Training Loss: 0.003505
#
# Epoch: 431/500 	Training Loss: 0.004268
#
# Epoch: 432/500 	Training Loss: 0.003775
#
# Epoch: 433/500 	Training Loss: 0.003454
#
# Epoch: 434/500 	Training Loss: 0.003428
#
# Epoch: 435/500 	Training Loss: 0.003656
#
# Epoch: 436/500 	Training Loss: 0.004122
#
# Epoch: 437/500 	Training Loss: 0.003570
#
# Epoch: 438/500 	Training Loss: 0.003917
#
# Epoch: 439/500 	Training Loss: 0.003370
#
# Epoch: 440/500 	Training Loss: 0.003974
#
# Epoch: 441/500 	Training Loss: 0.003971
#
# Epoch: 442/500 	Training Loss: 0.003451
#
# Epoch: 443/500 	Training Loss: 0.003523
#
# Epoch: 444/500 	Training Loss: 0.003493
#
# Epoch: 445/500 	Training Loss: 0.003858
#
# Epoch: 446/500 	Training Loss: 0.003739
#
# Epoch: 447/500 	Training Loss: 0.003620
#
# Epoch: 448/500 	Training Loss: 0.003637
#
# Epoch: 449/500 	Training Loss: 0.003827
#
# Epoch: 450/500 	Training Loss: 0.003795
#
# Epoch: 451/500 	Training Loss: 0.004017
#
# Epoch: 452/500 	Training Loss: 0.003486
#
# Epoch: 453/500 	Training Loss: 0.003470
#
# Epoch: 454/500 	Training Loss: 0.003361
#
# Epoch: 455/500 	Training Loss: 0.004061
#
# Epoch: 456/500 	Training Loss: 0.003346
#
# Epoch: 457/500 	Training Loss: 0.003446
#
# Epoch: 458/500 	Training Loss: 0.004030
#
# Epoch: 459/500 	Training Loss: 0.003429
#
# Epoch: 460/500 	Training Loss: 0.004076
#
# Epoch: 461/500 	Training Loss: 0.004633
#
# Epoch: 462/500 	Training Loss: 0.004117
#
# Epoch: 463/500 	Training Loss: 0.004627
#
# Epoch: 464/500 	Training Loss: 0.004028
#
# Epoch: 465/500 	Training Loss: 0.003781
#
# Epoch: 466/500 	Training Loss: 0.004313
#
# Epoch: 467/500 	Training Loss: 0.004013
#
# Epoch: 468/500 	Training Loss: 0.003426
#
# Epoch: 469/500 	Training Loss: 0.003556
#
# Epoch: 470/500 	Training Loss: 0.003360
#
# Epoch: 471/500 	Training Loss: 0.003291
#
# Epoch: 472/500 	Training Loss: 0.003631
#
# Epoch: 473/500 	Training Loss: 0.003668
#
# Epoch: 474/500 	Training Loss: 0.003332
#
# Epoch: 475/500 	Training Loss: 0.003673
#
# Epoch: 476/500 	Training Loss: 0.003301
#
# Epoch: 477/500 	Training Loss: 0.003409
#
# Epoch: 478/500 	Training Loss: 0.003583
#
# Epoch: 479/500 	Training Loss: 0.004301
#
# Epoch: 480/500 	Training Loss: 0.004139
#
# Epoch: 481/500 	Training Loss: 0.003917
#
# Epoch: 482/500 	Training Loss: 0.003302
#
# Epoch: 483/500 	Training Loss: 0.003789
#
# Epoch: 484/500 	Training Loss: 0.004135
#
# Epoch: 485/500 	Training Loss: 0.003492
#
# Epoch: 486/500 	Training Loss: 0.003803
#
# Epoch: 487/500 	Training Loss: 0.003933
#
# Epoch: 488/500 	Training Loss: 0.003500
#
# Epoch: 489/500 	Training Loss: 0.003706
# Lowest MAPE: 0.05263773384829169
#
# Epoch: 490/500 	Training Loss: 0.003806
#
# Epoch: 491/500 	Training Loss: 0.003813
#
# Epoch: 492/500 	Training Loss: 0.004101
#
# Epoch: 493/500 	Training Loss: 0.004083
#
# Epoch: 494/500 	Training Loss: 0.003567
#
# Epoch: 495/500 	Training Loss: 0.003288
#
# Epoch: 496/500 	Training Loss: 0.004348
#
# Epoch: 497/500 	Training Loss: 0.003685
#
# Epoch: 498/500 	Training Loss: 0.004188
#
# Epoch: 499/500 	Training Loss: 0.004210
#
# Epoch: 500/500 	Training Loss: 0.003646
#
# Time taken: 101.8820923000003

# %%
plt.plot(train_losses)

# %%
model.load_state_dict(torch.load('PyTorch_Model/Single_PositiveImpulse_lowest.pt', map_location=torch.device('cpu')))

model.eval()           # prep model for *evaluation*
model.to(device)
with torch.no_grad():  # turn off gradient to save memory
    y_predNN_torch = model(X_test_torch.to(device))

y_predNN_normal = y_predNN_torch.cpu().numpy()     # convert to numpy array
y_test_normal = y_test_torch.cpu().numpy()



print(y_predNN_normal)
# Out:
# [[-0.11350129]
#  [-0.2304585 ]
#  [-0.33345497]
#  ...
#  [-0.43256742]
#  [-0.45888647]
#  [-0.48455507]]

# %%
mape = mean_absolute_percentage_error(y_test_normal, y_predNN_normal)
r2 = r2_score(y_test_normal, y_predNN_normal)
rmse = np.sqrt(mean_squared_error(y_test_normal, y_predNN_normal))
print(f"Scores in normal distribution: r2 = {r2}, mape = {mape}, rmse = {rmse}")
# Out:
# Scores in normal distribution: r2 = 0.9931248064376015, mape = 0.22143767774105072, rmse = 0.0828637182712555

# %%
y_predNN = quantile.inverse_transform(y_predNN_normal)
mape = mean_absolute_percentage_error(y_test, y_predNN)
r2 = r2_score(y_test, y_predNN)
rmse = np.sqrt(mean_squared_error(y_test, y_predNN))


print(f"Scores in actual distribution for positive impulse")
print('r2:', r2*100)
print('mape:', mape*100)
print('rmse:', rmse)
print()
# Out:
# Scores in actual distribution for negative duration
# r2: 97.56266134703755
# mape: 5.263773384829169
# rmse: 15.763427368838805
