# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import timeit
#import shap
from sklearn.metrics import r2_score, mean_absolute_percentage_error, mean_squared_error
from sklearn.model_selection import cross_val_score, GridSearchCV, KFold
from sklearn.model_selection import train_test_split

# %% [markdown]
# ___

# %% [markdown]
# # Read-in and One-Hot Encoding

# %%
df = pd.read_excel("data_new/train.xlsx", sheet_name="positive_pressure")

dt = pd.read_excel("data_new/test.xlsx", sheet_name="positive_pressure")

# %%
# Label encoding 'Status' feature into 0 and 1 
# 0 for Subcooled and 1 for Superheated

from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()

df['Status'] = LE.fit_transform(df['Status'])
dt['Status'] = LE.fit_transform(dt['Status'])

df
# Out:
#          ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0      B291                         13.6          0.665119             1.0
# 1      B291                         13.6          0.665119             1.0
# 2      B291                         13.6          0.665119             1.0
# 3      B291                         13.6          0.665119             1.0
# 4      B291                         13.6          0.665119             1.0
# ...     ...                          ...               ...             ...
# 21595  B103                         30.7          0.181290             0.6
# 21596  B103                         30.7          0.181290             0.6
# 21597  B103                         30.7          0.181290             0.6
# 21598  B103                         30.7          0.181290             0.6
# 21599  B103                         30.7          0.181290             0.6
#
#        Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 0                  4.0              0.8                  1.8
# 1                  4.0              0.8                  1.8
# 2                  4.0              0.8                  1.8
# 3                  4.0              0.8                  1.8
# 4                  4.0              0.8                  1.8
# ...                ...              ...                  ...
# 21595              2.0              2.8                  1.2
# 21596              2.0              2.8                  1.2
# 21597              2.0              2.8                  1.2
# 21598              2.0              2.8                  1.2
# 21599              2.0              2.8                  1.2
#
#        Tank Height with Gas (m)   Vapour Temerature (K)  \
# 0                           0.4                   435.0
# 1                           0.4                   435.0
# 2                           0.4                   435.0
# 3                           0.4                   435.0
# 4                           0.4                   435.0
# ...                         ...                     ...
# 21595                       2.2                   334.7
# 21596                       2.2                   334.7
# 21597                       2.2                   334.7
# 21598                       2.2                   334.7
# 21599                       2.2                   334.7
#
#         Liquid Temerature (K)  Status  Stand-off Distance    Target
# 0                       372.5       1                   5  0.613341
# 1                       372.5       1                   6  0.485480
# 2                       372.5       1                   7  0.397631
# 3                       372.5       1                   8  0.334425
# 4                       372.5       1                   9  0.287146
# ...                       ...     ...                 ...       ...
# 21595                   404.9       0                  36  0.073998
# 21596                   404.9       0                  37  0.071330
# 21597                   404.9       0                  38  0.068824
# 21598                   404.9       0                  39  0.066467
# 21599                   404.9       0                  40  0.064247
#
# [21600 rows x 13 columns]

# %%
dt.iloc[30:50,:]
# Out:
#       ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 30  P197                     11.55904          0.602823             3.0
# 31  P197                     11.55904          0.602823             3.0
# 32  P197                     11.55904          0.602823             3.0
# 33  P197                     11.55904          0.602823             3.0
# 34  P197                     11.55904          0.602823             3.0
# 35  P197                     11.55904          0.602823             3.0
# 36  P168                     12.72223          0.648320             1.8
# 37  P168                     12.72223          0.648320             1.8
# 38  P168                     12.72223          0.648320             1.8
# 39  P168                     12.72223          0.648320             1.8
# 40  P168                     12.72223          0.648320             1.8
# 41  P168                     12.72223          0.648320             1.8
# 42  P168                     12.72223          0.648320             1.8
# 43  P168                     12.72223          0.648320             1.8
# 44  P168                     12.72223          0.648320             1.8
# 45  P168                     12.72223          0.648320             1.8
# 46  P168                     12.72223          0.648320             1.8
# 47  P168                     12.72223          0.648320             1.8
# 48  P168                     12.72223          0.648320             1.8
# 49  P168                     12.72223          0.648320             1.8
#
#     Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 30              0.8              2.2                  0.2
# 31              0.8              2.2                  0.2
# 32              0.8              2.2                  0.2
# 33              0.8              2.2                  0.2
# 34              0.8              2.2                  0.2
# 35              0.8              2.2                  0.2
# 36              8.2              0.6                  1.8
# 37              8.2              0.6                  1.8
# 38              8.2              0.6                  1.8
# 39              8.2              0.6                  1.8
# 40              8.2              0.6                  1.8
# 41              8.2              0.6                  1.8
# 42              8.2              0.6                  1.8
# 43              8.2              0.6                  1.8
# 44              8.2              0.6                  1.8
# 45              8.2              0.6                  1.8
# 46              8.2              0.6                  1.8
# 47              8.2              0.6                  1.8
# 48              8.2              0.6                  1.8
# 49              8.2              0.6                  1.8
#
#     Tank Height with Gas (m)   Vapour Temerature (K)   Liquid Temerature (K)  \
# 30                       1.0                   296.7                   328.5
# 31                       1.0                   296.7                   328.5
# 32                       1.0                   296.7                   328.5
# 33                       1.0                   296.7                   328.5
# 34                       1.0                   296.7                   328.5
# 35                       1.0                   296.7                   328.5
# 36                       0.2                   389.7                   296.4
# 37                       0.2                   389.7                   296.4
# 38                       0.2                   389.7                   296.4
# 39                       0.2                   389.7                   296.4
# 40                       0.2                   389.7                   296.4
# 41                       0.2                   389.7                   296.4
# 42                       0.2                   389.7                   296.4
# 43                       0.2                   389.7                   296.4
# 44                       0.2                   389.7                   296.4
# 45                       0.2                   389.7                   296.4
# 46                       0.2                   389.7                   296.4
# 47                       0.2                   389.7                   296.4
# 48                       0.2                   389.7                   296.4
# 49                       0.2                   389.7                   296.4
#
#     Status  Stand-off Distance    Target
# 30       1                  35  0.024635
# 31       1                  36  0.023818
# 32       1                  37  0.023049
# 33       1                  38  0.022324
# 34       1                  39  0.021639
# 35       1                  40  0.020991
# 36       0                   5  0.390993
# 37       0                   6  0.341073
# 38       0                   7  0.301264
# 39       0                   8  0.267706
# 40       0                   9  0.239026
# 41       0                  10  0.214537
# 42       0                  11  0.193654
# 43       0                  12  0.175807
# 44       0                  13  0.160474
# 45       0                  14  0.147219
# 46       0                  15  0.135687
# 47       0                  16  0.125592
# 48       0                  17  0.116698
# 49       0                  18  0.108819

# %%
X_traindf = df.drop(['ID','Target'], axis=1)
X_testdf = dt.drop(['ID','Target'], axis=1)

X_traindf
# Out:
#        Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0                             13.6          0.665119             1.0
# 1                             13.6          0.665119             1.0
# 2                             13.6          0.665119             1.0
# 3                             13.6          0.665119             1.0
# 4                             13.6          0.665119             1.0
# ...                            ...               ...             ...
# 21595                         30.7          0.181290             0.6
# 21596                         30.7          0.181290             0.6
# 21597                         30.7          0.181290             0.6
# 21598                         30.7          0.181290             0.6
# 21599                         30.7          0.181290             0.6
#
#        Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 0                  4.0              0.8                  1.8
# 1                  4.0              0.8                  1.8
# 2                  4.0              0.8                  1.8
# 3                  4.0              0.8                  1.8
# 4                  4.0              0.8                  1.8
# ...                ...              ...                  ...
# 21595              2.0              2.8                  1.2
# 21596              2.0              2.8                  1.2
# 21597              2.0              2.8                  1.2
# 21598              2.0              2.8                  1.2
# 21599              2.0              2.8                  1.2
#
#        Tank Height with Gas (m)   Vapour Temerature (K)  \
# 0                           0.4                   435.0
# 1                           0.4                   435.0
# 2                           0.4                   435.0
# 3                           0.4                   435.0
# 4                           0.4                   435.0
# ...                         ...                     ...
# 21595                       2.2                   334.7
# 21596                       2.2                   334.7
# 21597                       2.2                   334.7
# 21598                       2.2                   334.7
# 21599                       2.2                   334.7
#
#         Liquid Temerature (K)  Status  Stand-off Distance
# 0                       372.5       1                   5
# 1                       372.5       1                   6
# 2                       372.5       1                   7
# 3                       372.5       1                   8
# 4                       372.5       1                   9
# ...                       ...     ...                 ...
# 21595                   404.9       0                  36
# 21596                   404.9       0                  37
# 21597                   404.9       0                  38
# 21598                   404.9       0                  39
# 21599                   404.9       0                  40
#
# [21600 rows x 11 columns]

# %%
y_train = df['Target']
y_train
# Out:
# 0        0.613341
# 1        0.485480
# 2        0.397631
# 3        0.334425
# 4        0.287146
#            ...
# 21595    0.073998
# 21596    0.071330
# 21597    0.068824
# 21598    0.066467
# 21599    0.064247
# Name: Target, Length: 21600, dtype: float64

# %%
y_test = dt['Target']

y_test
# Out:
# 0       0.250616
# 1       0.200787
# 2       0.166701
# 3       0.142053
# 4       0.123448
#           ...
# 7195    0.097647
# 7196    0.094047
# 7197    0.090670
# 7198    0.087499
# 7199    0.084514
# Name: Target, Length: 7200, dtype: float64

# %% [markdown]
# ___

# %% [markdown]
# # Standardization and Power Transform

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import QuantileTransformer

# %%
# Processing both X_train and X_test using standardization
scaler = StandardScaler()
X_train = scaler.fit_transform(X_traindf)
X_test = scaler.transform(X_testdf)

# %%
quantile = QuantileTransformer(output_distribution='normal', random_state=42)



y_train_normal = quantile.fit_transform(y_train.values.reshape(-1,1))
y_test_normal = quantile.transform(y_test.values.reshape(-1,1))

# %%
# Visualize the effect of power transformation
f = plt.figure(figsize=(15, 6))

ax = f.add_subplot(121)
sns.distplot(y_train, bins=50, color='r', ax=ax)
ax.set_title('Distribution before processing')

ax=f.add_subplot(122)
sns.distplot(y_train_normal, bins=50, color='b', ax=ax)
ax.set_title('Distribution after quantile processing')
print()
# Out:
# /home/tendou/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/tendou/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ___

# %% [markdown]
# # ANN

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt

torch.backends.cudnn.version() , torch.backends.cudnn.enabled
torch.manual_seed(0)

# %%
# convert data to torch.FloatTensor
X_train_torch = torch.from_numpy(X_train.astype(np.float32))
X_test_torch = torch.from_numpy(X_test.astype(np.float32))



y_train_torch = torch.from_numpy(y_train_normal.astype(np.float32))
y_test_torch = torch.from_numpy(y_test_normal.astype(np.float32))

print(X_train_torch)
# Out:
# tensor([[-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.6846],
#         [-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.5883],
#         [-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.4921],
#         ...,
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.4921],
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.5883],
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.6846]])

# %%
train_data = []
for i in range(len(X_train_torch)):
   train_data.append([X_train_torch[i],
                      y_train_torch[i]
                     ])

test_data = []
for i in range(len(X_test_torch)):
   test_data.append([X_test_torch[i], 
                     y_test_torch[i]
                     ])
   
# prepare data loaders
train_loader = torch.utils.data.DataLoader(train_data, batch_size=512,               # batch_size could be smaller
    num_workers=0, shuffle=True)                                                                   # Increasing num_workers slow down the training because it does not use GPU at all
test_loader = torch.utils.data.DataLoader(test_data, batch_size=512,
    num_workers=0)

# %%
for data, target in train_loader:
    print(data.shape[0] == data.size(0))
    break
# Out:
# True

# %%
## Define the NN architecture
## NN with 3 hidden layer, s=[11, 256, 256, 256, 1]

class BleveNet(nn.Module):
    def __init__(self):
        super(BleveNet, self).__init__()
        # The first hidden layer has 256 neurons
        self.fc1 = nn.Linear(X_train_torch.shape[1], 256)
        # The second hidden layer has 256 neurons
        self.fc2 = nn.Linear(256, 256)
        # The third hidden layer has 256 neurons
        self.fc3 = nn.Linear(256, 256)
        # The final layer has 1 output neuron
        self.fc4 = nn.Linear(256, 1)


        # Define proportion or neurons to dropout
        self.dropout = nn.Dropout(0.1)

        # Mish activation
        self.mish = nn.Mish()


    def forward(self, x):
        # add first fully connected layer
        x = self.fc1(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add second fully connected layer
        x = self.fc2(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add third fully connected layer
        x = self.fc3(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add final output layers:
        output = self.fc4(x)
       
        return output

# initialize the NN
model = BleveNet()
print(model)
# Out:
# BleveNet(
#   (fc1): Linear(in_features=11, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=256, bias=True)
#   (fc4): Linear(in_features=256, out_features=1, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (mish): Mish()
# )

# %%
criterion = nn.HuberLoss()        # This is the best loss function for my model
# criterion = nn.MSELoss()


optimizer = torch.optim.Adam(model.parameters(), lr=0.005, weight_decay=1e-5)     # This is the best optimizer for my model 

# Check for GPU
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
startTime = timeit.default_timer() 

n_epochs = 500 

model.to(device)    # bring the model to gpu

train_losses = []
lowest_mape = 100
for epoch in range(n_epochs):

    model.train()       

    # monitor training loss
    train_loss = 0.0
    
    ###################
    # train the model #
    ###################
    for data, target in train_loader:
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        #bring data and target to gpu
        data, target = data.to(device), target.to(device)
        
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update running training loss
        train_loss += loss.item()*data.size(0)
        
    # print training statistics 
    # calculate average loss over an epoch
    train_loss = train_loss/len(train_loader.dataset)
    train_losses.append(train_loss)

    print('Epoch: {}/{} \tTraining Loss: {:.6f}'.format(
        epoch+1,
        n_epochs, 
        train_loss
        ))
    

    ############################
    # Evaluate the lowest MAPE #
    ############################
    model.eval()
    with torch.no_grad():  # turn off gradient to save memory
        y_predNN_torch = model(X_test_torch.to(device))

    y_predNN = quantile.inverse_transform(y_predNN_torch.cpu().numpy())
    MAPE = mean_absolute_percentage_error(y_test, y_predNN)

    if MAPE < lowest_mape:
        lowest_mape = MAPE
        print(f'Lowest MAPE: {lowest_mape}')
        torch.save(model.state_dict(), 'PyTorch_Model/Single_PositivePressure_lowest.pt')
    print()

endTime = timeit.default_timer()
runningTotal = (endTime - startTime)
print(f"Time taken: {runningTotal}")
# Out:
# Epoch: 1/500 	Training Loss: 0.047864
# Lowest MAPE: 0.1046266739371387
#
# Epoch: 2/500 	Training Loss: 0.012448
# Lowest MAPE: 0.08770782048728007
#
# Epoch: 3/500 	Training Loss: 0.009929
# Lowest MAPE: 0.06988385239919358
#
# Epoch: 4/500 	Training Loss: 0.008882
#
# Epoch: 5/500 	Training Loss: 0.008784
#
# Epoch: 6/500 	Training Loss: 0.007200
#
# Epoch: 7/500 	Training Loss: 0.007504
#
# Epoch: 8/500 	Training Loss: 0.006170
#
# Epoch: 9/500 	Training Loss: 0.006019
#
# Epoch: 10/500 	Training Loss: 0.006191
# Lowest MAPE: 0.06284338455104864
#
# Epoch: 11/500 	Training Loss: 0.005248
# Lowest MAPE: 0.05573452507135933
#
# Epoch: 12/500 	Training Loss: 0.005008
#
# Epoch: 13/500 	Training Loss: 0.005345
#
# Epoch: 14/500 	Training Loss: 0.006866
#
# Epoch: 15/500 	Training Loss: 0.005643
#
# Epoch: 16/500 	Training Loss: 0.004581
#
# Epoch: 17/500 	Training Loss: 0.004831
# Lowest MAPE: 0.05395381479537627
#
# Epoch: 18/500 	Training Loss: 0.004527
#
# Epoch: 19/500 	Training Loss: 0.004762
#
# Epoch: 20/500 	Training Loss: 0.007334
#
# Epoch: 21/500 	Training Loss: 0.004912
#
# Epoch: 22/500 	Training Loss: 0.004038
# Lowest MAPE: 0.05283554044378085
#
# Epoch: 23/500 	Training Loss: 0.004242
#
# Epoch: 24/500 	Training Loss: 0.004266
#
# Epoch: 25/500 	Training Loss: 0.004869
#
# Epoch: 26/500 	Training Loss: 0.004503
#
# Epoch: 27/500 	Training Loss: 0.004677
# Lowest MAPE: 0.05281842908688619
#
# Epoch: 28/500 	Training Loss: 0.003583
#
# Epoch: 29/500 	Training Loss: 0.004220
#
# Epoch: 30/500 	Training Loss: 0.003706
# Lowest MAPE: 0.05100251785371509
#
# Epoch: 31/500 	Training Loss: 0.004434
#
# Epoch: 32/500 	Training Loss: 0.004605
#
# Epoch: 33/500 	Training Loss: 0.003915
#
# Epoch: 34/500 	Training Loss: 0.003729
#
# Epoch: 35/500 	Training Loss: 0.003946
#
# Epoch: 36/500 	Training Loss: 0.004288
#
# Epoch: 37/500 	Training Loss: 0.005558
#
# Epoch: 38/500 	Training Loss: 0.004207
#
# Epoch: 39/500 	Training Loss: 0.004022
#
# Epoch: 40/500 	Training Loss: 0.004022
#
# Epoch: 41/500 	Training Loss: 0.003654
#
# Epoch: 42/500 	Training Loss: 0.003712
#
# Epoch: 43/500 	Training Loss: 0.003989
#
# Epoch: 44/500 	Training Loss: 0.003991
#
# Epoch: 45/500 	Training Loss: 0.004350
#
# Epoch: 46/500 	Training Loss: 0.003683
#
# Epoch: 47/500 	Training Loss: 0.004591
#
# Epoch: 48/500 	Training Loss: 0.004832
#
# Epoch: 49/500 	Training Loss: 0.003614
#
# Epoch: 50/500 	Training Loss: 0.003535
#
# Epoch: 51/500 	Training Loss: 0.006087
#
# Epoch: 52/500 	Training Loss: 0.003712
#
# Epoch: 53/500 	Training Loss: 0.003402
#
# Epoch: 54/500 	Training Loss: 0.003457
#
# Epoch: 55/500 	Training Loss: 0.003570
# Lowest MAPE: 0.05070449205410165
#
# Epoch: 56/500 	Training Loss: 0.003551
#
# Epoch: 57/500 	Training Loss: 0.003388
#
# Epoch: 58/500 	Training Loss: 0.003705
#
# Epoch: 59/500 	Training Loss: 0.003452
# Lowest MAPE: 0.050685204589298476
#
# Epoch: 60/500 	Training Loss: 0.003640
#
# Epoch: 61/500 	Training Loss: 0.004196
#
# Epoch: 62/500 	Training Loss: 0.003639
#
# Epoch: 63/500 	Training Loss: 0.003527
# Lowest MAPE: 0.05010164874216526
#
# Epoch: 64/500 	Training Loss: 0.003649
#
# Epoch: 65/500 	Training Loss: 0.003949
#
# Epoch: 66/500 	Training Loss: 0.003935
#
# Epoch: 67/500 	Training Loss: 0.004805
#
# Epoch: 68/500 	Training Loss: 0.003755
#
# Epoch: 69/500 	Training Loss: 0.003529
# Lowest MAPE: 0.04632417196107882
#
# Epoch: 70/500 	Training Loss: 0.003988
#
# Epoch: 71/500 	Training Loss: 0.003854
#
# Epoch: 72/500 	Training Loss: 0.004360
#
# Epoch: 73/500 	Training Loss: 0.004404
#
# Epoch: 74/500 	Training Loss: 0.003666
#
# Epoch: 75/500 	Training Loss: 0.003797
#
# Epoch: 76/500 	Training Loss: 0.003785
#
# Epoch: 77/500 	Training Loss: 0.003954
#
# Epoch: 78/500 	Training Loss: 0.004264
#
# Epoch: 79/500 	Training Loss: 0.003332
#
# Epoch: 80/500 	Training Loss: 0.003267
#
# Epoch: 81/500 	Training Loss: 0.004978
#
# Epoch: 82/500 	Training Loss: 0.003737
#
# Epoch: 83/500 	Training Loss: 0.003255
# Lowest MAPE: 0.04540262733898394
#
# Epoch: 84/500 	Training Loss: 0.003628
#
# Epoch: 85/500 	Training Loss: 0.003217
#
# Epoch: 86/500 	Training Loss: 0.003180
#
# Epoch: 87/500 	Training Loss: 0.004847
#
# Epoch: 88/500 	Training Loss: 0.003699
#
# Epoch: 89/500 	Training Loss: 0.005994
#
# Epoch: 90/500 	Training Loss: 0.003865
#
# Epoch: 91/500 	Training Loss: 0.003656
#
# Epoch: 92/500 	Training Loss: 0.003577
#
# Epoch: 93/500 	Training Loss: 0.003560
#
# Epoch: 94/500 	Training Loss: 0.003349
#
# Epoch: 95/500 	Training Loss: 0.003470
#
# Epoch: 96/500 	Training Loss: 0.003172
#
# Epoch: 97/500 	Training Loss: 0.004037
#
# Epoch: 98/500 	Training Loss: 0.003022
#
# Epoch: 99/500 	Training Loss: 0.004351
#
# Epoch: 100/500 	Training Loss: 0.003671
#
# Epoch: 101/500 	Training Loss: 0.003529
#
# Epoch: 102/500 	Training Loss: 0.003710
#
# Epoch: 103/500 	Training Loss: 0.003193
#
# Epoch: 104/500 	Training Loss: 0.003524
#
# Epoch: 105/500 	Training Loss: 0.003266
#
# Epoch: 106/500 	Training Loss: 0.003669
#
# Epoch: 107/500 	Training Loss: 0.003301
#
# Epoch: 108/500 	Training Loss: 0.003509
#
# Epoch: 109/500 	Training Loss: 0.004539
#
# Epoch: 110/500 	Training Loss: 0.003052
#
# Epoch: 111/500 	Training Loss: 0.003592
#
# Epoch: 112/500 	Training Loss: 0.003446
#
# Epoch: 113/500 	Training Loss: 0.003617
#
# Epoch: 114/500 	Training Loss: 0.003305
#
# Epoch: 115/500 	Training Loss: 0.003677
#
# Epoch: 116/500 	Training Loss: 0.003470
#
# Epoch: 117/500 	Training Loss: 0.004196
#
# Epoch: 118/500 	Training Loss: 0.003733
#
# Epoch: 119/500 	Training Loss: 0.005017
#
# Epoch: 120/500 	Training Loss: 0.003533
#
# Epoch: 121/500 	Training Loss: 0.003550
#
# Epoch: 122/500 	Training Loss: 0.003181
#
# Epoch: 123/500 	Training Loss: 0.003553
#
# Epoch: 124/500 	Training Loss: 0.003455
#
# Epoch: 125/500 	Training Loss: 0.003630
#
# Epoch: 126/500 	Training Loss: 0.003575
#
# Epoch: 127/500 	Training Loss: 0.003284
#
# Epoch: 128/500 	Training Loss: 0.003493
#
# Epoch: 129/500 	Training Loss: 0.003643
#
# Epoch: 130/500 	Training Loss: 0.003868
#
# Epoch: 131/500 	Training Loss: 0.003945
#
# Epoch: 132/500 	Training Loss: 0.003108
#
# Epoch: 133/500 	Training Loss: 0.003978
#
# Epoch: 134/500 	Training Loss: 0.003316
#
# Epoch: 135/500 	Training Loss: 0.003354
#
# Epoch: 136/500 	Training Loss: 0.003590
#
# Epoch: 137/500 	Training Loss: 0.003969
#
# Epoch: 138/500 	Training Loss: 0.004496
#
# Epoch: 139/500 	Training Loss: 0.003478
#
# Epoch: 140/500 	Training Loss: 0.004032
#
# Epoch: 141/500 	Training Loss: 0.003044
#
# Epoch: 142/500 	Training Loss: 0.003554
#
# Epoch: 143/500 	Training Loss: 0.003165
#
# Epoch: 144/500 	Training Loss: 0.004182
#
# Epoch: 145/500 	Training Loss: 0.004902
#
# Epoch: 146/500 	Training Loss: 0.003580
#
# Epoch: 147/500 	Training Loss: 0.003333
#
# Epoch: 148/500 	Training Loss: 0.003783
#
# Epoch: 149/500 	Training Loss: 0.003749
#
# Epoch: 150/500 	Training Loss: 0.003543
#
# Epoch: 151/500 	Training Loss: 0.002921
#
# Epoch: 152/500 	Training Loss: 0.004017
#
# Epoch: 153/500 	Training Loss: 0.003706
#
# Epoch: 154/500 	Training Loss: 0.004551
#
# Epoch: 155/500 	Training Loss: 0.003257
#
# Epoch: 156/500 	Training Loss: 0.002960
#
# Epoch: 157/500 	Training Loss: 0.003055
#
# Epoch: 158/500 	Training Loss: 0.003136
#
# Epoch: 159/500 	Training Loss: 0.003427
#
# Epoch: 160/500 	Training Loss: 0.003143
#
# Epoch: 161/500 	Training Loss: 0.003551
#
# Epoch: 162/500 	Training Loss: 0.003581
#
# Epoch: 163/500 	Training Loss: 0.004290
#
# Epoch: 164/500 	Training Loss: 0.003746
#
# Epoch: 165/500 	Training Loss: 0.003379
#
# Epoch: 166/500 	Training Loss: 0.003011
#
# Epoch: 167/500 	Training Loss: 0.003271
#
# Epoch: 168/500 	Training Loss: 0.002876
# Lowest MAPE: 0.04209249978321785
#
# Epoch: 169/500 	Training Loss: 0.003237
#
# Epoch: 170/500 	Training Loss: 0.003306
#
# Epoch: 171/500 	Training Loss: 0.003835
#
# Epoch: 172/500 	Training Loss: 0.003530
#
# Epoch: 173/500 	Training Loss: 0.003198
#
# Epoch: 174/500 	Training Loss: 0.003552
#
# Epoch: 175/500 	Training Loss: 0.003281
#
# Epoch: 176/500 	Training Loss: 0.003992
#
# Epoch: 177/500 	Training Loss: 0.004128
#
# Epoch: 178/500 	Training Loss: 0.104921
#
# Epoch: 179/500 	Training Loss: 0.016287
#
# Epoch: 180/500 	Training Loss: 0.007527
#
# Epoch: 181/500 	Training Loss: 0.005592
#
# Epoch: 182/500 	Training Loss: 0.004930
#
# Epoch: 183/500 	Training Loss: 0.004719
#
# Epoch: 184/500 	Training Loss: 0.004599
#
# Epoch: 185/500 	Training Loss: 0.004611
#
# Epoch: 186/500 	Training Loss: 0.004324
#
# Epoch: 187/500 	Training Loss: 0.004417
#
# Epoch: 188/500 	Training Loss: 0.003904
#
# Epoch: 189/500 	Training Loss: 0.003748
#
# Epoch: 190/500 	Training Loss: 0.004138
#
# Epoch: 191/500 	Training Loss: 0.004182
#
# Epoch: 192/500 	Training Loss: 0.003712
#
# Epoch: 193/500 	Training Loss: 0.003822
#
# Epoch: 194/500 	Training Loss: 0.004005
#
# Epoch: 195/500 	Training Loss: 0.004100
#
# Epoch: 196/500 	Training Loss: 0.004209
#
# Epoch: 197/500 	Training Loss: 0.003621
#
# Epoch: 198/500 	Training Loss: 0.003553
#
# Epoch: 199/500 	Training Loss: 0.003411
#
# Epoch: 200/500 	Training Loss: 0.003346
#
# Epoch: 201/500 	Training Loss: 0.003467
#
# Epoch: 202/500 	Training Loss: 0.003581
#
# Epoch: 203/500 	Training Loss: 0.003297
#
# Epoch: 204/500 	Training Loss: 0.003385
#
# Epoch: 205/500 	Training Loss: 0.003304
#
# Epoch: 206/500 	Training Loss: 0.003364
#
# Epoch: 207/500 	Training Loss: 0.003749
#
# Epoch: 208/500 	Training Loss: 0.003407
#
# Epoch: 209/500 	Training Loss: 0.003710
#
# Epoch: 210/500 	Training Loss: 0.003399
#
# Epoch: 211/500 	Training Loss: 0.003270
#
# Epoch: 212/500 	Training Loss: 0.003235
#
# Epoch: 213/500 	Training Loss: 0.003687
#
# Epoch: 214/500 	Training Loss: 0.003700
#
# Epoch: 215/500 	Training Loss: 0.003690
#
# Epoch: 216/500 	Training Loss: 0.003497
#
# Epoch: 217/500 	Training Loss: 0.004173
#
# Epoch: 218/500 	Training Loss: 0.003467
#
# Epoch: 219/500 	Training Loss: 0.003062
#
# Epoch: 220/500 	Training Loss: 0.003192
#
# Epoch: 221/500 	Training Loss: 0.003217
#
# Epoch: 222/500 	Training Loss: 0.003135
#
# Epoch: 223/500 	Training Loss: 0.003648
#
# Epoch: 224/500 	Training Loss: 0.003606
#
# Epoch: 225/500 	Training Loss: 0.003574
#
# Epoch: 226/500 	Training Loss: 0.003472
#
# Epoch: 227/500 	Training Loss: 0.003138
#
# Epoch: 228/500 	Training Loss: 0.003207
#
# Epoch: 229/500 	Training Loss: 0.003376
#
# Epoch: 230/500 	Training Loss: 0.003620
#
# Epoch: 231/500 	Training Loss: 0.003264
#
# Epoch: 232/500 	Training Loss: 0.003480
#
# Epoch: 233/500 	Training Loss: 0.003225
#
# Epoch: 234/500 	Training Loss: 0.003964
#
# Epoch: 235/500 	Training Loss: 0.003852
#
# Epoch: 236/500 	Training Loss: 0.003421
#
# Epoch: 237/500 	Training Loss: 0.003408
#
# Epoch: 238/500 	Training Loss: 0.003118
#
# Epoch: 239/500 	Training Loss: 0.003631
#
# Epoch: 240/500 	Training Loss: 0.003835
#
# Epoch: 241/500 	Training Loss: 0.003698
#
# Epoch: 242/500 	Training Loss: 0.003887
#
# Epoch: 243/500 	Training Loss: 0.003633
#
# Epoch: 244/500 	Training Loss: 0.003343
#
# Epoch: 245/500 	Training Loss: 0.003614
#
# Epoch: 246/500 	Training Loss: 0.003423
#
# Epoch: 247/500 	Training Loss: 0.003157
#
# Epoch: 248/500 	Training Loss: 0.003272
#
# Epoch: 249/500 	Training Loss: 0.003616
#
# Epoch: 250/500 	Training Loss: 0.003342
#
# Epoch: 251/500 	Training Loss: 0.003478
#
# Epoch: 252/500 	Training Loss: 0.003968
#
# Epoch: 253/500 	Training Loss: 0.003607
#
# Epoch: 254/500 	Training Loss: 0.003710
#
# Epoch: 255/500 	Training Loss: 0.003407
#
# Epoch: 256/500 	Training Loss: 0.003101
#
# Epoch: 257/500 	Training Loss: 0.004180
#
# Epoch: 258/500 	Training Loss: 0.003171
#
# Epoch: 259/500 	Training Loss: 0.003363
#
# Epoch: 260/500 	Training Loss: 0.003196
#
# Epoch: 261/500 	Training Loss: 0.003243
#
# Epoch: 262/500 	Training Loss: 0.003462
#
# Epoch: 263/500 	Training Loss: 0.003317
#
# Epoch: 264/500 	Training Loss: 0.003903
#
# Epoch: 265/500 	Training Loss: 0.003550
#
# Epoch: 266/500 	Training Loss: 0.003695
#
# Epoch: 267/500 	Training Loss: 0.003940
#
# Epoch: 268/500 	Training Loss: 0.003488
#
# Epoch: 269/500 	Training Loss: 0.004617
#
# Epoch: 270/500 	Training Loss: 0.003985
#
# Epoch: 271/500 	Training Loss: 0.003769
#
# Epoch: 272/500 	Training Loss: 0.003790
#
# Epoch: 273/500 	Training Loss: 0.003924
#
# Epoch: 274/500 	Training Loss: 0.003675
#
# Epoch: 275/500 	Training Loss: 0.003331
#
# Epoch: 276/500 	Training Loss: 0.003190
#
# Epoch: 277/500 	Training Loss: 0.003197
#
# Epoch: 278/500 	Training Loss: 0.003339
#
# Epoch: 279/500 	Training Loss: 0.004228
#
# Epoch: 280/500 	Training Loss: 0.003451
#
# Epoch: 281/500 	Training Loss: 0.004141
#
# Epoch: 282/500 	Training Loss: 0.003864
#
# Epoch: 283/500 	Training Loss: 0.003509
#
# Epoch: 284/500 	Training Loss: 0.003122
#
# Epoch: 285/500 	Training Loss: 0.003012
#
# Epoch: 286/500 	Training Loss: 0.003542
#
# Epoch: 287/500 	Training Loss: 0.004196
#
# Epoch: 288/500 	Training Loss: 0.004108
#
# Epoch: 289/500 	Training Loss: 0.003261
#
# Epoch: 290/500 	Training Loss: 0.003511
#
# Epoch: 291/500 	Training Loss: 0.003858
#
# Epoch: 292/500 	Training Loss: 0.003340
#
# Epoch: 293/500 	Training Loss: 0.003273
#
# Epoch: 294/500 	Training Loss: 0.003566
#
# Epoch: 295/500 	Training Loss: 0.003831
#
# Epoch: 296/500 	Training Loss: 0.003702
#
# Epoch: 297/500 	Training Loss: 0.003411
#
# Epoch: 298/500 	Training Loss: 0.003772
#
# Epoch: 299/500 	Training Loss: 0.003347
#
# Epoch: 300/500 	Training Loss: 0.003491
#
# Epoch: 301/500 	Training Loss: 0.003282
#
# Epoch: 302/500 	Training Loss: 0.003507
#
# Epoch: 303/500 	Training Loss: 0.003213
#
# Epoch: 304/500 	Training Loss: 0.003270
#
# Epoch: 305/500 	Training Loss: 0.003196
#
# Epoch: 306/500 	Training Loss: 0.003084
#
# Epoch: 307/500 	Training Loss: 0.003263
#
# Epoch: 308/500 	Training Loss: 0.003433
#
# Epoch: 309/500 	Training Loss: 0.003402
#
# Epoch: 310/500 	Training Loss: 0.003470
#
# Epoch: 311/500 	Training Loss: 0.003742
#
# Epoch: 312/500 	Training Loss: 0.003630
#
# Epoch: 313/500 	Training Loss: 0.003324
#
# Epoch: 314/500 	Training Loss: 0.004095
#
# Epoch: 315/500 	Training Loss: 0.003247
#
# Epoch: 316/500 	Training Loss: 0.004735
#
# Epoch: 317/500 	Training Loss: 0.003625
#
# Epoch: 318/500 	Training Loss: 0.003430
#
# Epoch: 319/500 	Training Loss: 0.003161
#
# Epoch: 320/500 	Training Loss: 0.003070
#
# Epoch: 321/500 	Training Loss: 0.003528
#
# Epoch: 322/500 	Training Loss: 0.004089
#
# Epoch: 323/500 	Training Loss: 0.002972
#
# Epoch: 324/500 	Training Loss: 0.003695
#
# Epoch: 325/500 	Training Loss: 0.003762
#
# Epoch: 326/500 	Training Loss: 0.003342
#
# Epoch: 327/500 	Training Loss: 0.002982
#
# Epoch: 328/500 	Training Loss: 0.003090
#
# Epoch: 329/500 	Training Loss: 0.004120
#
# Epoch: 330/500 	Training Loss: 0.003467
#
# Epoch: 331/500 	Training Loss: 0.003682
#
# Epoch: 332/500 	Training Loss: 0.003576
#
# Epoch: 333/500 	Training Loss: 0.003354
#
# Epoch: 334/500 	Training Loss: 0.003354
#
# Epoch: 335/500 	Training Loss: 0.003656
#
# Epoch: 336/500 	Training Loss: 0.003457
#
# Epoch: 337/500 	Training Loss: 0.004207
#
# Epoch: 338/500 	Training Loss: 0.003687
#
# Epoch: 339/500 	Training Loss: 0.003500
#
# Epoch: 340/500 	Training Loss: 0.003063
#
# Epoch: 341/500 	Training Loss: 0.003104
#
# Epoch: 342/500 	Training Loss: 0.003258
#
# Epoch: 343/500 	Training Loss: 0.003205
#
# Epoch: 344/500 	Training Loss: 0.003306
#
# Epoch: 345/500 	Training Loss: 0.003342
#
# Epoch: 346/500 	Training Loss: 0.003213
#
# Epoch: 347/500 	Training Loss: 0.003202
#
# Epoch: 348/500 	Training Loss: 0.003400
#
# Epoch: 349/500 	Training Loss: 0.003275
#
# Epoch: 350/500 	Training Loss: 0.003531
#
# Epoch: 351/500 	Training Loss: 0.003760
#
# Epoch: 352/500 	Training Loss: 0.003342
#
# Epoch: 353/500 	Training Loss: 0.003399
#
# Epoch: 354/500 	Training Loss: 0.003285
#
# Epoch: 355/500 	Training Loss: 0.003618
#
# Epoch: 356/500 	Training Loss: 0.004541
#
# Epoch: 357/500 	Training Loss: 0.003383
#
# Epoch: 358/500 	Training Loss: 0.003788
#
# Epoch: 359/500 	Training Loss: 0.003467
#
# Epoch: 360/500 	Training Loss: 0.003658
#
# Epoch: 361/500 	Training Loss: 0.003360
#
# Epoch: 362/500 	Training Loss: 0.003662
#
# Epoch: 363/500 	Training Loss: 0.003124
#
# Epoch: 364/500 	Training Loss: 0.003717
#
# Epoch: 365/500 	Training Loss: 0.003612
#
# Epoch: 366/500 	Training Loss: 0.003320
#
# Epoch: 367/500 	Training Loss: 0.003404
#
# Epoch: 368/500 	Training Loss: 0.003133
#
# Epoch: 369/500 	Training Loss: 0.003600
#
# Epoch: 370/500 	Training Loss: 0.003869
#
# Epoch: 371/500 	Training Loss: 0.004239
#
# Epoch: 372/500 	Training Loss: 0.003951
#
# Epoch: 373/500 	Training Loss: 0.003694
#
# Epoch: 374/500 	Training Loss: 0.003779
#
# Epoch: 375/500 	Training Loss: 0.003358
#
# Epoch: 376/500 	Training Loss: 0.003749
#
# Epoch: 377/500 	Training Loss: 0.003318
#
# Epoch: 378/500 	Training Loss: 0.003565
#
# Epoch: 379/500 	Training Loss: 0.003545
#
# Epoch: 380/500 	Training Loss: 0.003145
#
# Epoch: 381/500 	Training Loss: 0.003380
#
# Epoch: 382/500 	Training Loss: 0.003126
#
# Epoch: 383/500 	Training Loss: 0.003428
#
# Epoch: 384/500 	Training Loss: 0.003264
#
# Epoch: 385/500 	Training Loss: 0.003372
#
# Epoch: 386/500 	Training Loss: 0.003104
#
# Epoch: 387/500 	Training Loss: 0.003517
#
# Epoch: 388/500 	Training Loss: 0.003652
#
# Epoch: 389/500 	Training Loss: 0.004284
#
# Epoch: 390/500 	Training Loss: 0.003701
#
# Epoch: 391/500 	Training Loss: 0.003025
#
# Epoch: 392/500 	Training Loss: 0.003000
#
# Epoch: 393/500 	Training Loss: 0.003164
#
# Epoch: 394/500 	Training Loss: 0.003241
#
# Epoch: 395/500 	Training Loss: 0.003398
#
# Epoch: 396/500 	Training Loss: 0.003229
#
# Epoch: 397/500 	Training Loss: 0.004916
#
# Epoch: 398/500 	Training Loss: 0.006259
#
# Epoch: 399/500 	Training Loss: 0.003282
#
# Epoch: 400/500 	Training Loss: 0.003366
#
# Epoch: 401/500 	Training Loss: 0.003670
#
# Epoch: 402/500 	Training Loss: 0.003369
#
# Epoch: 403/500 	Training Loss: 0.003170
#
# Epoch: 404/500 	Training Loss: 0.003458
#
# Epoch: 405/500 	Training Loss: 0.003341
#
# Epoch: 406/500 	Training Loss: 0.003070
#
# Epoch: 407/500 	Training Loss: 0.003409
#
# Epoch: 408/500 	Training Loss: 0.004247
#
# Epoch: 409/500 	Training Loss: 0.003570
#
# Epoch: 410/500 	Training Loss: 0.003361
#
# Epoch: 411/500 	Training Loss: 0.003514
#
# Epoch: 412/500 	Training Loss: 0.003234
#
# Epoch: 413/500 	Training Loss: 0.003255
#
# Epoch: 414/500 	Training Loss: 0.003631
#
# Epoch: 415/500 	Training Loss: 0.003336
#
# Epoch: 416/500 	Training Loss: 0.003504
#
# Epoch: 417/500 	Training Loss: 0.003369
#
# Epoch: 418/500 	Training Loss: 0.003500
#
# Epoch: 419/500 	Training Loss: 0.003707
#
# Epoch: 420/500 	Training Loss: 0.003755
#
# Epoch: 421/500 	Training Loss: 0.003379
#
# Epoch: 422/500 	Training Loss: 0.003351
#
# Epoch: 423/500 	Training Loss: 0.003192
#
# Epoch: 424/500 	Training Loss: 0.003313
#
# Epoch: 425/500 	Training Loss: 0.003744
#
# Epoch: 426/500 	Training Loss: 0.003996
#
# Epoch: 427/500 	Training Loss: 0.003926
#
# Epoch: 428/500 	Training Loss: 0.003018
#
# Epoch: 429/500 	Training Loss: 0.003046
#
# Epoch: 430/500 	Training Loss: 0.003160
#
# Epoch: 431/500 	Training Loss: 0.003321
#
# Epoch: 432/500 	Training Loss: 0.003412
#
# Epoch: 433/500 	Training Loss: 0.004418
#
# Epoch: 434/500 	Training Loss: 0.003869
#
# Epoch: 435/500 	Training Loss: 0.003166
#
# Epoch: 436/500 	Training Loss: 0.003378
#
# Epoch: 437/500 	Training Loss: 0.003186
#
# Epoch: 438/500 	Training Loss: 0.003078
#
# Epoch: 439/500 	Training Loss: 0.003366
#
# Epoch: 440/500 	Training Loss: 0.003660
#
# Epoch: 441/500 	Training Loss: 0.003594
#
# Epoch: 442/500 	Training Loss: 0.004022
#
# Epoch: 443/500 	Training Loss: 0.003838
#
# Epoch: 444/500 	Training Loss: 0.003412
#
# Epoch: 445/500 	Training Loss: 0.003500
#
# Epoch: 446/500 	Training Loss: 0.003355
#
# Epoch: 447/500 	Training Loss: 0.003447
#
# Epoch: 448/500 	Training Loss: 0.003715
#
# Epoch: 449/500 	Training Loss: 0.003023
#
# Epoch: 450/500 	Training Loss: 0.003296
#
# Epoch: 451/500 	Training Loss: 0.003119
#
# Epoch: 452/500 	Training Loss: 0.003218
#
# Epoch: 453/500 	Training Loss: 0.003699
#
# Epoch: 454/500 	Training Loss: 0.003169
#
# Epoch: 455/500 	Training Loss: 0.003966
#
# Epoch: 456/500 	Training Loss: 0.003195
#
# Epoch: 457/500 	Training Loss: 0.003621
#
# Epoch: 458/500 	Training Loss: 0.003402
#
# Epoch: 459/500 	Training Loss: 0.003410
#
# Epoch: 460/500 	Training Loss: 0.003475
#
# Epoch: 461/500 	Training Loss: 0.005392
#
# Epoch: 462/500 	Training Loss: 0.003521
#
# Epoch: 463/500 	Training Loss: 0.004023
#
# Epoch: 464/500 	Training Loss: 0.003229
#
# Epoch: 465/500 	Training Loss: 0.003709
#
# Epoch: 466/500 	Training Loss: 0.003224
#
# Epoch: 467/500 	Training Loss: 0.003246
#
# Epoch: 468/500 	Training Loss: 0.003331
#
# Epoch: 469/500 	Training Loss: 0.003200
#
# Epoch: 470/500 	Training Loss: 0.003962
#
# Epoch: 471/500 	Training Loss: 0.003552
#
# Epoch: 472/500 	Training Loss: 0.003207
#
# Epoch: 473/500 	Training Loss: 0.003484
#
# Epoch: 474/500 	Training Loss: 0.003447
#
# Epoch: 475/500 	Training Loss: 0.003302
#
# Epoch: 476/500 	Training Loss: 0.003133
#
# Epoch: 477/500 	Training Loss: 0.003974
#
# Epoch: 478/500 	Training Loss: 0.003716
#
# Epoch: 479/500 	Training Loss: 0.003792
#
# Epoch: 480/500 	Training Loss: 0.003305
#
# Epoch: 481/500 	Training Loss: 0.004179
#
# Epoch: 482/500 	Training Loss: 0.003321
#
# Epoch: 483/500 	Training Loss: 0.003361
#
# Epoch: 484/500 	Training Loss: 0.003316
#
# Epoch: 485/500 	Training Loss: 0.003095
#
# Epoch: 486/500 	Training Loss: 0.003391
#
# Epoch: 487/500 	Training Loss: 0.003709
#
# Epoch: 488/500 	Training Loss: 0.003348
#
# Epoch: 489/500 	Training Loss: 0.003268
#
# Epoch: 490/500 	Training Loss: 0.003155
#
# Epoch: 491/500 	Training Loss: 0.003057
#
# Epoch: 492/500 	Training Loss: 0.003376
#
# Epoch: 493/500 	Training Loss: 0.003619
#
# Epoch: 494/500 	Training Loss: 0.003585
#
# Epoch: 495/500 	Training Loss: 0.003284
#
# Epoch: 496/500 	Training Loss: 0.003254
#
# Epoch: 497/500 	Training Loss: 0.003667
#
# Epoch: 498/500 	Training Loss: 0.003355
#
# Epoch: 499/500 	Training Loss: 0.003275
#
# Epoch: 500/500 	Training Loss: 0.003381
#
# Time taken: 103.09315199999946

# %%
plt.plot(train_losses)

# %%
model.load_state_dict(torch.load('PyTorch_Model/Single_PositivePressure_lowest.pt', map_location=torch.device('cpu')))

model.eval()           # prep model for *evaluation*
model.to(device)
with torch.no_grad():  # turn off gradient to save memory
    y_predNN_torch = model(X_test_torch.to(device))

y_predNN_normal = y_predNN_torch.cpu().numpy()     # convert to numpy array
y_test_normal = y_test_torch.cpu().numpy()



print(y_predNN_normal)
# Out:
# [[ 0.43354   ]
#  [ 0.24180324]
#  [ 0.0665896 ]
#  ...
#  [-0.4281477 ]
#  [-0.469935  ]
#  [-0.51072043]]

# %%
mape = mean_absolute_percentage_error(y_test_normal, y_predNN_normal)
r2 = r2_score(y_test_normal, y_predNN_normal)
rmse = np.sqrt(mean_squared_error(y_test_normal, y_predNN_normal))
print(f"Scores in normal distribution: r2 = {r2}, mape = {mape}, rmse = {rmse}")
# Out:
# Scores in normal distribution: r2 = 0.9955640194597937, mape = 0.23464050889015198, rmse = 0.06689825654029846

# %%
y_predNN = quantile.inverse_transform(y_predNN_normal)
mape = mean_absolute_percentage_error(y_test, y_predNN)
r2 = r2_score(y_test, y_predNN)
rmse = np.sqrt(mean_squared_error(y_test, y_predNN))


print(f"Scores in actual distribution for positive pressure")
print('r2:', r2*100)
print('mape:', mape*100)
print('rmse:', rmse)
print()
# Out:
# Scores in actual distribution for negative duration
# r2: 99.26190642767041
# mape: 4.209249978321785
# rmse: 0.02867316814543223
