# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import timeit
#import shap
from sklearn.metrics import r2_score, mean_absolute_percentage_error, mean_squared_error
from sklearn.model_selection import cross_val_score, GridSearchCV, KFold
from sklearn.model_selection import train_test_split

# %% [markdown]
# ___

# %% [markdown]
# # Read-in and One-Hot Encoding

# %%
df = pd.read_excel("data_new/train.xlsx", sheet_name="negative_peak_time")

dt = pd.read_excel("data_new/test.xlsx", sheet_name="negative_peak_time")

# %%
# Label encoding 'Status' feature into 0 and 1 
# 0 for Subcooled and 1 for Superheated

from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()

df['Status'] = LE.fit_transform(df['Status'])
dt['Status'] = LE.fit_transform(dt['Status'])

df
# Out:
#          ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0      B291                         13.6          0.665119             1.0
# 1      B291                         13.6          0.665119             1.0
# 2      B291                         13.6          0.665119             1.0
# 3      B291                         13.6          0.665119             1.0
# 4      B291                         13.6          0.665119             1.0
# ...     ...                          ...               ...             ...
# 21595  B103                         30.7          0.181290             0.6
# 21596  B103                         30.7          0.181290             0.6
# 21597  B103                         30.7          0.181290             0.6
# 21598  B103                         30.7          0.181290             0.6
# 21599  B103                         30.7          0.181290             0.6
#
#        Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 0                  4.0              0.8                  1.8
# 1                  4.0              0.8                  1.8
# 2                  4.0              0.8                  1.8
# 3                  4.0              0.8                  1.8
# 4                  4.0              0.8                  1.8
# ...                ...              ...                  ...
# 21595              2.0              2.8                  1.2
# 21596              2.0              2.8                  1.2
# 21597              2.0              2.8                  1.2
# 21598              2.0              2.8                  1.2
# 21599              2.0              2.8                  1.2
#
#        Tank Height with Gas (m)   Vapour Temerature (K)  \
# 0                           0.4                   435.0
# 1                           0.4                   435.0
# 2                           0.4                   435.0
# 3                           0.4                   435.0
# 4                           0.4                   435.0
# ...                         ...                     ...
# 21595                       2.2                   334.7
# 21596                       2.2                   334.7
# 21597                       2.2                   334.7
# 21598                       2.2                   334.7
# 21599                       2.2                   334.7
#
#         Liquid Temerature (K)  Status  Stand-off Distance    Target
# 0                       372.5       1                   5  0.019227
# 1                       372.5       1                   6  0.021948
# 2                       372.5       1                   7  0.024735
# 3                       372.5       1                   8  0.027562
# 4                       372.5       1                   9  0.030378
# ...                       ...     ...                 ...       ...
# 21595                   404.9       0                  36  0.108070
# 21596                   404.9       0                  37  0.110886
# 21597                   404.9       0                  38  0.113699
# 21598                   404.9       0                  39  0.116520
# 21599                   404.9       0                  40  0.119344
#
# [21600 rows x 13 columns]

# %%
dt.iloc[30:50,:]
# Out:
#       ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 30  P197                     11.55904          0.602823             3.0
# 31  P197                     11.55904          0.602823             3.0
# 32  P197                     11.55904          0.602823             3.0
# 33  P197                     11.55904          0.602823             3.0
# 34  P197                     11.55904          0.602823             3.0
# 35  P197                     11.55904          0.602823             3.0
# 36  P168                     12.72223          0.648320             1.8
# 37  P168                     12.72223          0.648320             1.8
# 38  P168                     12.72223          0.648320             1.8
# 39  P168                     12.72223          0.648320             1.8
# 40  P168                     12.72223          0.648320             1.8
# 41  P168                     12.72223          0.648320             1.8
# 42  P168                     12.72223          0.648320             1.8
# 43  P168                     12.72223          0.648320             1.8
# 44  P168                     12.72223          0.648320             1.8
# 45  P168                     12.72223          0.648320             1.8
# 46  P168                     12.72223          0.648320             1.8
# 47  P168                     12.72223          0.648320             1.8
# 48  P168                     12.72223          0.648320             1.8
# 49  P168                     12.72223          0.648320             1.8
#
#     Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 30              0.8              2.2                  0.2
# 31              0.8              2.2                  0.2
# 32              0.8              2.2                  0.2
# 33              0.8              2.2                  0.2
# 34              0.8              2.2                  0.2
# 35              0.8              2.2                  0.2
# 36              8.2              0.6                  1.8
# 37              8.2              0.6                  1.8
# 38              8.2              0.6                  1.8
# 39              8.2              0.6                  1.8
# 40              8.2              0.6                  1.8
# 41              8.2              0.6                  1.8
# 42              8.2              0.6                  1.8
# 43              8.2              0.6                  1.8
# 44              8.2              0.6                  1.8
# 45              8.2              0.6                  1.8
# 46              8.2              0.6                  1.8
# 47              8.2              0.6                  1.8
# 48              8.2              0.6                  1.8
# 49              8.2              0.6                  1.8
#
#     Tank Height with Gas (m)   Vapour Temerature (K)   Liquid Temerature (K)  \
# 30                       1.0                   296.7                   328.5
# 31                       1.0                   296.7                   328.5
# 32                       1.0                   296.7                   328.5
# 33                       1.0                   296.7                   328.5
# 34                       1.0                   296.7                   328.5
# 35                       1.0                   296.7                   328.5
# 36                       0.2                   389.7                   296.4
# 37                       0.2                   389.7                   296.4
# 38                       0.2                   389.7                   296.4
# 39                       0.2                   389.7                   296.4
# 40                       0.2                   389.7                   296.4
# 41                       0.2                   389.7                   296.4
# 42                       0.2                   389.7                   296.4
# 43                       0.2                   389.7                   296.4
# 44                       0.2                   389.7                   296.4
# 45                       0.2                   389.7                   296.4
# 46                       0.2                   389.7                   296.4
# 47                       0.2                   389.7                   296.4
# 48                       0.2                   389.7                   296.4
# 49                       0.2                   389.7                   296.4
#
#     Status  Stand-off Distance    Target
# 30       1                  35  0.111052
# 31       1                  36  0.113937
# 32       1                  37  0.116823
# 33       1                  38  0.119718
# 34       1                  39  0.122621
# 35       1                  40  0.125527
# 36       0                   5  0.021506
# 37       0                   6  0.024231
# 38       0                   7  0.026958
# 39       0                   8  0.029773
# 40       0                   9  0.032650
# 41       0                  10  0.035531
# 42       0                  11  0.038390
# 43       0                  12  0.041319
# 44       0                  13  0.044313
# 45       0                  14  0.047236
# 46       0                  15  0.050147
# 47       0                  16  0.051528
# 48       0                  17  0.054235
# 49       0                  18  0.057064

# %%
X_traindf = df.drop(['ID','Target'], axis=1)
X_testdf = dt.drop(['ID','Target'], axis=1)

X_traindf
# Out:
#        Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0                             13.6          0.665119             1.0
# 1                             13.6          0.665119             1.0
# 2                             13.6          0.665119             1.0
# 3                             13.6          0.665119             1.0
# 4                             13.6          0.665119             1.0
# ...                            ...               ...             ...
# 21595                         30.7          0.181290             0.6
# 21596                         30.7          0.181290             0.6
# 21597                         30.7          0.181290             0.6
# 21598                         30.7          0.181290             0.6
# 21599                         30.7          0.181290             0.6
#
#        Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 0                  4.0              0.8                  1.8
# 1                  4.0              0.8                  1.8
# 2                  4.0              0.8                  1.8
# 3                  4.0              0.8                  1.8
# 4                  4.0              0.8                  1.8
# ...                ...              ...                  ...
# 21595              2.0              2.8                  1.2
# 21596              2.0              2.8                  1.2
# 21597              2.0              2.8                  1.2
# 21598              2.0              2.8                  1.2
# 21599              2.0              2.8                  1.2
#
#        Tank Height with Gas (m)   Vapour Temerature (K)  \
# 0                           0.4                   435.0
# 1                           0.4                   435.0
# 2                           0.4                   435.0
# 3                           0.4                   435.0
# 4                           0.4                   435.0
# ...                         ...                     ...
# 21595                       2.2                   334.7
# 21596                       2.2                   334.7
# 21597                       2.2                   334.7
# 21598                       2.2                   334.7
# 21599                       2.2                   334.7
#
#         Liquid Temerature (K)  Status  Stand-off Distance
# 0                       372.5       1                   5
# 1                       372.5       1                   6
# 2                       372.5       1                   7
# 3                       372.5       1                   8
# 4                       372.5       1                   9
# ...                       ...     ...                 ...
# 21595                   404.9       0                  36
# 21596                   404.9       0                  37
# 21597                   404.9       0                  38
# 21598                   404.9       0                  39
# 21599                   404.9       0                  40
#
# [21600 rows x 11 columns]

# %%
y_train = df['Target']
y_train
# Out:
# 0        0.019227
# 1        0.021948
# 2        0.024735
# 3        0.027562
# 4        0.030378
#            ...
# 21595    0.108070
# 21596    0.110886
# 21597    0.113699
# 21598    0.116520
# 21599    0.119344
# Name: Target, Length: 21600, dtype: float64

# %%
y_test = dt['Target']

y_test
# Out:
# 0       0.023626
# 1       0.026637
# 2       0.029588
# 3       0.032553
# 4       0.035477
#           ...
# 7195    0.105469
# 7196    0.108324
# 7197    0.111183
# 7198    0.114052
# 7199    0.116930
# Name: Target, Length: 7200, dtype: float64

# %% [markdown]
# ___

# %% [markdown]
# # Standardization and Power Transform

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import QuantileTransformer

# %%
# Processing both X_train and X_test using standardization
scaler = StandardScaler()
X_train = scaler.fit_transform(X_traindf)
X_test = scaler.transform(X_testdf)

# %%
quantile1 = QuantileTransformer(output_distribution='normal')



y_train_normal = quantile1.fit_transform(y_train.values.reshape(-1,1))
y_test_normal = quantile1.transform(y_test.values.reshape(-1,1))

# %%
# Visualize the effect of power transformation
f = plt.figure(figsize=(15, 6))

ax = f.add_subplot(121)
sns.distplot(y_train, bins=50, color='r', ax=ax)
ax.set_title('Distribution before processing')

ax=f.add_subplot(122)
sns.distplot(y_train_normal, bins=50, color='b', ax=ax)
ax.set_title('Distribution after quantile processing')
print()
# Out:
# c:\Users\buita\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\buita\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ___

# %% [markdown]
# # ANN

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt

torch.backends.cudnn.version() , torch.backends.cudnn.enabled
# Out:
# (8500, True)

# %%
# convert data to torch.FloatTensor
X_train_torch = torch.from_numpy(X_train.astype(np.float32))
X_test_torch = torch.from_numpy(X_test.astype(np.float32))



y_train_torch = torch.from_numpy(y_train_normal.astype(np.float32))
y_test_torch = torch.from_numpy(y_test_normal.astype(np.float32))

print(X_train_torch)
# Out:
# tensor([[-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.6846],
#         [-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.5883],
#         [-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.4921],
#         ...,
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.4921],
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.5883],
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.6846]])

# %%
train_data = []
for i in range(len(X_train_torch)):
   train_data.append([X_train_torch[i],
                      y_train_torch[i]
                     ])

test_data = []
for i in range(len(X_test_torch)):
   test_data.append([X_test_torch[i], 
                     y_test_torch[i]
                     ])
   
# prepare data loaders
train_loader = torch.utils.data.DataLoader(train_data, batch_size=512,               # batch_size could be smaller
    num_workers=0)                                                                   # Increasing num_workers slow down the training because it does not use GPU at all
test_loader = torch.utils.data.DataLoader(test_data, batch_size=512,
    num_workers=0)

# %%
## Define the NN architecture
## NN with 3 hidden layer, s=[11, 256, 256, 256, 1]

class BleveNet(nn.Module):
    def __init__(self):
        super(BleveNet, self).__init__()
        # The first hidden layer has 256 neurons
        self.fc1 = nn.Linear(X_train_torch.shape[1], 256)
        # The second hidden layer has 256 neurons
        self.fc2 = nn.Linear(256, 256)
        # The third hidden layer has 256 neurons
        self.fc3 = nn.Linear(256, 256)
        # The final layer has 1 output neurons
        self.fc4 = nn.Linear(256, 1)


        # Define proportion or neurons to dropout
        self.dropout = nn.Dropout(0.1)

        # Mish activation
        self.mish = nn.Mish()


    def forward(self, x):
        # add first fully connected layer
        x = self.fc1(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add second fully connected layer
        x = self.fc2(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add third fully connected layer
        x = self.fc3(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add final output layers:
        output = self.fc4(x)
       
        return output

# initialize the NN
model = BleveNet()
print(model)
# Out:
# BleveNet(
#   (fc1): Linear(in_features=11, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=256, bias=True)
#   (fc4): Linear(in_features=256, out_features=1, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (mish): Mish()
# )

# %%
criterion = nn.HuberLoss()        # This is the best loss function for my model
# criterion = nn.MSELoss()


optimizer = torch.optim.Adam(model.parameters(), lr=0.005, weight_decay=1e-5)     # This is the best optimizer for my model 

# Check for GPU
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
startTime = timeit.default_timer() 

n_epochs = 200 

model.to(device)    # bring the model to gpu
model.train()       # prep model for training

train_losses = []
for epoch in range(n_epochs):
    # monitor training loss
    train_loss = 0.0
    
    ###################
    # train the model #
    ###################
    for data, target in train_loader:
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        #bring data and target to gpu
        data, target = data.to(device), target.to(device)
        
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update running training loss
        train_loss += loss.item()*data.size(0)
        
    # print training statistics 
    # calculate average loss over an epoch
    train_loss = train_loss/len(train_loader.dataset)
    train_losses.append(train_loss)

    print('Epoch: {}/{} \tTraining Loss: {:.6f}'.format(
        epoch+1,
        n_epochs, 
        train_loss
        ))
    

endTime = timeit.default_timer()
runningTotal = (endTime - startTime)
print(f"Time taken: {runningTotal}")
# Out:
# Epoch: 1/200 	Training Loss: 0.059570
# Epoch: 2/200 	Training Loss: 0.018951
# Epoch: 3/200 	Training Loss: 0.015405
# Epoch: 4/200 	Training Loss: 0.012253
# Epoch: 5/200 	Training Loss: 0.012812
# Epoch: 6/200 	Training Loss: 0.012390
# Epoch: 7/200 	Training Loss: 0.011593
# Epoch: 8/200 	Training Loss: 0.013732
# Epoch: 9/200 	Training Loss: 0.012053
# Epoch: 10/200 	Training Loss: 0.008426
# Epoch: 11/200 	Training Loss: 0.007541
# Epoch: 12/200 	Training Loss: 0.009137
# Epoch: 13/200 	Training Loss: 0.007536
# Epoch: 14/200 	Training Loss: 0.007100
# Epoch: 15/200 	Training Loss: 0.007429
# Epoch: 16/200 	Training Loss: 0.010399
# Epoch: 17/200 	Training Loss: 0.009352
# Epoch: 18/200 	Training Loss: 0.007067
# Epoch: 19/200 	Training Loss: 0.006083
# Epoch: 20/200 	Training Loss: 0.005764
# Epoch: 21/200 	Training Loss: 0.006397
# Epoch: 22/200 	Training Loss: 0.006611
# Epoch: 23/200 	Training Loss: 0.006999
# Epoch: 24/200 	Training Loss: 0.006830
# Epoch: 25/200 	Training Loss: 0.007737
# Epoch: 26/200 	Training Loss: 0.006457
# Epoch: 27/200 	Training Loss: 0.006535
# Epoch: 28/200 	Training Loss: 0.004735
# Epoch: 29/200 	Training Loss: 0.004860
# Epoch: 30/200 	Training Loss: 0.006614
# Epoch: 31/200 	Training Loss: 0.006201
# Epoch: 32/200 	Training Loss: 0.005946
# Epoch: 33/200 	Training Loss: 0.005214
# Epoch: 34/200 	Training Loss: 0.004289
# Epoch: 35/200 	Training Loss: 0.005256
# Epoch: 36/200 	Training Loss: 0.005301
# Epoch: 37/200 	Training Loss: 0.005923
# Epoch: 38/200 	Training Loss: 0.004651
# Epoch: 39/200 	Training Loss: 0.005713
# Epoch: 40/200 	Training Loss: 0.004593
# Epoch: 41/200 	Training Loss: 0.006285
# Epoch: 42/200 	Training Loss: 0.004777
# Epoch: 43/200 	Training Loss: 0.004520
# Epoch: 44/200 	Training Loss: 0.005371
# Epoch: 45/200 	Training Loss: 0.007083
# Epoch: 46/200 	Training Loss: 0.006166
# Epoch: 47/200 	Training Loss: 0.004390
# Epoch: 48/200 	Training Loss: 0.006115
# Epoch: 49/200 	Training Loss: 0.005496
# Epoch: 50/200 	Training Loss: 0.007276
# Epoch: 51/200 	Training Loss: 0.005804
# Epoch: 52/200 	Training Loss: 0.004820
# Epoch: 53/200 	Training Loss: 0.007627
# Epoch: 54/200 	Training Loss: 0.008329
# Epoch: 55/200 	Training Loss: 0.005681
# Epoch: 56/200 	Training Loss: 0.006524
# Epoch: 57/200 	Training Loss: 0.006205
# Epoch: 58/200 	Training Loss: 0.005071
# Epoch: 59/200 	Training Loss: 0.004848
# Epoch: 60/200 	Training Loss: 0.004380
# Epoch: 61/200 	Training Loss: 0.004805
# Epoch: 62/200 	Training Loss: 0.006685
# Epoch: 63/200 	Training Loss: 0.005279
# Epoch: 64/200 	Training Loss: 0.004656
# Epoch: 65/200 	Training Loss: 0.005003
# Epoch: 66/200 	Training Loss: 0.004559
# Epoch: 67/200 	Training Loss: 0.005080
# Epoch: 68/200 	Training Loss: 0.005445
# Epoch: 69/200 	Training Loss: 0.005239
# Epoch: 70/200 	Training Loss: 0.005276
# Epoch: 71/200 	Training Loss: 0.004495
# Epoch: 72/200 	Training Loss: 0.004694
# Epoch: 73/200 	Training Loss: 0.004578
# Epoch: 74/200 	Training Loss: 0.006849
# Epoch: 75/200 	Training Loss: 0.005862
# Epoch: 76/200 	Training Loss: 0.005206
# Epoch: 77/200 	Training Loss: 0.004688
# Epoch: 78/200 	Training Loss: 0.004779
# Epoch: 79/200 	Training Loss: 0.004123
# Epoch: 80/200 	Training Loss: 0.004451
# Epoch: 81/200 	Training Loss: 0.005967
# Epoch: 82/200 	Training Loss: 0.005558
# Epoch: 83/200 	Training Loss: 0.006062
# Epoch: 84/200 	Training Loss: 0.005246
# Epoch: 85/200 	Training Loss: 0.004887
# Epoch: 86/200 	Training Loss: 0.005964
# Epoch: 87/200 	Training Loss: 0.005949
# Epoch: 88/200 	Training Loss: 0.006251
# Epoch: 89/200 	Training Loss: 0.005167
# Epoch: 90/200 	Training Loss: 0.005247
# Epoch: 91/200 	Training Loss: 0.006839
# Epoch: 92/200 	Training Loss: 0.005655
# Epoch: 93/200 	Training Loss: 0.005138
# Epoch: 94/200 	Training Loss: 0.005721
# Epoch: 95/200 	Training Loss: 0.005141
# Epoch: 96/200 	Training Loss: 0.004223
# Epoch: 97/200 	Training Loss: 0.004805
# Epoch: 98/200 	Training Loss: 0.006107
# Epoch: 99/200 	Training Loss: 0.005340
# Epoch: 100/200 	Training Loss: 0.004550
# Epoch: 101/200 	Training Loss: 0.004449
# Epoch: 102/200 	Training Loss: 0.005624
# Epoch: 103/200 	Training Loss: 0.004898
# Epoch: 104/200 	Training Loss: 0.004386
# Epoch: 105/200 	Training Loss: 0.004173
# Epoch: 106/200 	Training Loss: 0.004203
# Epoch: 107/200 	Training Loss: 0.006791
# Epoch: 108/200 	Training Loss: 0.005719
# Epoch: 109/200 	Training Loss: 0.005038
# Epoch: 110/200 	Training Loss: 0.006939
# Epoch: 111/200 	Training Loss: 0.005980
# Epoch: 112/200 	Training Loss: 0.005858
# Epoch: 113/200 	Training Loss: 0.004409
# Epoch: 114/200 	Training Loss: 0.005184
# Epoch: 115/200 	Training Loss: 0.003985
# Epoch: 116/200 	Training Loss: 0.004718
# Epoch: 117/200 	Training Loss: 0.004149
# Epoch: 118/200 	Training Loss: 0.005003
# Epoch: 119/200 	Training Loss: 0.005517
# Epoch: 120/200 	Training Loss: 0.006603
# Epoch: 121/200 	Training Loss: 0.005046
# Epoch: 122/200 	Training Loss: 0.006396
# Epoch: 123/200 	Training Loss: 0.004768
# Epoch: 124/200 	Training Loss: 0.005381
# Epoch: 125/200 	Training Loss: 0.005262
# Epoch: 126/200 	Training Loss: 0.006595
# Epoch: 127/200 	Training Loss: 0.005678
# Epoch: 128/200 	Training Loss: 0.006178
# Epoch: 129/200 	Training Loss: 0.006432
# Epoch: 130/200 	Training Loss: 0.004703
# Epoch: 131/200 	Training Loss: 0.004936
# Epoch: 132/200 	Training Loss: 0.004271
# Epoch: 133/200 	Training Loss: 0.004604
# Epoch: 134/200 	Training Loss: 0.008017
# Epoch: 135/200 	Training Loss: 0.007020
# Epoch: 136/200 	Training Loss: 0.006616
# Epoch: 137/200 	Training Loss: 0.005241
# Epoch: 138/200 	Training Loss: 0.004734
# Epoch: 139/200 	Training Loss: 0.006062
# Epoch: 140/200 	Training Loss: 0.005485
# Epoch: 141/200 	Training Loss: 0.004825
# Epoch: 142/200 	Training Loss: 0.006571
# Epoch: 143/200 	Training Loss: 0.005945
# Epoch: 144/200 	Training Loss: 0.004977
# Epoch: 145/200 	Training Loss: 0.005727
# Epoch: 146/200 	Training Loss: 0.005945
# Epoch: 147/200 	Training Loss: 0.005968
# Epoch: 148/200 	Training Loss: 0.004637
# Epoch: 149/200 	Training Loss: 0.006257
# Epoch: 150/200 	Training Loss: 0.006639
# Epoch: 151/200 	Training Loss: 0.006370
# Epoch: 152/200 	Training Loss: 0.005042
# Epoch: 153/200 	Training Loss: 0.004264
# Epoch: 154/200 	Training Loss: 0.004543
# Epoch: 155/200 	Training Loss: 0.004283
# Epoch: 156/200 	Training Loss: 0.004914
# Epoch: 157/200 	Training Loss: 0.004411
# Epoch: 158/200 	Training Loss: 0.005019
# Epoch: 159/200 	Training Loss: 0.004649
# Epoch: 160/200 	Training Loss: 0.005033
# Epoch: 161/200 	Training Loss: 0.006680
# Epoch: 162/200 	Training Loss: 0.006299
# Epoch: 163/200 	Training Loss: 0.006067
# Epoch: 164/200 	Training Loss: 0.004343
# Epoch: 165/200 	Training Loss: 0.003859
# Epoch: 166/200 	Training Loss: 0.004250
# Epoch: 167/200 	Training Loss: 0.004202
# Epoch: 168/200 	Training Loss: 0.004631
# Epoch: 169/200 	Training Loss: 0.005996
# Epoch: 170/200 	Training Loss: 0.006335
# Epoch: 171/200 	Training Loss: 0.005971
# Epoch: 172/200 	Training Loss: 0.003988
# Epoch: 173/200 	Training Loss: 0.004623
# Epoch: 174/200 	Training Loss: 0.003928
# Epoch: 175/200 	Training Loss: 0.004165
# Epoch: 176/200 	Training Loss: 0.004409
# Epoch: 177/200 	Training Loss: 0.005093
# Epoch: 178/200 	Training Loss: 0.005210
# Epoch: 179/200 	Training Loss: 0.006046
# Epoch: 180/200 	Training Loss: 0.005530
# Epoch: 181/200 	Training Loss: 0.004183
# Epoch: 182/200 	Training Loss: 0.005726
# Epoch: 183/200 	Training Loss: 0.005223
# Epoch: 184/200 	Training Loss: 0.005165
# Epoch: 185/200 	Training Loss: 0.003951
# Epoch: 186/200 	Training Loss: 0.004499
# Epoch: 187/200 	Training Loss: 0.009475
# Epoch: 188/200 	Training Loss: 0.005326
# Epoch: 189/200 	Training Loss: 0.004831
# Epoch: 190/200 	Training Loss: 0.005600
# Epoch: 191/200 	Training Loss: 0.005117
# Epoch: 192/200 	Training Loss: 0.004353
# Epoch: 193/200 	Training Loss: 0.005288
# Epoch: 194/200 	Training Loss: 0.003943
# Epoch: 195/200 	Training Loss: 0.006157
# Epoch: 196/200 	Training Loss: 0.006567
# Epoch: 197/200 	Training Loss: 0.004716
# Epoch: 198/200 	Training Loss: 0.004074
# Epoch: 199/200 	Training Loss: 0.004146
# Epoch: 200/200 	Training Loss: 0.004068
# Time taken: 53.070679299999995

# %%
plt.plot(train_losses)

# Save the model  -- I already saved this and submitted
torch.save(model.state_dict(), 'PyTorch_Model/Default5_NegaPeakTime_NN_mish_Drop_L2_Huber_200Epochs.pt')

# %%
# model.load_state_dict(torch.load('PyTorch_Model/Default2_NegaPeakTime_NN_mish_Drop_L2_Huber_200Epochs.pt', map_location=torch.device('cpu')))

model.eval()           # prep model for *evaluation*
model.to(device)
with torch.no_grad():  # turn off gradient to save memory
    y_predNN_torch = model(X_test_torch.to(device))

y_predNN_normal = y_predNN_torch.cpu().numpy()     # convert to numpy array
y_test_normal = y_test_torch.cpu().numpy()



print(y_predNN_normal)
# Out:
# [[-1.7997599]
#  [-1.5451806]
#  [-1.346948 ]
#  ...
#  [ 1.3183134]
#  [ 1.5102489]
#  [ 1.740452 ]]

# %%
mape = mean_absolute_percentage_error(y_test_normal, y_predNN_normal)
r2 = r2_score(y_test_normal, y_predNN_normal)
rmse = np.sqrt(mean_squared_error(y_test_normal, y_predNN_normal))
print(f"Scores in normal distribution: r2 = {r2}, mape = {mape}, rmse = {rmse}")
# Out:
# Scores in normal distribution: r2 = 0.9867165174538667, mape = 0.20660609006881714, rmse = 0.11539242416620255

# %%
y_predNN = quantile1.inverse_transform(y_predNN_normal)
mape = mean_absolute_percentage_error(y_test, y_predNN)
r2 = r2_score(y_test, y_predNN)
rmse = np.sqrt(mean_squared_error(y_test, y_predNN))


print(f"Scores in actual distribution for arrival time: r2 = {r2}, mape = {mape}, rmse = {rmse}")
# Out:
# Scores in actual distribution for arrival time: r2 = 0.9969029084367755, mape = 0.019291159821676607, rmse = 0.0016614040099709182
