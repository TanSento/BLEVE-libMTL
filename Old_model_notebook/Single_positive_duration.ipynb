# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import timeit
#import shap
from sklearn.metrics import r2_score, mean_absolute_percentage_error, mean_squared_error
from sklearn.model_selection import cross_val_score, GridSearchCV, KFold
from sklearn.model_selection import train_test_split

# %% [markdown]
# ___

# %% [markdown]
# # Read-in and One-Hot Encoding

# %%
df = pd.read_excel("data_new/train.xlsx", sheet_name="positive_duration")

dt = pd.read_excel("data_new/test.xlsx", sheet_name="positive_duration")

# %%
# Label encoding 'Status' feature into 0 and 1 
# 0 for Subcooled and 1 for Superheated

from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()

df['Status'] = LE.fit_transform(df['Status'])
dt['Status'] = LE.fit_transform(dt['Status'])

df
# Out:
#          ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0      B291                         13.6          0.665119             1.0
# 1      B291                         13.6          0.665119             1.0
# 2      B291                         13.6          0.665119             1.0
# 3      B291                         13.6          0.665119             1.0
# 4      B291                         13.6          0.665119             1.0
# ...     ...                          ...               ...             ...
# 21595  B103                         30.7          0.181290             0.6
# 21596  B103                         30.7          0.181290             0.6
# 21597  B103                         30.7          0.181290             0.6
# 21598  B103                         30.7          0.181290             0.6
# 21599  B103                         30.7          0.181290             0.6
#
#        Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 0                  4.0              0.8                  1.8
# 1                  4.0              0.8                  1.8
# 2                  4.0              0.8                  1.8
# 3                  4.0              0.8                  1.8
# 4                  4.0              0.8                  1.8
# ...                ...              ...                  ...
# 21595              2.0              2.8                  1.2
# 21596              2.0              2.8                  1.2
# 21597              2.0              2.8                  1.2
# 21598              2.0              2.8                  1.2
# 21599              2.0              2.8                  1.2
#
#        Tank Height with Gas (m)   Vapour Temerature (K)  \
# 0                           0.4                   435.0
# 1                           0.4                   435.0
# 2                           0.4                   435.0
# 3                           0.4                   435.0
# 4                           0.4                   435.0
# ...                         ...                     ...
# 21595                       2.2                   334.7
# 21596                       2.2                   334.7
# 21597                       2.2                   334.7
# 21598                       2.2                   334.7
# 21599                       2.2                   334.7
#
#         Liquid Temerature (K)  Status  Stand-off Distance    Target
# 0                       372.5       1                   5  0.005043
# 1                       372.5       1                   6  0.005543
# 2                       372.5       1                   7  0.006014
# 3                       372.5       1                   8  0.006445
# 4                       372.5       1                   9  0.006840
# ...                       ...     ...                 ...       ...
# 21595                   404.9       0                  36  0.011906
# 21596                   404.9       0                  37  0.012024
# 21597                   404.9       0                  38  0.012137
# 21598                   404.9       0                  39  0.012256
# 21599                   404.9       0                  40  0.012363
#
# [21600 rows x 13 columns]

# %%
dt.iloc[30:50,:]
# Out:
#       ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 30  P197                     11.55904          0.602823             3.0
# 31  P197                     11.55904          0.602823             3.0
# 32  P197                     11.55904          0.602823             3.0
# 33  P197                     11.55904          0.602823             3.0
# 34  P197                     11.55904          0.602823             3.0
# 35  P197                     11.55904          0.602823             3.0
# 36  P168                     12.72223          0.648320             1.8
# 37  P168                     12.72223          0.648320             1.8
# 38  P168                     12.72223          0.648320             1.8
# 39  P168                     12.72223          0.648320             1.8
# 40  P168                     12.72223          0.648320             1.8
# 41  P168                     12.72223          0.648320             1.8
# 42  P168                     12.72223          0.648320             1.8
# 43  P168                     12.72223          0.648320             1.8
# 44  P168                     12.72223          0.648320             1.8
# 45  P168                     12.72223          0.648320             1.8
# 46  P168                     12.72223          0.648320             1.8
# 47  P168                     12.72223          0.648320             1.8
# 48  P168                     12.72223          0.648320             1.8
# 49  P168                     12.72223          0.648320             1.8
#
#     Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 30              0.8              2.2                  0.2
# 31              0.8              2.2                  0.2
# 32              0.8              2.2                  0.2
# 33              0.8              2.2                  0.2
# 34              0.8              2.2                  0.2
# 35              0.8              2.2                  0.2
# 36              8.2              0.6                  1.8
# 37              8.2              0.6                  1.8
# 38              8.2              0.6                  1.8
# 39              8.2              0.6                  1.8
# 40              8.2              0.6                  1.8
# 41              8.2              0.6                  1.8
# 42              8.2              0.6                  1.8
# 43              8.2              0.6                  1.8
# 44              8.2              0.6                  1.8
# 45              8.2              0.6                  1.8
# 46              8.2              0.6                  1.8
# 47              8.2              0.6                  1.8
# 48              8.2              0.6                  1.8
# 49              8.2              0.6                  1.8
#
#     Tank Height with Gas (m)   Vapour Temerature (K)   Liquid Temerature (K)  \
# 30                       1.0                   296.7                   328.5
# 31                       1.0                   296.7                   328.5
# 32                       1.0                   296.7                   328.5
# 33                       1.0                   296.7                   328.5
# 34                       1.0                   296.7                   328.5
# 35                       1.0                   296.7                   328.5
# 36                       0.2                   389.7                   296.4
# 37                       0.2                   389.7                   296.4
# 38                       0.2                   389.7                   296.4
# 39                       0.2                   389.7                   296.4
# 40                       0.2                   389.7                   296.4
# 41                       0.2                   389.7                   296.4
# 42                       0.2                   389.7                   296.4
# 43                       0.2                   389.7                   296.4
# 44                       0.2                   389.7                   296.4
# 45                       0.2                   389.7                   296.4
# 46                       0.2                   389.7                   296.4
# 47                       0.2                   389.7                   296.4
# 48                       0.2                   389.7                   296.4
# 49                       0.2                   389.7                   296.4
#
#     Status  Stand-off Distance    Target
# 30       1                  35  0.013368
# 31       1                  36  0.013475
# 32       1                  37  0.013574
# 33       1                  38  0.013673
# 34       1                  39  0.013771
# 35       1                  40  0.013866
# 36       0                   5  0.006377
# 37       0                   6  0.006572
# 38       0                   7  0.006815
# 39       0                   8  0.007089
# 40       0                   9  0.007368
# 41       0                  10  0.007663
# 42       0                  11  0.007957
# 43       0                  12  0.008263
# 44       0                  13  0.008576
# 45       0                  14  0.008863
# 46       0                  15  0.009139
# 47       0                  16  0.006809
# 48       0                  17  0.006635
# 49       0                  18  0.006662

# %%
X_traindf = df.drop(['ID','Target'], axis=1)
X_testdf = dt.drop(['ID','Target'], axis=1)

X_traindf
# Out:
#        Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0                             13.6          0.665119             1.0
# 1                             13.6          0.665119             1.0
# 2                             13.6          0.665119             1.0
# 3                             13.6          0.665119             1.0
# 4                             13.6          0.665119             1.0
# ...                            ...               ...             ...
# 21595                         30.7          0.181290             0.6
# 21596                         30.7          0.181290             0.6
# 21597                         30.7          0.181290             0.6
# 21598                         30.7          0.181290             0.6
# 21599                         30.7          0.181290             0.6
#
#        Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 0                  4.0              0.8                  1.8
# 1                  4.0              0.8                  1.8
# 2                  4.0              0.8                  1.8
# 3                  4.0              0.8                  1.8
# 4                  4.0              0.8                  1.8
# ...                ...              ...                  ...
# 21595              2.0              2.8                  1.2
# 21596              2.0              2.8                  1.2
# 21597              2.0              2.8                  1.2
# 21598              2.0              2.8                  1.2
# 21599              2.0              2.8                  1.2
#
#        Tank Height with Gas (m)   Vapour Temerature (K)  \
# 0                           0.4                   435.0
# 1                           0.4                   435.0
# 2                           0.4                   435.0
# 3                           0.4                   435.0
# 4                           0.4                   435.0
# ...                         ...                     ...
# 21595                       2.2                   334.7
# 21596                       2.2                   334.7
# 21597                       2.2                   334.7
# 21598                       2.2                   334.7
# 21599                       2.2                   334.7
#
#         Liquid Temerature (K)  Status  Stand-off Distance
# 0                       372.5       1                   5
# 1                       372.5       1                   6
# 2                       372.5       1                   7
# 3                       372.5       1                   8
# 4                       372.5       1                   9
# ...                       ...     ...                 ...
# 21595                   404.9       0                  36
# 21596                   404.9       0                  37
# 21597                   404.9       0                  38
# 21598                   404.9       0                  39
# 21599                   404.9       0                  40
#
# [21600 rows x 11 columns]

# %%
y_train = df['Target']
y_train
# Out:
# 0        0.005043
# 1        0.005543
# 2        0.006014
# 3        0.006445
# 4        0.006840
#            ...
# 21595    0.011906
# 21596    0.012024
# 21597    0.012137
# 21598    0.012256
# 21599    0.012363
# Name: Target, Length: 21600, dtype: float64

# %%
y_test = dt['Target']

y_test
# Out:
# 0       0.007010
# 1       0.007732
# 2       0.008249
# 3       0.008734
# 4       0.009039
#           ...
# 7195    0.011811
# 7196    0.011917
# 7197    0.012019
# 7198    0.012124
# 7199    0.012225
# Name: Target, Length: 7200, dtype: float64

# %% [markdown]
# ___

# %% [markdown]
# # Standardization and Power Transform

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import QuantileTransformer

# %%
# Processing both X_train and X_test using standardization
scaler = StandardScaler()
X_train = scaler.fit_transform(X_traindf)
X_test = scaler.transform(X_testdf)

# %%
quantile = QuantileTransformer(output_distribution='normal', random_state=42)



y_train_normal = quantile.fit_transform(y_train.values.reshape(-1,1))
y_test_normal = quantile.transform(y_test.values.reshape(-1,1))

# %%
# Visualize the effect of power transformation
f = plt.figure(figsize=(15, 6))

ax = f.add_subplot(121)
sns.distplot(y_train, bins=50, color='r', ax=ax)
ax.set_title('Distribution before processing')

ax=f.add_subplot(122)
sns.distplot(y_train_normal, bins=50, color='b', ax=ax)
ax.set_title('Distribution after quantile processing')
print()
# Out:
# /home/tendou/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/tendou/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ___

# %% [markdown]
# # ANN

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt

torch.backends.cudnn.version() , torch.backends.cudnn.enabled
torch.manual_seed(0)

# %%
# convert data to torch.FloatTensor
X_train_torch = torch.from_numpy(X_train.astype(np.float32))
X_test_torch = torch.from_numpy(X_test.astype(np.float32))



y_train_torch = torch.from_numpy(y_train_normal.astype(np.float32))
y_test_torch = torch.from_numpy(y_test_normal.astype(np.float32))

print(X_train_torch)
# Out:
# tensor([[-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.6846],
#         [-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.5883],
#         [-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.4921],
#         ...,
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.4921],
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.5883],
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.6846]])

# %%
train_data = []
for i in range(len(X_train_torch)):
   train_data.append([X_train_torch[i],
                      y_train_torch[i]
                     ])

test_data = []
for i in range(len(X_test_torch)):
   test_data.append([X_test_torch[i], 
                     y_test_torch[i]
                     ])
   
# prepare data loaders
train_loader = torch.utils.data.DataLoader(train_data, batch_size=512,               # batch_size could be smaller
    num_workers=0, shuffle=True)                                                                   # Increasing num_workers slow down the training because it does not use GPU at all
test_loader = torch.utils.data.DataLoader(test_data, batch_size=512,
    num_workers=0)

# %%
for data, target in train_loader:
    print(data.shape[0] == data.size(0))
    break
# Out:
# True

# %%
## Define the NN architecture
## NN with 3 hidden layer, s=[11, 256, 256, 256, 1]

class BleveNet(nn.Module):
    def __init__(self):
        super(BleveNet, self).__init__()
        # The first hidden layer has 256 neurons
        self.fc1 = nn.Linear(X_train_torch.shape[1], 256)
        # The second hidden layer has 256 neurons
        self.fc2 = nn.Linear(256, 256)
        # The third hidden layer has 256 neurons
        self.fc3 = nn.Linear(256, 256)
        # The final layer has 1 output neuron
        self.fc4 = nn.Linear(256, 1)


        # Define proportion or neurons to dropout
        self.dropout = nn.Dropout(0.1)

        # Mish activation
        self.mish = nn.Mish()


    def forward(self, x):
        # add first fully connected layer
        x = self.fc1(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add second fully connected layer
        x = self.fc2(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add third fully connected layer
        x = self.fc3(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add final output layers:
        output = self.fc4(x)
       
        return output

# initialize the NN
model = BleveNet()
print(model)
# Out:
# BleveNet(
#   (fc1): Linear(in_features=11, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=256, bias=True)
#   (fc4): Linear(in_features=256, out_features=1, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (mish): Mish()
# )

# %%
criterion = nn.HuberLoss()        # This is the best loss function for my model
# criterion = nn.MSELoss()


optimizer = torch.optim.Adam(model.parameters(), lr=0.005, weight_decay=1e-5)     # This is the best optimizer for my model 

# Check for GPU
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
startTime = timeit.default_timer() 

n_epochs = 500 

model.to(device)    # bring the model to gpu

train_losses = []
lowest_mape = 100
for epoch in range(n_epochs):

    model.train()       

    # monitor training loss
    train_loss = 0.0
    
    ###################
    # train the model #
    ###################
    for data, target in train_loader:
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        #bring data and target to gpu
        data, target = data.to(device), target.to(device)
        
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update running training loss
        train_loss += loss.item()*data.size(0)
        
    # print training statistics 
    # calculate average loss over an epoch
    train_loss = train_loss/len(train_loader.dataset)
    train_losses.append(train_loss)

    print('Epoch: {}/{} \tTraining Loss: {:.6f}'.format(
        epoch+1,
        n_epochs, 
        train_loss
        ))
    

    ############################
    # Evaluate the lowest MAPE #
    ############################
    model.eval()
    with torch.no_grad():  # turn off gradient to save memory
        y_predNN_torch = model(X_test_torch.to(device))

    y_predNN = quantile.inverse_transform(y_predNN_torch.cpu().numpy())
    MAPE = mean_absolute_percentage_error(y_test, y_predNN)

    if MAPE < lowest_mape:
        lowest_mape = MAPE
        print(f'Lowest MAPE: {lowest_mape}')
        torch.save(model.state_dict(), 'PyTorch_Model/Single_PositiveDuration_lowest.pt')
    print()

endTime = timeit.default_timer()
runningTotal = (endTime - startTime)
print(f"Time taken: {runningTotal}")
# Out:
# Epoch: 1/500 	Training Loss: 0.091551
# Lowest MAPE: 0.07374780115507358
#
# Epoch: 2/500 	Training Loss: 0.047297
# Lowest MAPE: 0.06630115805379266
#
# Epoch: 3/500 	Training Loss: 0.039764
# Lowest MAPE: 0.05860681300559016
#
# Epoch: 4/500 	Training Loss: 0.032253
#
# Epoch: 5/500 	Training Loss: 0.029048
# Lowest MAPE: 0.051006418978242866
#
# Epoch: 6/500 	Training Loss: 0.026480
#
# Epoch: 7/500 	Training Loss: 0.025272
# Lowest MAPE: 0.04881595128733918
#
# Epoch: 8/500 	Training Loss: 0.023596
#
# Epoch: 9/500 	Training Loss: 0.021923
#
# Epoch: 10/500 	Training Loss: 0.021419
# Lowest MAPE: 0.04777551901977533
#
# Epoch: 11/500 	Training Loss: 0.020134
#
# Epoch: 12/500 	Training Loss: 0.019659
# Lowest MAPE: 0.04625206926225486
#
# Epoch: 13/500 	Training Loss: 0.017671
#
# Epoch: 14/500 	Training Loss: 0.018735
#
# Epoch: 15/500 	Training Loss: 0.017599
#
# Epoch: 16/500 	Training Loss: 0.017599
# Lowest MAPE: 0.04477410906274069
#
# Epoch: 17/500 	Training Loss: 0.016566
#
# Epoch: 18/500 	Training Loss: 0.018105
#
# Epoch: 19/500 	Training Loss: 0.016347
# Lowest MAPE: 0.04469235298905978
#
# Epoch: 20/500 	Training Loss: 0.015448
#
# Epoch: 21/500 	Training Loss: 0.014877
#
# Epoch: 22/500 	Training Loss: 0.015319
#
# Epoch: 23/500 	Training Loss: 0.015099
#
# Epoch: 24/500 	Training Loss: 0.016514
#
# Epoch: 25/500 	Training Loss: 0.014543
#
# Epoch: 26/500 	Training Loss: 0.014199
# Lowest MAPE: 0.043224795138283714
#
# Epoch: 27/500 	Training Loss: 0.013874
#
# Epoch: 28/500 	Training Loss: 0.014242
#
# Epoch: 29/500 	Training Loss: 0.014034
#
# Epoch: 30/500 	Training Loss: 0.013060
#
# Epoch: 31/500 	Training Loss: 0.013971
#
# Epoch: 32/500 	Training Loss: 0.014337
# Lowest MAPE: 0.04307542354507287
#
# Epoch: 33/500 	Training Loss: 0.012862
#
# Epoch: 34/500 	Training Loss: 0.012924
#
# Epoch: 35/500 	Training Loss: 0.014338
#
# Epoch: 36/500 	Training Loss: 0.015110
# Lowest MAPE: 0.04233396922830336
#
# Epoch: 37/500 	Training Loss: 0.013713
#
# Epoch: 38/500 	Training Loss: 0.012736
#
# Epoch: 39/500 	Training Loss: 0.013301
#
# Epoch: 40/500 	Training Loss: 0.012369
# Lowest MAPE: 0.04158917843201474
#
# Epoch: 41/500 	Training Loss: 0.012649
#
# Epoch: 42/500 	Training Loss: 0.012339
#
# Epoch: 43/500 	Training Loss: 0.012616
#
# Epoch: 44/500 	Training Loss: 0.012553
#
# Epoch: 45/500 	Training Loss: 0.013711
#
# Epoch: 46/500 	Training Loss: 0.012109
#
# Epoch: 47/500 	Training Loss: 0.012220
#
# Epoch: 48/500 	Training Loss: 0.013262
#
# Epoch: 49/500 	Training Loss: 0.011845
#
# Epoch: 50/500 	Training Loss: 0.012506
#
# Epoch: 51/500 	Training Loss: 0.011657
#
# Epoch: 52/500 	Training Loss: 0.011899
#
# Epoch: 53/500 	Training Loss: 0.011100
#
# Epoch: 54/500 	Training Loss: 0.012209
#
# Epoch: 55/500 	Training Loss: 0.011213
# Lowest MAPE: 0.0412979512139976
#
# Epoch: 56/500 	Training Loss: 0.011307
#
# Epoch: 57/500 	Training Loss: 0.012372
#
# Epoch: 58/500 	Training Loss: 0.012189
#
# Epoch: 59/500 	Training Loss: 0.012400
#
# Epoch: 60/500 	Training Loss: 0.011903
# Lowest MAPE: 0.04120676779135812
#
# Epoch: 61/500 	Training Loss: 0.010722
#
# Epoch: 62/500 	Training Loss: 0.011041
# Lowest MAPE: 0.0403932761579013
#
# Epoch: 63/500 	Training Loss: 0.011502
#
# Epoch: 64/500 	Training Loss: 0.010889
#
# Epoch: 65/500 	Training Loss: 0.011027
#
# Epoch: 66/500 	Training Loss: 0.011105
#
# Epoch: 67/500 	Training Loss: 0.011528
#
# Epoch: 68/500 	Training Loss: 0.011602
#
# Epoch: 69/500 	Training Loss: 0.011184
#
# Epoch: 70/500 	Training Loss: 0.012861
#
# Epoch: 71/500 	Training Loss: 0.011520
#
# Epoch: 72/500 	Training Loss: 0.011126
#
# Epoch: 73/500 	Training Loss: 0.011023
#
# Epoch: 74/500 	Training Loss: 0.010618
#
# Epoch: 75/500 	Training Loss: 0.012927
#
# Epoch: 76/500 	Training Loss: 0.011503
#
# Epoch: 77/500 	Training Loss: 0.011754
#
# Epoch: 78/500 	Training Loss: 0.010537
# Lowest MAPE: 0.03950820419101804
#
# Epoch: 79/500 	Training Loss: 0.010306
#
# Epoch: 80/500 	Training Loss: 0.010670
#
# Epoch: 81/500 	Training Loss: 0.011448
#
# Epoch: 82/500 	Training Loss: 0.012062
#
# Epoch: 83/500 	Training Loss: 0.012209
#
# Epoch: 84/500 	Training Loss: 0.011869
#
# Epoch: 85/500 	Training Loss: 0.011196
#
# Epoch: 86/500 	Training Loss: 0.010859
#
# Epoch: 87/500 	Training Loss: 0.010425
#
# Epoch: 88/500 	Training Loss: 0.010165
#
# Epoch: 89/500 	Training Loss: 0.010174
#
# Epoch: 90/500 	Training Loss: 0.010558
#
# Epoch: 91/500 	Training Loss: 0.011758
#
# Epoch: 92/500 	Training Loss: 0.011329
#
# Epoch: 93/500 	Training Loss: 0.010637
#
# Epoch: 94/500 	Training Loss: 0.010455
#
# Epoch: 95/500 	Training Loss: 0.010675
#
# Epoch: 96/500 	Training Loss: 0.010133
#
# Epoch: 97/500 	Training Loss: 0.010296
#
# Epoch: 98/500 	Training Loss: 0.010657
#
# Epoch: 99/500 	Training Loss: 0.010961
#
# Epoch: 100/500 	Training Loss: 0.010591
#
# Epoch: 101/500 	Training Loss: 0.010512
#
# Epoch: 102/500 	Training Loss: 0.012566
#
# Epoch: 103/500 	Training Loss: 0.010565
#
# Epoch: 104/500 	Training Loss: 0.010201
#
# Epoch: 105/500 	Training Loss: 0.009927
#
# Epoch: 106/500 	Training Loss: 0.011425
#
# Epoch: 107/500 	Training Loss: 0.011139
#
# Epoch: 108/500 	Training Loss: 0.010719
#
# Epoch: 109/500 	Training Loss: 0.010332
#
# Epoch: 110/500 	Training Loss: 0.009945
#
# Epoch: 111/500 	Training Loss: 0.010179
#
# Epoch: 112/500 	Training Loss: 0.010729
#
# Epoch: 113/500 	Training Loss: 0.010632
#
# Epoch: 114/500 	Training Loss: 0.009956
#
# Epoch: 115/500 	Training Loss: 0.009945
#
# Epoch: 116/500 	Training Loss: 0.009907
#
# Epoch: 117/500 	Training Loss: 0.010010
#
# Epoch: 118/500 	Training Loss: 0.011240
#
# Epoch: 119/500 	Training Loss: 0.010747
#
# Epoch: 120/500 	Training Loss: 0.010285
#
# Epoch: 121/500 	Training Loss: 0.010183
#
# Epoch: 122/500 	Training Loss: 0.010143
#
# Epoch: 123/500 	Training Loss: 0.011606
#
# Epoch: 124/500 	Training Loss: 0.010215
#
# Epoch: 125/500 	Training Loss: 0.011012
#
# Epoch: 126/500 	Training Loss: 0.010892
#
# Epoch: 127/500 	Training Loss: 0.009537
#
# Epoch: 128/500 	Training Loss: 0.011523
#
# Epoch: 129/500 	Training Loss: 0.010270
#
# Epoch: 130/500 	Training Loss: 0.009975
#
# Epoch: 131/500 	Training Loss: 0.010727
#
# Epoch: 132/500 	Training Loss: 0.010794
#
# Epoch: 133/500 	Training Loss: 0.010115
#
# Epoch: 134/500 	Training Loss: 0.011499
#
# Epoch: 135/500 	Training Loss: 0.010713
#
# Epoch: 136/500 	Training Loss: 0.009907
#
# Epoch: 137/500 	Training Loss: 0.009577
#
# Epoch: 138/500 	Training Loss: 0.011964
#
# Epoch: 139/500 	Training Loss: 0.010927
#
# Epoch: 140/500 	Training Loss: 0.009646
#
# Epoch: 141/500 	Training Loss: 0.010458
#
# Epoch: 142/500 	Training Loss: 0.008945
#
# Epoch: 143/500 	Training Loss: 0.009649
#
# Epoch: 144/500 	Training Loss: 0.009473
#
# Epoch: 145/500 	Training Loss: 0.009353
#
# Epoch: 146/500 	Training Loss: 0.010160
#
# Epoch: 147/500 	Training Loss: 0.010322
#
# Epoch: 148/500 	Training Loss: 0.009938
#
# Epoch: 149/500 	Training Loss: 0.009806
#
# Epoch: 150/500 	Training Loss: 0.011127
#
# Epoch: 151/500 	Training Loss: 0.011284
#
# Epoch: 152/500 	Training Loss: 0.009620
#
# Epoch: 153/500 	Training Loss: 0.010183
#
# Epoch: 154/500 	Training Loss: 0.009568
#
# Epoch: 155/500 	Training Loss: 0.010011
#
# Epoch: 156/500 	Training Loss: 0.010081
#
# Epoch: 157/500 	Training Loss: 0.010079
#
# Epoch: 158/500 	Training Loss: 0.009862
#
# Epoch: 159/500 	Training Loss: 0.010475
#
# Epoch: 160/500 	Training Loss: 0.009829
#
# Epoch: 161/500 	Training Loss: 0.009497
#
# Epoch: 162/500 	Training Loss: 0.010167
#
# Epoch: 163/500 	Training Loss: 0.009399
#
# Epoch: 164/500 	Training Loss: 0.010866
#
# Epoch: 165/500 	Training Loss: 0.010820
#
# Epoch: 166/500 	Training Loss: 0.009962
#
# Epoch: 167/500 	Training Loss: 0.009924
#
# Epoch: 168/500 	Training Loss: 0.009231
#
# Epoch: 169/500 	Training Loss: 0.009805
#
# Epoch: 170/500 	Training Loss: 0.009819
#
# Epoch: 171/500 	Training Loss: 0.009369
#
# Epoch: 172/500 	Training Loss: 0.010182
#
# Epoch: 173/500 	Training Loss: 0.010479
#
# Epoch: 174/500 	Training Loss: 0.010453
#
# Epoch: 175/500 	Training Loss: 0.010413
#
# Epoch: 176/500 	Training Loss: 0.010920
#
# Epoch: 177/500 	Training Loss: 0.011020
#
# Epoch: 178/500 	Training Loss: 0.009197
#
# Epoch: 179/500 	Training Loss: 0.009764
#
# Epoch: 180/500 	Training Loss: 0.009567
#
# Epoch: 181/500 	Training Loss: 0.009142
#
# Epoch: 182/500 	Training Loss: 0.009843
#
# Epoch: 183/500 	Training Loss: 0.010765
#
# Epoch: 184/500 	Training Loss: 0.009534
#
# Epoch: 185/500 	Training Loss: 0.009419
#
# Epoch: 186/500 	Training Loss: 0.012751
#
# Epoch: 187/500 	Training Loss: 0.010756
#
# Epoch: 188/500 	Training Loss: 0.009155
#
# Epoch: 189/500 	Training Loss: 0.009664
#
# Epoch: 190/500 	Training Loss: 0.009576
#
# Epoch: 191/500 	Training Loss: 0.009760
#
# Epoch: 192/500 	Training Loss: 0.009071
#
# Epoch: 193/500 	Training Loss: 0.009884
#
# Epoch: 194/500 	Training Loss: 0.009158
# Lowest MAPE: 0.039157757859578576
#
# Epoch: 195/500 	Training Loss: 0.008701
#
# Epoch: 196/500 	Training Loss: 0.009593
#
# Epoch: 197/500 	Training Loss: 0.009909
#
# Epoch: 198/500 	Training Loss: 0.009507
#
# Epoch: 199/500 	Training Loss: 0.010332
#
# Epoch: 200/500 	Training Loss: 0.010207
#
# Epoch: 201/500 	Training Loss: 0.009782
#
# Epoch: 202/500 	Training Loss: 0.009479
#
# Epoch: 203/500 	Training Loss: 0.010903
#
# Epoch: 204/500 	Training Loss: 0.010433
#
# Epoch: 205/500 	Training Loss: 0.008952
#
# Epoch: 206/500 	Training Loss: 0.008903
#
# Epoch: 207/500 	Training Loss: 0.009372
# Lowest MAPE: 0.03909482010154749
#
# Epoch: 208/500 	Training Loss: 0.009068
#
# Epoch: 209/500 	Training Loss: 0.009234
#
# Epoch: 210/500 	Training Loss: 0.009408
#
# Epoch: 211/500 	Training Loss: 0.009472
#
# Epoch: 212/500 	Training Loss: 0.010053
#
# Epoch: 213/500 	Training Loss: 0.008996
#
# Epoch: 214/500 	Training Loss: 0.009423
#
# Epoch: 215/500 	Training Loss: 0.009803
#
# Epoch: 216/500 	Training Loss: 0.010413
#
# Epoch: 217/500 	Training Loss: 0.009207
#
# Epoch: 218/500 	Training Loss: 0.009463
#
# Epoch: 219/500 	Training Loss: 0.009669
#
# Epoch: 220/500 	Training Loss: 0.009669
# Lowest MAPE: 0.03871322053941523
#
# Epoch: 221/500 	Training Loss: 0.009979
#
# Epoch: 222/500 	Training Loss: 0.008905
#
# Epoch: 223/500 	Training Loss: 0.009244
#
# Epoch: 224/500 	Training Loss: 0.010122
#
# Epoch: 225/500 	Training Loss: 0.009250
#
# Epoch: 226/500 	Training Loss: 0.011663
#
# Epoch: 227/500 	Training Loss: 0.010116
#
# Epoch: 228/500 	Training Loss: 0.009362
# Lowest MAPE: 0.03815051357882085
#
# Epoch: 229/500 	Training Loss: 0.009118
#
# Epoch: 230/500 	Training Loss: 0.009483
#
# Epoch: 231/500 	Training Loss: 0.009202
#
# Epoch: 232/500 	Training Loss: 0.010156
#
# Epoch: 233/500 	Training Loss: 0.008756
#
# Epoch: 234/500 	Training Loss: 0.009396
#
# Epoch: 235/500 	Training Loss: 0.009349
#
# Epoch: 236/500 	Training Loss: 0.009806
#
# Epoch: 237/500 	Training Loss: 0.010180
#
# Epoch: 238/500 	Training Loss: 0.009524
#
# Epoch: 239/500 	Training Loss: 0.009479
#
# Epoch: 240/500 	Training Loss: 0.009722
#
# Epoch: 241/500 	Training Loss: 0.009624
#
# Epoch: 242/500 	Training Loss: 0.009337
#
# Epoch: 243/500 	Training Loss: 0.009485
#
# Epoch: 244/500 	Training Loss: 0.009139
#
# Epoch: 245/500 	Training Loss: 0.009065
#
# Epoch: 246/500 	Training Loss: 0.010226
#
# Epoch: 247/500 	Training Loss: 0.009019
#
# Epoch: 248/500 	Training Loss: 0.009453
#
# Epoch: 249/500 	Training Loss: 0.010384
#
# Epoch: 250/500 	Training Loss: 0.010893
#
# Epoch: 251/500 	Training Loss: 0.009752
#
# Epoch: 252/500 	Training Loss: 0.009573
#
# Epoch: 253/500 	Training Loss: 0.010658
#
# Epoch: 254/500 	Training Loss: 0.009626
#
# Epoch: 255/500 	Training Loss: 0.009521
#
# Epoch: 256/500 	Training Loss: 0.008646
#
# Epoch: 257/500 	Training Loss: 0.008834
#
# Epoch: 258/500 	Training Loss: 0.010032
#
# Epoch: 259/500 	Training Loss: 0.009645
#
# Epoch: 260/500 	Training Loss: 0.009082
#
# Epoch: 261/500 	Training Loss: 0.008836
#
# Epoch: 262/500 	Training Loss: 0.009185
#
# Epoch: 263/500 	Training Loss: 0.009075
#
# Epoch: 264/500 	Training Loss: 0.009186
# Lowest MAPE: 0.038119134087292304
#
# Epoch: 265/500 	Training Loss: 0.009089
#
# Epoch: 266/500 	Training Loss: 0.011987
#
# Epoch: 267/500 	Training Loss: 0.009753
#
# Epoch: 268/500 	Training Loss: 0.009859
#
# Epoch: 269/500 	Training Loss: 0.010046
#
# Epoch: 270/500 	Training Loss: 0.009419
#
# Epoch: 271/500 	Training Loss: 0.008904
#
# Epoch: 272/500 	Training Loss: 0.010104
#
# Epoch: 273/500 	Training Loss: 0.009769
#
# Epoch: 274/500 	Training Loss: 0.010749
#
# Epoch: 275/500 	Training Loss: 0.009505
#
# Epoch: 276/500 	Training Loss: 0.008945
# Lowest MAPE: 0.03770035615065031
#
# Epoch: 277/500 	Training Loss: 0.009792
#
# Epoch: 278/500 	Training Loss: 0.009497
#
# Epoch: 279/500 	Training Loss: 0.009565
#
# Epoch: 280/500 	Training Loss: 0.009154
#
# Epoch: 281/500 	Training Loss: 0.009944
#
# Epoch: 282/500 	Training Loss: 0.009662
#
# Epoch: 283/500 	Training Loss: 0.009026
#
# Epoch: 284/500 	Training Loss: 0.009134
#
# Epoch: 285/500 	Training Loss: 0.009215
#
# Epoch: 286/500 	Training Loss: 0.010263
#
# Epoch: 287/500 	Training Loss: 0.009744
#
# Epoch: 288/500 	Training Loss: 0.009625
#
# Epoch: 289/500 	Training Loss: 0.009355
#
# Epoch: 290/500 	Training Loss: 0.008696
#
# Epoch: 291/500 	Training Loss: 0.008968
#
# Epoch: 292/500 	Training Loss: 0.010366
#
# Epoch: 293/500 	Training Loss: 0.010332
#
# Epoch: 294/500 	Training Loss: 0.008908
#
# Epoch: 295/500 	Training Loss: 0.010284
#
# Epoch: 296/500 	Training Loss: 0.009841
#
# Epoch: 297/500 	Training Loss: 0.009362
#
# Epoch: 298/500 	Training Loss: 0.010419
#
# Epoch: 299/500 	Training Loss: 0.009705
#
# Epoch: 300/500 	Training Loss: 0.008936
#
# Epoch: 301/500 	Training Loss: 0.008942
#
# Epoch: 302/500 	Training Loss: 0.009848
#
# Epoch: 303/500 	Training Loss: 0.008757
#
# Epoch: 304/500 	Training Loss: 0.009595
#
# Epoch: 305/500 	Training Loss: 0.008894
# Lowest MAPE: 0.03701178112597224
#
# Epoch: 306/500 	Training Loss: 0.008642
#
# Epoch: 307/500 	Training Loss: 0.009039
#
# Epoch: 308/500 	Training Loss: 0.009335
#
# Epoch: 309/500 	Training Loss: 0.010081
#
# Epoch: 310/500 	Training Loss: 0.009926
#
# Epoch: 311/500 	Training Loss: 0.009017
#
# Epoch: 312/500 	Training Loss: 0.010329
#
# Epoch: 313/500 	Training Loss: 0.009349
#
# Epoch: 314/500 	Training Loss: 0.010259
#
# Epoch: 315/500 	Training Loss: 0.009135
#
# Epoch: 316/500 	Training Loss: 0.009138
#
# Epoch: 317/500 	Training Loss: 0.009971
#
# Epoch: 318/500 	Training Loss: 0.009459
#
# Epoch: 319/500 	Training Loss: 0.009552
#
# Epoch: 320/500 	Training Loss: 0.008986
#
# Epoch: 321/500 	Training Loss: 0.009414
#
# Epoch: 322/500 	Training Loss: 0.009211
#
# Epoch: 323/500 	Training Loss: 0.008925
#
# Epoch: 324/500 	Training Loss: 0.009151
#
# Epoch: 325/500 	Training Loss: 0.009507
#
# Epoch: 326/500 	Training Loss: 0.008639
#
# Epoch: 327/500 	Training Loss: 0.009859
#
# Epoch: 328/500 	Training Loss: 0.009629
#
# Epoch: 329/500 	Training Loss: 0.010249
#
# Epoch: 330/500 	Training Loss: 0.010565
#
# Epoch: 331/500 	Training Loss: 0.009208
#
# Epoch: 332/500 	Training Loss: 0.009287
#
# Epoch: 333/500 	Training Loss: 0.010024
#
# Epoch: 334/500 	Training Loss: 0.009405
#
# Epoch: 335/500 	Training Loss: 0.009513
#
# Epoch: 336/500 	Training Loss: 0.009164
#
# Epoch: 337/500 	Training Loss: 0.009026
#
# Epoch: 338/500 	Training Loss: 0.009427
#
# Epoch: 339/500 	Training Loss: 0.009115
#
# Epoch: 340/500 	Training Loss: 0.009093
#
# Epoch: 341/500 	Training Loss: 0.009476
#
# Epoch: 342/500 	Training Loss: 0.009887
#
# Epoch: 343/500 	Training Loss: 0.009472
#
# Epoch: 344/500 	Training Loss: 0.009760
#
# Epoch: 345/500 	Training Loss: 0.009790
#
# Epoch: 346/500 	Training Loss: 0.010358
#
# Epoch: 347/500 	Training Loss: 0.008787
#
# Epoch: 348/500 	Training Loss: 0.008888
#
# Epoch: 349/500 	Training Loss: 0.008757
#
# Epoch: 350/500 	Training Loss: 0.009124
#
# Epoch: 351/500 	Training Loss: 0.008795
#
# Epoch: 352/500 	Training Loss: 0.008707
#
# Epoch: 353/500 	Training Loss: 0.009037
#
# Epoch: 354/500 	Training Loss: 0.009240
#
# Epoch: 355/500 	Training Loss: 0.010427
#
# Epoch: 356/500 	Training Loss: 0.009386
#
# Epoch: 357/500 	Training Loss: 0.009316
#
# Epoch: 358/500 	Training Loss: 0.008969
#
# Epoch: 359/500 	Training Loss: 0.009765
#
# Epoch: 360/500 	Training Loss: 0.009268
#
# Epoch: 361/500 	Training Loss: 0.009458
#
# Epoch: 362/500 	Training Loss: 0.009346
#
# Epoch: 363/500 	Training Loss: 0.009724
#
# Epoch: 364/500 	Training Loss: 0.009924
#
# Epoch: 365/500 	Training Loss: 0.009835
#
# Epoch: 366/500 	Training Loss: 0.008290
#
# Epoch: 367/500 	Training Loss: 0.009592
#
# Epoch: 368/500 	Training Loss: 0.009145
#
# Epoch: 369/500 	Training Loss: 0.009881
#
# Epoch: 370/500 	Training Loss: 0.008863
#
# Epoch: 371/500 	Training Loss: 0.008694
#
# Epoch: 372/500 	Training Loss: 0.008252
#
# Epoch: 373/500 	Training Loss: 0.009312
#
# Epoch: 374/500 	Training Loss: 0.009049
#
# Epoch: 375/500 	Training Loss: 0.010804
#
# Epoch: 376/500 	Training Loss: 0.009829
#
# Epoch: 377/500 	Training Loss: 0.009308
#
# Epoch: 378/500 	Training Loss: 0.009202
#
# Epoch: 379/500 	Training Loss: 0.009290
#
# Epoch: 380/500 	Training Loss: 0.010046
#
# Epoch: 381/500 	Training Loss: 0.009737
#
# Epoch: 382/500 	Training Loss: 0.009841
#
# Epoch: 383/500 	Training Loss: 0.008744
#
# Epoch: 384/500 	Training Loss: 0.009232
#
# Epoch: 385/500 	Training Loss: 0.009239
#
# Epoch: 386/500 	Training Loss: 0.010028
#
# Epoch: 387/500 	Training Loss: 0.009136
#
# Epoch: 388/500 	Training Loss: 0.009653
#
# Epoch: 389/500 	Training Loss: 0.010294
#
# Epoch: 390/500 	Training Loss: 0.009008
#
# Epoch: 391/500 	Training Loss: 0.008902
#
# Epoch: 392/500 	Training Loss: 0.010257
#
# Epoch: 393/500 	Training Loss: 0.008744
#
# Epoch: 394/500 	Training Loss: 0.008792
#
# Epoch: 395/500 	Training Loss: 0.009124
#
# Epoch: 396/500 	Training Loss: 0.009172
#
# Epoch: 397/500 	Training Loss: 0.008858
#
# Epoch: 398/500 	Training Loss: 0.009207
#
# Epoch: 399/500 	Training Loss: 0.008764
#
# Epoch: 400/500 	Training Loss: 0.009085
#
# Epoch: 401/500 	Training Loss: 0.009208
#
# Epoch: 402/500 	Training Loss: 0.009004
#
# Epoch: 403/500 	Training Loss: 0.010262
#
# Epoch: 404/500 	Training Loss: 0.009952
#
# Epoch: 405/500 	Training Loss: 0.009802
#
# Epoch: 406/500 	Training Loss: 0.009279
#
# Epoch: 407/500 	Training Loss: 0.009317
#
# Epoch: 408/500 	Training Loss: 0.009038
#
# Epoch: 409/500 	Training Loss: 0.008785
#
# Epoch: 410/500 	Training Loss: 0.009973
#
# Epoch: 411/500 	Training Loss: 0.009201
#
# Epoch: 412/500 	Training Loss: 0.008778
#
# Epoch: 413/500 	Training Loss: 0.008907
#
# Epoch: 414/500 	Training Loss: 0.008804
#
# Epoch: 415/500 	Training Loss: 0.010051
#
# Epoch: 416/500 	Training Loss: 0.009290
#
# Epoch: 417/500 	Training Loss: 0.008998
#
# Epoch: 418/500 	Training Loss: 0.009396
#
# Epoch: 419/500 	Training Loss: 0.009137
#
# Epoch: 420/500 	Training Loss: 0.009384
#
# Epoch: 421/500 	Training Loss: 0.009310
#
# Epoch: 422/500 	Training Loss: 0.009081
#
# Epoch: 423/500 	Training Loss: 0.009409
#
# Epoch: 424/500 	Training Loss: 0.009087
#
# Epoch: 425/500 	Training Loss: 0.008488
#
# Epoch: 426/500 	Training Loss: 0.009043
#
# Epoch: 427/500 	Training Loss: 0.009494
#
# Epoch: 428/500 	Training Loss: 0.009442
#
# Epoch: 429/500 	Training Loss: 0.009248
#
# Epoch: 430/500 	Training Loss: 0.009035
#
# Epoch: 431/500 	Training Loss: 0.008748
#
# Epoch: 432/500 	Training Loss: 0.008746
#
# Epoch: 433/500 	Training Loss: 0.008917
#
# Epoch: 434/500 	Training Loss: 0.008919
#
# Epoch: 435/500 	Training Loss: 0.009037
#
# Epoch: 436/500 	Training Loss: 0.008914
#
# Epoch: 437/500 	Training Loss: 0.008546
#
# Epoch: 438/500 	Training Loss: 0.008642
#
# Epoch: 439/500 	Training Loss: 0.009364
#
# Epoch: 440/500 	Training Loss: 0.009408
#
# Epoch: 441/500 	Training Loss: 0.009387
#
# Epoch: 442/500 	Training Loss: 0.009520
#
# Epoch: 443/500 	Training Loss: 0.008901
#
# Epoch: 444/500 	Training Loss: 0.009110
#
# Epoch: 445/500 	Training Loss: 0.008913
#
# Epoch: 446/500 	Training Loss: 0.008848
#
# Epoch: 447/500 	Training Loss: 0.009065
#
# Epoch: 448/500 	Training Loss: 0.009693
#
# Epoch: 449/500 	Training Loss: 0.011073
#
# Epoch: 450/500 	Training Loss: 0.010109
#
# Epoch: 451/500 	Training Loss: 0.009847
#
# Epoch: 452/500 	Training Loss: 0.008992
#
# Epoch: 453/500 	Training Loss: 0.008747
#
# Epoch: 454/500 	Training Loss: 0.009449
#
# Epoch: 455/500 	Training Loss: 0.008914
#
# Epoch: 456/500 	Training Loss: 0.009610
#
# Epoch: 457/500 	Training Loss: 0.009865
#
# Epoch: 458/500 	Training Loss: 0.008325
#
# Epoch: 459/500 	Training Loss: 0.008579
#
# Epoch: 460/500 	Training Loss: 0.008944
#
# Epoch: 461/500 	Training Loss: 0.009825
#
# Epoch: 462/500 	Training Loss: 0.009086
#
# Epoch: 463/500 	Training Loss: 0.009001
#
# Epoch: 464/500 	Training Loss: 0.009179
#
# Epoch: 465/500 	Training Loss: 0.008375
#
# Epoch: 466/500 	Training Loss: 0.008589
#
# Epoch: 467/500 	Training Loss: 0.008696
#
# Epoch: 468/500 	Training Loss: 0.009032
#
# Epoch: 469/500 	Training Loss: 0.008725
#
# Epoch: 470/500 	Training Loss: 0.008955
#
# Epoch: 471/500 	Training Loss: 0.009473
#
# Epoch: 472/500 	Training Loss: 0.009716
#
# Epoch: 473/500 	Training Loss: 0.008978
#
# Epoch: 474/500 	Training Loss: 0.008578
#
# Epoch: 475/500 	Training Loss: 0.009109
#
# Epoch: 476/500 	Training Loss: 0.008667
#
# Epoch: 477/500 	Training Loss: 0.009034
#
# Epoch: 478/500 	Training Loss: 0.008630
#
# Epoch: 479/500 	Training Loss: 0.008891
#
# Epoch: 480/500 	Training Loss: 0.009361
#
# Epoch: 481/500 	Training Loss: 0.008991
#
# Epoch: 482/500 	Training Loss: 0.009380
#
# Epoch: 483/500 	Training Loss: 0.009087
#
# Epoch: 484/500 	Training Loss: 0.009168
#
# Epoch: 485/500 	Training Loss: 0.008816
#
# Epoch: 486/500 	Training Loss: 0.009898
#
# Epoch: 487/500 	Training Loss: 0.009204
#
# Epoch: 488/500 	Training Loss: 0.009350
#
# Epoch: 489/500 	Training Loss: 0.009063
#
# Epoch: 490/500 	Training Loss: 0.009399
#
# Epoch: 491/500 	Training Loss: 0.008378
#
# Epoch: 492/500 	Training Loss: 0.009327
#
# Epoch: 493/500 	Training Loss: 0.009841
#
# Epoch: 494/500 	Training Loss: 0.009091
#
# Epoch: 495/500 	Training Loss: 0.009549
#
# Epoch: 496/500 	Training Loss: 0.009292
#
# Epoch: 497/500 	Training Loss: 0.009093
#
# Epoch: 498/500 	Training Loss: 0.008629
#
# Epoch: 499/500 	Training Loss: 0.008707
#
# Epoch: 500/500 	Training Loss: 0.008985
#
# Time taken: 90.16287449999982

# %%
plt.plot(train_losses)

# %%
model.load_state_dict(torch.load('PyTorch_Model/Single_PositiveDuration_lowest.pt', map_location=torch.device('cpu')))

model.eval()           # prep model for *evaluation*
model.to(device)
with torch.no_grad():  # turn off gradient to save memory
    y_predNN_torch = model(X_test_torch.to(device))

y_predNN_normal = y_predNN_torch.cpu().numpy()     # convert to numpy array
y_test_normal = y_test_torch.cpu().numpy()



print(y_predNN_normal)
# Out:
# [[-1.5452528 ]
#  [-1.3097048 ]
#  [-1.096423  ]
#  ...
#  [ 0.24417306]
#  [ 0.2741825 ]
#  [ 0.3046593 ]]

# %%
mape = mean_absolute_percentage_error(y_test_normal, y_predNN_normal)
r2 = r2_score(y_test_normal, y_predNN_normal)
rmse = np.sqrt(mean_squared_error(y_test_normal, y_predNN_normal))
print(f"Scores in normal distribution: r2 = {r2}, mape = {mape}, rmse = {rmse}")
# Out:
# Scores in normal distribution: r2 = 0.9586192165311513, mape = 0.6989656686782837, rmse = 0.19846461713314056

# %%
y_predNN = quantile.inverse_transform(y_predNN_normal)
mape = mean_absolute_percentage_error(y_test, y_predNN)
r2 = r2_score(y_test, y_predNN)
rmse = np.sqrt(mean_squared_error(y_test, y_predNN))


print(f"Scores in actual distribution for positive duration")
print('r2:', r2*100)
print('mape:', mape*100)
print('rmse:', rmse)
print()
# Out:
# Scores in actual distribution for positive duration
# r2: 96.07807196694972
# mape: 3.701178112597224
# rmse: 0.0006694866439281673
