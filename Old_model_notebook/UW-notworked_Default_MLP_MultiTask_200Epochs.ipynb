# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import timeit
#import shap
from sklearn.metrics import r2_score, mean_absolute_percentage_error, mean_squared_error
from sklearn.model_selection import cross_val_score, GridSearchCV, KFold
from sklearn.model_selection import train_test_split

# %% [markdown]
# ___

# %% [markdown]
# # Read-in and One-Hot Encoding

# %%
df1 = pd.read_excel("data_new/train.xlsx", sheet_name="positive_peak_time")
df2 = pd.read_excel("data_new/train.xlsx", sheet_name="negative_peak_time")
df3 = pd.read_excel("data_new/train.xlsx", sheet_name="arrival_time")
df4 = pd.read_excel("data_new/train.xlsx", sheet_name="positive_duration")
df5 = pd.read_excel("data_new/train.xlsx", sheet_name="negative_duration")
df6 = pd.read_excel("data_new/train.xlsx", sheet_name="positive_pressure")
df7 = pd.read_excel("data_new/train.xlsx", sheet_name="negative_pressure")
df8 = pd.read_excel("data_new/train.xlsx", sheet_name="positive_impulse")



dt1 = pd.read_excel("data_new/test.xlsx", sheet_name="positive_peak_time")
dt2 = pd.read_excel("data_new/test.xlsx", sheet_name="negative_peak_time")
dt3 = pd.read_excel("data_new/test.xlsx", sheet_name="arrival_time")
dt4 = pd.read_excel("data_new/test.xlsx", sheet_name="positive_duration")
dt5 = pd.read_excel("data_new/test.xlsx", sheet_name="negative_duration")
dt6 = pd.read_excel("data_new/test.xlsx", sheet_name="positive_pressure")
dt7 = pd.read_excel("data_new/test.xlsx", sheet_name="negative_pressure")
dt8 = pd.read_excel("data_new/test.xlsx", sheet_name="positive_impulse")

# %%
df1
# Out:
#          ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0      B291                         13.6          0.665119             1.0
# 1      B291                         13.6          0.665119             1.0
# 2      B291                         13.6          0.665119             1.0
# 3      B291                         13.6          0.665119             1.0
# 4      B291                         13.6          0.665119             1.0
# ...     ...                          ...               ...             ...
# 21595  B103                         30.7          0.181290             0.6
# 21596  B103                         30.7          0.181290             0.6
# 21597  B103                         30.7          0.181290             0.6
# 21598  B103                         30.7          0.181290             0.6
# 21599  B103                         30.7          0.181290             0.6
#
#        Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 0                  4.0              0.8                  1.8
# 1                  4.0              0.8                  1.8
# 2                  4.0              0.8                  1.8
# 3                  4.0              0.8                  1.8
# 4                  4.0              0.8                  1.8
# ...                ...              ...                  ...
# 21595              2.0              2.8                  1.2
# 21596              2.0              2.8                  1.2
# 21597              2.0              2.8                  1.2
# 21598              2.0              2.8                  1.2
# 21599              2.0              2.8                  1.2
#
#        Tank Height with Gas (m)   Vapour Temerature (K)  \
# 0                           0.4                   435.0
# 1                           0.4                   435.0
# 2                           0.4                   435.0
# 3                           0.4                   435.0
# 4                           0.4                   435.0
# ...                         ...                     ...
# 21595                       2.2                   334.7
# 21596                       2.2                   334.7
# 21597                       2.2                   334.7
# 21598                       2.2                   334.7
# 21599                       2.2                   334.7
#
#         Liquid Temerature (K)       Status  Stand-off Distance    Target
# 0                       372.5  Superheated                   5  0.012166
# 1                       372.5  Superheated                   6  0.014556
# 2                       372.5  Superheated                   7  0.017034
# 3                       372.5  Superheated                   8  0.019576
# 4                       372.5  Superheated                   9  0.022172
# ...                       ...          ...                 ...       ...
# 21595                   404.9    Subcooled                  36  0.093782
# 21596                   404.9    Subcooled                  37  0.096635
# 21597                   404.9    Subcooled                  38  0.099487
# 21598                   404.9    Subcooled                  39  0.102341
# 21599                   404.9    Subcooled                  40  0.105201
#
# [21600 rows x 13 columns]

# %%
dt1
# Out:
#         ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0     P197                    11.559040          0.602823             3.0
# 1     P197                    11.559040          0.602823             3.0
# 2     P197                    11.559040          0.602823             3.0
# 3     P197                    11.559040          0.602823             3.0
# 4     P197                    11.559040          0.602823             3.0
# ...    ...                          ...               ...             ...
# 7195   P55                     5.970915          0.284706             0.6
# 7196   P55                     5.970915          0.284706             0.6
# 7197   P55                     5.970915          0.284706             0.6
# 7198   P55                     5.970915          0.284706             0.6
# 7199   P55                     5.970915          0.284706             0.6
#
#       Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 0                 0.8              2.2                  0.2
# 1                 0.8              2.2                  0.2
# 2                 0.8              2.2                  0.2
# 3                 0.8              2.2                  0.2
# 4                 0.8              2.2                  0.2
# ...               ...              ...                  ...
# 7195              9.8              2.8                  1.0
# 7196              9.8              2.8                  1.0
# 7197              9.8              2.8                  1.0
# 7198              9.8              2.8                  1.0
# 7199              9.8              2.8                  1.0
#
#       Tank Height with Gas (m)   Vapour Temerature (K)  \
# 0                          1.0                   296.7
# 1                          1.0                   296.7
# 2                          1.0                   296.7
# 3                          1.0                   296.7
# 4                          1.0                   296.7
# ...                        ...                     ...
# 7195                       2.2                   439.3
# 7196                       2.2                   439.3
# 7197                       2.2                   439.3
# 7198                       2.2                   439.3
# 7199                       2.2                   439.3
#
#        Liquid Temerature (K)       Status  Stand-off Distance    Target
# 0                      328.5  Superheated                   5  0.012114
# 1                      328.5  Superheated                   6  0.014798
# 2                      328.5  Superheated                   7  0.017533
# 3                      328.5  Superheated                   8  0.020293
# 4                      328.5  Superheated                   9  0.023077
# ...                      ...          ...                 ...       ...
# 7195                   349.9  Superheated                  36  0.091819
# 7196                   349.9  Superheated                  37  0.094618
# 7197                   349.9  Superheated                  38  0.097421
# 7198                   349.9  Superheated                  39  0.100227
# 7199                   349.9  Superheated                  40  0.103035
#
# [7200 rows x 13 columns]

# %%
# Label encoding 'Status' feature into 0 and 1 
# 0 for Subcooled and 1 for Superheated

from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()

df5['Status'] = LE.fit_transform(df5['Status'])
dt5['Status'] = LE.fit_transform(dt5['Status'])

df5
# Out:
#          ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0      B291                         13.6          0.665119             1.0
# 1      B291                         13.6          0.665119             1.0
# 2      B291                         13.6          0.665119             1.0
# 3      B291                         13.6          0.665119             1.0
# 4      B291                         13.6          0.665119             1.0
# ...     ...                          ...               ...             ...
# 21595  B103                         30.7          0.181290             0.6
# 21596  B103                         30.7          0.181290             0.6
# 21597  B103                         30.7          0.181290             0.6
# 21598  B103                         30.7          0.181290             0.6
# 21599  B103                         30.7          0.181290             0.6
#
#        Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 0                  4.0              0.8                  1.8
# 1                  4.0              0.8                  1.8
# 2                  4.0              0.8                  1.8
# 3                  4.0              0.8                  1.8
# 4                  4.0              0.8                  1.8
# ...                ...              ...                  ...
# 21595              2.0              2.8                  1.2
# 21596              2.0              2.8                  1.2
# 21597              2.0              2.8                  1.2
# 21598              2.0              2.8                  1.2
# 21599              2.0              2.8                  1.2
#
#        Tank Height with Gas (m)   Vapour Temerature (K)  \
# 0                           0.4                   435.0
# 1                           0.4                   435.0
# 2                           0.4                   435.0
# 3                           0.4                   435.0
# 4                           0.4                   435.0
# ...                         ...                     ...
# 21595                       2.2                   334.7
# 21596                       2.2                   334.7
# 21597                       2.2                   334.7
# 21598                       2.2                   334.7
# 21599                       2.2                   334.7
#
#         Liquid Temerature (K)  Status  Stand-off Distance    Target
# 0                       372.5       1                   5  0.009827
# 1                       372.5       1                   6  0.009906
# 2                       372.5       1                   7  0.009970
# 3                       372.5       1                   8  0.010039
# 4                       372.5       1                   9  0.010011
# ...                       ...     ...                 ...       ...
# 21595                   404.9       0                  36  0.017944
# 21596                   404.9       0                  37  0.017724
# 21597                   404.9       0                  38  0.017498
# 21598                   404.9       0                  39  0.017280
# 21599                   404.9       0                  40  0.017078
#
# [21600 rows x 13 columns]

# %%
dt5.iloc[30:50,:]
# Out:
#       ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 30  P197                     11.55904          0.602823             3.0
# 31  P197                     11.55904          0.602823             3.0
# 32  P197                     11.55904          0.602823             3.0
# 33  P197                     11.55904          0.602823             3.0
# 34  P197                     11.55904          0.602823             3.0
# 35  P197                     11.55904          0.602823             3.0
# 36  P168                     12.72223          0.648320             1.8
# 37  P168                     12.72223          0.648320             1.8
# 38  P168                     12.72223          0.648320             1.8
# 39  P168                     12.72223          0.648320             1.8
# 40  P168                     12.72223          0.648320             1.8
# 41  P168                     12.72223          0.648320             1.8
# 42  P168                     12.72223          0.648320             1.8
# 43  P168                     12.72223          0.648320             1.8
# 44  P168                     12.72223          0.648320             1.8
# 45  P168                     12.72223          0.648320             1.8
# 46  P168                     12.72223          0.648320             1.8
# 47  P168                     12.72223          0.648320             1.8
# 48  P168                     12.72223          0.648320             1.8
# 49  P168                     12.72223          0.648320             1.8
#
#     Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 30              0.8              2.2                  0.2
# 31              0.8              2.2                  0.2
# 32              0.8              2.2                  0.2
# 33              0.8              2.2                  0.2
# 34              0.8              2.2                  0.2
# 35              0.8              2.2                  0.2
# 36              8.2              0.6                  1.8
# 37              8.2              0.6                  1.8
# 38              8.2              0.6                  1.8
# 39              8.2              0.6                  1.8
# 40              8.2              0.6                  1.8
# 41              8.2              0.6                  1.8
# 42              8.2              0.6                  1.8
# 43              8.2              0.6                  1.8
# 44              8.2              0.6                  1.8
# 45              8.2              0.6                  1.8
# 46              8.2              0.6                  1.8
# 47              8.2              0.6                  1.8
# 48              8.2              0.6                  1.8
# 49              8.2              0.6                  1.8
#
#     Tank Height with Gas (m)   Vapour Temerature (K)   Liquid Temerature (K)  \
# 30                       1.0                   296.7                   328.5
# 31                       1.0                   296.7                   328.5
# 32                       1.0                   296.7                   328.5
# 33                       1.0                   296.7                   328.5
# 34                       1.0                   296.7                   328.5
# 35                       1.0                   296.7                   328.5
# 36                       0.2                   389.7                   296.4
# 37                       0.2                   389.7                   296.4
# 38                       0.2                   389.7                   296.4
# 39                       0.2                   389.7                   296.4
# 40                       0.2                   389.7                   296.4
# 41                       0.2                   389.7                   296.4
# 42                       0.2                   389.7                   296.4
# 43                       0.2                   389.7                   296.4
# 44                       0.2                   389.7                   296.4
# 45                       0.2                   389.7                   296.4
# 46                       0.2                   389.7                   296.4
# 47                       0.2                   389.7                   296.4
# 48                       0.2                   389.7                   296.4
# 49                       0.2                   389.7                   296.4
#
#     Status  Stand-off Distance    Target
# 30       1                  35  0.015426
# 31       1                  36  0.015341
# 32       1                  37  0.015277
# 33       1                  38  0.015224
# 34       1                  39  0.015191
# 35       1                  40  0.015170
# 36       0                   5  0.009043
# 37       0                   6  0.009390
# 38       0                   7  0.009452
# 39       0                   8  0.009528
# 40       0                   9  0.009658
# 41       0                  10  0.009688
# 42       0                  11  0.009588
# 43       0                  12  0.009598
# 44       0                  13  0.009700
# 45       0                  14  0.009631
# 46       0                  15  0.009524
# 47       0                  16  0.012086
# 48       0                  17  0.012530
# 49       0                  18  0.012757

# %%
X_traindf = df5.drop(['ID','Target'], axis=1)
X_testdf = dt5.drop(['ID','Target'], axis=1)

X_traindf
# Out:
#        Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0                             13.6          0.665119             1.0
# 1                             13.6          0.665119             1.0
# 2                             13.6          0.665119             1.0
# 3                             13.6          0.665119             1.0
# 4                             13.6          0.665119             1.0
# ...                            ...               ...             ...
# 21595                         30.7          0.181290             0.6
# 21596                         30.7          0.181290             0.6
# 21597                         30.7          0.181290             0.6
# 21598                         30.7          0.181290             0.6
# 21599                         30.7          0.181290             0.6
#
#        Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 0                  4.0              0.8                  1.8
# 1                  4.0              0.8                  1.8
# 2                  4.0              0.8                  1.8
# 3                  4.0              0.8                  1.8
# 4                  4.0              0.8                  1.8
# ...                ...              ...                  ...
# 21595              2.0              2.8                  1.2
# 21596              2.0              2.8                  1.2
# 21597              2.0              2.8                  1.2
# 21598              2.0              2.8                  1.2
# 21599              2.0              2.8                  1.2
#
#        Tank Height with Gas (m)   Vapour Temerature (K)  \
# 0                           0.4                   435.0
# 1                           0.4                   435.0
# 2                           0.4                   435.0
# 3                           0.4                   435.0
# 4                           0.4                   435.0
# ...                         ...                     ...
# 21595                       2.2                   334.7
# 21596                       2.2                   334.7
# 21597                       2.2                   334.7
# 21598                       2.2                   334.7
# 21599                       2.2                   334.7
#
#         Liquid Temerature (K)  Status  Stand-off Distance
# 0                       372.5       1                   5
# 1                       372.5       1                   6
# 2                       372.5       1                   7
# 3                       372.5       1                   8
# 4                       372.5       1                   9
# ...                       ...     ...                 ...
# 21595                   404.9       0                  36
# 21596                   404.9       0                  37
# 21597                   404.9       0                  38
# 21598                   404.9       0                  39
# 21599                   404.9       0                  40
#
# [21600 rows x 11 columns]

# %%
X_testdf
# Out:
#       Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0                       11.559040          0.602823             3.0
# 1                       11.559040          0.602823             3.0
# 2                       11.559040          0.602823             3.0
# 3                       11.559040          0.602823             3.0
# 4                       11.559040          0.602823             3.0
# ...                           ...               ...             ...
# 7195                     5.970915          0.284706             0.6
# 7196                     5.970915          0.284706             0.6
# 7197                     5.970915          0.284706             0.6
# 7198                     5.970915          0.284706             0.6
# 7199                     5.970915          0.284706             0.6
#
#       Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 0                 0.8              2.2                  0.2
# 1                 0.8              2.2                  0.2
# 2                 0.8              2.2                  0.2
# 3                 0.8              2.2                  0.2
# 4                 0.8              2.2                  0.2
# ...               ...              ...                  ...
# 7195              9.8              2.8                  1.0
# 7196              9.8              2.8                  1.0
# 7197              9.8              2.8                  1.0
# 7198              9.8              2.8                  1.0
# 7199              9.8              2.8                  1.0
#
#       Tank Height with Gas (m)   Vapour Temerature (K)  \
# 0                          1.0                   296.7
# 1                          1.0                   296.7
# 2                          1.0                   296.7
# 3                          1.0                   296.7
# 4                          1.0                   296.7
# ...                        ...                     ...
# 7195                       2.2                   439.3
# 7196                       2.2                   439.3
# 7197                       2.2                   439.3
# 7198                       2.2                   439.3
# 7199                       2.2                   439.3
#
#        Liquid Temerature (K)  Status  Stand-off Distance
# 0                      328.5       1                   5
# 1                      328.5       1                   6
# 2                      328.5       1                   7
# 3                      328.5       1                   8
# 4                      328.5       1                   9
# ...                      ...     ...                 ...
# 7195                   349.9       1                  36
# 7196                   349.9       1                  37
# 7197                   349.9       1                  38
# 7198                   349.9       1                  39
# 7199                   349.9       1                  40
#
# [7200 rows x 11 columns]

# %%
y5_train = df5['Target']
y5_train
# Out:
# 0        0.009827
# 1        0.009906
# 2        0.009970
# 3        0.010039
# 4        0.010011
#            ...
# 21595    0.017944
# 21596    0.017724
# 21597    0.017498
# 21598    0.017280
# 21599    0.017078
# Name: Target, Length: 21600, dtype: float64

# %%
y1_train = df1['Target']
y2_train = df2['Target']
y3_train = df3['Target']
y4_train = df4['Target']
y6_train = df6['Target']
y7_train = df7['Target']
y8_train = df8['Target']

# %%
y1_test = dt1['Target']
y2_test = dt2['Target']
y3_test = dt3['Target']
y4_test = dt4['Target']
y5_test = dt5['Target']
y6_test = dt6['Target']
y7_test = dt7['Target']
y8_test = dt8['Target']

y1_test
# Out:
# 0       0.012114
# 1       0.014798
# 2       0.017533
# 3       0.020293
# 4       0.023077
#           ...
# 7195    0.091819
# 7196    0.094618
# 7197    0.097421
# 7198    0.100227
# 7199    0.103035
# Name: Target, Length: 7200, dtype: float64

# %% [markdown]
# ___

# %% [markdown]
# # Standardization and Power Transform

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import QuantileTransformer

# %%
# Processing both X_train and X_test using standardization
scaler = StandardScaler()
X_train = scaler.fit_transform(X_traindf)
X_test = scaler.transform(X_testdf)

# %%
# Double check if it succeeded
# df_stdscal = pd.DataFrame(X_train)
# df_stdscal.hist(figsize = (20,20), bins=10)

# %%
quantile1 = QuantileTransformer(output_distribution='normal', random_state=42)
quantile2 = QuantileTransformer(output_distribution='normal', random_state=42)
quantile3 = QuantileTransformer(output_distribution='normal', random_state=42)
quantile4 = QuantileTransformer(output_distribution='normal', random_state=42)
quantile5 = QuantileTransformer(output_distribution='normal', random_state=42)
quantile6 = QuantileTransformer(output_distribution='normal', random_state=42)
quantile7 = QuantileTransformer(output_distribution='normal', random_state=42)
quantile8 = QuantileTransformer(output_distribution='normal', random_state=42)


y1_train_normal = quantile1.fit_transform(y1_train.values.reshape(-1,1))
y1_test_normal = quantile1.transform(y1_test.values.reshape(-1,1))


y2_train_normal = quantile2.fit_transform(y2_train.values.reshape(-1,1))
y2_test_normal = quantile2.transform(y2_test.values.reshape(-1,1))

y3_train_normal = quantile3.fit_transform(y3_train.values.reshape(-1,1))
y3_test_normal = quantile3.transform(y3_test.values.reshape(-1,1))

y4_train_normal = quantile4.fit_transform(y4_train.values.reshape(-1,1))
y4_test_normal = quantile4.transform(y4_test.values.reshape(-1,1))

y5_train_normal = quantile5.fit_transform(y5_train.values.reshape(-1,1))
y5_test_normal = quantile5.transform(y5_test.values.reshape(-1,1))

y6_train_normal = quantile6.fit_transform(y6_train.values.reshape(-1,1))
y6_test_normal = quantile6.transform(y6_test.values.reshape(-1,1))

y7_train_normal = quantile7.fit_transform(y7_train.values.reshape(-1,1))
y7_test_normal = quantile7.transform(y7_test.values.reshape(-1,1))

y8_train_normal = quantile8.fit_transform(y8_train.values.reshape(-1,1))
y8_test_normal = quantile8.transform(y8_test.values.reshape(-1,1))

# %%
# Visualize the effect of power transformation
f = plt.figure(figsize=(15, 6))

ax = f.add_subplot(321)
sns.distplot(y1_train, bins=50, color='r', ax=ax)
ax.set_title('Distribution before processing')

ax=f.add_subplot(322)
sns.distplot(y1_train_normal, bins=50, color='b', ax=ax)
ax.set_title('Distribution after quantile processing')
print()

ax = f.add_subplot(323)
sns.distplot(y2_train, bins=50, color='r', ax=ax)
ax.set_title('Distribution before processing')

ax=f.add_subplot(324)
sns.distplot(y2_train_normal, bins=50, color='b', ax=ax)
ax.set_title('Distribution after quantile processing')
print()

ax = f.add_subplot(325)
sns.distplot(y2_test, bins=50, color='r', ax=ax)
ax.set_title('Distribution before processing')

ax=f.add_subplot(326)
sns.distplot(y2_test_normal, bins=50, color='b', ax=ax)
ax.set_title('Distribution after quantile processing')
print()

plt.tight_layout()
# Out:
# /home/tendou/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/tendou/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/tendou/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/tendou/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/tendou/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/tendou/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
y1_test_check = quantile1.inverse_transform(y1_test_normal)
y1_test_check
# Out:
# array([[0.01211439],
#        [0.01479826],
#        [0.01753254],
#        ...,
#        [0.09742104],
#        [0.1002275 ],
#        [0.10303451]])

# %%
y1_test
# Out:
# 0       0.012114
# 1       0.014798
# 2       0.017533
# 3       0.020293
# 4       0.023077
#           ...
# 7195    0.091819
# 7196    0.094618
# 7197    0.097421
# 7198    0.100227
# 7199    0.103035
# Name: Target, Length: 7200, dtype: float64

# %%
y1_test_normal
# Out:
# array([[-1.89465723],
#        [-1.5461956 ],
#        [-1.32031725],
#        ...,
#        [ 1.30032046],
#        [ 1.46547647],
#        [ 1.66329102]])

# %% [markdown]
# ___

# %% [markdown]
# # ANN

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, Dataset, TensorDataset

torch.backends.cudnn.version() , torch.backends.cudnn.enabled
# Out:
# (8500, True)

# %%
# convert data to torch.FloatTensor
X_train_torch = torch.from_numpy(X_train.astype(np.float32))
X_test_torch = torch.from_numpy(X_test.astype(np.float32))



y1_train_torch = torch.from_numpy(y1_train_normal.astype(np.float32))
y1_test_torch = torch.from_numpy(y1_test_normal.astype(np.float32))

y2_train_torch = torch.from_numpy(y2_train_normal.astype(np.float32))
y2_test_torch = torch.from_numpy(y2_test_normal.astype(np.float32))

y3_train_torch = torch.from_numpy(y3_train_normal.astype(np.float32))
y3_test_torch = torch.from_numpy(y3_test_normal.astype(np.float32))

y4_train_torch = torch.from_numpy(y4_train_normal.astype(np.float32))
y4_test_torch = torch.from_numpy(y4_test_normal.astype(np.float32))

y5_train_torch = torch.from_numpy(y5_train_normal.astype(np.float32))
y5_test_torch = torch.from_numpy(y5_test_normal.astype(np.float32))

y6_train_torch = torch.from_numpy(y6_train_normal.astype(np.float32))
y6_test_torch = torch.from_numpy(y6_test_normal.astype(np.float32))

y7_train_torch = torch.from_numpy(y7_train_normal.astype(np.float32))
y7_test_torch = torch.from_numpy(y7_test_normal.astype(np.float32))

y8_train_torch = torch.from_numpy(y8_train_normal.astype(np.float32))
y8_test_torch = torch.from_numpy(y8_test_normal.astype(np.float32))

print(X_train_torch)
# Out:
# tensor([[-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.6846],
#         [-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.5883],
#         [-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.4921],
#         ...,
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.4921],
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.5883],
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.6846]])

# %%
y1_train_torch
# Out:
# tensor([[-1.8878],
#         [-1.5732],
#         [-1.3570],
#         ...,
#         [ 1.4216],
#         [ 1.6162],
#         [ 1.8511]])

# %%
y1_test_torch
# Out:
# tensor([[-1.8947],
#         [-1.5462],
#         [-1.3203],
#         ...,
#         [ 1.3003],
#         [ 1.4655],
#         [ 1.6633]])

# %%
train_data = []
for i in range(len(X_train_torch)):
   train_data.append([X_train_torch[i],
                      y1_train_torch[i], 
                      y2_train_torch[i],
                      y3_train_torch[i],
                      y4_train_torch[i],
                      y5_train_torch[i],
                      y6_train_torch[i],
                      y7_train_torch[i],
                      y8_train_torch[i]])    # 2D List with 21600 points

test_data = []
for i in range(len(X_test_torch)):
   test_data.append([X_test_torch[i], 
                     y1_test_torch[i],
                     y2_test_torch[i],
                     y3_test_torch[i],
                     y4_test_torch[i],
                     y5_test_torch[i],
                     y6_test_torch[i],
                     y7_test_torch[i],
                     y8_test_torch[i]])

# prepare data loaders
train_loader = DataLoader(train_data, batch_size=512,               # batch_size could be smaller
    num_workers=0, shuffle=False)                                                                   # Increasing num_workers slow down the training because it does not use GPU at all
test_loader = DataLoader(test_data, batch_size=512,
    num_workers=0, shuffle=False)


dataiter = iter(train_loader)
point, y1, y2, y3, y4, y5, y6, y7, y8 = next(dataiter)  # .next() does not work on torch 2.0

# print(train_data[:3])   # until 2nd data point, same as the first 3 rows of torch.cat
# print('*'*50)
# print(y1)
# print('*'*50)
# print(torch.cat((y1,y2,y3,y4,y5,y6,y7,y8), dim=1))
# print()
# print('*'*50)

# %%
# for point, y1, y2, y3, y4, y5, y6, y7, y8 in train_loader:
#     print(y2)
#     break

# %%
## Define the NN architecture
## NN with 3 hidden layer, s=[11, 256, 256] -> 8*[256,1]

class BleveNet(nn.Module):
    def __init__(self):
        super(BleveNet, self).__init__()
        # The first hidden layer has 256 neurons
        self.fc1 = nn.Linear(X_train_torch.shape[1], 256)
        # The second hidden layer has 256 neurons
        self.fc2 = nn.Linear(256, 256)
        
        # The final layer has 8 heads and 1 output neuron
        self.fc3 = nn.Linear(256, 256)
        self.fc4 = nn.Linear(256, 256)
        self.fc5 = nn.Linear(256, 256)
        self.fc6 = nn.Linear(256, 256)
        self.fc7 = nn.Linear(256, 256)
        self.fc8 = nn.Linear(256, 256)
        self.fc9 = nn.Linear(256, 256)
        self.fc10 = nn.Linear(256, 256)
        
        self.fc11 = nn.Linear(256,1)
        self.fc12 = nn.Linear(256,1)
        self.fc13 = nn.Linear(256,1)
        self.fc14 = nn.Linear(256,1)
        self.fc15 = nn.Linear(256,1)
        self.fc16 = nn.Linear(256,1)
        self.fc17 = nn.Linear(256,1)
        self.fc18 = nn.Linear(256,1)
       

        # Define proportion or neurons to dropout
        self.dropout = nn.Dropout(0.1)

        # Mish activation
        self.mish = nn.Mish()


    def forward(self, x):
        # add first fully connected layer
        x = self.fc1(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add second fully connected layer
        x = self.fc2(x)
        x = self.mish(x)
        x = self.dropout(x)
       
        # separated in 8 different heads and outputs
        head1 = self.fc3(x)
        head1 = self.mish(head1)
        head1 = self.dropout(head1)
        output1 = self.fc11(head1)

        head2 = self.fc4(x)
        head2 = self.mish(head2)
        head2 = self.dropout(head2)
        output2 = self.fc12(head2)

        head3 = self.fc5(x)
        head3 = self.mish(head3)
        head3 = self.dropout(head3)
        output3 = self.fc13(head3)

        head4 = self.fc6(x)
        head4 = self.mish(head4)
        head4 = self.dropout(head4)
        output4 = self.fc14(head4)

        head5 = self.fc7(x)
        head5 = self.mish(head5)
        head5 = self.dropout(head5)
        output5 = self.fc15(head5)

        head6 = self.fc8(x)
        head6 = self.mish(head6)
        head6 = self.dropout(head6)
        output6 = self.fc16(head6)

        head7 = self.fc9(x)
        head7 = self.mish(head7)
        head7 = self.dropout(head7)
        output7 = self.fc17(head7)

        head8 = self.fc10(x)
        head8 = self.mish(head8)
        head8 = self.dropout(head8)
        output8 = self.fc18(head8)
        
       
        return output1, output2, output3, output4, output5, output6, output7, output8

# initialize the NN
model = BleveNet()
print(model)
# Out:
# BleveNet(
#   (fc1): Linear(in_features=11, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=256, bias=True)
#   (fc4): Linear(in_features=256, out_features=256, bias=True)
#   (fc5): Linear(in_features=256, out_features=256, bias=True)
#   (fc6): Linear(in_features=256, out_features=256, bias=True)
#   (fc7): Linear(in_features=256, out_features=256, bias=True)
#   (fc8): Linear(in_features=256, out_features=256, bias=True)
#   (fc9): Linear(in_features=256, out_features=256, bias=True)
#   (fc10): Linear(in_features=256, out_features=256, bias=True)
#   (fc11): Linear(in_features=256, out_features=1, bias=True)
#   (fc12): Linear(in_features=256, out_features=1, bias=True)
#   (fc13): Linear(in_features=256, out_features=1, bias=True)
#   (fc14): Linear(in_features=256, out_features=1, bias=True)
#   (fc15): Linear(in_features=256, out_features=1, bias=True)
#   (fc16): Linear(in_features=256, out_features=1, bias=True)
#   (fc17): Linear(in_features=256, out_features=1, bias=True)
#   (fc18): Linear(in_features=256, out_features=1, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (mish): Mish()
# )

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
# criterion = nn.HuberLoss()        # This is the best loss function for my model
criterion = nn.MSELoss()


optimizer = torch.optim.Adam(model.parameters(), lr=0.005, weight_decay=1e-5)     # This is the best optimizer for my model 

# Check for GPU
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
startTime = timeit.default_timer() 


n_epochs = 200
task_num = 8 
loss_scale = nn.Parameter(torch.tensor([-0.5]*task_num, device=device))



model.to(device)    # bring the model to gpu
model.train()       # prep model for training

train_losses = []
for epoch in range(n_epochs):
    # monitor training loss
    train_loss = 0.0
    
    ###################
    # train the model #
    ###################
    for data, target1, target2, target3, target4, target5, target6, target7, target8 in train_loader:
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        #bring data and target to gpu
        data, target1 = data.to(device), target1.to(device)
        target2, target3 = target2.to(device), target3.to(device)
        target4, target5 = target4.to(device), target5.to(device)
        target6, target7 = target6.to(device), target7.to(device)
        target8 = target8.to(device)
        
        # forward pass: compute predicted outputs by passing inputs to the model
        output1, output2, output3, output4, output5, output6, output7, output8 = model(data)


        # calculate the loss
        loss1 = criterion(output1, target1)
        loss2 = criterion(output2, target2)
        loss3 = criterion(output3, target3)
        loss4 = criterion(output4, target4)
        loss5 = criterion(output5, target5)
        loss6 = criterion(output6, target6)
        loss7 = criterion(output7, target7)
        loss8 = criterion(output8, target8)
        losses = torch.Tensor([loss1, loss2, loss3, loss4, loss5, loss6, loss7, loss8])
        losses = losses.to(device)
        loss = (losses/(2*loss_scale.exp())+loss_scale/2).sum()
        # loss = loss1 + loss2 + loss3 + loss4 + loss5 + loss6 + loss7 + loss8
        
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update running training loss
        train_loss += loss.item()*data.size(0)
        
    # print training statistics 
    # calculate average loss over an epoch
    train_loss = train_loss/len(train_loader.dataset)
    train_losses.append(train_loss)

    print('Epoch: {}/{} \tTraining Loss: {:.6f}'.format(
        epoch+1,
        n_epochs, 
        train_loss
        ))
    
endTime = timeit.default_timer()
runningTotal = (endTime - startTime)
print(f"Time taken: {runningTotal}")
# Out:
# Epoch: 1/200 	Training Loss: 4.571220
# Epoch: 2/200 	Training Loss: 4.571932
# Epoch: 3/200 	Training Loss: 4.572247
# Epoch: 4/200 	Training Loss: 4.571010
# Epoch: 5/200 	Training Loss: 4.571542
# Epoch: 6/200 	Training Loss: 4.572837
# Epoch: 7/200 	Training Loss: 4.571264
# Epoch: 8/200 	Training Loss: 4.571916
# Epoch: 9/200 	Training Loss: 4.571276
# Epoch: 10/200 	Training Loss: 4.572070
# Epoch: 11/200 	Training Loss: 4.572525
# Epoch: 12/200 	Training Loss: 4.572144
# Epoch: 13/200 	Training Loss: 4.572051
# Epoch: 14/200 	Training Loss: 4.572118
# Epoch: 15/200 	Training Loss: 4.571054
# Epoch: 16/200 	Training Loss: 4.571372
# Epoch: 17/200 	Training Loss: 4.572344
# Epoch: 18/200 	Training Loss: 4.572089
# Epoch: 19/200 	Training Loss: 4.572110
# Epoch: 20/200 	Training Loss: 4.570429
# Epoch: 21/200 	Training Loss: 4.571866
# Epoch: 22/200 	Training Loss: 4.571182
# Epoch: 23/200 	Training Loss: 4.572445
# Epoch: 24/200 	Training Loss: 4.572690
# Epoch: 25/200 	Training Loss: 4.571964
# Epoch: 26/200 	Training Loss: 4.572341
# Epoch: 27/200 	Training Loss: 4.571523
# Epoch: 28/200 	Training Loss: 4.570910
# Epoch: 29/200 	Training Loss: 4.570633
# Epoch: 30/200 	Training Loss: 4.572095
# Epoch: 31/200 	Training Loss: 4.571581
# Epoch: 32/200 	Training Loss: 4.571503
# Epoch: 33/200 	Training Loss: 4.571131
# Epoch: 34/200 	Training Loss: 4.571491
# Epoch: 35/200 	Training Loss: 4.571111
# Epoch: 36/200 	Training Loss: 4.571757
# Epoch: 37/200 	Training Loss: 4.573190
# Epoch: 38/200 	Training Loss: 4.571430
# Epoch: 39/200 	Training Loss: 4.572061
# Epoch: 40/200 	Training Loss: 4.572275
# Epoch: 41/200 	Training Loss: 4.572098
# Epoch: 42/200 	Training Loss: 4.571703
# Epoch: 43/200 	Training Loss: 4.570661
# Epoch: 44/200 	Training Loss: 4.571323
# Epoch: 45/200 	Training Loss: 4.572196
# Epoch: 46/200 	Training Loss: 4.571078
# Epoch: 47/200 	Training Loss: 4.572324
# Epoch: 48/200 	Training Loss: 4.571888
# Epoch: 49/200 	Training Loss: 4.571891
# Epoch: 50/200 	Training Loss: 4.571955
# Epoch: 51/200 	Training Loss: 4.571488
# Epoch: 52/200 	Training Loss: 4.571990
# Epoch: 53/200 	Training Loss: 4.571476
# Epoch: 54/200 	Training Loss: 4.572569
# Epoch: 55/200 	Training Loss: 4.572418
# Epoch: 56/200 	Training Loss: 4.571699
# Epoch: 57/200 	Training Loss: 4.572655
# Epoch: 58/200 	Training Loss: 4.571747
# Epoch: 59/200 	Training Loss: 4.572896
# Epoch: 60/200 	Training Loss: 4.572248
# Epoch: 61/200 	Training Loss: 4.571692
# Epoch: 62/200 	Training Loss: 4.571890
# Epoch: 63/200 	Training Loss: 4.572992
# Epoch: 64/200 	Training Loss: 4.571375
# Epoch: 65/200 	Training Loss: 4.571416
# Epoch: 66/200 	Training Loss: 4.571625
# Epoch: 67/200 	Training Loss: 4.572324
# Epoch: 68/200 	Training Loss: 4.572131
# Epoch: 69/200 	Training Loss: 4.572022
# Epoch: 70/200 	Training Loss: 4.571780
# Epoch: 71/200 	Training Loss: 4.571638
# Epoch: 72/200 	Training Loss: 4.572277
# Epoch: 73/200 	Training Loss: 4.572067
# Epoch: 74/200 	Training Loss: 4.571733
# Epoch: 75/200 	Training Loss: 4.572148
# Epoch: 76/200 	Training Loss: 4.572306
# Epoch: 77/200 	Training Loss: 4.571807
# Epoch: 78/200 	Training Loss: 4.572553
# Epoch: 79/200 	Training Loss: 4.571653
# Epoch: 80/200 	Training Loss: 4.571567
# Epoch: 81/200 	Training Loss: 4.571630
# Epoch: 82/200 	Training Loss: 4.572148
# Epoch: 83/200 	Training Loss: 4.571993
# Epoch: 84/200 	Training Loss: 4.571105
# Epoch: 85/200 	Training Loss: 4.572236
# Epoch: 86/200 	Training Loss: 4.571913
# Epoch: 87/200 	Training Loss: 4.572752
# Epoch: 88/200 	Training Loss: 4.572073
# Epoch: 89/200 	Training Loss: 4.570972
# Epoch: 90/200 	Training Loss: 4.571553
# Epoch: 91/200 	Training Loss: 4.571872
# Epoch: 92/200 	Training Loss: 4.573369
# Epoch: 93/200 	Training Loss: 4.571625
# Epoch: 94/200 	Training Loss: 4.571383
# Epoch: 95/200 	Training Loss: 4.571050
# Epoch: 96/200 	Training Loss: 4.571820
# Epoch: 97/200 	Training Loss: 4.572633
# Epoch: 98/200 	Training Loss: 4.572083
# Epoch: 99/200 	Training Loss: 4.571654
# Epoch: 100/200 	Training Loss: 4.572304
# Epoch: 101/200 	Training Loss: 4.572207
# Epoch: 102/200 	Training Loss: 4.572356
# Epoch: 103/200 	Training Loss: 4.571643
# Epoch: 104/200 	Training Loss: 4.571727
# Epoch: 105/200 	Training Loss: 4.572095
# Epoch: 106/200 	Training Loss: 4.572592
# Epoch: 107/200 	Training Loss: 4.571632
# Epoch: 108/200 	Training Loss: 4.572050
# Epoch: 109/200 	Training Loss: 4.571776
# Epoch: 110/200 	Training Loss: 4.571008
# Epoch: 111/200 	Training Loss: 4.571611
# Epoch: 112/200 	Training Loss: 4.571630
# Epoch: 113/200 	Training Loss: 4.571364
# Epoch: 114/200 	Training Loss: 4.571905
# Epoch: 115/200 	Training Loss: 4.572725
# Epoch: 116/200 	Training Loss: 4.572249
# Epoch: 117/200 	Training Loss: 4.571124
# Epoch: 118/200 	Training Loss: 4.571960
# Epoch: 119/200 	Training Loss: 4.572720
# Epoch: 120/200 	Training Loss: 4.572387
# Epoch: 121/200 	Training Loss: 4.572353
# Epoch: 122/200 	Training Loss: 4.571898
# Epoch: 123/200 	Training Loss: 4.571846
# Epoch: 124/200 	Training Loss: 4.571518
# Epoch: 125/200 	Training Loss: 4.572109
# Epoch: 126/200 	Training Loss: 4.572089
# Epoch: 127/200 	Training Loss: 4.572226
# Epoch: 128/200 	Training Loss: 4.572760
# Epoch: 129/200 	Training Loss: 4.572145
# Epoch: 130/200 	Training Loss: 4.571906
# Epoch: 131/200 	Training Loss: 4.571633
# Epoch: 132/200 	Training Loss: 4.571940
# Epoch: 133/200 	Training Loss: 4.571660
# Epoch: 134/200 	Training Loss: 4.571837
# Epoch: 135/200 	Training Loss: 4.572162
# Epoch: 136/200 	Training Loss: 4.570950
# Epoch: 137/200 	Training Loss: 4.571118
# Epoch: 138/200 	Training Loss: 4.571418
# Epoch: 139/200 	Training Loss: 4.571894
# Epoch: 140/200 	Training Loss: 4.572224
# Epoch: 141/200 	Training Loss: 4.572529
# Epoch: 142/200 	Training Loss: 4.572045
# Epoch: 143/200 	Training Loss: 4.573227
# Epoch: 144/200 	Training Loss: 4.572030
# Epoch: 145/200 	Training Loss: 4.571934
# Epoch: 146/200 	Training Loss: 4.571978
# Epoch: 147/200 	Training Loss: 4.570338
# Epoch: 148/200 	Training Loss: 4.571709
# Epoch: 149/200 	Training Loss: 4.572262
# Epoch: 150/200 	Training Loss: 4.571125
# Epoch: 151/200 	Training Loss: 4.571271
# Epoch: 152/200 	Training Loss: 4.571881
# Epoch: 153/200 	Training Loss: 4.571152
# Epoch: 154/200 	Training Loss: 4.572660
# Epoch: 155/200 	Training Loss: 4.571562
# Epoch: 156/200 	Training Loss: 4.572229
# Epoch: 157/200 	Training Loss: 4.572041
# Epoch: 158/200 	Training Loss: 4.572119
# Epoch: 159/200 	Training Loss: 4.571512
# Epoch: 160/200 	Training Loss: 4.571606
# Epoch: 161/200 	Training Loss: 4.571736
# Epoch: 162/200 	Training Loss: 4.571659
# Epoch: 163/200 	Training Loss: 4.571289
# Epoch: 164/200 	Training Loss: 4.571608
# Epoch: 165/200 	Training Loss: 4.571835
# Epoch: 166/200 	Training Loss: 4.572390
# Epoch: 167/200 	Training Loss: 4.571507
# Epoch: 168/200 	Training Loss: 4.571142
# Epoch: 169/200 	Training Loss: 4.571721
# Epoch: 170/200 	Training Loss: 4.571503
# Epoch: 171/200 	Training Loss: 4.571664
# Epoch: 172/200 	Training Loss: 4.572040
# Epoch: 173/200 	Training Loss: 4.572306
# Epoch: 174/200 	Training Loss: 4.572080
# Epoch: 175/200 	Training Loss: 4.570641
# Epoch: 176/200 	Training Loss: 4.571624
# Epoch: 177/200 	Training Loss: 4.572048
# Epoch: 178/200 	Training Loss: 4.571490
# Epoch: 179/200 	Training Loss: 4.572078
# Epoch: 180/200 	Training Loss: 4.571899
# Epoch: 181/200 	Training Loss: 4.572196
# Epoch: 182/200 	Training Loss: 4.572062
# Epoch: 183/200 	Training Loss: 4.571937
# Epoch: 184/200 	Training Loss: 4.571004
# Epoch: 185/200 	Training Loss: 4.571060
# Epoch: 186/200 	Training Loss: 4.573535
# Epoch: 187/200 	Training Loss: 4.572417
# Epoch: 188/200 	Training Loss: 4.571848
# Epoch: 189/200 	Training Loss: 4.572573
# Epoch: 190/200 	Training Loss: 4.572514
# Epoch: 191/200 	Training Loss: 4.571667
# Epoch: 192/200 	Training Loss: 4.573003
# Epoch: 193/200 	Training Loss: 4.571413
# Epoch: 194/200 	Training Loss: 4.572770
# Epoch: 195/200 	Training Loss: 4.571626
# Epoch: 196/200 	Training Loss: 4.571543
# Epoch: 197/200 	Training Loss: 4.570781
# Epoch: 198/200 	Training Loss: 4.572610
# Epoch: 199/200 	Training Loss: 4.572037
# Epoch: 200/200 	Training Loss: 4.572082
# Time taken: 55.17965379999987

# %%
plt.plot(train_losses)

# Save the model  -- I already saved this and submitted
# torch.save(model.state_dict(), 'PyTorch_Model/Default7_Multi-task_NN_mish_Drop_L2_Huber_200Epoch.pt')

# %%
# with torch.no_grad():
#     output1, output2, output3, output4, output5, output6, output7, output8 = model(X_train_torch.to(device))

# y1_predtrain = quantile1.inverse_transform(output1.cpu().numpy())
# mape = mean_absolute_percentage_error(y1_train, y1_predtrain)
# r2 = r2_score(y1_train, y1_predtrain)
# rmse = np.sqrt(mean_squared_error(y1_train, y1_predtrain))
# r2, mape

# %% [markdown]
# **Loading the saved state**

# %%
# model.load_state_dict(torch.load('PyTorch_Model/Default1_Multi-task_NN_mish_Drop_L2_Huber_200Epoch.pt', map_location=torch.device('cpu')))

model.eval()           # prep model for *evaluation*
model.to(device)
with torch.no_grad():  # turn off gradient to save memory
    y1_predNN_torch, y2_predNN_torch, y3_predNN_torch, y4_predNN_torch, y5_predNN_torch, y6_predNN_torch, y7_predNN_torch, y8_predNN_torch  = model(X_test_torch.to(device))

y1_predNN_normal = y1_predNN_torch.cpu().numpy()     # convert to numpy array
y1_test_normal = y1_test_torch.cpu().numpy()       # not necessary because we used it to convert into torch tensors

y2_predNN_normal = y2_predNN_torch.cpu().numpy()     # convert to numpy array
# y2_test_normal = y2_test_torch.cpu().numpy()

y3_predNN_normal = y3_predNN_torch.cpu().numpy()     # convert to numpy array
# y3_test_normal = y3_test_torch.cpu().numpy()

y4_predNN_normal = y4_predNN_torch.cpu().numpy()     # convert to numpy array
# y4_test_normal = y4_test_torch.cpu().numpy()

y5_predNN_normal = y5_predNN_torch.cpu().numpy()     # convert to numpy array
# y5_test_normal = y5_test_torch.cpu().numpy()

y6_predNN_normal = y6_predNN_torch.cpu().numpy()     # convert to numpy array
# y6_test_normal = y6_test_torch.cpu().numpy()

y7_predNN_normal = y7_predNN_torch.cpu().numpy()     # convert to numpy array
# y7_test_normal = y7_test_torch.cpu().numpy()

y8_predNN_normal = y8_predNN_torch.cpu().numpy()     # convert to numpy array
# y8_test_normal = y8_test_torch.cpu().numpy()

print(y1_predNN_normal)
# Out:
# [[ 0.0471475 ]
#  [ 0.04774631]
#  [ 0.0483505 ]
#  ...
#  [-0.01386321]
#  [-0.01310899]
#  [-0.01234515]]

# %%
mape = mean_absolute_percentage_error(y1_test_normal, y1_predNN_normal)
r2 = r2_score(y1_test_normal, y1_predNN_normal)
rmse = np.sqrt(mean_squared_error(y1_test_normal, y1_predNN_normal))
print(f"Scores in normal distribution: r2 = {r2}, mape = {mape}, rmse = {rmse}")
# Out:
# Scores in normal distribution: r2 = 0.006539517420367846, mape = 1.6199003458023071, rmse = 0.9913929104804993

# %%
mape = mean_absolute_percentage_error(y1_test_normal, y1_predNN_normal)
r2 = r2_score(y1_test_normal, y1_predNN_normal)
rmse = np.sqrt(mean_squared_error(y1_test_normal, y1_predNN_normal))
print(f"Scores in normal distribution: r2 = {r2}, mape = {mape}, rmse = {rmse}")
# Out:
# Scores in normal distribution: r2 = 0.9837506004241211, mape = 0.22265322506427765, rmse = 0.12658345699310303

# %% [markdown]
# ___

# %% [markdown]
# # Positive Peak Time

# %%
y1_predNN = quantile1.inverse_transform(y1_predNN_normal)
mape = mean_absolute_percentage_error(y1_test, y1_predNN)
r2 = r2_score(y1_test, y1_predNN)
rmse = np.sqrt(mean_squared_error(y1_test, y1_predNN))


print(f"Scores in actual distribution for arrival time: r2 = {r2}, mape = {mape}, rmse = {rmse}")
# Out:
# Scores in actual distribution for arrival time: r2 = 0.009169760906456936, mape = 0.7629685223588978, rmse = 0.028588256023190577

# %%
y1_test
# Out:
# 0       0.012114
# 1       0.014798
# 2       0.017533
# 3       0.020293
# 4       0.023077
#           ...
# 7195    0.091819
# 7196    0.094618
# 7197    0.097421
# 7198    0.100227
# 7199    0.103035
# Name: Target, Length: 7200, dtype: float64

# %%
y1_predNN
# Out:
# array([[0.01358774],
#        [0.0160777 ],
#        [0.01866132],
#        ...,
#        [0.09423795],
#        [0.09724113],
#        [0.1000365 ]], dtype=float32)

# %% [markdown]
# ___

# %% [markdown]
# # Negative Peak Time

# %%
y2_predNN = quantile2.inverse_transform(y2_predNN_normal)
mape = mean_absolute_percentage_error(y2_test, y2_predNN)
r2 = r2_score(y2_test, y2_predNN)
rmse = np.sqrt(mean_squared_error(y2_test, y2_predNN))


print(f"Scores in actual distribution for arrival time: r2 = {r2}, mape = {mape}, rmse = {rmse}")
# Out:
# Scores in actual distribution for arrival time: r2 = 0.997878746567627, mape = 0.02078182609576199, rmse = 0.0013749740785980566

# %%
y2_test
# Out:
# 0       0.023626
# 1       0.026637
# 2       0.029588
# 3       0.032553
# 4       0.035477
#           ...
# 7195    0.105469
# 7196    0.108324
# 7197    0.111183
# 7198    0.114052
# 7199    0.116930
# Name: Target, Length: 7200, dtype: float64

# %% [markdown]
# ___

# %% [markdown]
# # Arrival Time

# %%
y3_predNN = quantile3.inverse_transform(y3_predNN_normal)
mape = mean_absolute_percentage_error(y3_test, y3_predNN.astype('float64'))
r2 = r2_score(y3_test, y3_predNN)
rmse = np.sqrt(mean_squared_error(y3_test, y3_predNN))


print(f"Scores in actual distribution for arrival time: r2 = {r2}, mape = {mape}, rmse = {rmse}")
# Out:
# Scores in actual distribution for arrival time: r2 = 0.997366223075764, mape = 0.028345666697295258, rmse = 0.0014227147293254308

# %%
y3_predNN = quantile3.inverse_transform(y3_predNN_normal)
mape = mean_absolute_percentage_error(y3_test, y3_predNN)
r2 = r2_score(y3_test, y3_predNN)
rmse = np.sqrt(mean_squared_error(y3_test, y3_predNN))


print(f"Scores in actual distribution for arrival time: r2 = {r2}, mape = {mape}, rmse = {rmse}")
# Out:
# Scores in actual distribution for arrival time: r2 = 0.9942784460813239, mape = 0.03845448408030399, rmse = 0.0020969367505092

# %%
y3_test
# Out:
# 0       0.009646
# 1       0.012093
# 2       0.014611
# 3       0.017177
# 4       0.019785
#           ...
# 7195    0.087402
# 7196    0.090136
# 7197    0.092877
# 7198    0.095618
# 7199    0.098365
# Name: Target, Length: 7200, dtype: float64

# %% [markdown]
# ___

# %% [markdown]
# # Positive Duration

# %%
y4_predNN = quantile4.inverse_transform(y4_predNN_normal)
mape = mean_absolute_percentage_error(y4_test, y4_predNN)
r2 = r2_score(y4_test, y4_predNN)
rmse = np.sqrt(mean_squared_error(y4_test, y4_predNN))


print(f"Scores in actual distribution for arrival time: r2 = {r2}, mape = {mape}, rmse = {rmse}")
# Out:
# Scores in actual distribution for arrival time: r2 = 0.9568603928498226, mape = 0.0438844775493572, rmse = 0.0007021504851400414

# %%
y4_test
# Out:
# 0       0.007010
# 1       0.007732
# 2       0.008249
# 3       0.008734
# 4       0.009039
#           ...
# 7195    0.011811
# 7196    0.011917
# 7197    0.012019
# 7198    0.012124
# 7199    0.012225
# Name: Target, Length: 7200, dtype: float64

# %% [markdown]
# ___

# %% [markdown]
# # Negative Duration

# %%
y5_predNN = quantile5.inverse_transform(y5_predNN_normal)
mape = mean_absolute_percentage_error(y5_test, y5_predNN)
r2 = r2_score(y5_test, y5_predNN)
rmse = np.sqrt(mean_squared_error(y5_test, y5_predNN))


print(f"Scores in actual distribution for arrival time: r2 = {r2}, mape = {mape}, rmse = {rmse}")
# Out:
# Scores in actual distribution for arrival time: r2 = 0.9829545202234848, mape = 0.04121104378063299, rmse = 0.0008218399733067523

# %%
y5_test[100:120]
# Out:
# 100    0.007093
# 101    0.007088
# 102    0.007090
# 103    0.007085
# 104    0.007079
# 105    0.007068
# 106    0.007064
# 107    0.007045
# 108    0.009888
# 109    0.010129
# 110    0.010376
# 111    0.010301
# 112    0.010790
# 113    0.010871
# 114    0.010731
# 115    0.010871
# 116    0.011529
# 117    0.011713
# 118    0.012421
# 119    0.012635
# Name: Target, dtype: float64

# %%
y5_predNN[100:120]
# Out:
# array([[0.00749896],
#        [0.00751026],
#        [0.0075189 ],
#        [0.00752495],
#        [0.00752887],
#        [0.00753262],
#        [0.00754255],
#        [0.00757418],
#        [0.01030744],
#        [0.01056808],
#        [0.01085123],
#        [0.01105563],
#        [0.01123117],
#        [0.01139253],
#        [0.01150973],
#        [0.01161872],
#        [0.01171831],
#        [0.01182643],
#        [0.01192488],
#        [0.01202544]], dtype=float32)

# %% [markdown]
# ___

# %% [markdown]
# # Positive Pressure

# %%
y6_predNN = quantile6.inverse_transform(y6_predNN_normal)
mape = mean_absolute_percentage_error(y6_test, y6_predNN)
r2 = r2_score(y6_test, y6_predNN)
rmse = np.sqrt(mean_squared_error(y6_test, y6_predNN))


print(f"Scores in actual distribution for arrival time: r2 = {r2}, mape = {mape}, rmse = {rmse}")
# Out:
# Scores in actual distribution for arrival time: r2 = 0.9160577284190885, mape = 0.09041936039608295, rmse = 0.09669640512418207

# %%
y6_test
# Out:
# 0       0.250616
# 1       0.200787
# 2       0.166701
# 3       0.142053
# 4       0.123448
#           ...
# 7195    0.097647
# 7196    0.094047
# 7197    0.090670
# 7198    0.087499
# 7199    0.084514
# Name: Target, Length: 7200, dtype: float64

# %%
y6_predNN
# Out:
# array([[0.19249998],
#        [0.16358303],
#        [0.14073054],
#        ...,
#        [0.09568972],
#        [0.09216544],
#        [0.08849088]], dtype=float32)

# %% [markdown]
# ___

# %% [markdown]
# # Negative Pressure

# %%
y7_predNN = quantile7.inverse_transform(y7_predNN_normal)
mape = mean_absolute_percentage_error(y7_test, y7_predNN)
r2 = r2_score(y7_test, y7_predNN)
rmse = np.sqrt(mean_squared_error(y7_test, y7_predNN))


print(f"Scores in actual distribution for arrival time: r2 = {r2}, mape = {mape}, rmse = {rmse}")
# Out:
# Scores in actual distribution for arrival time: r2 = 0.9838707856407117, mape = 0.059088957149578424, rmse = 0.009960396696000108

# %%
y7_test[1010:1020]
# Out:
# 1010   -0.139212
# 1011   -0.132530
# 1012   -0.121560
# 1013   -0.108367
# 1014   -0.096830
# 1015   -0.094761
# 1016   -0.090152
# 1017   -0.083977
# 1018   -0.076700
# 1019   -0.069374
# Name: Target, dtype: float64

# %%
y7_predNN[1010:1020]
# Out:
# array([[-0.13839257],
#        [-0.12583293],
#        [-0.11575607],
#        [-0.10680796],
#        [-0.09838247],
#        [-0.09069339],
#        [-0.08479797],
#        [-0.07928108],
#        [-0.07440846],
#        [-0.07022002]], dtype=float32)

# %% [markdown]
# ___

# %% [markdown]
# # Positive Impulse

# %%
y8_predNN = quantile8.inverse_transform(y8_predNN_normal)
mape = mean_absolute_percentage_error(y8_test, y8_predNN)
r2 = r2_score(y8_test, y8_predNN)
rmse = np.sqrt(mean_squared_error(y8_test, y8_predNN))


print(f"Scores in actual distribution for arrival time: r2 = {r2}, mape = {mape}, rmse = {rmse}")
# Out:
# Scores in actual distribution for arrival time: r2 = 0.956983886292475, mape = 0.08244151900533878, rmse = 20.941524674038444

# %%
y8_test
# Out:
# 0       52.619038
# 1       46.055485
# 2       41.131420
# 3       37.347630
# 4       34.215847
#           ...
# 7195    37.768711
# 7196    36.680138
# 7197    35.652153
# 7198    34.679951
# 7199    33.759022
# Name: Target, Length: 7200, dtype: float64

# %%
y8_predNN
# Out:
# array([[44.861702],
#        [39.624344],
#        [35.71903 ],
#        ...,
#        [36.2363  ],
#        [35.399883],
#        [34.44028 ]], dtype=float32)

# %%
y8_predNN[:10]
# Out:
# array([[44.861702],
#        [39.624344],
#        [35.71903 ],
#        [32.526672],
#        [29.61776 ],
#        [27.487625],
#        [25.605072],
#        [24.041851],
#        [22.581627],
#        [21.249279]], dtype=float32)

# %%
import torch, argparse
import torch.nn as nn
import torch.nn.functional as F

# from utils import *
# from aspp import DeepLabHead
# from create_dataset import NYUv2

from LibMTL import Trainer
from LibMTL.model import resnet_dilated
from LibMTL.utils import set_random_seed, set_device
from LibMTL.config import LibMTL_args, prepare_args
import LibMTL.weighting as weighting_method
import LibMTL.architecture as architecture_method

# %%
x = nn.ModuleDict({
                'conv': nn.Conv2d(10, 10, 3),
                'pool': nn.MaxPool2d(3)
                })

# %%
x['conv']
# Out:
# Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1))

# %%
loss_scale = nn.Parameter(torch.tensor([-0.5]*8))
loss_scale
# Out:
# Parameter containing:
# tensor([-0.5000, -0.5000, -0.5000, -0.5000, -0.5000, -0.5000, -0.5000, -0.5000],
#        requires_grad=True)
