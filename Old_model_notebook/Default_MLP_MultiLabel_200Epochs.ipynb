# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import timeit
#import shap
from sklearn.metrics import r2_score, mean_absolute_percentage_error, mean_squared_error
from sklearn.model_selection import cross_val_score, GridSearchCV, KFold
from sklearn.model_selection import train_test_split

# %% [markdown]
# ___

# %% [markdown]
# # Read-in and One-Hot Encoding

# %%
df1 = pd.read_excel("data_new/train.xlsx", sheet_name="positive_peak_time")
df2 = pd.read_excel("data_new/train.xlsx", sheet_name="negative_peak_time")
df3 = pd.read_excel("data_new/train.xlsx", sheet_name="arrival_time")
df4 = pd.read_excel("data_new/train.xlsx", sheet_name="positive_duration")
df5 = pd.read_excel("data_new/train.xlsx", sheet_name="negative_duration")
df6 = pd.read_excel("data_new/train.xlsx", sheet_name="positive_pressure")
df7 = pd.read_excel("data_new/train.xlsx", sheet_name="negative_pressure")
df8 = pd.read_excel("data_new/train.xlsx", sheet_name="positive_impulse")



dt1 = pd.read_excel("data_new/test.xlsx", sheet_name="positive_peak_time")
dt2 = pd.read_excel("data_new/test.xlsx", sheet_name="negative_peak_time")
dt3 = pd.read_excel("data_new/test.xlsx", sheet_name="arrival_time")
dt4 = pd.read_excel("data_new/test.xlsx", sheet_name="positive_duration")
dt5 = pd.read_excel("data_new/test.xlsx", sheet_name="negative_duration")
dt6 = pd.read_excel("data_new/test.xlsx", sheet_name="positive_pressure")
dt7 = pd.read_excel("data_new/test.xlsx", sheet_name="negative_pressure")
dt8 = pd.read_excel("data_new/test.xlsx", sheet_name="positive_impulse")

# %%
df1
# Out:
#          ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0      B291                         13.6          0.665119             1.0
# 1      B291                         13.6          0.665119             1.0
# 2      B291                         13.6          0.665119             1.0
# 3      B291                         13.6          0.665119             1.0
# 4      B291                         13.6          0.665119             1.0
# ...     ...                          ...               ...             ...
# 21595  B103                         30.7          0.181290             0.6
# 21596  B103                         30.7          0.181290             0.6
# 21597  B103                         30.7          0.181290             0.6
# 21598  B103                         30.7          0.181290             0.6
# 21599  B103                         30.7          0.181290             0.6
#
#        Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 0                  4.0              0.8                  1.8
# 1                  4.0              0.8                  1.8
# 2                  4.0              0.8                  1.8
# 3                  4.0              0.8                  1.8
# 4                  4.0              0.8                  1.8
# ...                ...              ...                  ...
# 21595              2.0              2.8                  1.2
# 21596              2.0              2.8                  1.2
# 21597              2.0              2.8                  1.2
# 21598              2.0              2.8                  1.2
# 21599              2.0              2.8                  1.2
#
#        Tank Height with Gas (m)   Vapour Temerature (K)  \
# 0                           0.4                   435.0
# 1                           0.4                   435.0
# 2                           0.4                   435.0
# 3                           0.4                   435.0
# 4                           0.4                   435.0
# ...                         ...                     ...
# 21595                       2.2                   334.7
# 21596                       2.2                   334.7
# 21597                       2.2                   334.7
# 21598                       2.2                   334.7
# 21599                       2.2                   334.7
#
#         Liquid Temerature (K)       Status  Stand-off Distance    Target
# 0                       372.5  Superheated                   5  0.012166
# 1                       372.5  Superheated                   6  0.014556
# 2                       372.5  Superheated                   7  0.017034
# 3                       372.5  Superheated                   8  0.019576
# 4                       372.5  Superheated                   9  0.022172
# ...                       ...          ...                 ...       ...
# 21595                   404.9    Subcooled                  36  0.093782
# 21596                   404.9    Subcooled                  37  0.096635
# 21597                   404.9    Subcooled                  38  0.099487
# 21598                   404.9    Subcooled                  39  0.102341
# 21599                   404.9    Subcooled                  40  0.105201
#
# [21600 rows x 13 columns]

# %%
dt1
# Out:
#         ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0     P197                    11.559040          0.602823             3.0
# 1     P197                    11.559040          0.602823             3.0
# 2     P197                    11.559040          0.602823             3.0
# 3     P197                    11.559040          0.602823             3.0
# 4     P197                    11.559040          0.602823             3.0
# ...    ...                          ...               ...             ...
# 7195   P55                     5.970915          0.284706             0.6
# 7196   P55                     5.970915          0.284706             0.6
# 7197   P55                     5.970915          0.284706             0.6
# 7198   P55                     5.970915          0.284706             0.6
# 7199   P55                     5.970915          0.284706             0.6
#
#       Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 0                 0.8              2.2                  0.2
# 1                 0.8              2.2                  0.2
# 2                 0.8              2.2                  0.2
# 3                 0.8              2.2                  0.2
# 4                 0.8              2.2                  0.2
# ...               ...              ...                  ...
# 7195              9.8              2.8                  1.0
# 7196              9.8              2.8                  1.0
# 7197              9.8              2.8                  1.0
# 7198              9.8              2.8                  1.0
# 7199              9.8              2.8                  1.0
#
#       Tank Height with Gas (m)   Vapour Temerature (K)  \
# 0                          1.0                   296.7
# 1                          1.0                   296.7
# 2                          1.0                   296.7
# 3                          1.0                   296.7
# 4                          1.0                   296.7
# ...                        ...                     ...
# 7195                       2.2                   439.3
# 7196                       2.2                   439.3
# 7197                       2.2                   439.3
# 7198                       2.2                   439.3
# 7199                       2.2                   439.3
#
#        Liquid Temerature (K)       Status  Stand-off Distance    Target
# 0                      328.5  Superheated                   5  0.012114
# 1                      328.5  Superheated                   6  0.014798
# 2                      328.5  Superheated                   7  0.017533
# 3                      328.5  Superheated                   8  0.020293
# 4                      328.5  Superheated                   9  0.023077
# ...                      ...          ...                 ...       ...
# 7195                   349.9  Superheated                  36  0.091819
# 7196                   349.9  Superheated                  37  0.094618
# 7197                   349.9  Superheated                  38  0.097421
# 7198                   349.9  Superheated                  39  0.100227
# 7199                   349.9  Superheated                  40  0.103035
#
# [7200 rows x 13 columns]

# %%
# Label encoding 'Status' feature into 0 and 1 
# 0 for Subcooled and 1 for Superheated

from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()

df5['Status'] = LE.fit_transform(df5['Status'])
dt5['Status'] = LE.fit_transform(dt5['Status'])

df5
# Out:
#          ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0      B291                         13.6          0.665119             1.0
# 1      B291                         13.6          0.665119             1.0
# 2      B291                         13.6          0.665119             1.0
# 3      B291                         13.6          0.665119             1.0
# 4      B291                         13.6          0.665119             1.0
# ...     ...                          ...               ...             ...
# 21595  B103                         30.7          0.181290             0.6
# 21596  B103                         30.7          0.181290             0.6
# 21597  B103                         30.7          0.181290             0.6
# 21598  B103                         30.7          0.181290             0.6
# 21599  B103                         30.7          0.181290             0.6
#
#        Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 0                  4.0              0.8                  1.8
# 1                  4.0              0.8                  1.8
# 2                  4.0              0.8                  1.8
# 3                  4.0              0.8                  1.8
# 4                  4.0              0.8                  1.8
# ...                ...              ...                  ...
# 21595              2.0              2.8                  1.2
# 21596              2.0              2.8                  1.2
# 21597              2.0              2.8                  1.2
# 21598              2.0              2.8                  1.2
# 21599              2.0              2.8                  1.2
#
#        Tank Height with Gas (m)   Vapour Temerature (K)  \
# 0                           0.4                   435.0
# 1                           0.4                   435.0
# 2                           0.4                   435.0
# 3                           0.4                   435.0
# 4                           0.4                   435.0
# ...                         ...                     ...
# 21595                       2.2                   334.7
# 21596                       2.2                   334.7
# 21597                       2.2                   334.7
# 21598                       2.2                   334.7
# 21599                       2.2                   334.7
#
#         Liquid Temerature (K)  Status  Stand-off Distance    Target
# 0                       372.5       1                   5  0.009827
# 1                       372.5       1                   6  0.009906
# 2                       372.5       1                   7  0.009970
# 3                       372.5       1                   8  0.010039
# 4                       372.5       1                   9  0.010011
# ...                       ...     ...                 ...       ...
# 21595                   404.9       0                  36  0.017944
# 21596                   404.9       0                  37  0.017724
# 21597                   404.9       0                  38  0.017498
# 21598                   404.9       0                  39  0.017280
# 21599                   404.9       0                  40  0.017078
#
# [21600 rows x 13 columns]

# %%
dt5.iloc[30:50,:]
# Out:
#       ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 30  P197                     11.55904          0.602823             3.0
# 31  P197                     11.55904          0.602823             3.0
# 32  P197                     11.55904          0.602823             3.0
# 33  P197                     11.55904          0.602823             3.0
# 34  P197                     11.55904          0.602823             3.0
# 35  P197                     11.55904          0.602823             3.0
# 36  P168                     12.72223          0.648320             1.8
# 37  P168                     12.72223          0.648320             1.8
# 38  P168                     12.72223          0.648320             1.8
# 39  P168                     12.72223          0.648320             1.8
# 40  P168                     12.72223          0.648320             1.8
# 41  P168                     12.72223          0.648320             1.8
# 42  P168                     12.72223          0.648320             1.8
# 43  P168                     12.72223          0.648320             1.8
# 44  P168                     12.72223          0.648320             1.8
# 45  P168                     12.72223          0.648320             1.8
# 46  P168                     12.72223          0.648320             1.8
# 47  P168                     12.72223          0.648320             1.8
# 48  P168                     12.72223          0.648320             1.8
# 49  P168                     12.72223          0.648320             1.8
#
#     Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 30              0.8              2.2                  0.2
# 31              0.8              2.2                  0.2
# 32              0.8              2.2                  0.2
# 33              0.8              2.2                  0.2
# 34              0.8              2.2                  0.2
# 35              0.8              2.2                  0.2
# 36              8.2              0.6                  1.8
# 37              8.2              0.6                  1.8
# 38              8.2              0.6                  1.8
# 39              8.2              0.6                  1.8
# 40              8.2              0.6                  1.8
# 41              8.2              0.6                  1.8
# 42              8.2              0.6                  1.8
# 43              8.2              0.6                  1.8
# 44              8.2              0.6                  1.8
# 45              8.2              0.6                  1.8
# 46              8.2              0.6                  1.8
# 47              8.2              0.6                  1.8
# 48              8.2              0.6                  1.8
# 49              8.2              0.6                  1.8
#
#     Tank Height with Gas (m)   Vapour Temerature (K)   Liquid Temerature (K)  \
# 30                       1.0                   296.7                   328.5
# 31                       1.0                   296.7                   328.5
# 32                       1.0                   296.7                   328.5
# 33                       1.0                   296.7                   328.5
# 34                       1.0                   296.7                   328.5
# 35                       1.0                   296.7                   328.5
# 36                       0.2                   389.7                   296.4
# 37                       0.2                   389.7                   296.4
# 38                       0.2                   389.7                   296.4
# 39                       0.2                   389.7                   296.4
# 40                       0.2                   389.7                   296.4
# 41                       0.2                   389.7                   296.4
# 42                       0.2                   389.7                   296.4
# 43                       0.2                   389.7                   296.4
# 44                       0.2                   389.7                   296.4
# 45                       0.2                   389.7                   296.4
# 46                       0.2                   389.7                   296.4
# 47                       0.2                   389.7                   296.4
# 48                       0.2                   389.7                   296.4
# 49                       0.2                   389.7                   296.4
#
#     Status  Stand-off Distance    Target
# 30       1                  35  0.015426
# 31       1                  36  0.015341
# 32       1                  37  0.015277
# 33       1                  38  0.015224
# 34       1                  39  0.015191
# 35       1                  40  0.015170
# 36       0                   5  0.009043
# 37       0                   6  0.009390
# 38       0                   7  0.009452
# 39       0                   8  0.009528
# 40       0                   9  0.009658
# 41       0                  10  0.009688
# 42       0                  11  0.009588
# 43       0                  12  0.009598
# 44       0                  13  0.009700
# 45       0                  14  0.009631
# 46       0                  15  0.009524
# 47       0                  16  0.012086
# 48       0                  17  0.012530
# 49       0                  18  0.012757

# %%
X_traindf = df5.drop(['ID','Target'], axis=1)
X_testdf = dt5.drop(['ID','Target'], axis=1)

X_traindf
# Out:
#        Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0                             13.6          0.665119             1.0
# 1                             13.6          0.665119             1.0
# 2                             13.6          0.665119             1.0
# 3                             13.6          0.665119             1.0
# 4                             13.6          0.665119             1.0
# ...                            ...               ...             ...
# 21595                         30.7          0.181290             0.6
# 21596                         30.7          0.181290             0.6
# 21597                         30.7          0.181290             0.6
# 21598                         30.7          0.181290             0.6
# 21599                         30.7          0.181290             0.6
#
#        Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 0                  4.0              0.8                  1.8
# 1                  4.0              0.8                  1.8
# 2                  4.0              0.8                  1.8
# 3                  4.0              0.8                  1.8
# 4                  4.0              0.8                  1.8
# ...                ...              ...                  ...
# 21595              2.0              2.8                  1.2
# 21596              2.0              2.8                  1.2
# 21597              2.0              2.8                  1.2
# 21598              2.0              2.8                  1.2
# 21599              2.0              2.8                  1.2
#
#        Tank Height with Gas (m)   Vapour Temerature (K)  \
# 0                           0.4                   435.0
# 1                           0.4                   435.0
# 2                           0.4                   435.0
# 3                           0.4                   435.0
# 4                           0.4                   435.0
# ...                         ...                     ...
# 21595                       2.2                   334.7
# 21596                       2.2                   334.7
# 21597                       2.2                   334.7
# 21598                       2.2                   334.7
# 21599                       2.2                   334.7
#
#         Liquid Temerature (K)  Status  Stand-off Distance
# 0                       372.5       1                   5
# 1                       372.5       1                   6
# 2                       372.5       1                   7
# 3                       372.5       1                   8
# 4                       372.5       1                   9
# ...                       ...     ...                 ...
# 21595                   404.9       0                  36
# 21596                   404.9       0                  37
# 21597                   404.9       0                  38
# 21598                   404.9       0                  39
# 21599                   404.9       0                  40
#
# [21600 rows x 11 columns]

# %%
X_testdf
# Out:
#       Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0                       11.559040          0.602823             3.0
# 1                       11.559040          0.602823             3.0
# 2                       11.559040          0.602823             3.0
# 3                       11.559040          0.602823             3.0
# 4                       11.559040          0.602823             3.0
# ...                           ...               ...             ...
# 7195                     5.970915          0.284706             0.6
# 7196                     5.970915          0.284706             0.6
# 7197                     5.970915          0.284706             0.6
# 7198                     5.970915          0.284706             0.6
# 7199                     5.970915          0.284706             0.6
#
#       Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 0                 0.8              2.2                  0.2
# 1                 0.8              2.2                  0.2
# 2                 0.8              2.2                  0.2
# 3                 0.8              2.2                  0.2
# 4                 0.8              2.2                  0.2
# ...               ...              ...                  ...
# 7195              9.8              2.8                  1.0
# 7196              9.8              2.8                  1.0
# 7197              9.8              2.8                  1.0
# 7198              9.8              2.8                  1.0
# 7199              9.8              2.8                  1.0
#
#       Tank Height with Gas (m)   Vapour Temerature (K)  \
# 0                          1.0                   296.7
# 1                          1.0                   296.7
# 2                          1.0                   296.7
# 3                          1.0                   296.7
# 4                          1.0                   296.7
# ...                        ...                     ...
# 7195                       2.2                   439.3
# 7196                       2.2                   439.3
# 7197                       2.2                   439.3
# 7198                       2.2                   439.3
# 7199                       2.2                   439.3
#
#        Liquid Temerature (K)  Status  Stand-off Distance
# 0                      328.5       1                   5
# 1                      328.5       1                   6
# 2                      328.5       1                   7
# 3                      328.5       1                   8
# 4                      328.5       1                   9
# ...                      ...     ...                 ...
# 7195                   349.9       1                  36
# 7196                   349.9       1                  37
# 7197                   349.9       1                  38
# 7198                   349.9       1                  39
# 7199                   349.9       1                  40
#
# [7200 rows x 11 columns]

# %%
y5_train = df5['Target']
y5_train
# Out:
# 0        0.009827
# 1        0.009906
# 2        0.009970
# 3        0.010039
# 4        0.010011
#            ...
# 21595    0.017944
# 21596    0.017724
# 21597    0.017498
# 21598    0.017280
# 21599    0.017078
# Name: Target, Length: 21600, dtype: float64

# %%
y1_train = df1['Target']
y2_train = df2['Target']
y3_train = df3['Target']
y4_train = df4['Target']
y6_train = df6['Target']
y7_train = df7['Target']
y8_train = df8['Target']

# %%
y1_test = dt1['Target']
y2_test = dt2['Target']
y3_test = dt3['Target']
y4_test = dt4['Target']
y5_test = dt5['Target']
y6_test = dt6['Target']
y7_test = dt7['Target']
y8_test = dt8['Target']

y1_test
# Out:
# 0       0.012114
# 1       0.014798
# 2       0.017533
# 3       0.020293
# 4       0.023077
#           ...
# 7195    0.091819
# 7196    0.094618
# 7197    0.097421
# 7198    0.100227
# 7199    0.103035
# Name: Target, Length: 7200, dtype: float64

# %%
y_train = np.concatenate((y1_train.values.reshape(-1,1), y2_train.values.reshape(-1,1), y3_train.values.reshape(-1,1), 
                          y4_train.values.reshape(-1,1), y5_train.values.reshape(-1,1), y6_train.values.reshape(-1,1),
                          y7_train.values.reshape(-1,1), y8_train.values.reshape(-1,1)), axis=1)

y_test = np.concatenate((y1_test.values.reshape(-1,1), y2_test.values.reshape(-1,1), y3_test.values.reshape(-1,1), 
                          y4_test.values.reshape(-1,1), y5_test.values.reshape(-1,1), y6_test.values.reshape(-1,1),
                          y7_test.values.reshape(-1,1), y8_test.values.reshape(-1,1)), axis=1)

# %%
print(y_train.shape)
print(y_test.shape)

y_train
# Out:
# (21600, 8)
# (7200, 8)
# array([[ 1.21663990e-02,  1.92270974e-02,  1.02530480e-02, ...,
#          6.13340850e-01, -2.35990550e-01,  1.05453270e+02],
#        [ 1.45556140e-02,  2.19475630e-02,  1.24416710e-02, ...,
#          4.85479950e-01, -2.01730860e-01,  8.91907810e+01],
#        [ 1.70337890e-02,  2.47348970e-02,  1.47326780e-02, ...,
#          3.97631170e-01, -1.78507950e-01,  7.72377550e+01],
#        ...,
#        [ 9.94869250e-02,  1.13699184e-01,  9.45632310e-02, ...,
#          6.88239110e-02, -4.64044960e-02,  2.74606420e+01],
#        [ 1.02341190e-01,  1.16520062e-01,  9.73516780e-02, ...,
#          6.64670090e-02, -4.60044180e-02,  2.67297230e+01],
#        [ 1.05201100e-01,  1.19343956e-01,  1.00149770e-01, ...,
#          6.42466250e-02, -4.48966060e-02,  2.60354210e+01]])

# %%
y_test
# Out:
# array([[ 1.21143940e-02,  2.36260840e-02,  9.64583550e-03, ...,
#          2.50615600e-01, -1.13256240e-01,  5.26190380e+01],
#        [ 1.47982630e-02,  2.66367886e-02,  1.20925640e-02, ...,
#          2.00786950e-01, -1.03320270e-01,  4.60554850e+01],
#        [ 1.75325390e-02,  2.95875370e-02,  1.46107920e-02, ...,
#          1.66701170e-01, -9.43374630e-02,  4.11314200e+01],
#        ...,
#        [ 9.74210350e-02,  1.11182812e-01,  9.28768070e-02, ...,
#          9.06703620e-02, -5.40905860e-02,  3.56521530e+01],
#        [ 1.00227500e-01,  1.14051970e-01,  9.56180690e-02, ...,
#          8.74992310e-02, -5.23571000e-02,  3.46799510e+01],
#        [ 1.03034510e-01,  1.16930324e-01,  9.83653590e-02, ...,
#          8.45144470e-02, -5.04742410e-02,  3.37590220e+01]])

# %% [markdown]
# ___

# %% [markdown]
# # Standardization and Power Transform

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import QuantileTransformer

# %%
# Processing both X_train and X_test using standardization
scaler = StandardScaler()
X_train = scaler.fit_transform(X_traindf)
X_test = scaler.transform(X_testdf)

# %%
# Double check if it succeeded
# df_stdscal = pd.DataFrame(X_train)
# df_stdscal.hist(figsize = (20,20), bins=10)

# %%
quantile = QuantileTransformer(output_distribution='normal')

y_train_normal = quantile.fit_transform(y_train)
y_test_normal = quantile.transform(y_test)

# %%
y_test_normal[1:41, 7]
# Out:
# array([-0.13282937, -0.24046414, -0.33752546, -0.42328697, -0.50113971,
#        -0.56880009, -0.6374526 , -0.6996398 , -0.75546111, -0.80519565,
#        -0.85363159, -0.89909811, -0.94159534, -0.97887334, -1.01505231,
#        -1.0521215 , -1.08724264, -1.12069735, -1.15449619, -1.18573499,
#        -1.21596976, -1.2436481 , -1.27113591, -1.29845258, -1.32647432,
#        -1.35388867, -1.37806628, -1.40604031, -1.43284272, -1.45727479,
#        -1.48291819, -1.50498221, -1.53121516, -1.55699008, -1.57938197,
#         0.45279688,  0.32077739,  0.19759081,  0.08977174, -0.00920681])

# %%
y_test_check = quantile.inverse_transform(y_test_normal)
y_test_check[1:41,7]
# Out:
# array([46.055485, 41.13142 , 37.34763 , 34.215847, 31.660479, 29.51226 ,
#        27.62623 , 25.996059, 24.593987, 23.341728, 22.203737, 21.178555,
#        20.26375 , 19.439846, 18.682037, 17.977852, 17.324688, 16.722097,
#        16.167007, 15.652895, 15.172283, 14.719731, 14.292322, 13.888784,
#        13.508397, 13.149973, 12.811902, 12.492044, 12.188312, 11.898917,
#        11.622511, 11.358176, 11.105268, 10.863276, 10.631696, 83.744408,
#        73.62957 , 65.149193, 58.173275, 52.403481])

# %%
y_test[1:41,7]
# Out:
# array([46.055485, 41.13142 , 37.34763 , 34.215847, 31.660479, 29.51226 ,
#        27.62623 , 25.996059, 24.593987, 23.341728, 22.203737, 21.178555,
#        20.26375 , 19.439846, 18.682037, 17.977852, 17.324688, 16.722097,
#        16.167007, 15.652895, 15.172283, 14.719731, 14.292322, 13.888784,
#        13.508397, 13.149973, 12.811902, 12.492044, 12.188312, 11.898917,
#        11.622511, 11.358176, 11.105268, 10.863276, 10.631696, 83.744408,
#        73.62957 , 65.149193, 58.173275, 52.403481])

# %%
# Double check if it succeeded
# df_stdscal = pd.DataFrame(y_train)
# df_stdscal.hist(figsize = (20,20), bins=10)

# %% [markdown]
# ___

# %% [markdown]
# # ANN

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt

torch.backends.cudnn.version() , torch.backends.cudnn.enabled
# Out:
# (8500, True)

# %%
# convert data to torch.FloatTensor
X_train_torch = torch.from_numpy(X_train.astype(np.float32))
X_test_torch = torch.from_numpy(X_test.astype(np.float32))



y_train_torch = torch.from_numpy(y_train_normal.astype(np.float32))
y_test_torch = torch.from_numpy(y_test_normal.astype(np.float32))


print(X_train_torch)
# Out:
# tensor([[-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.6846],
#         [-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.5883],
#         [-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.4921],
#         ...,
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.4921],
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.5883],
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.6846]])

# %%
y_train_torch
# Out:
# tensor([[-1.8878, -2.6412, -1.8978,  ...,  1.3802, -1.4426,  0.6927],
#         [-1.5732, -2.1187, -1.5748,  ...,  1.1909, -1.2257,  0.5174],
#         [-1.3570, -1.7601, -1.3660,  ...,  1.0275, -1.0601,  0.3689],
#         ...,
#         [ 1.4216,  1.3089,  1.4319,  ..., -0.7408,  0.7991, -0.6441],
#         [ 1.6162,  1.4910,  1.6337,  ..., -0.7787,  0.8107, -0.6733],
#         [ 1.8511,  1.7361,  1.8826,  ..., -0.8198,  0.8473, -0.6979]])

# %%
y_test_torch
# Out:
# tensor([[-1.8947, -1.8800, -2.0452,  ...,  0.6301, -0.4754, -0.0063],
#         [-1.5462, -1.5752, -1.6165,  ...,  0.4224, -0.3520, -0.1328],
#         [-1.3203, -1.3580, -1.3736,  ...,  0.2338, -0.2298, -0.2405],
#         ...,
#         [ 1.3003,  1.1768,  1.3228,  ..., -0.4314,  0.5893, -0.3827],
#         [ 1.4655,  1.3283,  1.4963,  ..., -0.4692,  0.6343, -0.4098],
#         [ 1.6633,  1.5193,  1.7074,  ..., -0.5085,  0.6895, -0.4363]])

# %%
train_data = []
for i in range(len(X_train_torch)):
   train_data.append([X_train_torch[i],
                      y_train_torch[i] 
                     ])

test_data = []
for i in range(len(X_test_torch)):
   test_data.append([X_test_torch[i], 
                     y_test_torch[i]
                     ])


# prepare data loaders
train_loader = torch.utils.data.DataLoader(train_data, batch_size=512,               # batch_size could be smaller
    num_workers=0)                                                                   # Increasing num_workers slow down the training because it does not use GPU at all
test_loader = torch.utils.data.DataLoader(test_data, batch_size=512,
    num_workers=0)

# %%
# for x,y in train_loader:
#     print(y)
#     # break

# %%
## Define the NN architecture
## NN with 3 hidden layer, s=[11, 256, 256, 256, 8]

class BleveNet(nn.Module):
    def __init__(self):
        super(BleveNet, self).__init__()
        # The first hidden layer has 256 neurons
        self.fc1 = nn.Linear(X_train_torch.shape[1], 256)
        # The second hidden layer has 256 neurons
        self.fc2 = nn.Linear(256, 256)
        # The third hidden layer has 256 neurons
        self.fc3 = nn.Linear(256, 256)
        # The final layer has 8 output neurons
        self.fc4 = nn.Linear(256, 8)


        # Define proportion or neurons to dropout
        self.dropout = nn.Dropout(0.1)

        # Mish activation
        self.mish = nn.Mish()


    def forward(self, x):
        # add first fully connected layer
        x = self.fc1(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add second fully connected layer
        x = self.fc2(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add third fully connected layer
        x = self.fc3(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add final output layers:
        output = self.fc4(x)
       
        return output

# initialize the NN
model = BleveNet()
print(model)
# Out:
# BleveNet(
#   (fc1): Linear(in_features=11, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=256, bias=True)
#   (fc4): Linear(in_features=256, out_features=8, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (mish): Mish()
# )

# %%
criterion = nn.HuberLoss()        # This is the best loss function for my model
# criterion = nn.MSELoss()


optimizer = torch.optim.Adam(model.parameters(), lr=0.005, weight_decay=1e-5)     # This is the best optimizer for my model 

# Check for GPU
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
startTime = timeit.default_timer() 


n_epochs = 200 

model.to(device)    # bring the model to gpu
model.train()       # prep model for training

train_losses = []
for epoch in range(n_epochs):
    # monitor training loss
    train_loss = 0.0
    
    ###################
    # train the model #
    ###################
    for data, target in train_loader:
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        #bring data and target to gpu
        data, target = data.to(device), target.to(device)
        
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update running training loss
        train_loss += loss.item()*data.size(0)
        
    # print training statistics 
    # calculate average loss over an epoch
    train_loss = train_loss/len(train_loader.dataset)
    train_losses.append(train_loss)

    print('Epoch: {}/{} \tTraining Loss: {:.6f}'.format(
        epoch+1,
        n_epochs, 
        train_loss
        ))
    

endTime = timeit.default_timer()
runningTotal = (endTime - startTime)
print(f"Time taken: {runningTotal}")
# Out:
# Epoch: 1/200 	Training Loss: 0.100131
# Epoch: 2/200 	Training Loss: 0.041790
# Epoch: 3/200 	Training Loss: 0.033482
# Epoch: 4/200 	Training Loss: 0.030970
# Epoch: 5/200 	Training Loss: 0.027957
# Epoch: 6/200 	Training Loss: 0.025174
# Epoch: 7/200 	Training Loss: 0.024443
# Epoch: 8/200 	Training Loss: 0.022695
# Epoch: 9/200 	Training Loss: 0.022428
# Epoch: 10/200 	Training Loss: 0.023215
# Epoch: 11/200 	Training Loss: 0.021362
# Epoch: 12/200 	Training Loss: 0.018095
# Epoch: 13/200 	Training Loss: 0.022103
# Epoch: 14/200 	Training Loss: 0.019465
# Epoch: 15/200 	Training Loss: 0.020598
# Epoch: 16/200 	Training Loss: 0.021704
# Epoch: 17/200 	Training Loss: 0.021062
# Epoch: 18/200 	Training Loss: 0.016766
# Epoch: 19/200 	Training Loss: 0.019171
# Epoch: 20/200 	Training Loss: 0.017502
# Epoch: 21/200 	Training Loss: 0.016488
# Epoch: 22/200 	Training Loss: 0.018887
# Epoch: 23/200 	Training Loss: 0.016279
# Epoch: 24/200 	Training Loss: 0.016743
# Epoch: 25/200 	Training Loss: 0.017058
# Epoch: 26/200 	Training Loss: 0.016172
# Epoch: 27/200 	Training Loss: 0.015589
# Epoch: 28/200 	Training Loss: 0.018674
# Epoch: 29/200 	Training Loss: 0.020113
# Epoch: 30/200 	Training Loss: 0.015456
# Epoch: 31/200 	Training Loss: 0.015023
# Epoch: 32/200 	Training Loss: 0.014305
# Epoch: 33/200 	Training Loss: 0.014566
# Epoch: 34/200 	Training Loss: 0.017043
# Epoch: 35/200 	Training Loss: 0.015662
# Epoch: 36/200 	Training Loss: 0.015763
# Epoch: 37/200 	Training Loss: 0.017353
# Epoch: 38/200 	Training Loss: 0.016102
# Epoch: 39/200 	Training Loss: 0.014717
# Epoch: 40/200 	Training Loss: 0.018549
# Epoch: 41/200 	Training Loss: 0.015325
# Epoch: 42/200 	Training Loss: 0.016154
# Epoch: 43/200 	Training Loss: 0.015101
# Epoch: 44/200 	Training Loss: 0.020483
# Epoch: 45/200 	Training Loss: 0.018450
# Epoch: 46/200 	Training Loss: 0.024279
# Epoch: 47/200 	Training Loss: 0.021584
# Epoch: 48/200 	Training Loss: 0.020340
# Epoch: 49/200 	Training Loss: 0.017213
# Epoch: 50/200 	Training Loss: 0.015601
# Epoch: 51/200 	Training Loss: 0.015539
# Epoch: 52/200 	Training Loss: 0.015858
# Epoch: 53/200 	Training Loss: 0.015581
# Epoch: 54/200 	Training Loss: 0.014851
# Epoch: 55/200 	Training Loss: 0.014505
# Epoch: 56/200 	Training Loss: 0.014833
# Epoch: 57/200 	Training Loss: 0.016461
# Epoch: 58/200 	Training Loss: 0.015137
# Epoch: 59/200 	Training Loss: 0.014664
# Epoch: 60/200 	Training Loss: 0.019700
# Epoch: 61/200 	Training Loss: 0.017362
# Epoch: 62/200 	Training Loss: 0.017714
# Epoch: 63/200 	Training Loss: 0.015537
# Epoch: 64/200 	Training Loss: 0.014855
# Epoch: 65/200 	Training Loss: 0.014593
# Epoch: 66/200 	Training Loss: 0.014124
# Epoch: 67/200 	Training Loss: 0.016182
# Epoch: 68/200 	Training Loss: 0.019134
# Epoch: 69/200 	Training Loss: 0.015943
# Epoch: 70/200 	Training Loss: 0.014876
# Epoch: 71/200 	Training Loss: 0.014246
# Epoch: 72/200 	Training Loss: 0.013352
# Epoch: 73/200 	Training Loss: 0.018296
# Epoch: 74/200 	Training Loss: 0.019577
# Epoch: 75/200 	Training Loss: 0.018997
# Epoch: 76/200 	Training Loss: 0.016904
# Epoch: 77/200 	Training Loss: 0.014715
# Epoch: 78/200 	Training Loss: 0.014747
# Epoch: 79/200 	Training Loss: 0.012377
# Epoch: 80/200 	Training Loss: 0.013936
# Epoch: 81/200 	Training Loss: 0.017725
# Epoch: 82/200 	Training Loss: 0.014968
# Epoch: 83/200 	Training Loss: 0.015834
# Epoch: 84/200 	Training Loss: 0.017219
# Epoch: 85/200 	Training Loss: 0.015712
# Epoch: 86/200 	Training Loss: 0.014332
# Epoch: 87/200 	Training Loss: 0.013989
# Epoch: 88/200 	Training Loss: 0.013817
# Epoch: 89/200 	Training Loss: 0.018757
# Epoch: 90/200 	Training Loss: 0.016379
# Epoch: 91/200 	Training Loss: 0.017204
# Epoch: 92/200 	Training Loss: 0.018089
# Epoch: 93/200 	Training Loss: 0.019123
# Epoch: 94/200 	Training Loss: 0.016093
# Epoch: 95/200 	Training Loss: 0.016620
# Epoch: 96/200 	Training Loss: 0.016519
# Epoch: 97/200 	Training Loss: 0.016645
# Epoch: 98/200 	Training Loss: 0.015883
# Epoch: 99/200 	Training Loss: 0.017614
# Epoch: 100/200 	Training Loss: 0.015410
# Epoch: 101/200 	Training Loss: 0.014384
# Epoch: 102/200 	Training Loss: 0.014312
# Epoch: 103/200 	Training Loss: 0.013538
# Epoch: 104/200 	Training Loss: 0.015067
# Epoch: 105/200 	Training Loss: 0.017191
# Epoch: 106/200 	Training Loss: 0.017666
# Epoch: 107/200 	Training Loss: 0.017031
# Epoch: 108/200 	Training Loss: 0.016227
# Epoch: 109/200 	Training Loss: 0.015508
# Epoch: 110/200 	Training Loss: 0.014994
# Epoch: 111/200 	Training Loss: 0.015893
# Epoch: 112/200 	Training Loss: 0.015231
# Epoch: 113/200 	Training Loss: 0.014314
# Epoch: 114/200 	Training Loss: 0.014467
# Epoch: 115/200 	Training Loss: 0.015786
# Epoch: 116/200 	Training Loss: 0.013583
# Epoch: 117/200 	Training Loss: 0.017928
# Epoch: 118/200 	Training Loss: 0.018498
# Epoch: 119/200 	Training Loss: 0.017588
# Epoch: 120/200 	Training Loss: 0.019450
# Epoch: 121/200 	Training Loss: 0.014560
# Epoch: 122/200 	Training Loss: 0.013444
# Epoch: 123/200 	Training Loss: 0.012834
# Epoch: 124/200 	Training Loss: 0.013473
# Epoch: 125/200 	Training Loss: 0.013001
# Epoch: 126/200 	Training Loss: 0.019143
# Epoch: 127/200 	Training Loss: 0.017341
# Epoch: 128/200 	Training Loss: 0.016578
# Epoch: 129/200 	Training Loss: 0.015698
# Epoch: 130/200 	Training Loss: 0.014516
# Epoch: 131/200 	Training Loss: 0.014047
# Epoch: 132/200 	Training Loss: 0.013576
# Epoch: 133/200 	Training Loss: 0.013775
# Epoch: 134/200 	Training Loss: 0.013385
# Epoch: 135/200 	Training Loss: 0.014918
# Epoch: 136/200 	Training Loss: 0.015105
# Epoch: 137/200 	Training Loss: 0.014638
# Epoch: 138/200 	Training Loss: 0.017654
# Epoch: 139/200 	Training Loss: 0.014394
# Epoch: 140/200 	Training Loss: 0.013336
# Epoch: 141/200 	Training Loss: 0.013954
# Epoch: 142/200 	Training Loss: 0.013277
# Epoch: 143/200 	Training Loss: 0.013478
# Epoch: 144/200 	Training Loss: 0.018452
# Epoch: 145/200 	Training Loss: 0.016128
# Epoch: 146/200 	Training Loss: 0.012823
# Epoch: 147/200 	Training Loss: 0.013266
# Epoch: 148/200 	Training Loss: 0.014051
# Epoch: 149/200 	Training Loss: 0.014373
# Epoch: 150/200 	Training Loss: 0.014019
# Epoch: 151/200 	Training Loss: 0.014663
# Epoch: 152/200 	Training Loss: 0.014625
# Epoch: 153/200 	Training Loss: 0.017126
# Epoch: 154/200 	Training Loss: 0.017154
# Epoch: 155/200 	Training Loss: 0.015862
# Epoch: 156/200 	Training Loss: 0.019516
# Epoch: 157/200 	Training Loss: 0.017315
# Epoch: 158/200 	Training Loss: 0.014456
# Epoch: 159/200 	Training Loss: 0.013980
# Epoch: 160/200 	Training Loss: 0.011979
# Epoch: 161/200 	Training Loss: 0.013837
# Epoch: 162/200 	Training Loss: 0.014136
# Epoch: 163/200 	Training Loss: 0.012377
# Epoch: 164/200 	Training Loss: 0.011862
# Epoch: 165/200 	Training Loss: 0.012766
# Epoch: 166/200 	Training Loss: 0.014231
# Epoch: 167/200 	Training Loss: 0.015213
# Epoch: 168/200 	Training Loss: 0.015472
# Epoch: 169/200 	Training Loss: 0.016191
# Epoch: 170/200 	Training Loss: 0.019257
# Epoch: 171/200 	Training Loss: 0.020369
# Epoch: 172/200 	Training Loss: 0.019133
# Epoch: 173/200 	Training Loss: 0.016532
# Epoch: 174/200 	Training Loss: 0.015143
# Epoch: 175/200 	Training Loss: 0.015376
# Epoch: 176/200 	Training Loss: 0.013557
# Epoch: 177/200 	Training Loss: 0.013070
# Epoch: 178/200 	Training Loss: 0.015428
# Epoch: 179/200 	Training Loss: 0.015758
# Epoch: 180/200 	Training Loss: 0.014752
# Epoch: 181/200 	Training Loss: 0.017766
# Epoch: 182/200 	Training Loss: 0.016107
# Epoch: 183/200 	Training Loss: 0.013442
# Epoch: 184/200 	Training Loss: 0.012932
# Epoch: 185/200 	Training Loss: 0.015539
# Epoch: 186/200 	Training Loss: 0.017088
# Epoch: 187/200 	Training Loss: 0.014287
# Epoch: 188/200 	Training Loss: 0.013057
# Epoch: 189/200 	Training Loss: 0.013288
# Epoch: 190/200 	Training Loss: 0.016012
# Epoch: 191/200 	Training Loss: 0.016095
# Epoch: 192/200 	Training Loss: 0.014626
# Epoch: 193/200 	Training Loss: 0.014640
# Epoch: 194/200 	Training Loss: 0.013428
# Epoch: 195/200 	Training Loss: 0.013947
# Epoch: 196/200 	Training Loss: 0.013383
# Epoch: 197/200 	Training Loss: 0.014579
# Epoch: 198/200 	Training Loss: 0.014110
# Epoch: 199/200 	Training Loss: 0.022332
# Epoch: 200/200 	Training Loss: 0.020894
# Time taken: 49.909958

# %%
plt.plot(train_losses)

# Save the model  -- I already saved this and submitted
torch.save(model.state_dict(), 'PyTorch_Model/Default5_MultiLabel_NN_mish_Drop_L2_Huber_200Epochs.pt')

# %% [markdown]
# **Loading the saved state**

# %%
# model.load_state_dict(torch.load('PyTorch_Model/Default1_MultiLabel_NN_mish_Drop_L2_Huber_200Epochs.pt', map_location=torch.device('cpu')))

model.eval()           # prep model for *evaluation*
model.to(device)
with torch.no_grad():  # turn off gradient to save memory
    y_predNN_torch = model(X_test_torch.to(device))

y_predNN_normal = y_predNN_torch.cpu().numpy()     # convert to numpy array
y_test_normal = y_test_torch.cpu().numpy()
print(y_predNN_normal)
# Out:
# [[-1.857394   -1.8259152  -1.9528453  ...  0.4152936  -0.4455038
#   -0.01989587]
#  [-1.5384607  -1.5749758  -1.6106198  ...  0.23108357 -0.29707864
#   -0.16500154]
#  [-1.2815069  -1.3375335  -1.3357422  ...  0.03940108 -0.15048906
#   -0.3065543 ]
#  ...
#  [ 1.2081188   1.1763513   1.2236736  ... -0.4440517   0.5137733
#   -0.37406117]
#  [ 1.3552544   1.3197887   1.3737519  ... -0.48404086  0.5442443
#   -0.4026381 ]
#  [ 1.5239353   1.4839532   1.5463641  ... -0.52527153  0.57392585
#   -0.43363655]]

# %%
mape = mean_absolute_percentage_error(y_test_normal, y_predNN_normal)
r2 = r2_score(y_test_normal, y_predNN_normal)
print(f"Neural Network scores in normal distribution: r2 = {r2}, mape = {mape}")
# Out:
# Neural Network scores in normal distribution: r2 = 0.9675178734782524, mape = 0.7248937487602234

# %%
y_predNN = quantile.inverse_transform(y_predNN_normal)
mape = mean_absolute_percentage_error(y_test, y_predNN.astype('float64'))
r2 = r2_score(y_test, y_predNN)

print(f"Neural Network scores in actual distribution: r2 = {r2}, mape = {mape}")
# Out:
# Neural Network scores in actual distribution: r2 = 0.9567660374065524, mape = 0.07937034460694262

# %%
y_predNN[1:41,7]
# Out:
# array([44.598656 , 38.517387 , 33.836723 , 30.167776 , 27.30008  ,
#        24.910275 , 22.974703 , 21.297882 , 19.828833 , 18.59634  ,
#        17.537031 , 16.673285 , 15.948013 , 15.319622 , 14.737612 ,
#        14.244355 , 13.818698 , 13.47966  , 13.171393 , 12.871942 ,
#        12.663719 , 12.42754  , 12.209036 , 11.9852295, 11.757388 ,
#        11.559076 , 11.335763 , 11.125776 , 10.9315   , 10.7056675,
#        10.476744 , 10.2339   ,  9.958914 ,  9.622276 ,  9.213793 ,
#        72.76763  , 64.78772  , 58.015697 , 52.50157  , 47.950672 ],
#       dtype=float32)

# %%
y_test[1:41,7]
# Out:
# array([46.055485, 41.13142 , 37.34763 , 34.215847, 31.660479, 29.51226 ,
#        27.62623 , 25.996059, 24.593987, 23.341728, 22.203737, 21.178555,
#        20.26375 , 19.439846, 18.682037, 17.977852, 17.324688, 16.722097,
#        16.167007, 15.652895, 15.172283, 14.719731, 14.292322, 13.888784,
#        13.508397, 13.149973, 12.811902, 12.492044, 12.188312, 11.898917,
#        11.622511, 11.358176, 11.105268, 10.863276, 10.631696, 83.744408,
#        73.62957 , 65.149193, 58.173275, 52.403481])

# %%
y_test
# Out:
# array([[ 1.21143940e-02,  2.36260840e-02,  9.64583550e-03, ...,
#          2.50615600e-01, -1.13256240e-01,  5.26190380e+01],
#        [ 1.47982630e-02,  2.66367886e-02,  1.20925640e-02, ...,
#          2.00786950e-01, -1.03320270e-01,  4.60554850e+01],
#        [ 1.75325390e-02,  2.95875370e-02,  1.46107920e-02, ...,
#          1.66701170e-01, -9.43374630e-02,  4.11314200e+01],
#        ...,
#        [ 9.74210350e-02,  1.11182812e-01,  9.28768070e-02, ...,
#          9.06703620e-02, -5.40905860e-02,  3.56521530e+01],
#        [ 1.00227500e-01,  1.14051970e-01,  9.56180690e-02, ...,
#          8.74992310e-02, -5.23571000e-02,  3.46799510e+01],
#        [ 1.03034510e-01,  1.16930324e-01,  9.83653590e-02, ...,
#          8.45144470e-02, -5.04742410e-02,  3.37590220e+01]])

# %%
# Positive Impulse
print("Positive Pressure")
print(y_predNN[:,5])
print()

# Negative Pressure
print("Negative Pressure")
print(y_predNN[1010:1020,6])
print()


# Positive Impulse
print("Positive Impulse")
print(y_predNN[:10,7])
# Out:
# Positive Pressure
# [0.19950694 0.1662122  0.13863632 ... 0.08960155 0.08636393 0.08327346]
#
# Negative Pressure
# [-0.11808828 -0.10609644 -0.09602489 -0.08779966 -0.08134145 -0.07577722
#  -0.07080214 -0.06647929 -0.06264377 -0.05918685]
#
# Positive Impulse
# [51.913643 44.598656 38.517387 33.836723 30.167776 27.30008  24.910275
#  22.974703 21.297882 19.828833]

# %% [markdown]
# ___

# %% [markdown]
# # Positive Peak Time

# %%
mape = mean_absolute_percentage_error(y_test[:,0], y_predNN[:,0])
r2 = r2_score(y_test[:,0], y_predNN[:,0])
rmse = np.sqrt(mean_squared_error(y_test[:,0], y_predNN[:,0]))


print(f"Scores in actual distribution for arrival time: r2 = {r2}, mape = {mape}, rmse = {rmse}")
# Out:
# Scores in actual distribution for arrival time: r2 = 0.9921548430885644, mape = 0.06099203287281972, rmse = 0.002543834504612414

# %% [markdown]
# ____

# %% [markdown]
# # Negative Peak Time

# %%
mape = mean_absolute_percentage_error(y_test[:,1], y_predNN[:,1])
r2 = r2_score(y_test[:,1], y_predNN[:,1])
rmse = np.sqrt(mean_squared_error(y_test[:,1], y_predNN[:,1]))


print(f"Scores in actual distribution for arrival time: r2 = {r2}, mape = {mape}, rmse = {rmse}")
# Out:
# Scores in actual distribution for arrival time: r2 = 0.9914539843615616, mape = 0.04419113605402012, rmse = 0.0027598156520185816

# %% [markdown]
# ___

# %% [markdown]
# # Arrival Time

# %%
mape = mean_absolute_percentage_error(y_test[:,2], y_predNN[:,2])
r2 = r2_score(y_test[:,2], y_predNN[:,2])
rmse = np.sqrt(mean_squared_error(y_test[:,2], y_predNN[:,2]))


print(f"Scores in actual distribution for arrival time: r2 = {r2}, mape = {mape}, rmse = {rmse}")
# Out:
# Scores in actual distribution for arrival time: r2 = 0.9919694328423633, mape = 0.06456182892879865, rmse = 0.0024842851469074694

# %% [markdown]
# ___

# %% [markdown]
# # Positive Duration

# %%
mape = mean_absolute_percentage_error(y_test[:,3], y_predNN[:,3])
r2 = r2_score(y_test[:,3], y_predNN[:,3])
rmse = np.sqrt(mean_squared_error(y_test[:,4], y_predNN[:,3]))


print(f"Scores in actual distribution for arrival time: r2 = {r2}, mape = {mape}, rmse = {rmse}")
# Out:
# Scores in actual distribution for arrival time: r2 = 0.9550413156064884, mape = 0.045415908755315496, rmse = 0.007970472439952895

# %% [markdown]
# ___

# %% [markdown]
# # Negative Duration

# %%
mape = mean_absolute_percentage_error(y_test[:,4], y_predNN[:,4])
r2 = r2_score(y_test[:,4], y_predNN[:,4])
rmse = np.sqrt(mean_squared_error(y_test[:,4], y_predNN[:,4]))


print(f"Scores in actual distribution for arrival time: r2 = {r2}, mape = {mape}, rmse = {rmse}")
# Out:
# Scores in actual distribution for arrival time: r2 = 0.963717016744293, mape = 0.058129514634961854, rmse = 0.001199041294566198

# %%
y_test[100:120, 4]
# Out:
# array([0.0070927 , 0.00708828, 0.00709008, 0.0070853 , 0.00707912,
#        0.00706785, 0.00706412, 0.00704504, 0.00988789, 0.01012937,
#        0.01037642, 0.01030135, 0.01078974, 0.01087129, 0.0107311 ,
#        0.01087087, 0.01152926, 0.0117134 , 0.01242085, 0.01263455])

# %%
y_predNN[100:120, 4]
# Out:
# array([0.0087907 , 0.00876244, 0.00872825, 0.00868012, 0.0086181 ,
#        0.00854333, 0.00845205, 0.00836844, 0.01119058, 0.01134085,
#        0.01146988, 0.01157727, 0.0116611 , 0.01172507, 0.01178324,
#        0.01182439, 0.01186029, 0.01190416, 0.01193515, 0.01197913],
#       dtype=float32)

# %% [markdown]
# ___

# %% [markdown]
# # Positive Pressure

# %%
mape = mean_absolute_percentage_error(y_test[:,5], y_predNN[:,5])
r2 = r2_score(y_test[:,5], y_predNN[:,5])
rmse = np.sqrt(mean_squared_error(y_test[:,5], y_predNN[:,5]))


print(f"Scores in actual distribution for arrival time: r2 = {r2}, mape = {mape}, rmse = {rmse}")
# Out:
# Scores in actual distribution for arrival time: r2 = 0.9107140652331871, mape = 0.1307981427184557, rmse = 0.09972671066829958

# %%
y_test[:,5]
# Out:
# array([0.2506156 , 0.20078695, 0.16670117, ..., 0.09067036, 0.08749923,
#        0.08451445])

# %%
y_predNN[:,5]
# Out:
# array([0.19950694, 0.1662122 , 0.13863632, ..., 0.08960155, 0.08636393,
#        0.08327346], dtype=float32)

# %% [markdown]
# ___

# %% [markdown]
# # Negative Pressure

# %%
mape = mean_absolute_percentage_error(y_test[:,6], y_predNN[:,6])
r2 = r2_score(y_test[:,6], y_predNN[:,6])
rmse = np.sqrt(mean_squared_error(y_test[:,6], y_predNN[:,6]))


print(f"Scores in actual distribution for arrival time: r2 = {r2}, mape = {mape}, rmse = {rmse}")
# Out:
# Scores in actual distribution for arrival time: r2 = 0.9214239305647168, mape = 0.10409576017809519, rmse = 0.021984428430299817

# %%
y_test[1010:1020, 6]
# Out:
# array([-0.13921224, -0.13253026, -0.12156035, -0.10836691, -0.09683013,
#        -0.09476076, -0.09015154, -0.08397743, -0.07669979, -0.06937373])

# %%
y_predNN[1010:1020, 6]
# Out:
# array([-0.11808828, -0.10609644, -0.09602489, -0.08779966, -0.08134145,
#        -0.07577722, -0.07080214, -0.06647929, -0.06264377, -0.05918685],
#       dtype=float32)

# %% [markdown]
# ____

# %% [markdown]
# # Positive Impulse

# %%
mape = mean_absolute_percentage_error(y_test[:,7], y_predNN[:,7])
r2 = r2_score(y_test[:,7], y_predNN[:,7])
rmse = np.sqrt(mean_squared_error(y_test[:,7], y_predNN[:,7]))


print(f"Scores in actual distribution for arrival time: r2 = {r2}, mape = {mape}, rmse = {rmse}")
# Out:
# Scores in actual distribution for arrival time: r2 = 0.9276537108112448, mape = 0.12677843271307424, rmse = 27.158191237917848

# %%
y_test[:,7]
# Out:
# array([52.619038, 46.055485, 41.13142 , ..., 35.652153, 34.679951,
#        33.759022])

# %%
y_predNN[:,7]
# Out:
# array([51.913643, 44.598656, 38.517387, ..., 35.91605 , 34.94345 ,
#        33.862587], dtype=float32)
