# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import timeit
#import shap
from sklearn.metrics import r2_score, mean_absolute_percentage_error, mean_squared_error
from sklearn.model_selection import cross_val_score, GridSearchCV, KFold
from sklearn.model_selection import train_test_split

# %% [markdown]
# ___

# %% [markdown]
# # Read-in and One-Hot Encoding

# %%
df = pd.read_excel("data_new/train.xlsx", sheet_name="negative_pressure")

dt = pd.read_excel("data_new/test.xlsx", sheet_name="negative_pressure")

# %%
# Label encoding 'Status' feature into 0 and 1 
# 0 for Subcooled and 1 for Superheated

from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()

df['Status'] = LE.fit_transform(df['Status'])
dt['Status'] = LE.fit_transform(dt['Status'])

df
# Out:
#          ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0      B291                         13.6          0.665119             1.0
# 1      B291                         13.6          0.665119             1.0
# 2      B291                         13.6          0.665119             1.0
# 3      B291                         13.6          0.665119             1.0
# 4      B291                         13.6          0.665119             1.0
# ...     ...                          ...               ...             ...
# 21595  B103                         30.7          0.181290             0.6
# 21596  B103                         30.7          0.181290             0.6
# 21597  B103                         30.7          0.181290             0.6
# 21598  B103                         30.7          0.181290             0.6
# 21599  B103                         30.7          0.181290             0.6
#
#        Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 0                  4.0              0.8                  1.8
# 1                  4.0              0.8                  1.8
# 2                  4.0              0.8                  1.8
# 3                  4.0              0.8                  1.8
# 4                  4.0              0.8                  1.8
# ...                ...              ...                  ...
# 21595              2.0              2.8                  1.2
# 21596              2.0              2.8                  1.2
# 21597              2.0              2.8                  1.2
# 21598              2.0              2.8                  1.2
# 21599              2.0              2.8                  1.2
#
#        Tank Height with Gas (m)   Vapour Temerature (K)  \
# 0                           0.4                   435.0
# 1                           0.4                   435.0
# 2                           0.4                   435.0
# 3                           0.4                   435.0
# 4                           0.4                   435.0
# ...                         ...                     ...
# 21595                       2.2                   334.7
# 21596                       2.2                   334.7
# 21597                       2.2                   334.7
# 21598                       2.2                   334.7
# 21599                       2.2                   334.7
#
#         Liquid Temerature (K)  Status  Stand-off Distance    Target
# 0                       372.5       1                   5 -0.235991
# 1                       372.5       1                   6 -0.201731
# 2                       372.5       1                   7 -0.178508
# 3                       372.5       1                   8 -0.155312
# 4                       372.5       1                   9 -0.140151
# ...                       ...     ...                 ...       ...
# 21595                   404.9       0                  36 -0.043038
# 21596                   404.9       0                  37 -0.045629
# 21597                   404.9       0                  38 -0.046404
# 21598                   404.9       0                  39 -0.046004
# 21599                   404.9       0                  40 -0.044897
#
# [21600 rows x 13 columns]

# %%
dt.iloc[30:50,:]
# Out:
#       ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 30  P197                     11.55904          0.602823             3.0
# 31  P197                     11.55904          0.602823             3.0
# 32  P197                     11.55904          0.602823             3.0
# 33  P197                     11.55904          0.602823             3.0
# 34  P197                     11.55904          0.602823             3.0
# 35  P197                     11.55904          0.602823             3.0
# 36  P168                     12.72223          0.648320             1.8
# 37  P168                     12.72223          0.648320             1.8
# 38  P168                     12.72223          0.648320             1.8
# 39  P168                     12.72223          0.648320             1.8
# 40  P168                     12.72223          0.648320             1.8
# 41  P168                     12.72223          0.648320             1.8
# 42  P168                     12.72223          0.648320             1.8
# 43  P168                     12.72223          0.648320             1.8
# 44  P168                     12.72223          0.648320             1.8
# 45  P168                     12.72223          0.648320             1.8
# 46  P168                     12.72223          0.648320             1.8
# 47  P168                     12.72223          0.648320             1.8
# 48  P168                     12.72223          0.648320             1.8
# 49  P168                     12.72223          0.648320             1.8
#
#     Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 30              0.8              2.2                  0.2
# 31              0.8              2.2                  0.2
# 32              0.8              2.2                  0.2
# 33              0.8              2.2                  0.2
# 34              0.8              2.2                  0.2
# 35              0.8              2.2                  0.2
# 36              8.2              0.6                  1.8
# 37              8.2              0.6                  1.8
# 38              8.2              0.6                  1.8
# 39              8.2              0.6                  1.8
# 40              8.2              0.6                  1.8
# 41              8.2              0.6                  1.8
# 42              8.2              0.6                  1.8
# 43              8.2              0.6                  1.8
# 44              8.2              0.6                  1.8
# 45              8.2              0.6                  1.8
# 46              8.2              0.6                  1.8
# 47              8.2              0.6                  1.8
# 48              8.2              0.6                  1.8
# 49              8.2              0.6                  1.8
#
#     Tank Height with Gas (m)   Vapour Temerature (K)   Liquid Temerature (K)  \
# 30                       1.0                   296.7                   328.5
# 31                       1.0                   296.7                   328.5
# 32                       1.0                   296.7                   328.5
# 33                       1.0                   296.7                   328.5
# 34                       1.0                   296.7                   328.5
# 35                       1.0                   296.7                   328.5
# 36                       0.2                   389.7                   296.4
# 37                       0.2                   389.7                   296.4
# 38                       0.2                   389.7                   296.4
# 39                       0.2                   389.7                   296.4
# 40                       0.2                   389.7                   296.4
# 41                       0.2                   389.7                   296.4
# 42                       0.2                   389.7                   296.4
# 43                       0.2                   389.7                   296.4
# 44                       0.2                   389.7                   296.4
# 45                       0.2                   389.7                   296.4
# 46                       0.2                   389.7                   296.4
# 47                       0.2                   389.7                   296.4
# 48                       0.2                   389.7                   296.4
# 49                       0.2                   389.7                   296.4
#
#     Status  Stand-off Distance    Target
# 30       1                  35 -0.024911
# 31       1                  36 -0.023293
# 32       1                  37 -0.022821
# 33       1                  38 -0.022314
# 34       1                  39 -0.021763
# 35       1                  40 -0.021158
# 36       0                   5 -0.211949
# 37       0                   6 -0.176115
# 38       0                   7 -0.169283
# 39       0                   8 -0.150481
# 40       0                   9 -0.128202
# 41       0                  10 -0.121717
# 42       0                  11 -0.116220
# 43       0                  12 -0.105101
# 44       0                  13 -0.091579
# 45       0                  14 -0.088244
# 46       0                  15 -0.085789
# 47       0                  16 -0.078990
# 48       0                  17 -0.071669
# 49       0                  18 -0.067574

# %%
X_traindf = df.drop(['ID','Target'], axis=1)
X_testdf = dt.drop(['ID','Target'], axis=1)

X_traindf
# Out:
#        Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0                             13.6          0.665119             1.0
# 1                             13.6          0.665119             1.0
# 2                             13.6          0.665119             1.0
# 3                             13.6          0.665119             1.0
# 4                             13.6          0.665119             1.0
# ...                            ...               ...             ...
# 21595                         30.7          0.181290             0.6
# 21596                         30.7          0.181290             0.6
# 21597                         30.7          0.181290             0.6
# 21598                         30.7          0.181290             0.6
# 21599                         30.7          0.181290             0.6
#
#        Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 0                  4.0              0.8                  1.8
# 1                  4.0              0.8                  1.8
# 2                  4.0              0.8                  1.8
# 3                  4.0              0.8                  1.8
# 4                  4.0              0.8                  1.8
# ...                ...              ...                  ...
# 21595              2.0              2.8                  1.2
# 21596              2.0              2.8                  1.2
# 21597              2.0              2.8                  1.2
# 21598              2.0              2.8                  1.2
# 21599              2.0              2.8                  1.2
#
#        Tank Height with Gas (m)   Vapour Temerature (K)  \
# 0                           0.4                   435.0
# 1                           0.4                   435.0
# 2                           0.4                   435.0
# 3                           0.4                   435.0
# 4                           0.4                   435.0
# ...                         ...                     ...
# 21595                       2.2                   334.7
# 21596                       2.2                   334.7
# 21597                       2.2                   334.7
# 21598                       2.2                   334.7
# 21599                       2.2                   334.7
#
#         Liquid Temerature (K)  Status  Stand-off Distance
# 0                       372.5       1                   5
# 1                       372.5       1                   6
# 2                       372.5       1                   7
# 3                       372.5       1                   8
# 4                       372.5       1                   9
# ...                       ...     ...                 ...
# 21595                   404.9       0                  36
# 21596                   404.9       0                  37
# 21597                   404.9       0                  38
# 21598                   404.9       0                  39
# 21599                   404.9       0                  40
#
# [21600 rows x 11 columns]

# %%
y_train = df['Target']
y_train
# Out:
# 0       -0.235991
# 1       -0.201731
# 2       -0.178508
# 3       -0.155312
# 4       -0.140151
#            ...
# 21595   -0.043038
# 21596   -0.045629
# 21597   -0.046404
# 21598   -0.046004
# 21599   -0.044897
# Name: Target, Length: 21600, dtype: float64

# %%
y_test = dt['Target']

y_test
# Out:
# 0      -0.113256
# 1      -0.103320
# 2      -0.094337
# 3      -0.085396
# 4      -0.075286
#           ...
# 7195   -0.057054
# 7196   -0.055646
# 7197   -0.054091
# 7198   -0.052357
# 7199   -0.050474
# Name: Target, Length: 7200, dtype: float64

# %% [markdown]
# ___

# %% [markdown]
# # Standardization and Power Transform

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import QuantileTransformer

# %%
# Processing both X_train and X_test using standardization
scaler = StandardScaler()
X_train = scaler.fit_transform(X_traindf)
X_test = scaler.transform(X_testdf)

# %%
quantile1 = QuantileTransformer(output_distribution='normal')



y_train_normal = quantile1.fit_transform(y_train.values.reshape(-1,1))
y_test_normal = quantile1.transform(y_test.values.reshape(-1,1))

# %%
# Visualize the effect of power transformation
f = plt.figure(figsize=(15, 6))

ax = f.add_subplot(121)
sns.distplot(y_train, bins=50, color='r', ax=ax)
ax.set_title('Distribution before processing')

ax=f.add_subplot(122)
sns.distplot(y_train_normal, bins=50, color='b', ax=ax)
ax.set_title('Distribution after quantile processing')
print()
# Out:
# c:\Users\buita\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\buita\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ___

# %% [markdown]
# # ANN

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt

torch.backends.cudnn.version() , torch.backends.cudnn.enabled
# Out:
# (8500, True)

# %%
# convert data to torch.FloatTensor
X_train_torch = torch.from_numpy(X_train.astype(np.float32))
X_test_torch = torch.from_numpy(X_test.astype(np.float32))



y_train_torch = torch.from_numpy(y_train_normal.astype(np.float32))
y_test_torch = torch.from_numpy(y_test_normal.astype(np.float32))

print(X_train_torch)
# Out:
# tensor([[-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.6846],
#         [-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.5883],
#         [-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.4921],
#         ...,
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.4921],
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.5883],
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.6846]])

# %%
train_data = []
for i in range(len(X_train_torch)):
   train_data.append([X_train_torch[i],
                      y_train_torch[i]
                     ])

test_data = []
for i in range(len(X_test_torch)):
   test_data.append([X_test_torch[i], 
                     y_test_torch[i]
                     ])
   
# prepare data loaders
train_loader = torch.utils.data.DataLoader(train_data, batch_size=512,               # batch_size could be smaller
    num_workers=0)                                                                   # Increasing num_workers slow down the training because it does not use GPU at all
test_loader = torch.utils.data.DataLoader(test_data, batch_size=512,
    num_workers=0)

# %%
## Define the NN architecture
## NN with 3 hidden layer, s=[26, 256, 256, 256, 128, 8]

class BleveNet(nn.Module):
    def __init__(self):
        super(BleveNet, self).__init__()
        # The first hidden layer has 256 neurons
        self.fc1 = nn.Linear(X_train_torch.shape[1], 256)
        # The second hidden layer has 256 neurons
        self.fc2 = nn.Linear(256, 256)
        # The third hidden layer has 256 neurons
        self.fc3 = nn.Linear(256, 256)
        # The final layer has 1 output neuron
        self.fc4 = nn.Linear(256, 1)


        # Define proportion or neurons to dropout
        self.dropout = nn.Dropout(0.1)

        # Mish activation
        self.mish = nn.Mish()


    def forward(self, x):
        # add first fully connected layer
        x = self.fc1(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add second fully connected layer
        x = self.fc2(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add third fully connected layer
        x = self.fc3(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add final output layers:
        output = self.fc4(x)
       
        return output

# initialize the NN
model = BleveNet()
print(model)
# Out:
# BleveNet(
#   (fc1): Linear(in_features=11, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=256, bias=True)
#   (fc4): Linear(in_features=256, out_features=1, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (mish): Mish()
# )

# %%
criterion = nn.HuberLoss()        # This is the best loss function for my model
# criterion = nn.MSELoss()


optimizer = torch.optim.Adam(model.parameters(), lr=0.005, weight_decay=1e-5)     # This is the best optimizer for my model 

# Check for GPU
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
startTime = timeit.default_timer() 

n_epochs = 200 

model.to(device)    # bring the model to gpu
model.train()       # prep model for training

train_losses = []
for epoch in range(n_epochs):
    # monitor training loss
    train_loss = 0.0
    
    ###################
    # train the model #
    ###################
    for data, target in train_loader:
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        #bring data and target to gpu
        data, target = data.to(device), target.to(device)
        
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update running training loss
        train_loss += loss.item()*data.size(0)
        
    # print training statistics 
    # calculate average loss over an epoch
    train_loss = train_loss/len(train_loader.dataset)
    train_losses.append(train_loss)

    print('Epoch: {}/{} \tTraining Loss: {:.6f}'.format(
        epoch+1,
        n_epochs, 
        train_loss
        ))
    

endTime = timeit.default_timer()
runningTotal = (endTime - startTime)
print(f"Time taken: {runningTotal}")
# Out:
# Epoch: 1/200 	Training Loss: 0.109795
# Epoch: 2/200 	Training Loss: 0.039727
# Epoch: 3/200 	Training Loss: 0.027230
# Epoch: 4/200 	Training Loss: 0.025067
# Epoch: 5/200 	Training Loss: 0.020527
# Epoch: 6/200 	Training Loss: 0.019044
# Epoch: 7/200 	Training Loss: 0.016889
# Epoch: 8/200 	Training Loss: 0.018049
# Epoch: 9/200 	Training Loss: 0.016276
# Epoch: 10/200 	Training Loss: 0.016856
# Epoch: 11/200 	Training Loss: 0.016666
# Epoch: 12/200 	Training Loss: 0.016283
# Epoch: 13/200 	Training Loss: 0.017475
# Epoch: 14/200 	Training Loss: 0.014882
# Epoch: 15/200 	Training Loss: 0.021267
# Epoch: 16/200 	Training Loss: 0.014990
# Epoch: 17/200 	Training Loss: 0.015389
# Epoch: 18/200 	Training Loss: 0.024205
# Epoch: 19/200 	Training Loss: 0.024916
# Epoch: 20/200 	Training Loss: 0.016195
# Epoch: 21/200 	Training Loss: 0.014449
# Epoch: 22/200 	Training Loss: 0.013601
# Epoch: 23/200 	Training Loss: 0.017439
# Epoch: 24/200 	Training Loss: 0.012434
# Epoch: 25/200 	Training Loss: 0.015923
# Epoch: 26/200 	Training Loss: 0.013164
# Epoch: 27/200 	Training Loss: 0.017147
# Epoch: 28/200 	Training Loss: 0.011896
# Epoch: 29/200 	Training Loss: 0.019028
# Epoch: 30/200 	Training Loss: 0.016261
# Epoch: 31/200 	Training Loss: 0.018952
# Epoch: 32/200 	Training Loss: 0.020320
# Epoch: 33/200 	Training Loss: 0.018275
# Epoch: 34/200 	Training Loss: 0.018629
# Epoch: 35/200 	Training Loss: 0.016139
# Epoch: 36/200 	Training Loss: 0.013876
# Epoch: 37/200 	Training Loss: 0.012263
# Epoch: 38/200 	Training Loss: 0.014095
# Epoch: 39/200 	Training Loss: 0.016019
# Epoch: 40/200 	Training Loss: 0.013741
# Epoch: 41/200 	Training Loss: 0.014916
# Epoch: 42/200 	Training Loss: 0.017736
# Epoch: 43/200 	Training Loss: 0.016581
# Epoch: 44/200 	Training Loss: 0.015430
# Epoch: 45/200 	Training Loss: 0.019088
# Epoch: 46/200 	Training Loss: 0.020235
# Epoch: 47/200 	Training Loss: 0.017119
# Epoch: 48/200 	Training Loss: 0.018369
# Epoch: 49/200 	Training Loss: 0.012828
# Epoch: 50/200 	Training Loss: 0.017047
# Epoch: 51/200 	Training Loss: 0.013466
# Epoch: 52/200 	Training Loss: 0.017211
# Epoch: 53/200 	Training Loss: 0.014649
# Epoch: 54/200 	Training Loss: 0.012602
# Epoch: 55/200 	Training Loss: 0.013065
# Epoch: 56/200 	Training Loss: 0.013089
# Epoch: 57/200 	Training Loss: 0.014137
# Epoch: 58/200 	Training Loss: 0.016048
# Epoch: 59/200 	Training Loss: 0.021038
# Epoch: 60/200 	Training Loss: 0.020468
# Epoch: 61/200 	Training Loss: 0.017278
# Epoch: 62/200 	Training Loss: 0.012976
# Epoch: 63/200 	Training Loss: 0.014829
# Epoch: 64/200 	Training Loss: 0.012484
# Epoch: 65/200 	Training Loss: 0.014954
# Epoch: 66/200 	Training Loss: 0.013961
# Epoch: 67/200 	Training Loss: 0.012420
# Epoch: 68/200 	Training Loss: 0.014113
# Epoch: 69/200 	Training Loss: 0.012502
# Epoch: 70/200 	Training Loss: 0.011224
# Epoch: 71/200 	Training Loss: 0.011200
# Epoch: 72/200 	Training Loss: 0.010853
# Epoch: 73/200 	Training Loss: 0.011007
# Epoch: 74/200 	Training Loss: 0.010844
# Epoch: 75/200 	Training Loss: 0.010733
# Epoch: 76/200 	Training Loss: 0.010532
# Epoch: 77/200 	Training Loss: 0.013559
# Epoch: 78/200 	Training Loss: 0.019568
# Epoch: 79/200 	Training Loss: 0.018043
# Epoch: 80/200 	Training Loss: 0.016926
# Epoch: 81/200 	Training Loss: 0.014333
# Epoch: 82/200 	Training Loss: 0.016115
# Epoch: 83/200 	Training Loss: 0.021025
# Epoch: 84/200 	Training Loss: 0.013855
# Epoch: 85/200 	Training Loss: 0.017907
# Epoch: 86/200 	Training Loss: 0.014559
# Epoch: 87/200 	Training Loss: 0.018998
# Epoch: 88/200 	Training Loss: 0.016225
# Epoch: 89/200 	Training Loss: 0.014859
# Epoch: 90/200 	Training Loss: 0.011688
# Epoch: 91/200 	Training Loss: 0.011229
# Epoch: 92/200 	Training Loss: 0.016389
# Epoch: 93/200 	Training Loss: 0.027053
# Epoch: 94/200 	Training Loss: 0.020288
# Epoch: 95/200 	Training Loss: 0.015109
# Epoch: 96/200 	Training Loss: 0.013660
# Epoch: 97/200 	Training Loss: 0.013399
# Epoch: 98/200 	Training Loss: 0.013599
# Epoch: 99/200 	Training Loss: 0.013094
# Epoch: 100/200 	Training Loss: 0.013471
# Epoch: 101/200 	Training Loss: 0.010739
# Epoch: 102/200 	Training Loss: 0.010620
# Epoch: 103/200 	Training Loss: 0.010887
# Epoch: 104/200 	Training Loss: 0.010693
# Epoch: 105/200 	Training Loss: 0.011951
# Epoch: 106/200 	Training Loss: 0.013108
# Epoch: 107/200 	Training Loss: 0.013681
# Epoch: 108/200 	Training Loss: 0.013028
# Epoch: 109/200 	Training Loss: 0.010123
# Epoch: 110/200 	Training Loss: 0.010664
# Epoch: 111/200 	Training Loss: 0.012477
# Epoch: 112/200 	Training Loss: 0.015518
# Epoch: 113/200 	Training Loss: 0.015682
# Epoch: 114/200 	Training Loss: 0.011011
# Epoch: 115/200 	Training Loss: 0.010790
# Epoch: 116/200 	Training Loss: 0.010372
# Epoch: 117/200 	Training Loss: 0.009521
# Epoch: 118/200 	Training Loss: 0.011145
# Epoch: 119/200 	Training Loss: 0.009817
# Epoch: 120/200 	Training Loss: 0.013317
# Epoch: 121/200 	Training Loss: 0.016823
# Epoch: 122/200 	Training Loss: 0.021468
# Epoch: 123/200 	Training Loss: 0.020201
# Epoch: 124/200 	Training Loss: 0.016386
# Epoch: 125/200 	Training Loss: 0.022410
# Epoch: 126/200 	Training Loss: 0.013290
# Epoch: 127/200 	Training Loss: 0.011861
# Epoch: 128/200 	Training Loss: 0.010200
# Epoch: 129/200 	Training Loss: 0.011134
# Epoch: 130/200 	Training Loss: 0.010372
# Epoch: 131/200 	Training Loss: 0.009464
# Epoch: 132/200 	Training Loss: 0.010311
# Epoch: 133/200 	Training Loss: 0.009542
# Epoch: 134/200 	Training Loss: 0.009475
# Epoch: 135/200 	Training Loss: 0.008500
# Epoch: 136/200 	Training Loss: 0.009813
# Epoch: 137/200 	Training Loss: 0.012268
# Epoch: 138/200 	Training Loss: 0.013308
# Epoch: 139/200 	Training Loss: 0.011302
# Epoch: 140/200 	Training Loss: 0.015969
# Epoch: 141/200 	Training Loss: 0.014587
# Epoch: 142/200 	Training Loss: 0.011319
# Epoch: 143/200 	Training Loss: 0.012710
# Epoch: 144/200 	Training Loss: 0.010435
# Epoch: 145/200 	Training Loss: 0.010811
# Epoch: 146/200 	Training Loss: 0.009801
# Epoch: 147/200 	Training Loss: 0.010723
# Epoch: 148/200 	Training Loss: 0.010261
# Epoch: 149/200 	Training Loss: 0.010287
# Epoch: 150/200 	Training Loss: 0.011050
# Epoch: 151/200 	Training Loss: 0.010181
# Epoch: 152/200 	Training Loss: 0.009319
# Epoch: 153/200 	Training Loss: 0.009619
# Epoch: 154/200 	Training Loss: 0.009206
# Epoch: 155/200 	Training Loss: 0.009305
# Epoch: 156/200 	Training Loss: 0.010442
# Epoch: 157/200 	Training Loss: 0.010845
# Epoch: 158/200 	Training Loss: 0.021168
# Epoch: 159/200 	Training Loss: 0.016782
# Epoch: 160/200 	Training Loss: 0.011588
# Epoch: 161/200 	Training Loss: 0.010669
# Epoch: 162/200 	Training Loss: 0.014396
# Epoch: 163/200 	Training Loss: 0.015431
# Epoch: 164/200 	Training Loss: 0.010906
# Epoch: 165/200 	Training Loss: 0.010108
# Epoch: 166/200 	Training Loss: 0.011686
# Epoch: 167/200 	Training Loss: 0.010599
# Epoch: 168/200 	Training Loss: 0.010084
# Epoch: 169/200 	Training Loss: 0.013753
# Epoch: 170/200 	Training Loss: 0.011400
# Epoch: 171/200 	Training Loss: 0.010402
# Epoch: 172/200 	Training Loss: 0.015007
# Epoch: 173/200 	Training Loss: 0.018468
# Epoch: 174/200 	Training Loss: 0.013983
# Epoch: 175/200 	Training Loss: 0.010864
# Epoch: 176/200 	Training Loss: 0.010560
# Epoch: 177/200 	Training Loss: 0.011645
# Epoch: 178/200 	Training Loss: 0.011489
# Epoch: 179/200 	Training Loss: 0.010780
# Epoch: 180/200 	Training Loss: 0.013333
# Epoch: 181/200 	Training Loss: 0.008733
# Epoch: 182/200 	Training Loss: 0.010067
# Epoch: 183/200 	Training Loss: 0.010376
# Epoch: 184/200 	Training Loss: 0.009545
# Epoch: 185/200 	Training Loss: 0.009542
# Epoch: 186/200 	Training Loss: 0.010760
# Epoch: 187/200 	Training Loss: 0.010673
# Epoch: 188/200 	Training Loss: 0.013810
# Epoch: 189/200 	Training Loss: 0.011421
# Epoch: 190/200 	Training Loss: 0.009875
# Epoch: 191/200 	Training Loss: 0.013743
# Epoch: 192/200 	Training Loss: 0.012400
# Epoch: 193/200 	Training Loss: 0.015764
# Epoch: 194/200 	Training Loss: 0.013503
# Epoch: 195/200 	Training Loss: 0.011415
# Epoch: 196/200 	Training Loss: 0.011332
# Epoch: 197/200 	Training Loss: 0.010349
# Epoch: 198/200 	Training Loss: 0.010343
# Epoch: 199/200 	Training Loss: 0.010738
# Epoch: 200/200 	Training Loss: 0.009163
# Time taken: 56.822562299999994

# %%
plt.plot(train_losses)

# Save the model  -- I already saved this and submitted
torch.save(model.state_dict(), 'PyTorch_Model/Default5_NegaPress_NN_mish_Drop_L2_Huber_200Epochs.pt')

# %%
# model.load_state_dict(torch.load('PyTorch_Model/Default1_NegaPress_NN_mish_Drop_L2_Huber_200Epochs.pt', map_location=torch.device('cpu')))

model.eval()           # prep model for *evaluation*
model.to(device)
with torch.no_grad():  # turn off gradient to save memory
    y_predNN_torch = model(X_test_torch.to(device))

y_predNN_normal = y_predNN_torch.cpu().numpy()     # convert to numpy array
y_test_normal = y_test_torch.cpu().numpy()



print(y_predNN_normal)
# Out:
# [[-0.43401486]
#  [-0.2773042 ]
#  [-0.13859133]
#  ...
#  [ 0.7073407 ]
#  [ 0.749568  ]
#  [ 0.7904667 ]]

# %%
mape = mean_absolute_percentage_error(y_test_normal, y_predNN_normal)
r2 = r2_score(y_test_normal, y_predNN_normal)
rmse = np.sqrt(mean_squared_error(y_test_normal, y_predNN_normal))
print(f"Scores in normal distribution: r2 = {r2}, mape = {mape}, rmse = {rmse}")
# Out:
# Scores in normal distribution: r2 = 0.9835109407002838, mape = 0.7068588137626648, rmse = 0.1300937533378601

# %%
y_predNN = quantile1.inverse_transform(y_predNN_normal)
mape = mean_absolute_percentage_error(y_test, y_predNN)
r2 = r2_score(y_test, y_predNN)
rmse = np.sqrt(mean_squared_error(y_test, y_predNN))


print(f"Scores in actual distribution for arrival time: r2 = {r2}, mape = {mape}, rmse = {rmse}")
# Out:
# Scores in actual distribution for arrival time: r2 = 0.9892044810408048, mape = 0.07098772389376172, rmse = 0.008148764951424706
