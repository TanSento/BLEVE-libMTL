# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import timeit
#import shap
from sklearn.metrics import r2_score, mean_absolute_percentage_error, mean_squared_error
from sklearn.model_selection import cross_val_score, GridSearchCV, KFold
from sklearn.model_selection import train_test_split

# %% [markdown]
# ___

# %% [markdown]
# # Read-in and One-Hot Encoding

# %%
df = pd.read_excel("data_new/train.xlsx", sheet_name="positive_duration")

dt = pd.read_excel("data_new/test.xlsx", sheet_name="positive_duration")

# %%
# Label encoding 'Status' feature into 0 and 1 
# 0 for Subcooled and 1 for Superheated

from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()

df['Status'] = LE.fit_transform(df['Status'])
dt['Status'] = LE.fit_transform(dt['Status'])

df
# Out:
#          ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0      B291                         13.6          0.665119             1.0
# 1      B291                         13.6          0.665119             1.0
# 2      B291                         13.6          0.665119             1.0
# 3      B291                         13.6          0.665119             1.0
# 4      B291                         13.6          0.665119             1.0
# ...     ...                          ...               ...             ...
# 21595  B103                         30.7          0.181290             0.6
# 21596  B103                         30.7          0.181290             0.6
# 21597  B103                         30.7          0.181290             0.6
# 21598  B103                         30.7          0.181290             0.6
# 21599  B103                         30.7          0.181290             0.6
#
#        Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 0                  4.0              0.8                  1.8
# 1                  4.0              0.8                  1.8
# 2                  4.0              0.8                  1.8
# 3                  4.0              0.8                  1.8
# 4                  4.0              0.8                  1.8
# ...                ...              ...                  ...
# 21595              2.0              2.8                  1.2
# 21596              2.0              2.8                  1.2
# 21597              2.0              2.8                  1.2
# 21598              2.0              2.8                  1.2
# 21599              2.0              2.8                  1.2
#
#        Tank Height with Gas (m)   Vapour Temerature (K)  \
# 0                           0.4                   435.0
# 1                           0.4                   435.0
# 2                           0.4                   435.0
# 3                           0.4                   435.0
# 4                           0.4                   435.0
# ...                         ...                     ...
# 21595                       2.2                   334.7
# 21596                       2.2                   334.7
# 21597                       2.2                   334.7
# 21598                       2.2                   334.7
# 21599                       2.2                   334.7
#
#         Liquid Temerature (K)  Status  Stand-off Distance    Target
# 0                       372.5       1                   5  0.005043
# 1                       372.5       1                   6  0.005543
# 2                       372.5       1                   7  0.006014
# 3                       372.5       1                   8  0.006445
# 4                       372.5       1                   9  0.006840
# ...                       ...     ...                 ...       ...
# 21595                   404.9       0                  36  0.011906
# 21596                   404.9       0                  37  0.012024
# 21597                   404.9       0                  38  0.012137
# 21598                   404.9       0                  39  0.012256
# 21599                   404.9       0                  40  0.012363
#
# [21600 rows x 13 columns]

# %%
dt.iloc[30:50,:]
# Out:
#       ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 30  P197                     11.55904          0.602823             3.0
# 31  P197                     11.55904          0.602823             3.0
# 32  P197                     11.55904          0.602823             3.0
# 33  P197                     11.55904          0.602823             3.0
# 34  P197                     11.55904          0.602823             3.0
# 35  P197                     11.55904          0.602823             3.0
# 36  P168                     12.72223          0.648320             1.8
# 37  P168                     12.72223          0.648320             1.8
# 38  P168                     12.72223          0.648320             1.8
# 39  P168                     12.72223          0.648320             1.8
# 40  P168                     12.72223          0.648320             1.8
# 41  P168                     12.72223          0.648320             1.8
# 42  P168                     12.72223          0.648320             1.8
# 43  P168                     12.72223          0.648320             1.8
# 44  P168                     12.72223          0.648320             1.8
# 45  P168                     12.72223          0.648320             1.8
# 46  P168                     12.72223          0.648320             1.8
# 47  P168                     12.72223          0.648320             1.8
# 48  P168                     12.72223          0.648320             1.8
# 49  P168                     12.72223          0.648320             1.8
#
#     Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 30              0.8              2.2                  0.2
# 31              0.8              2.2                  0.2
# 32              0.8              2.2                  0.2
# 33              0.8              2.2                  0.2
# 34              0.8              2.2                  0.2
# 35              0.8              2.2                  0.2
# 36              8.2              0.6                  1.8
# 37              8.2              0.6                  1.8
# 38              8.2              0.6                  1.8
# 39              8.2              0.6                  1.8
# 40              8.2              0.6                  1.8
# 41              8.2              0.6                  1.8
# 42              8.2              0.6                  1.8
# 43              8.2              0.6                  1.8
# 44              8.2              0.6                  1.8
# 45              8.2              0.6                  1.8
# 46              8.2              0.6                  1.8
# 47              8.2              0.6                  1.8
# 48              8.2              0.6                  1.8
# 49              8.2              0.6                  1.8
#
#     Tank Height with Gas (m)   Vapour Temerature (K)   Liquid Temerature (K)  \
# 30                       1.0                   296.7                   328.5
# 31                       1.0                   296.7                   328.5
# 32                       1.0                   296.7                   328.5
# 33                       1.0                   296.7                   328.5
# 34                       1.0                   296.7                   328.5
# 35                       1.0                   296.7                   328.5
# 36                       0.2                   389.7                   296.4
# 37                       0.2                   389.7                   296.4
# 38                       0.2                   389.7                   296.4
# 39                       0.2                   389.7                   296.4
# 40                       0.2                   389.7                   296.4
# 41                       0.2                   389.7                   296.4
# 42                       0.2                   389.7                   296.4
# 43                       0.2                   389.7                   296.4
# 44                       0.2                   389.7                   296.4
# 45                       0.2                   389.7                   296.4
# 46                       0.2                   389.7                   296.4
# 47                       0.2                   389.7                   296.4
# 48                       0.2                   389.7                   296.4
# 49                       0.2                   389.7                   296.4
#
#     Status  Stand-off Distance    Target
# 30       1                  35  0.013368
# 31       1                  36  0.013475
# 32       1                  37  0.013574
# 33       1                  38  0.013673
# 34       1                  39  0.013771
# 35       1                  40  0.013866
# 36       0                   5  0.006377
# 37       0                   6  0.006572
# 38       0                   7  0.006815
# 39       0                   8  0.007089
# 40       0                   9  0.007368
# 41       0                  10  0.007663
# 42       0                  11  0.007957
# 43       0                  12  0.008263
# 44       0                  13  0.008576
# 45       0                  14  0.008863
# 46       0                  15  0.009139
# 47       0                  16  0.006809
# 48       0                  17  0.006635
# 49       0                  18  0.006662

# %%
X_traindf = df.drop(['ID','Target'], axis=1)
X_testdf = dt.drop(['ID','Target'], axis=1)

X_traindf
# Out:
#        Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0                             13.6          0.665119             1.0
# 1                             13.6          0.665119             1.0
# 2                             13.6          0.665119             1.0
# 3                             13.6          0.665119             1.0
# 4                             13.6          0.665119             1.0
# ...                            ...               ...             ...
# 21595                         30.7          0.181290             0.6
# 21596                         30.7          0.181290             0.6
# 21597                         30.7          0.181290             0.6
# 21598                         30.7          0.181290             0.6
# 21599                         30.7          0.181290             0.6
#
#        Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 0                  4.0              0.8                  1.8
# 1                  4.0              0.8                  1.8
# 2                  4.0              0.8                  1.8
# 3                  4.0              0.8                  1.8
# 4                  4.0              0.8                  1.8
# ...                ...              ...                  ...
# 21595              2.0              2.8                  1.2
# 21596              2.0              2.8                  1.2
# 21597              2.0              2.8                  1.2
# 21598              2.0              2.8                  1.2
# 21599              2.0              2.8                  1.2
#
#        Tank Height with Gas (m)   Vapour Temerature (K)  \
# 0                           0.4                   435.0
# 1                           0.4                   435.0
# 2                           0.4                   435.0
# 3                           0.4                   435.0
# 4                           0.4                   435.0
# ...                         ...                     ...
# 21595                       2.2                   334.7
# 21596                       2.2                   334.7
# 21597                       2.2                   334.7
# 21598                       2.2                   334.7
# 21599                       2.2                   334.7
#
#         Liquid Temerature (K)  Status  Stand-off Distance
# 0                       372.5       1                   5
# 1                       372.5       1                   6
# 2                       372.5       1                   7
# 3                       372.5       1                   8
# 4                       372.5       1                   9
# ...                       ...     ...                 ...
# 21595                   404.9       0                  36
# 21596                   404.9       0                  37
# 21597                   404.9       0                  38
# 21598                   404.9       0                  39
# 21599                   404.9       0                  40
#
# [21600 rows x 11 columns]

# %%
y_train = df['Target']
y_train
# Out:
# 0        0.005043
# 1        0.005543
# 2        0.006014
# 3        0.006445
# 4        0.006840
#            ...
# 21595    0.011906
# 21596    0.012024
# 21597    0.012137
# 21598    0.012256
# 21599    0.012363
# Name: Target, Length: 21600, dtype: float64

# %%
y_test = dt['Target']

y_test
# Out:
# 0       0.007010
# 1       0.007732
# 2       0.008249
# 3       0.008734
# 4       0.009039
#           ...
# 7195    0.011811
# 7196    0.011917
# 7197    0.012019
# 7198    0.012124
# 7199    0.012225
# Name: Target, Length: 7200, dtype: float64

# %% [markdown]
# ___

# %% [markdown]
# # Standardization and Power Transform

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import QuantileTransformer

# %%
# Processing both X_train and X_test using standardization
scaler = StandardScaler()
X_train = scaler.fit_transform(X_traindf)
X_test = scaler.transform(X_testdf)

# %%
quantile1 = QuantileTransformer(output_distribution='normal')



y_train_normal = quantile1.fit_transform(y_train.values.reshape(-1,1))
y_test_normal = quantile1.transform(y_test.values.reshape(-1,1))

# %%
# Visualize the effect of power transformation
f = plt.figure(figsize=(15, 6))

ax = f.add_subplot(121)
sns.distplot(y_train, bins=50, color='r', ax=ax)
ax.set_title('Distribution before processing')

ax=f.add_subplot(122)
sns.distplot(y_train_normal, bins=50, color='b', ax=ax)
ax.set_title('Distribution after quantile processing')
print()
# Out:
# c:\Users\buita\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\buita\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ___

# %% [markdown]
# # ANN

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt

torch.backends.cudnn.version() , torch.backends.cudnn.enabled
# Out:
# (8500, True)

# %%
# convert data to torch.FloatTensor
X_train_torch = torch.from_numpy(X_train.astype(np.float32))
X_test_torch = torch.from_numpy(X_test.astype(np.float32))



y_train_torch = torch.from_numpy(y_train_normal.astype(np.float32))
y_test_torch = torch.from_numpy(y_test_normal.astype(np.float32))

print(X_train_torch)
# Out:
# tensor([[-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.6846],
#         [-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.5883],
#         [-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.4921],
#         ...,
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.4921],
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.5883],
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.6846]])

# %%
train_data = []
for i in range(len(X_train_torch)):
   train_data.append([X_train_torch[i],
                      y_train_torch[i]
                     ])

test_data = []
for i in range(len(X_test_torch)):
   test_data.append([X_test_torch[i], 
                     y_test_torch[i]
                     ])
   
# prepare data loaders
train_loader = torch.utils.data.DataLoader(train_data, batch_size=512,               # batch_size could be smaller
    num_workers=0)                                                                   # Increasing num_workers slow down the training because it does not use GPU at all
test_loader = torch.utils.data.DataLoader(test_data, batch_size=512,
    num_workers=0)

# %%
## Define the NN architecture
## NN with 3 hidden layer, s=[11, 256, 256, 256, 1]

class BleveNet(nn.Module):
    def __init__(self):
        super(BleveNet, self).__init__()
        # The first hidden layer has 256 neurons
        self.fc1 = nn.Linear(X_train_torch.shape[1], 256)
        # The second hidden layer has 256 neurons
        self.fc2 = nn.Linear(256, 256)
        # The third hidden layer has 256 neurons
        self.fc3 = nn.Linear(256, 256)
        # The final layer has 1 output neuron
        self.fc4 = nn.Linear(256, 1)


        # Define proportion or neurons to dropout
        self.dropout = nn.Dropout(0.1)

        # Mish activation
        self.mish = nn.Mish()


    def forward(self, x):
        # add first fully connected layer
        x = self.fc1(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add second fully connected layer
        x = self.fc2(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add third fully connected layer
        x = self.fc3(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add final output layers:
        output = self.fc4(x)
       
        return output

# initialize the NN
model = BleveNet()
print(model)
# Out:
# BleveNet(
#   (fc1): Linear(in_features=11, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=256, bias=True)
#   (fc4): Linear(in_features=256, out_features=1, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (mish): Mish()
# )

# %%
criterion = nn.HuberLoss()        # This is the best loss function for my model
# criterion = nn.MSELoss()


optimizer = torch.optim.Adam(model.parameters(), lr=0.005, weight_decay=1e-5)     # This is the best optimizer for my model 

# Check for GPU
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
startTime = timeit.default_timer() 

n_epochs = 200 

model.to(device)    # bring the model to gpu
model.train()       # prep model for training

train_losses = []
for epoch in range(n_epochs):
    # monitor training loss
    train_loss = 0.0
    
    ###################
    # train the model #
    ###################
    for data, target in train_loader:
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        #bring data and target to gpu
        data, target = data.to(device), target.to(device)
        
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update running training loss
        train_loss += loss.item()*data.size(0)
        
    # print training statistics 
    # calculate average loss over an epoch
    train_loss = train_loss/len(train_loader.dataset)
    train_losses.append(train_loss)

    print('Epoch: {}/{} \tTraining Loss: {:.6f}'.format(
        epoch+1,
        n_epochs, 
        train_loss
        ))
    

endTime = timeit.default_timer()
runningTotal = (endTime - startTime)
print(f"Time taken: {runningTotal}")
# Out:
# Epoch: 1/200 	Training Loss: 0.137526
# Epoch: 2/200 	Training Loss: 0.083876
# Epoch: 3/200 	Training Loss: 0.080728
# Epoch: 4/200 	Training Loss: 0.065576
# Epoch: 5/200 	Training Loss: 0.060773
# Epoch: 6/200 	Training Loss: 0.056340
# Epoch: 7/200 	Training Loss: 0.055317
# Epoch: 8/200 	Training Loss: 0.054720
# Epoch: 9/200 	Training Loss: 0.049147
# Epoch: 10/200 	Training Loss: 0.049646
# Epoch: 11/200 	Training Loss: 0.047077
# Epoch: 12/200 	Training Loss: 0.046320
# Epoch: 13/200 	Training Loss: 0.048076
# Epoch: 14/200 	Training Loss: 0.045158
# Epoch: 15/200 	Training Loss: 0.045858
# Epoch: 16/200 	Training Loss: 0.042509
# Epoch: 17/200 	Training Loss: 0.043092
# Epoch: 18/200 	Training Loss: 0.042666
# Epoch: 19/200 	Training Loss: 0.039899
# Epoch: 20/200 	Training Loss: 0.034876
# Epoch: 21/200 	Training Loss: 0.033380
# Epoch: 22/200 	Training Loss: 0.031552
# Epoch: 23/200 	Training Loss: 0.032898
# Epoch: 24/200 	Training Loss: 0.033391
# Epoch: 25/200 	Training Loss: 0.033561
# Epoch: 26/200 	Training Loss: 0.030152
# Epoch: 27/200 	Training Loss: 0.029721
# Epoch: 28/200 	Training Loss: 0.028862
# Epoch: 29/200 	Training Loss: 0.029357
# Epoch: 30/200 	Training Loss: 0.025602
# Epoch: 31/200 	Training Loss: 0.028996
# Epoch: 32/200 	Training Loss: 0.029448
# Epoch: 33/200 	Training Loss: 0.031682
# Epoch: 34/200 	Training Loss: 0.033419
# Epoch: 35/200 	Training Loss: 0.026296
# Epoch: 36/200 	Training Loss: 0.025659
# Epoch: 37/200 	Training Loss: 0.027619
# Epoch: 38/200 	Training Loss: 0.026917
# Epoch: 39/200 	Training Loss: 0.032659
# Epoch: 40/200 	Training Loss: 0.030723
# Epoch: 41/200 	Training Loss: 0.024958
# Epoch: 42/200 	Training Loss: 0.024028
# Epoch: 43/200 	Training Loss: 0.022775
# Epoch: 44/200 	Training Loss: 0.026730
# Epoch: 45/200 	Training Loss: 0.026025
# Epoch: 46/200 	Training Loss: 0.027024
# Epoch: 47/200 	Training Loss: 0.026405
# Epoch: 48/200 	Training Loss: 0.028660
# Epoch: 49/200 	Training Loss: 0.027395
# Epoch: 50/200 	Training Loss: 0.026710
# Epoch: 51/200 	Training Loss: 0.030873
# Epoch: 52/200 	Training Loss: 0.024115
# Epoch: 53/200 	Training Loss: 0.035579
# Epoch: 54/200 	Training Loss: 0.027503
# Epoch: 55/200 	Training Loss: 0.030628
# Epoch: 56/200 	Training Loss: 0.032368
# Epoch: 57/200 	Training Loss: 0.036480
# Epoch: 58/200 	Training Loss: 0.032383
# Epoch: 59/200 	Training Loss: 0.027896
# Epoch: 60/200 	Training Loss: 0.030804
# Epoch: 61/200 	Training Loss: 0.027182
# Epoch: 62/200 	Training Loss: 0.023243
# Epoch: 63/200 	Training Loss: 0.021679
# Epoch: 64/200 	Training Loss: 0.022070
# Epoch: 65/200 	Training Loss: 0.028290
# Epoch: 66/200 	Training Loss: 0.026090
# Epoch: 67/200 	Training Loss: 0.027323
# Epoch: 68/200 	Training Loss: 0.023417
# Epoch: 69/200 	Training Loss: 0.026903
# Epoch: 70/200 	Training Loss: 0.025347
# Epoch: 71/200 	Training Loss: 0.027127
# Epoch: 72/200 	Training Loss: 0.029851
# Epoch: 73/200 	Training Loss: 0.034668
# Epoch: 74/200 	Training Loss: 0.031401
# Epoch: 75/200 	Training Loss: 0.032398
# Epoch: 76/200 	Training Loss: 0.030218
# Epoch: 77/200 	Training Loss: 0.030089
# Epoch: 78/200 	Training Loss: 0.026047
# Epoch: 79/200 	Training Loss: 0.025158
# Epoch: 80/200 	Training Loss: 0.024179
# Epoch: 81/200 	Training Loss: 0.026702
# Epoch: 82/200 	Training Loss: 0.030065
# Epoch: 83/200 	Training Loss: 0.024841
# Epoch: 84/200 	Training Loss: 0.027303
# Epoch: 85/200 	Training Loss: 0.025919
# Epoch: 86/200 	Training Loss: 0.026008
# Epoch: 87/200 	Training Loss: 0.023286
# Epoch: 88/200 	Training Loss: 0.020947
# Epoch: 89/200 	Training Loss: 0.017637
# Epoch: 90/200 	Training Loss: 0.016832
# Epoch: 91/200 	Training Loss: 0.016859
# Epoch: 92/200 	Training Loss: 0.015848
# Epoch: 93/200 	Training Loss: 0.015445
# Epoch: 94/200 	Training Loss: 0.014234
# Epoch: 95/200 	Training Loss: 0.015774
# Epoch: 96/200 	Training Loss: 0.015978
# Epoch: 97/200 	Training Loss: 0.015385
# Epoch: 98/200 	Training Loss: 0.016228
# Epoch: 99/200 	Training Loss: 0.016995
# Epoch: 100/200 	Training Loss: 0.017772
# Epoch: 101/200 	Training Loss: 0.018302
# Epoch: 102/200 	Training Loss: 0.017276
# Epoch: 103/200 	Training Loss: 0.019505
# Epoch: 104/200 	Training Loss: 0.025048
# Epoch: 105/200 	Training Loss: 0.018648
# Epoch: 106/200 	Training Loss: 0.017301
# Epoch: 107/200 	Training Loss: 0.015132
# Epoch: 108/200 	Training Loss: 0.015411
# Epoch: 109/200 	Training Loss: 0.017140
# Epoch: 110/200 	Training Loss: 0.015456
# Epoch: 111/200 	Training Loss: 0.016432
# Epoch: 112/200 	Training Loss: 0.017208
# Epoch: 113/200 	Training Loss: 0.018281
# Epoch: 114/200 	Training Loss: 0.020644
# Epoch: 115/200 	Training Loss: 0.018143
# Epoch: 116/200 	Training Loss: 0.023822
# Epoch: 117/200 	Training Loss: 0.022636
# Epoch: 118/200 	Training Loss: 0.021945
# Epoch: 119/200 	Training Loss: 0.023966
# Epoch: 120/200 	Training Loss: 0.022575
# Epoch: 121/200 	Training Loss: 0.023703
# Epoch: 122/200 	Training Loss: 0.022000
# Epoch: 123/200 	Training Loss: 0.023120
# Epoch: 124/200 	Training Loss: 0.017955
# Epoch: 125/200 	Training Loss: 0.019825
# Epoch: 126/200 	Training Loss: 0.017976
# Epoch: 127/200 	Training Loss: 0.021321
# Epoch: 128/200 	Training Loss: 0.021351
# Epoch: 129/200 	Training Loss: 0.021121
# Epoch: 130/200 	Training Loss: 0.020137
# Epoch: 131/200 	Training Loss: 0.020632
# Epoch: 132/200 	Training Loss: 0.018522
# Epoch: 133/200 	Training Loss: 0.017004
# Epoch: 134/200 	Training Loss: 0.015859
# Epoch: 135/200 	Training Loss: 0.016214
# Epoch: 136/200 	Training Loss: 0.016358
# Epoch: 137/200 	Training Loss: 0.014606
# Epoch: 138/200 	Training Loss: 0.014933
# Epoch: 139/200 	Training Loss: 0.020002
# Epoch: 140/200 	Training Loss: 0.018816
# Epoch: 141/200 	Training Loss: 0.017027
# Epoch: 142/200 	Training Loss: 0.014175
# Epoch: 143/200 	Training Loss: 0.012656
# Epoch: 144/200 	Training Loss: 0.013531
# Epoch: 145/200 	Training Loss: 0.014203
# Epoch: 146/200 	Training Loss: 0.016064
# Epoch: 147/200 	Training Loss: 0.013502
# Epoch: 148/200 	Training Loss: 0.014565
# Epoch: 149/200 	Training Loss: 0.013368
# Epoch: 150/200 	Training Loss: 0.013848
# Epoch: 151/200 	Training Loss: 0.016781
# Epoch: 152/200 	Training Loss: 0.018504
# Epoch: 153/200 	Training Loss: 0.015760
# Epoch: 154/200 	Training Loss: 0.017473
# Epoch: 155/200 	Training Loss: 0.018675
# Epoch: 156/200 	Training Loss: 0.019604
# Epoch: 157/200 	Training Loss: 0.018566
# Epoch: 158/200 	Training Loss: 0.020346
# Epoch: 159/200 	Training Loss: 0.018926
# Epoch: 160/200 	Training Loss: 0.017457
# Epoch: 161/200 	Training Loss: 0.018172
# Epoch: 162/200 	Training Loss: 0.019113
# Epoch: 163/200 	Training Loss: 0.020926
# Epoch: 164/200 	Training Loss: 0.022336
# Epoch: 165/200 	Training Loss: 0.016735
# Epoch: 166/200 	Training Loss: 0.018651
# Epoch: 167/200 	Training Loss: 0.025785
# Epoch: 168/200 	Training Loss: 0.030755
# Epoch: 169/200 	Training Loss: 0.024925
# Epoch: 170/200 	Training Loss: 0.026746
# Epoch: 171/200 	Training Loss: 0.018544
# Epoch: 172/200 	Training Loss: 0.016790
# Epoch: 173/200 	Training Loss: 0.014053
# Epoch: 174/200 	Training Loss: 0.015167
# Epoch: 175/200 	Training Loss: 0.013357
# Epoch: 176/200 	Training Loss: 0.014649
# Epoch: 177/200 	Training Loss: 0.014646
# Epoch: 178/200 	Training Loss: 0.014033
# Epoch: 179/200 	Training Loss: 0.014403
# Epoch: 180/200 	Training Loss: 0.015852
# Epoch: 181/200 	Training Loss: 0.014462
# Epoch: 182/200 	Training Loss: 0.014316
# Epoch: 183/200 	Training Loss: 0.014542
# Epoch: 184/200 	Training Loss: 0.014745
# Epoch: 185/200 	Training Loss: 0.013911
# Epoch: 186/200 	Training Loss: 0.014441
# Epoch: 187/200 	Training Loss: 0.015039
# Epoch: 188/200 	Training Loss: 0.014926
# Epoch: 189/200 	Training Loss: 0.016882
# Epoch: 190/200 	Training Loss: 0.016137
# Epoch: 191/200 	Training Loss: 0.018390
# Epoch: 192/200 	Training Loss: 0.019082
# Epoch: 193/200 	Training Loss: 0.016686
# Epoch: 194/200 	Training Loss: 0.016909
# Epoch: 195/200 	Training Loss: 0.015475
# Epoch: 196/200 	Training Loss: 0.014296
# Epoch: 197/200 	Training Loss: 0.013568
# Epoch: 198/200 	Training Loss: 0.014195
# Epoch: 199/200 	Training Loss: 0.014340
# Epoch: 200/200 	Training Loss: 0.013965
# Time taken: 47.615846700000006

# %%
plt.plot(train_losses)

# Save the model  -- I already saved this and submitted
torch.save(model.state_dict(), 'PyTorch_Model/Default5_PosiDura_NN_mish_Drop_L2_Huber_200Epochs.pt')

# %%
# model.load_state_dict(torch.load('PyTorch_Model/Default1_PosiDura_NN_mish_Drop_L2_Huber_200Epochs.pt', map_location=torch.device('cpu')))

model.eval()           # prep model for *evaluation*
model.to(device)
with torch.no_grad():  # turn off gradient to save memory
    y_predNN_torch = model(X_test_torch.to(device))

y_predNN_normal = y_predNN_torch.cpu().numpy()     # convert to numpy array
y_test_normal = y_test_torch.cpu().numpy()



print(y_predNN_normal)
# Out:
# [[-1.5487553 ]
#  [-1.3682507 ]
#  [-1.2017004 ]
#  ...
#  [ 0.24270475]
#  [ 0.26324177]
#  [ 0.2834674 ]]

# %%
mape = mean_absolute_percentage_error(y_test_normal, y_predNN_normal)
r2 = r2_score(y_test_normal, y_predNN_normal)
rmse = np.sqrt(mean_squared_error(y_test_normal, y_predNN_normal))
print(f"Scores in normal distribution: r2 = {r2}, mape = {mape}, rmse = {rmse}")
# Out:
# Scores in normal distribution: r2 = 0.9476789114824938, mape = 1.097454309463501, rmse = 0.2231629639863968

# %%
y_predNN = quantile1.inverse_transform(y_predNN_normal)
mape = mean_absolute_percentage_error(y_test, y_predNN)
r2 = r2_score(y_test, y_predNN)
rmse = np.sqrt(mean_squared_error(y_test, y_predNN))


print(f"Scores in actual distribution for arrival time: r2 = {r2}, mape = {mape}, rmse = {rmse}")
# Out:
# Scores in actual distribution for arrival time: r2 = 0.9474467292772822, mape = 0.04588610378281271, rmse = 0.0007749826545531091
