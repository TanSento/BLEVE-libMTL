# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import timeit
#import shap
from sklearn.metrics import r2_score, mean_absolute_percentage_error, mean_squared_error
from sklearn.model_selection import cross_val_score, GridSearchCV, KFold
from sklearn.model_selection import train_test_split

# %% [markdown]
# ___

# %% [markdown]
# # Read-in and One-Hot Encoding

# %%
df = pd.read_excel("data_new/train.xlsx", sheet_name="negative_duration")

dt = pd.read_excel("data_new/test.xlsx", sheet_name="negative_duration")

# %%
# Label encoding 'Status' feature into 0 and 1 
# 0 for Subcooled and 1 for Superheated

from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()

df['Status'] = LE.fit_transform(df['Status'])
dt['Status'] = LE.fit_transform(dt['Status'])

df
# Out:
#          ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0      B291                         13.6          0.665119             1.0
# 1      B291                         13.6          0.665119             1.0
# 2      B291                         13.6          0.665119             1.0
# 3      B291                         13.6          0.665119             1.0
# 4      B291                         13.6          0.665119             1.0
# ...     ...                          ...               ...             ...
# 21595  B103                         30.7          0.181290             0.6
# 21596  B103                         30.7          0.181290             0.6
# 21597  B103                         30.7          0.181290             0.6
# 21598  B103                         30.7          0.181290             0.6
# 21599  B103                         30.7          0.181290             0.6
#
#        Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 0                  4.0              0.8                  1.8
# 1                  4.0              0.8                  1.8
# 2                  4.0              0.8                  1.8
# 3                  4.0              0.8                  1.8
# 4                  4.0              0.8                  1.8
# ...                ...              ...                  ...
# 21595              2.0              2.8                  1.2
# 21596              2.0              2.8                  1.2
# 21597              2.0              2.8                  1.2
# 21598              2.0              2.8                  1.2
# 21599              2.0              2.8                  1.2
#
#        Tank Height with Gas (m)   Vapour Temerature (K)  \
# 0                           0.4                   435.0
# 1                           0.4                   435.0
# 2                           0.4                   435.0
# 3                           0.4                   435.0
# 4                           0.4                   435.0
# ...                         ...                     ...
# 21595                       2.2                   334.7
# 21596                       2.2                   334.7
# 21597                       2.2                   334.7
# 21598                       2.2                   334.7
# 21599                       2.2                   334.7
#
#         Liquid Temerature (K)  Status  Stand-off Distance    Target
# 0                       372.5       1                   5  0.009827
# 1                       372.5       1                   6  0.009906
# 2                       372.5       1                   7  0.009970
# 3                       372.5       1                   8  0.010039
# 4                       372.5       1                   9  0.010011
# ...                       ...     ...                 ...       ...
# 21595                   404.9       0                  36  0.017944
# 21596                   404.9       0                  37  0.017724
# 21597                   404.9       0                  38  0.017498
# 21598                   404.9       0                  39  0.017280
# 21599                   404.9       0                  40  0.017078
#
# [21600 rows x 13 columns]

# %%
dt.iloc[30:50,:]
# Out:
#       ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 30  P197                     11.55904          0.602823             3.0
# 31  P197                     11.55904          0.602823             3.0
# 32  P197                     11.55904          0.602823             3.0
# 33  P197                     11.55904          0.602823             3.0
# 34  P197                     11.55904          0.602823             3.0
# 35  P197                     11.55904          0.602823             3.0
# 36  P168                     12.72223          0.648320             1.8
# 37  P168                     12.72223          0.648320             1.8
# 38  P168                     12.72223          0.648320             1.8
# 39  P168                     12.72223          0.648320             1.8
# 40  P168                     12.72223          0.648320             1.8
# 41  P168                     12.72223          0.648320             1.8
# 42  P168                     12.72223          0.648320             1.8
# 43  P168                     12.72223          0.648320             1.8
# 44  P168                     12.72223          0.648320             1.8
# 45  P168                     12.72223          0.648320             1.8
# 46  P168                     12.72223          0.648320             1.8
# 47  P168                     12.72223          0.648320             1.8
# 48  P168                     12.72223          0.648320             1.8
# 49  P168                     12.72223          0.648320             1.8
#
#     Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 30              0.8              2.2                  0.2
# 31              0.8              2.2                  0.2
# 32              0.8              2.2                  0.2
# 33              0.8              2.2                  0.2
# 34              0.8              2.2                  0.2
# 35              0.8              2.2                  0.2
# 36              8.2              0.6                  1.8
# 37              8.2              0.6                  1.8
# 38              8.2              0.6                  1.8
# 39              8.2              0.6                  1.8
# 40              8.2              0.6                  1.8
# 41              8.2              0.6                  1.8
# 42              8.2              0.6                  1.8
# 43              8.2              0.6                  1.8
# 44              8.2              0.6                  1.8
# 45              8.2              0.6                  1.8
# 46              8.2              0.6                  1.8
# 47              8.2              0.6                  1.8
# 48              8.2              0.6                  1.8
# 49              8.2              0.6                  1.8
#
#     Tank Height with Gas (m)   Vapour Temerature (K)   Liquid Temerature (K)  \
# 30                       1.0                   296.7                   328.5
# 31                       1.0                   296.7                   328.5
# 32                       1.0                   296.7                   328.5
# 33                       1.0                   296.7                   328.5
# 34                       1.0                   296.7                   328.5
# 35                       1.0                   296.7                   328.5
# 36                       0.2                   389.7                   296.4
# 37                       0.2                   389.7                   296.4
# 38                       0.2                   389.7                   296.4
# 39                       0.2                   389.7                   296.4
# 40                       0.2                   389.7                   296.4
# 41                       0.2                   389.7                   296.4
# 42                       0.2                   389.7                   296.4
# 43                       0.2                   389.7                   296.4
# 44                       0.2                   389.7                   296.4
# 45                       0.2                   389.7                   296.4
# 46                       0.2                   389.7                   296.4
# 47                       0.2                   389.7                   296.4
# 48                       0.2                   389.7                   296.4
# 49                       0.2                   389.7                   296.4
#
#     Status  Stand-off Distance    Target
# 30       1                  35  0.015426
# 31       1                  36  0.015341
# 32       1                  37  0.015277
# 33       1                  38  0.015224
# 34       1                  39  0.015191
# 35       1                  40  0.015170
# 36       0                   5  0.009043
# 37       0                   6  0.009390
# 38       0                   7  0.009452
# 39       0                   8  0.009528
# 40       0                   9  0.009658
# 41       0                  10  0.009688
# 42       0                  11  0.009588
# 43       0                  12  0.009598
# 44       0                  13  0.009700
# 45       0                  14  0.009631
# 46       0                  15  0.009524
# 47       0                  16  0.012086
# 48       0                  17  0.012530
# 49       0                  18  0.012757

# %%
X_traindf = df.drop(['ID','Target'], axis=1)
X_testdf = dt.drop(['ID','Target'], axis=1)

X_traindf
# Out:
#        Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0                             13.6          0.665119             1.0
# 1                             13.6          0.665119             1.0
# 2                             13.6          0.665119             1.0
# 3                             13.6          0.665119             1.0
# 4                             13.6          0.665119             1.0
# ...                            ...               ...             ...
# 21595                         30.7          0.181290             0.6
# 21596                         30.7          0.181290             0.6
# 21597                         30.7          0.181290             0.6
# 21598                         30.7          0.181290             0.6
# 21599                         30.7          0.181290             0.6
#
#        Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 0                  4.0              0.8                  1.8
# 1                  4.0              0.8                  1.8
# 2                  4.0              0.8                  1.8
# 3                  4.0              0.8                  1.8
# 4                  4.0              0.8                  1.8
# ...                ...              ...                  ...
# 21595              2.0              2.8                  1.2
# 21596              2.0              2.8                  1.2
# 21597              2.0              2.8                  1.2
# 21598              2.0              2.8                  1.2
# 21599              2.0              2.8                  1.2
#
#        Tank Height with Gas (m)   Vapour Temerature (K)  \
# 0                           0.4                   435.0
# 1                           0.4                   435.0
# 2                           0.4                   435.0
# 3                           0.4                   435.0
# 4                           0.4                   435.0
# ...                         ...                     ...
# 21595                       2.2                   334.7
# 21596                       2.2                   334.7
# 21597                       2.2                   334.7
# 21598                       2.2                   334.7
# 21599                       2.2                   334.7
#
#         Liquid Temerature (K)  Status  Stand-off Distance
# 0                       372.5       1                   5
# 1                       372.5       1                   6
# 2                       372.5       1                   7
# 3                       372.5       1                   8
# 4                       372.5       1                   9
# ...                       ...     ...                 ...
# 21595                   404.9       0                  36
# 21596                   404.9       0                  37
# 21597                   404.9       0                  38
# 21598                   404.9       0                  39
# 21599                   404.9       0                  40
#
# [21600 rows x 11 columns]

# %%
y_train = df['Target']
y_train
# Out:
# 0        0.009827
# 1        0.009906
# 2        0.009970
# 3        0.010039
# 4        0.010011
#            ...
# 21595    0.017944
# 21596    0.017724
# 21597    0.017498
# 21598    0.017280
# 21599    0.017078
# Name: Target, Length: 21600, dtype: float64

# %%
y_test = dt['Target']

y_test
# Out:
# 0       0.017425
# 1       0.017031
# 2       0.016819
# 3       0.016603
# 4       0.016633
#           ...
# 7195    0.015640
# 7196    0.015677
# 7197    0.015717
# 7198    0.015774
# 7199    0.015850
# Name: Target, Length: 7200, dtype: float64

# %% [markdown]
# ___

# %% [markdown]
# # Standardization and Power Transform

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import QuantileTransformer

# %%
# Processing both X_train and X_test using standardization
scaler = StandardScaler()
X_train = scaler.fit_transform(X_traindf)
X_test = scaler.transform(X_testdf)

# %%
quantile1 = QuantileTransformer(output_distribution='normal')



y_train_normal = quantile1.fit_transform(y_train.values.reshape(-1,1))
y_test_normal = quantile1.transform(y_test.values.reshape(-1,1))

# %%
# Visualize the effect of power transformation
f = plt.figure(figsize=(15, 6))

ax = f.add_subplot(121)
sns.distplot(y_train, bins=50, color='r', ax=ax)
ax.set_title('Distribution before processing')

ax=f.add_subplot(122)
sns.distplot(y_train_normal, bins=50, color='b', ax=ax)
ax.set_title('Distribution after quantile processing')
print()
# Out:
# c:\Users\buita\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\buita\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ___

# %% [markdown]
# # ANN

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt

torch.backends.cudnn.version() , torch.backends.cudnn.enabled
# Out:
# (8500, True)

# %%
# convert data to torch.FloatTensor
X_train_torch = torch.from_numpy(X_train.astype(np.float32))
X_test_torch = torch.from_numpy(X_test.astype(np.float32))



y_train_torch = torch.from_numpy(y_train_normal.astype(np.float32))
y_test_torch = torch.from_numpy(y_test_normal.astype(np.float32))

print(X_train_torch)
# Out:
# tensor([[-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.6846],
#         [-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.5883],
#         [-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.4921],
#         ...,
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.4921],
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.5883],
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.6846]])

# %%
train_data = []
for i in range(len(X_train_torch)):
   train_data.append([X_train_torch[i],
                      y_train_torch[i]
                     ])

test_data = []
for i in range(len(X_test_torch)):
   test_data.append([X_test_torch[i], 
                     y_test_torch[i]
                     ])
   
# prepare data loaders
train_loader = torch.utils.data.DataLoader(train_data, batch_size=512,               # batch_size could be smaller
    num_workers=0)                                                                   # Increasing num_workers slow down the training because it does not use GPU at all
test_loader = torch.utils.data.DataLoader(test_data, batch_size=512,
    num_workers=0)

# %%
## Define the NN architecture
## NN with 3 hidden layer, s=[26, 256, 256, 256, 128, 8]

class BleveNet(nn.Module):
    def __init__(self):
        super(BleveNet, self).__init__()
        # The first hidden layer has 256 neurons
        self.fc1 = nn.Linear(X_train_torch.shape[1], 256)
        # The second hidden layer has 256 neurons
        self.fc2 = nn.Linear(256, 256)
        # The third hidden layer has 256 neurons
        self.fc3 = nn.Linear(256, 256)
        # The fourth layer has 128 output neurons
        self.fc4 = nn.Linear(256, 128)
        # The final layer has 8 output neurons
        self.fc5 = nn.Linear(128, 1)


        # Define proportion or neurons to dropout
        self.dropout = nn.Dropout(0.1)

        # Mish activation
        self.mish = nn.Mish()


    def forward(self, x):
        # add first fully connected layer
        x = self.fc1(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add second fully connected layer
        x = self.fc2(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add third fully connected layer
        x = self.fc3(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add fourth fully connected layers
        x = self.fc4(x)
        x = self.mish(x)
        x = self.dropout(x)

        # add final output layers:
        output = self.fc5(x)
       
        return output

# initialize the NN
model = BleveNet()
print(model)
# Out:
# BleveNet(
#   (fc1): Linear(in_features=11, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=256, bias=True)
#   (fc4): Linear(in_features=256, out_features=128, bias=True)
#   (fc5): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (mish): Mish()
# )

# %%
criterion = nn.HuberLoss()        # This is the best loss function for my model
# criterion = nn.MSELoss()


optimizer = torch.optim.Adam(model.parameters(), lr=0.005, weight_decay=1e-5)     # This is the best optimizer for my model 

# Check for GPU
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
startTime = timeit.default_timer() 

n_epochs = 200 

model.to(device)    # bring the model to gpu
model.train()       # prep model for training

train_losses = []
for epoch in range(n_epochs):
    # monitor training loss
    train_loss = 0.0
    
    ###################
    # train the model #
    ###################
    for data, target in train_loader:
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        #bring data and target to gpu
        data, target = data.to(device), target.to(device)
        
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update running training loss
        train_loss += loss.item()*data.size(0)
        
    # print training statistics 
    # calculate average loss over an epoch
    train_loss = train_loss/len(train_loader.dataset)
    train_losses.append(train_loss)

    print('Epoch: {}/{} \tTraining Loss: {:.6f}'.format(
        epoch+1,
        n_epochs, 
        train_loss
        ))
    

endTime = timeit.default_timer()
runningTotal = (endTime - startTime)
print(f"Time taken: {runningTotal}")
# Out:
# Epoch: 1/200 	Training Loss: 0.137229
# Epoch: 2/200 	Training Loss: 0.067768
# Epoch: 3/200 	Training Loss: 0.064664
# Epoch: 4/200 	Training Loss: 0.052627
# Epoch: 5/200 	Training Loss: 0.050893
# Epoch: 6/200 	Training Loss: 0.053918
# Epoch: 7/200 	Training Loss: 0.055446
# Epoch: 8/200 	Training Loss: 0.050570
# Epoch: 9/200 	Training Loss: 0.050272
# Epoch: 10/200 	Training Loss: 0.049421
# Epoch: 11/200 	Training Loss: 0.040012
# Epoch: 12/200 	Training Loss: 0.036003
# Epoch: 13/200 	Training Loss: 0.038411
# Epoch: 14/200 	Training Loss: 0.035376
# Epoch: 15/200 	Training Loss: 0.041887
# Epoch: 16/200 	Training Loss: 0.038863
# Epoch: 17/200 	Training Loss: 0.041789
# Epoch: 18/200 	Training Loss: 0.047411
# Epoch: 19/200 	Training Loss: 0.038911
# Epoch: 20/200 	Training Loss: 0.032708
# Epoch: 21/200 	Training Loss: 0.033652
# Epoch: 22/200 	Training Loss: 0.036981
# Epoch: 23/200 	Training Loss: 0.034418
# Epoch: 24/200 	Training Loss: 0.032207
# Epoch: 25/200 	Training Loss: 0.037771
# Epoch: 26/200 	Training Loss: 0.036620
# Epoch: 27/200 	Training Loss: 0.036980
# Epoch: 28/200 	Training Loss: 0.032212
# Epoch: 29/200 	Training Loss: 0.037046
# Epoch: 30/200 	Training Loss: 0.033246
# Epoch: 31/200 	Training Loss: 0.034734
# Epoch: 32/200 	Training Loss: 0.033679
# Epoch: 33/200 	Training Loss: 0.029264
# Epoch: 34/200 	Training Loss: 0.030474
# Epoch: 35/200 	Training Loss: 0.032301
# Epoch: 36/200 	Training Loss: 0.030916
# Epoch: 37/200 	Training Loss: 0.023275
# Epoch: 38/200 	Training Loss: 0.022044
# Epoch: 39/200 	Training Loss: 0.023814
# Epoch: 40/200 	Training Loss: 0.025146
# Epoch: 41/200 	Training Loss: 0.022659
# Epoch: 42/200 	Training Loss: 0.021703
# Epoch: 43/200 	Training Loss: 0.022318
# Epoch: 44/200 	Training Loss: 0.025562
# Epoch: 45/200 	Training Loss: 0.025377
# Epoch: 46/200 	Training Loss: 0.032617
# Epoch: 47/200 	Training Loss: 0.030152
# Epoch: 48/200 	Training Loss: 0.028868
# Epoch: 49/200 	Training Loss: 0.027692
# Epoch: 50/200 	Training Loss: 0.022835
# Epoch: 51/200 	Training Loss: 0.029568
# Epoch: 52/200 	Training Loss: 0.032380
# Epoch: 53/200 	Training Loss: 0.042851
# Epoch: 54/200 	Training Loss: 0.035452
# Epoch: 55/200 	Training Loss: 0.034143
# Epoch: 56/200 	Training Loss: 0.051121
# Epoch: 57/200 	Training Loss: 0.056935
# Epoch: 58/200 	Training Loss: 0.034388
# Epoch: 59/200 	Training Loss: 0.038838
# Epoch: 60/200 	Training Loss: 0.037811
# Epoch: 61/200 	Training Loss: 0.040794
# Epoch: 62/200 	Training Loss: 0.029647
# Epoch: 63/200 	Training Loss: 0.026476
# Epoch: 64/200 	Training Loss: 0.024772
# Epoch: 65/200 	Training Loss: 0.023319
# Epoch: 66/200 	Training Loss: 0.025281
# Epoch: 67/200 	Training Loss: 0.027436
# Epoch: 68/200 	Training Loss: 0.024064
# Epoch: 69/200 	Training Loss: 0.020669
# Epoch: 70/200 	Training Loss: 0.021551
# Epoch: 71/200 	Training Loss: 0.025131
# Epoch: 72/200 	Training Loss: 0.027552
# Epoch: 73/200 	Training Loss: 0.026739
# Epoch: 74/200 	Training Loss: 0.022942
# Epoch: 75/200 	Training Loss: 0.020017
# Epoch: 76/200 	Training Loss: 0.022175
# Epoch: 77/200 	Training Loss: 0.021148
# Epoch: 78/200 	Training Loss: 0.020102
# Epoch: 79/200 	Training Loss: 0.019711
# Epoch: 80/200 	Training Loss: 0.023560
# Epoch: 81/200 	Training Loss: 0.032044
# Epoch: 82/200 	Training Loss: 0.027405
# Epoch: 83/200 	Training Loss: 0.029177
# Epoch: 84/200 	Training Loss: 0.032207
# Epoch: 85/200 	Training Loss: 0.025851
# Epoch: 86/200 	Training Loss: 0.020920
# Epoch: 87/200 	Training Loss: 0.019411
# Epoch: 88/200 	Training Loss: 0.019887
# Epoch: 89/200 	Training Loss: 0.020169
# Epoch: 90/200 	Training Loss: 0.020966
# Epoch: 91/200 	Training Loss: 0.022553
# Epoch: 92/200 	Training Loss: 0.029551
# Epoch: 93/200 	Training Loss: 0.121783
# Epoch: 94/200 	Training Loss: 1.299392
# Epoch: 95/200 	Training Loss: 0.117616
# Epoch: 96/200 	Training Loss: 0.073757
# Epoch: 97/200 	Training Loss: 0.070076
# Epoch: 98/200 	Training Loss: 0.060559
# Epoch: 99/200 	Training Loss: 0.049796
# Epoch: 100/200 	Training Loss: 0.044744
# Epoch: 101/200 	Training Loss: 0.042341
# Epoch: 102/200 	Training Loss: 0.040715
# Epoch: 103/200 	Training Loss: 0.040478
# Epoch: 104/200 	Training Loss: 0.040226
# Epoch: 105/200 	Training Loss: 0.045176
# Epoch: 106/200 	Training Loss: 0.042051
# Epoch: 107/200 	Training Loss: 0.036174
# Epoch: 108/200 	Training Loss: 0.032670
# Epoch: 109/200 	Training Loss: 0.030717
# Epoch: 110/200 	Training Loss: 0.029181
# Epoch: 111/200 	Training Loss: 0.029363
# Epoch: 112/200 	Training Loss: 0.029297
# Epoch: 113/200 	Training Loss: 0.028520
# Epoch: 114/200 	Training Loss: 0.028609
# Epoch: 115/200 	Training Loss: 0.026799
# Epoch: 116/200 	Training Loss: 0.026498
# Epoch: 117/200 	Training Loss: 0.025735
# Epoch: 118/200 	Training Loss: 0.024744
# Epoch: 119/200 	Training Loss: 0.025255
# Epoch: 120/200 	Training Loss: 0.026008
# Epoch: 121/200 	Training Loss: 0.025891
# Epoch: 122/200 	Training Loss: 0.025954
# Epoch: 123/200 	Training Loss: 0.026562
# Epoch: 124/200 	Training Loss: 0.024917
# Epoch: 125/200 	Training Loss: 0.026240
# Epoch: 126/200 	Training Loss: 0.025555
# Epoch: 127/200 	Training Loss: 0.026570
# Epoch: 128/200 	Training Loss: 0.025410
# Epoch: 129/200 	Training Loss: 0.024551
# Epoch: 130/200 	Training Loss: 0.026607
# Epoch: 131/200 	Training Loss: 0.026355
# Epoch: 132/200 	Training Loss: 0.024020
# Epoch: 133/200 	Training Loss: 0.023378
# Epoch: 134/200 	Training Loss: 0.023297
# Epoch: 135/200 	Training Loss: 0.025052
# Epoch: 136/200 	Training Loss: 0.024853
# Epoch: 137/200 	Training Loss: 0.025316
# Epoch: 138/200 	Training Loss: 0.026711
# Epoch: 139/200 	Training Loss: 0.027056
# Epoch: 140/200 	Training Loss: 0.026517
# Epoch: 141/200 	Training Loss: 0.025637
# Epoch: 142/200 	Training Loss: 0.027615
# Epoch: 143/200 	Training Loss: 0.028750
# Epoch: 144/200 	Training Loss: 0.028337
# Epoch: 145/200 	Training Loss: 0.028920
# Epoch: 146/200 	Training Loss: 0.030379
# Epoch: 147/200 	Training Loss: 0.029147
# Epoch: 148/200 	Training Loss: 0.026002
# Epoch: 149/200 	Training Loss: 0.028343
# Epoch: 150/200 	Training Loss: 0.025130
# Epoch: 151/200 	Training Loss: 0.024786
# Epoch: 152/200 	Training Loss: 0.024551
# Epoch: 153/200 	Training Loss: 0.024170
# Epoch: 154/200 	Training Loss: 0.021404
# Epoch: 155/200 	Training Loss: 0.020786
# Epoch: 156/200 	Training Loss: 0.021575
# Epoch: 157/200 	Training Loss: 0.020174
# Epoch: 158/200 	Training Loss: 0.019866
# Epoch: 159/200 	Training Loss: 0.018772
# Epoch: 160/200 	Training Loss: 0.018789
# Epoch: 161/200 	Training Loss: 0.017920
# Epoch: 162/200 	Training Loss: 0.018183
# Epoch: 163/200 	Training Loss: 0.018309
# Epoch: 164/200 	Training Loss: 0.017483
# Epoch: 165/200 	Training Loss: 0.018788
# Epoch: 166/200 	Training Loss: 0.016978
# Epoch: 167/200 	Training Loss: 0.016963
# Epoch: 168/200 	Training Loss: 0.017530
# Epoch: 169/200 	Training Loss: 0.016138
# Epoch: 170/200 	Training Loss: 0.017651
# Epoch: 171/200 	Training Loss: 0.016659
# Epoch: 172/200 	Training Loss: 0.018705
# Epoch: 173/200 	Training Loss: 0.019068
# Epoch: 174/200 	Training Loss: 0.020511
# Epoch: 175/200 	Training Loss: 0.018814
# Epoch: 176/200 	Training Loss: 0.018875
# Epoch: 177/200 	Training Loss: 0.018196
# Epoch: 178/200 	Training Loss: 0.018138
# Epoch: 179/200 	Training Loss: 0.017635
# Epoch: 180/200 	Training Loss: 0.016865
# Epoch: 181/200 	Training Loss: 0.017235
# Epoch: 182/200 	Training Loss: 0.016862
# Epoch: 183/200 	Training Loss: 0.016238
# Epoch: 184/200 	Training Loss: 0.015181
# Epoch: 185/200 	Training Loss: 0.016259
# Epoch: 186/200 	Training Loss: 0.015952
# Epoch: 187/200 	Training Loss: 0.017442
# Epoch: 188/200 	Training Loss: 0.018364
# Epoch: 189/200 	Training Loss: 0.017463
# Epoch: 190/200 	Training Loss: 0.016957
# Epoch: 191/200 	Training Loss: 0.017331
# Epoch: 192/200 	Training Loss: 0.017394
# Epoch: 193/200 	Training Loss: 0.017866
# Epoch: 194/200 	Training Loss: 0.018052
# Epoch: 195/200 	Training Loss: 0.017191
# Epoch: 196/200 	Training Loss: 0.017227
# Epoch: 197/200 	Training Loss: 0.017644
# Epoch: 198/200 	Training Loss: 0.017237
# Epoch: 199/200 	Training Loss: 0.016813
# Epoch: 200/200 	Training Loss: 0.021165
# Time taken: 71.79532859999999

# %%
plt.plot(train_losses)

# Save the model  -- I already saved this and submitted
torch.save(model.state_dict(), 'PyTorch_Model/NegaDura_NN_mish_Drop_L2_Huber_200Epochs.pt')

# %%
model.load_state_dict(torch.load('PyTorch_Model/NegaDura_NN_mish_Drop_L2_Huber_200Epochs.pt', map_location=torch.device('cpu')))

model.eval()           # prep model for *evaluation*
model.to(device)
with torch.no_grad():  # turn off gradient to save memory
    y_predNN_torch = model(X_test_torch.to(device))

y_predNN_normal = y_predNN_torch.cpu().numpy()     # convert to numpy array
y_test_normal = y_test_torch.cpu().numpy()



print(y_predNN_normal)
# Out:
# [[-0.17478988]
#  [-0.2064153 ]
#  [-0.23553744]
#  ...
#  [-0.0127876 ]
#  [ 0.00258884]
#  [ 0.01672377]]

# %%
mape = mean_absolute_percentage_error(y_test_normal, y_predNN_normal)
r2 = r2_score(y_test_normal, y_predNN_normal)
rmse = np.sqrt(mean_squared_error(y_test_normal, y_predNN_normal))
print(f"Scores in normal distribution: r2 = {r2}, mape = {mape}, rmse = {rmse}")
# Out:
# Scores in normal distribution: r2 = 0.9023242924067961, mape = 1.8832426071166992, rmse = 0.31771671772003174

# %%
y_predNN = quantile1.inverse_transform(y_predNN_normal)
mape = mean_absolute_percentage_error(y_test, y_predNN)
r2 = r2_score(y_test, y_predNN)
rmse = np.sqrt(mean_squared_error(y_test, y_predNN))


print(f"Scores in actual distribution for arrival time: r2 = {r2}, mape = {mape}, rmse = {rmse}")
# Out:
# Scores in actual distribution for arrival time: r2 = 0.9148066227173894, mape = 0.082540667312328, rmse = 0.001837323220092001
