# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import timeit
#import shap
from sklearn.metrics import r2_score, mean_absolute_percentage_error, mean_squared_error
from sklearn.model_selection import cross_val_score, GridSearchCV, KFold
from sklearn.model_selection import train_test_split

# %% [markdown]
# ___

# %% [markdown]
# # Read-in and One-Hot Encoding

# %%
df = pd.read_excel("data_new/train.xlsx", sheet_name="positive_impulse")

dt = pd.read_excel("data_new/test.xlsx", sheet_name="positive_impulse")

# %%
# Label encoding 'Status' feature into 0 and 1 
# 0 for Subcooled and 1 for Superheated

from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()

df['Status'] = LE.fit_transform(df['Status'])
dt['Status'] = LE.fit_transform(dt['Status'])

df
# Out:
#          ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0      B291                         13.6          0.665119             1.0
# 1      B291                         13.6          0.665119             1.0
# 2      B291                         13.6          0.665119             1.0
# 3      B291                         13.6          0.665119             1.0
# 4      B291                         13.6          0.665119             1.0
# ...     ...                          ...               ...             ...
# 21595  B103                         30.7          0.181290             0.6
# 21596  B103                         30.7          0.181290             0.6
# 21597  B103                         30.7          0.181290             0.6
# 21598  B103                         30.7          0.181290             0.6
# 21599  B103                         30.7          0.181290             0.6
#
#        Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 0                  4.0              0.8                  1.8
# 1                  4.0              0.8                  1.8
# 2                  4.0              0.8                  1.8
# 3                  4.0              0.8                  1.8
# 4                  4.0              0.8                  1.8
# ...                ...              ...                  ...
# 21595              2.0              2.8                  1.2
# 21596              2.0              2.8                  1.2
# 21597              2.0              2.8                  1.2
# 21598              2.0              2.8                  1.2
# 21599              2.0              2.8                  1.2
#
#        Tank Height with Gas (m)   Vapour Temerature (K)  \
# 0                           0.4                   435.0
# 1                           0.4                   435.0
# 2                           0.4                   435.0
# 3                           0.4                   435.0
# 4                           0.4                   435.0
# ...                         ...                     ...
# 21595                       2.2                   334.7
# 21596                       2.2                   334.7
# 21597                       2.2                   334.7
# 21598                       2.2                   334.7
# 21599                       2.2                   334.7
#
#         Liquid Temerature (K)  Status  Stand-off Distance      Target
# 0                       372.5       1                   5  105.453270
# 1                       372.5       1                   6   89.190781
# 2                       372.5       1                   7   77.237755
# 3                       372.5       1                   8   68.085800
# 4                       372.5       1                   9   60.845432
# ...                       ...     ...                 ...         ...
# 21595                   404.9       0                  36   29.048307
# 21596                   404.9       0                  37   28.231998
# 21597                   404.9       0                  38   27.460642
# 21598                   404.9       0                  39   26.729723
# 21599                   404.9       0                  40   26.035421
#
# [21600 rows x 13 columns]

# %%
dt.iloc[30:50,:]
# Out:
#       ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 30  P197                     11.55904          0.602823             3.0
# 31  P197                     11.55904          0.602823             3.0
# 32  P197                     11.55904          0.602823             3.0
# 33  P197                     11.55904          0.602823             3.0
# 34  P197                     11.55904          0.602823             3.0
# 35  P197                     11.55904          0.602823             3.0
# 36  P168                     12.72223          0.648320             1.8
# 37  P168                     12.72223          0.648320             1.8
# 38  P168                     12.72223          0.648320             1.8
# 39  P168                     12.72223          0.648320             1.8
# 40  P168                     12.72223          0.648320             1.8
# 41  P168                     12.72223          0.648320             1.8
# 42  P168                     12.72223          0.648320             1.8
# 43  P168                     12.72223          0.648320             1.8
# 44  P168                     12.72223          0.648320             1.8
# 45  P168                     12.72223          0.648320             1.8
# 46  P168                     12.72223          0.648320             1.8
# 47  P168                     12.72223          0.648320             1.8
# 48  P168                     12.72223          0.648320             1.8
# 49  P168                     12.72223          0.648320             1.8
#
#     Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 30              0.8              2.2                  0.2
# 31              0.8              2.2                  0.2
# 32              0.8              2.2                  0.2
# 33              0.8              2.2                  0.2
# 34              0.8              2.2                  0.2
# 35              0.8              2.2                  0.2
# 36              8.2              0.6                  1.8
# 37              8.2              0.6                  1.8
# 38              8.2              0.6                  1.8
# 39              8.2              0.6                  1.8
# 40              8.2              0.6                  1.8
# 41              8.2              0.6                  1.8
# 42              8.2              0.6                  1.8
# 43              8.2              0.6                  1.8
# 44              8.2              0.6                  1.8
# 45              8.2              0.6                  1.8
# 46              8.2              0.6                  1.8
# 47              8.2              0.6                  1.8
# 48              8.2              0.6                  1.8
# 49              8.2              0.6                  1.8
#
#     Tank Height with Gas (m)   Vapour Temerature (K)   Liquid Temerature (K)  \
# 30                       1.0                   296.7                   328.5
# 31                       1.0                   296.7                   328.5
# 32                       1.0                   296.7                   328.5
# 33                       1.0                   296.7                   328.5
# 34                       1.0                   296.7                   328.5
# 35                       1.0                   296.7                   328.5
# 36                       0.2                   389.7                   296.4
# 37                       0.2                   389.7                   296.4
# 38                       0.2                   389.7                   296.4
# 39                       0.2                   389.7                   296.4
# 40                       0.2                   389.7                   296.4
# 41                       0.2                   389.7                   296.4
# 42                       0.2                   389.7                   296.4
# 43                       0.2                   389.7                   296.4
# 44                       0.2                   389.7                   296.4
# 45                       0.2                   389.7                   296.4
# 46                       0.2                   389.7                   296.4
# 47                       0.2                   389.7                   296.4
# 48                       0.2                   389.7                   296.4
# 49                       0.2                   389.7                   296.4
#
#     Status  Stand-off Distance     Target
# 30       1                  35  11.898917
# 31       1                  36  11.622511
# 32       1                  37  11.358176
# 33       1                  38  11.105268
# 34       1                  39  10.863276
# 35       1                  40  10.631696
# 36       0                   5  83.744408
# 37       0                   6  73.629570
# 38       0                   7  65.149193
# 39       0                   8  58.173275
# 40       0                   9  52.403481
# 41       0                  10  47.589138
# 42       0                  11  43.535988
# 43       0                  12  40.098892
# 44       0                  13  37.164490
# 45       0                  14  34.629341
# 46       0                  15  32.415222
# 47       0                  16  29.546595
# 48       0                  17  27.957481
# 49       0                  18  26.551182

# %%
X_traindf = df.drop(['ID','Target'], axis=1)
X_testdf = dt.drop(['ID','Target'], axis=1)

X_traindf
# Out:
#        Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0                             13.6          0.665119             1.0
# 1                             13.6          0.665119             1.0
# 2                             13.6          0.665119             1.0
# 3                             13.6          0.665119             1.0
# 4                             13.6          0.665119             1.0
# ...                            ...               ...             ...
# 21595                         30.7          0.181290             0.6
# 21596                         30.7          0.181290             0.6
# 21597                         30.7          0.181290             0.6
# 21598                         30.7          0.181290             0.6
# 21599                         30.7          0.181290             0.6
#
#        Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 0                  4.0              0.8                  1.8
# 1                  4.0              0.8                  1.8
# 2                  4.0              0.8                  1.8
# 3                  4.0              0.8                  1.8
# 4                  4.0              0.8                  1.8
# ...                ...              ...                  ...
# 21595              2.0              2.8                  1.2
# 21596              2.0              2.8                  1.2
# 21597              2.0              2.8                  1.2
# 21598              2.0              2.8                  1.2
# 21599              2.0              2.8                  1.2
#
#        Tank Height with Gas (m)   Vapour Temerature (K)  \
# 0                           0.4                   435.0
# 1                           0.4                   435.0
# 2                           0.4                   435.0
# 3                           0.4                   435.0
# 4                           0.4                   435.0
# ...                         ...                     ...
# 21595                       2.2                   334.7
# 21596                       2.2                   334.7
# 21597                       2.2                   334.7
# 21598                       2.2                   334.7
# 21599                       2.2                   334.7
#
#         Liquid Temerature (K)  Status  Stand-off Distance
# 0                       372.5       1                   5
# 1                       372.5       1                   6
# 2                       372.5       1                   7
# 3                       372.5       1                   8
# 4                       372.5       1                   9
# ...                       ...     ...                 ...
# 21595                   404.9       0                  36
# 21596                   404.9       0                  37
# 21597                   404.9       0                  38
# 21598                   404.9       0                  39
# 21599                   404.9       0                  40
#
# [21600 rows x 11 columns]

# %%
y_train = df['Target']
y_train
# Out:
# 0        105.453270
# 1         89.190781
# 2         77.237755
# 3         68.085800
# 4         60.845432
#             ...
# 21595     29.048307
# 21596     28.231998
# 21597     27.460642
# 21598     26.729723
# 21599     26.035421
# Name: Target, Length: 21600, dtype: float64

# %%
y_test = dt['Target']

y_test
# Out:
# 0       52.619038
# 1       46.055485
# 2       41.131420
# 3       37.347630
# 4       34.215847
#           ...
# 7195    37.768711
# 7196    36.680138
# 7197    35.652153
# 7198    34.679951
# 7199    33.759022
# Name: Target, Length: 7200, dtype: float64

# %% [markdown]
# ___

# %% [markdown]
# # Standardization and Power Transform

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import QuantileTransformer

# %%
# Processing both X_train and X_test using standardization
scaler = StandardScaler()
X_train = scaler.fit_transform(X_traindf)
X_test = scaler.transform(X_testdf)

# %%
quantile1 = QuantileTransformer(output_distribution='normal')



y_train_normal = quantile1.fit_transform(y_train.values.reshape(-1,1))
y_test_normal = quantile1.transform(y_test.values.reshape(-1,1))

# %%
# Visualize the effect of power transformation
f = plt.figure(figsize=(15, 6))

ax = f.add_subplot(121)
sns.distplot(y_train, bins=50, color='r', ax=ax)
ax.set_title('Distribution before processing')

ax=f.add_subplot(122)
sns.distplot(y_train_normal, bins=50, color='b', ax=ax)
ax.set_title('Distribution after quantile processing')
print()
# Out:
# c:\Users\buita\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\buita\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ___

# %% [markdown]
# # ANN

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt

torch.backends.cudnn.version() , torch.backends.cudnn.enabled
# Out:
# (8500, True)

# %%
# convert data to torch.FloatTensor
X_train_torch = torch.from_numpy(X_train.astype(np.float32))
X_test_torch = torch.from_numpy(X_test.astype(np.float32))



y_train_torch = torch.from_numpy(y_train_normal.astype(np.float32))
y_test_torch = torch.from_numpy(y_test_normal.astype(np.float32))

print(X_train_torch)
# Out:
# tensor([[-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.6846],
#         [-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.5883],
#         [-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.4921],
#         ...,
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.4921],
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.5883],
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.6846]])

# %%
train_data = []
for i in range(len(X_train_torch)):
   train_data.append([X_train_torch[i],
                      y_train_torch[i]
                     ])

test_data = []
for i in range(len(X_test_torch)):
   test_data.append([X_test_torch[i], 
                     y_test_torch[i]
                     ])
   
# prepare data loaders
train_loader = torch.utils.data.DataLoader(train_data, batch_size=512,               # batch_size could be smaller
    num_workers=0)                                                                   # Increasing num_workers slow down the training because it does not use GPU at all
test_loader = torch.utils.data.DataLoader(test_data, batch_size=512,
    num_workers=0)

# %%
## Define the NN architecture
## NN with 3 hidden layer, s=[26, 256, 256, 256, 128, 8]

class BleveNet(nn.Module):
    def __init__(self):
        super(BleveNet, self).__init__()
        # The first hidden layer has 256 neurons
        self.fc1 = nn.Linear(X_train_torch.shape[1], 256)
        # The second hidden layer has 256 neurons
        self.fc2 = nn.Linear(256, 256)
        # The third hidden layer has 256 neurons
        self.fc3 = nn.Linear(256, 256)
        # The fourth layer has 128 output neurons
        self.fc4 = nn.Linear(256, 128)
        # The final layer has 8 output neurons
        self.fc5 = nn.Linear(128, 1)


        # Define proportion or neurons to dropout
        self.dropout = nn.Dropout(0.1)

        # Mish activation
        self.mish = nn.Mish()


    def forward(self, x):
        # add first fully connected layer
        x = self.fc1(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add second fully connected layer
        x = self.fc2(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add third fully connected layer
        x = self.fc3(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add fourth fully connected layers
        x = self.fc4(x)
        x = self.mish(x)
        x = self.dropout(x)

        # add final output layers:
        output = self.fc5(x)
       
        return output

# initialize the NN
model = BleveNet()
print(model)
# Out:
# BleveNet(
#   (fc1): Linear(in_features=11, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=256, bias=True)
#   (fc4): Linear(in_features=256, out_features=128, bias=True)
#   (fc5): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (mish): Mish()
# )

# %%
criterion = nn.HuberLoss()        # This is the best loss function for my model
# criterion = nn.MSELoss()


optimizer = torch.optim.Adam(model.parameters(), lr=0.005, weight_decay=1e-5)     # This is the best optimizer for my model 

# Check for GPU
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
startTime = timeit.default_timer() 

n_epochs = 200 

model.to(device)    # bring the model to gpu
model.train()       # prep model for training

train_losses = []
for epoch in range(n_epochs):
    # monitor training loss
    train_loss = 0.0
    
    ###################
    # train the model #
    ###################
    for data, target in train_loader:
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        #bring data and target to gpu
        data, target = data.to(device), target.to(device)
        
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update running training loss
        train_loss += loss.item()*data.size(0)
        
    # print training statistics 
    # calculate average loss over an epoch
    train_loss = train_loss/len(train_loader.dataset)
    train_losses.append(train_loss)

    print('Epoch: {}/{} \tTraining Loss: {:.6f}'.format(
        epoch+1,
        n_epochs, 
        train_loss
        ))
    

endTime = timeit.default_timer()
runningTotal = (endTime - startTime)
print(f"Time taken: {runningTotal}")
# Out:
# Epoch: 1/200 	Training Loss: 0.132432
# Epoch: 2/200 	Training Loss: 0.037211
# Epoch: 3/200 	Training Loss: 0.031246
# Epoch: 4/200 	Training Loss: 0.038464
# Epoch: 5/200 	Training Loss: 0.026947
# Epoch: 6/200 	Training Loss: 0.032613
# Epoch: 7/200 	Training Loss: 0.028908
# Epoch: 8/200 	Training Loss: 0.022778
# Epoch: 9/200 	Training Loss: 0.024474
# Epoch: 10/200 	Training Loss: 0.021329
# Epoch: 11/200 	Training Loss: 0.018705
# Epoch: 12/200 	Training Loss: 0.020534
# Epoch: 13/200 	Training Loss: 0.016884
# Epoch: 14/200 	Training Loss: 0.015003
# Epoch: 15/200 	Training Loss: 0.016735
# Epoch: 16/200 	Training Loss: 0.020937
# Epoch: 17/200 	Training Loss: 0.027993
# Epoch: 18/200 	Training Loss: 0.021213
# Epoch: 19/200 	Training Loss: 0.020488
# Epoch: 20/200 	Training Loss: 0.020328
# Epoch: 21/200 	Training Loss: 0.023687
# Epoch: 22/200 	Training Loss: 0.027210
# Epoch: 23/200 	Training Loss: 0.015408
# Epoch: 24/200 	Training Loss: 0.013858
# Epoch: 25/200 	Training Loss: 0.015825
# Epoch: 26/200 	Training Loss: 0.013156
# Epoch: 27/200 	Training Loss: 0.016716
# Epoch: 28/200 	Training Loss: 0.022066
# Epoch: 29/200 	Training Loss: 0.016315
# Epoch: 30/200 	Training Loss: 0.014161
# Epoch: 31/200 	Training Loss: 0.018622
# Epoch: 32/200 	Training Loss: 0.012080
# Epoch: 33/200 	Training Loss: 0.015568
# Epoch: 34/200 	Training Loss: 0.022509
# Epoch: 35/200 	Training Loss: 0.015062
# Epoch: 36/200 	Training Loss: 0.019198
# Epoch: 37/200 	Training Loss: 0.022667
# Epoch: 38/200 	Training Loss: 0.019601
# Epoch: 39/200 	Training Loss: 0.020340
# Epoch: 40/200 	Training Loss: 0.014768
# Epoch: 41/200 	Training Loss: 0.011113
# Epoch: 42/200 	Training Loss: 0.011529
# Epoch: 43/200 	Training Loss: 0.010927
# Epoch: 169/200 	Training Loss: 0.010795
# Epoch: 170/200 	Training Loss: 0.012089
# Epoch: 171/200 	Training Loss: 0.013258
# Epoch: 172/200 	Training Loss: 0.011543
# Epoch: 173/200 	Training Loss: 0.009938
# Epoch: 174/200 	Training Loss: 0.009770
# Epoch: 175/200 	Training Loss: 0.011430
# Epoch: 176/200 	Training Loss: 0.010162
# Epoch: 177/200 	Training Loss: 0.009634
# Epoch: 178/200 	Training Loss: 0.009268
# Epoch: 179/200 	Training Loss: 0.012686
# Epoch: 180/200 	Training Loss: 0.013909
# Epoch: 181/200 	Training Loss: 0.010400
# Epoch: 182/200 	Training Loss: 0.009246
# Epoch: 183/200 	Training Loss: 0.008589
# Epoch: 184/200 	Training Loss: 0.010817
# Epoch: 185/200 	Training Loss: 0.008610
# Epoch: 186/200 	Training Loss: 0.016425
# Epoch: 187/200 	Training Loss: 0.011438
# Epoch: 188/200 	Training Loss: 0.010872
# Epoch: 189/200 	Training Loss: 0.010007
# Epoch: 190/200 	Training Loss: 0.010751
# Epoch: 191/200 	Training Loss: 0.009328
# Epoch: 192/200 	Training Loss: 0.010008
# Epoch: 193/200 	Training Loss: 0.010238
# Epoch: 194/200 	Training Loss: 0.008283
# Epoch: 195/200 	Training Loss: 0.008304
# Epoch: 196/200 	Training Loss: 0.010590
# Epoch: 197/200 	Training Loss: 0.011245
# Epoch: 198/200 	Training Loss: 0.012053
# Epoch: 199/200 	Training Loss: 0.009988
# Epoch: 200/200 	Training Loss: 0.009731
# Time taken: 72.6419247

# %%
plt.plot(train_losses)

# Save the model  -- I already saved this and submitted
torch.save(model.state_dict(), 'PyTorch_Model/PosiImpul_1_NN_mish_Drop_L2_Huber_200Epochs.pt')

# %%
model.load_state_dict(torch.load('PyTorch_Model/PosiImpul_1_NN_mish_Drop_L2_Huber_200Epochs.pt', map_location=torch.device('cpu')))

model.eval()           # prep model for *evaluation*
model.to(device)
with torch.no_grad():  # turn off gradient to save memory
    y_predNN_torch = model(X_test_torch.to(device))

y_predNN_normal = y_predNN_torch.cpu().numpy()     # convert to numpy array
y_test_normal = y_test_torch.cpu().numpy()



print(y_predNN_normal)
# Out:
# [[-0.19037683]
#  [-0.24766272]
#  [-0.32280064]
#  ...
#  [-0.5303293 ]
#  [-0.56584346]
#  [-0.598743  ]]

# %%
mape = mean_absolute_percentage_error(y_test_normal, y_predNN_normal)
r2 = r2_score(y_test_normal, y_predNN_normal)
rmse = np.sqrt(mean_squared_error(y_test_normal, y_predNN_normal))
print(f"Scores in normal distribution: r2 = {r2}, mape = {mape}, rmse = {rmse}")
# Out:
# Scores in normal distribution: r2 = 0.960109538964746, mape = 0.7703363299369812, rmse = 0.19959811866283417

# %%
y_predNN = quantile1.inverse_transform(y_predNN_normal)
mape = mean_absolute_percentage_error(y_test, y_predNN)
r2 = r2_score(y_test, y_predNN)
rmse = np.sqrt(mean_squared_error(y_test, y_predNN))


print(f"Scores in actual distribution for arrival time: r2 = {r2}, mape = {mape}, rmse = {rmse}")
# Out:
# Scores in actual distribution for arrival time: r2 = 0.8572185280925829, mape = 0.14995613694201115, rmse = 38.15299533700139
