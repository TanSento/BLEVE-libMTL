# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import timeit
#import shap
from sklearn.metrics import r2_score, mean_absolute_percentage_error, mean_squared_error
from sklearn.model_selection import cross_val_score, GridSearchCV, KFold
from sklearn.model_selection import train_test_split

# %% [markdown]
# ___

# %% [markdown]
# # Read-in and One-Hot Encoding

# %%
df = pd.read_excel("data_new/train.xlsx", sheet_name="positive_peak_time")

dt = pd.read_excel("data_new/test.xlsx", sheet_name="positive_peak_time")

# %%
# Label encoding 'Status' feature into 0 and 1 
# 0 for Subcooled and 1 for Superheated

from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()

df['Status'] = LE.fit_transform(df['Status'])
dt['Status'] = LE.fit_transform(dt['Status'])

df
# Out:
#          ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0      B291                         13.6          0.665119             1.0
# 1      B291                         13.6          0.665119             1.0
# 2      B291                         13.6          0.665119             1.0
# 3      B291                         13.6          0.665119             1.0
# 4      B291                         13.6          0.665119             1.0
# ...     ...                          ...               ...             ...
# 21595  B103                         30.7          0.181290             0.6
# 21596  B103                         30.7          0.181290             0.6
# 21597  B103                         30.7          0.181290             0.6
# 21598  B103                         30.7          0.181290             0.6
# 21599  B103                         30.7          0.181290             0.6
#
#        Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 0                  4.0              0.8                  1.8
# 1                  4.0              0.8                  1.8
# 2                  4.0              0.8                  1.8
# 3                  4.0              0.8                  1.8
# 4                  4.0              0.8                  1.8
# ...                ...              ...                  ...
# 21595              2.0              2.8                  1.2
# 21596              2.0              2.8                  1.2
# 21597              2.0              2.8                  1.2
# 21598              2.0              2.8                  1.2
# 21599              2.0              2.8                  1.2
#
#        Tank Height with Gas (m)   Vapour Temerature (K)  \
# 0                           0.4                   435.0
# 1                           0.4                   435.0
# 2                           0.4                   435.0
# 3                           0.4                   435.0
# 4                           0.4                   435.0
# ...                         ...                     ...
# 21595                       2.2                   334.7
# 21596                       2.2                   334.7
# 21597                       2.2                   334.7
# 21598                       2.2                   334.7
# 21599                       2.2                   334.7
#
#         Liquid Temerature (K)  Status  Stand-off Distance    Target
# 0                       372.5       1                   5  0.012166
# 1                       372.5       1                   6  0.014556
# 2                       372.5       1                   7  0.017034
# 3                       372.5       1                   8  0.019576
# 4                       372.5       1                   9  0.022172
# ...                       ...     ...                 ...       ...
# 21595                   404.9       0                  36  0.093782
# 21596                   404.9       0                  37  0.096635
# 21597                   404.9       0                  38  0.099487
# 21598                   404.9       0                  39  0.102341
# 21599                   404.9       0                  40  0.105201
#
# [21600 rows x 13 columns]

# %%
dt.iloc[30:50,:]
# Out:
#       ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 30  P197                     11.55904          0.602823             3.0
# 31  P197                     11.55904          0.602823             3.0
# 32  P197                     11.55904          0.602823             3.0
# 33  P197                     11.55904          0.602823             3.0
# 34  P197                     11.55904          0.602823             3.0
# 35  P197                     11.55904          0.602823             3.0
# 36  P168                     12.72223          0.648320             1.8
# 37  P168                     12.72223          0.648320             1.8
# 38  P168                     12.72223          0.648320             1.8
# 39  P168                     12.72223          0.648320             1.8
# 40  P168                     12.72223          0.648320             1.8
# 41  P168                     12.72223          0.648320             1.8
# 42  P168                     12.72223          0.648320             1.8
# 43  P168                     12.72223          0.648320             1.8
# 44  P168                     12.72223          0.648320             1.8
# 45  P168                     12.72223          0.648320             1.8
# 46  P168                     12.72223          0.648320             1.8
# 47  P168                     12.72223          0.648320             1.8
# 48  P168                     12.72223          0.648320             1.8
# 49  P168                     12.72223          0.648320             1.8
#
#     Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 30              0.8              2.2                  0.2
# 31              0.8              2.2                  0.2
# 32              0.8              2.2                  0.2
# 33              0.8              2.2                  0.2
# 34              0.8              2.2                  0.2
# 35              0.8              2.2                  0.2
# 36              8.2              0.6                  1.8
# 37              8.2              0.6                  1.8
# 38              8.2              0.6                  1.8
# 39              8.2              0.6                  1.8
# 40              8.2              0.6                  1.8
# 41              8.2              0.6                  1.8
# 42              8.2              0.6                  1.8
# 43              8.2              0.6                  1.8
# 44              8.2              0.6                  1.8
# 45              8.2              0.6                  1.8
# 46              8.2              0.6                  1.8
# 47              8.2              0.6                  1.8
# 48              8.2              0.6                  1.8
# 49              8.2              0.6                  1.8
#
#     Tank Height with Gas (m)   Vapour Temerature (K)   Liquid Temerature (K)  \
# 30                       1.0                   296.7                   328.5
# 31                       1.0                   296.7                   328.5
# 32                       1.0                   296.7                   328.5
# 33                       1.0                   296.7                   328.5
# 34                       1.0                   296.7                   328.5
# 35                       1.0                   296.7                   328.5
# 36                       0.2                   389.7                   296.4
# 37                       0.2                   389.7                   296.4
# 38                       0.2                   389.7                   296.4
# 39                       0.2                   389.7                   296.4
# 40                       0.2                   389.7                   296.4
# 41                       0.2                   389.7                   296.4
# 42                       0.2                   389.7                   296.4
# 43                       0.2                   389.7                   296.4
# 44                       0.2                   389.7                   296.4
# 45                       0.2                   389.7                   296.4
# 46                       0.2                   389.7                   296.4
# 47                       0.2                   389.7                   296.4
# 48                       0.2                   389.7                   296.4
# 49                       0.2                   389.7                   296.4
#
#     Status  Stand-off Distance    Target
# 30       1                  35  0.097314
# 31       1                  36  0.100188
# 32       1                  37  0.103059
# 33       1                  38  0.105934
# 34       1                  39  0.108809
# 35       1                  40  0.111685
# 36       0                   5  0.013986
# 37       0                   6  0.016534
# 38       0                   7  0.019128
# 39       0                   8  0.021753
# 40       0                   9  0.024412
# 41       0                  10  0.027099
# 42       0                  11  0.029815
# 43       0                  12  0.032545
# 44       0                  13  0.035298
# 45       0                  14  0.038060
# 46       0                  15  0.040841
# 47       0                  16  0.043633
# 48       0                  17  0.046439
# 49       0                  18  0.049246

# %%
X_traindf = df.drop(['ID','Target'], axis=1)
X_testdf = dt.drop(['ID','Target'], axis=1)

X_traindf
# Out:
#        Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0                             13.6          0.665119             1.0
# 1                             13.6          0.665119             1.0
# 2                             13.6          0.665119             1.0
# 3                             13.6          0.665119             1.0
# 4                             13.6          0.665119             1.0
# ...                            ...               ...             ...
# 21595                         30.7          0.181290             0.6
# 21596                         30.7          0.181290             0.6
# 21597                         30.7          0.181290             0.6
# 21598                         30.7          0.181290             0.6
# 21599                         30.7          0.181290             0.6
#
#        Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 0                  4.0              0.8                  1.8
# 1                  4.0              0.8                  1.8
# 2                  4.0              0.8                  1.8
# 3                  4.0              0.8                  1.8
# 4                  4.0              0.8                  1.8
# ...                ...              ...                  ...
# 21595              2.0              2.8                  1.2
# 21596              2.0              2.8                  1.2
# 21597              2.0              2.8                  1.2
# 21598              2.0              2.8                  1.2
# 21599              2.0              2.8                  1.2
#
#        Tank Height with Gas (m)   Vapour Temerature (K)  \
# 0                           0.4                   435.0
# 1                           0.4                   435.0
# 2                           0.4                   435.0
# 3                           0.4                   435.0
# 4                           0.4                   435.0
# ...                         ...                     ...
# 21595                       2.2                   334.7
# 21596                       2.2                   334.7
# 21597                       2.2                   334.7
# 21598                       2.2                   334.7
# 21599                       2.2                   334.7
#
#         Liquid Temerature (K)  Status  Stand-off Distance
# 0                       372.5       1                   5
# 1                       372.5       1                   6
# 2                       372.5       1                   7
# 3                       372.5       1                   8
# 4                       372.5       1                   9
# ...                       ...     ...                 ...
# 21595                   404.9       0                  36
# 21596                   404.9       0                  37
# 21597                   404.9       0                  38
# 21598                   404.9       0                  39
# 21599                   404.9       0                  40
#
# [21600 rows x 11 columns]

# %%
y_train = df['Target']
y_train
# Out:
# 0        0.012166
# 1        0.014556
# 2        0.017034
# 3        0.019576
# 4        0.022172
#            ...
# 21595    0.093782
# 21596    0.096635
# 21597    0.099487
# 21598    0.102341
# 21599    0.105201
# Name: Target, Length: 21600, dtype: float64

# %%
y_test = dt['Target']

y_test
# Out:
# 0       0.012114
# 1       0.014798
# 2       0.017533
# 3       0.020293
# 4       0.023077
#           ...
# 7195    0.091819
# 7196    0.094618
# 7197    0.097421
# 7198    0.100227
# 7199    0.103035
# Name: Target, Length: 7200, dtype: float64

# %% [markdown]
# ___

# %% [markdown]
# # Standardization and Power Transform

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import QuantileTransformer

# %%
# Processing both X_train and X_test using standardization
scaler = StandardScaler()
X_train = scaler.fit_transform(X_traindf)
X_test = scaler.transform(X_testdf)

# %%
quantile1 = QuantileTransformer(output_distribution='normal')



y_train_normal = quantile1.fit_transform(y_train.values.reshape(-1,1))
y_test_normal = quantile1.transform(y_test.values.reshape(-1,1))

# %%
# Visualize the effect of power transformation
f = plt.figure(figsize=(15, 6))

ax = f.add_subplot(121)
sns.distplot(y_train, bins=50, color='r', ax=ax)
ax.set_title('Distribution before processing')

ax=f.add_subplot(122)
sns.distplot(y_train_normal, bins=50, color='b', ax=ax)
ax.set_title('Distribution after quantile processing')
print()
# Out:
# c:\Users\buita\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\buita\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ___

# %% [markdown]
# # ANN

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt

torch.backends.cudnn.version() , torch.backends.cudnn.enabled
# Out:
# (8500, True)

# %%
# convert data to torch.FloatTensor
X_train_torch = torch.from_numpy(X_train.astype(np.float32))
X_test_torch = torch.from_numpy(X_test.astype(np.float32))



y_train_torch = torch.from_numpy(y_train_normal.astype(np.float32))
y_test_torch = torch.from_numpy(y_test_normal.astype(np.float32))

print(X_train_torch)
# Out:
# tensor([[-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.6846],
#         [-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.5883],
#         [-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.4921],
#         ...,
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.4921],
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.5883],
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.6846]])

# %%
train_data = []
for i in range(len(X_train_torch)):
   train_data.append([X_train_torch[i],
                      y_train_torch[i]
                     ])

test_data = []
for i in range(len(X_test_torch)):
   test_data.append([X_test_torch[i], 
                     y_test_torch[i]
                     ])
   
# prepare data loaders
train_loader = torch.utils.data.DataLoader(train_data, batch_size=512,               # batch_size could be smaller
    num_workers=0)                                                                   # Increasing num_workers slow down the training because it does not use GPU at all
test_loader = torch.utils.data.DataLoader(test_data, batch_size=512,
    num_workers=0)

# %%
## Define the NN architecture
## NN with 3 hidden layer, s=[26, 256, 256, 256, 128, 8]

class BleveNet(nn.Module):
    def __init__(self):
        super(BleveNet, self).__init__()
        # The first hidden layer has 256 neurons
        self.fc1 = nn.Linear(X_train_torch.shape[1], 256)
        # The second hidden layer has 256 neurons
        self.fc2 = nn.Linear(256, 256)
        # The third hidden layer has 256 neurons
        self.fc3 = nn.Linear(256, 256)
        # The fourth layer has 128 output neurons
        self.fc4 = nn.Linear(256, 128)
        # The final layer has 8 output neurons
        self.fc5 = nn.Linear(128, 1)


        # Define proportion or neurons to dropout
        self.dropout = nn.Dropout(0.1)

        # Mish activation
        self.mish = nn.Mish()


    def forward(self, x):
        # add first fully connected layer
        x = self.fc1(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add second fully connected layer
        x = self.fc2(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add third fully connected layer
        x = self.fc3(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add fourth fully connected layers
        x = self.fc4(x)
        x = self.mish(x)
        x = self.dropout(x)

        # add final output layers:
        output = self.fc5(x)
       
        return output

# initialize the NN
model = BleveNet()
print(model)
# Out:
# BleveNet(
#   (fc1): Linear(in_features=11, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=256, bias=True)
#   (fc4): Linear(in_features=256, out_features=128, bias=True)
#   (fc5): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (mish): Mish()
# )

# %%
criterion = nn.HuberLoss()        # This is the best loss function for my model
# criterion = nn.MSELoss()


optimizer = torch.optim.Adam(model.parameters(), lr=0.005, weight_decay=1e-5)     # This is the best optimizer for my model 

# Check for GPU
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
startTime = timeit.default_timer() 

n_epochs = 200 

model.to(device)    # bring the model to gpu
model.train()       # prep model for training

train_losses = []
for epoch in range(n_epochs):
    # monitor training loss
    train_loss = 0.0
    
    ###################
    # train the model #
    ###################
    for data, target in train_loader:
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        #bring data and target to gpu
        data, target = data.to(device), target.to(device)
        
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update running training loss
        train_loss += loss.item()*data.size(0)
        
    # print training statistics 
    # calculate average loss over an epoch
    train_loss = train_loss/len(train_loader.dataset)
    train_losses.append(train_loss)

    print('Epoch: {}/{} \tTraining Loss: {:.6f}'.format(
        epoch+1,
        n_epochs, 
        train_loss
        ))
    

endTime = timeit.default_timer()
runningTotal = (endTime - startTime)
print(f"Time taken: {runningTotal}")
# Out:
# Epoch: 1/200 	Training Loss: 0.091878
# Epoch: 2/200 	Training Loss: 0.023750
# Epoch: 3/200 	Training Loss: 0.016780
# Epoch: 4/200 	Training Loss: 0.014069
# Epoch: 5/200 	Training Loss: 0.013490
# Epoch: 6/200 	Training Loss: 0.018018
# Epoch: 7/200 	Training Loss: 0.012828
# Epoch: 8/200 	Training Loss: 0.011467
# Epoch: 9/200 	Training Loss: 0.011502
# Epoch: 10/200 	Training Loss: 0.010081
# Epoch: 11/200 	Training Loss: 0.010142
# Epoch: 12/200 	Training Loss: 0.010773
# Epoch: 13/200 	Training Loss: 0.010552
# Epoch: 14/200 	Training Loss: 0.008536
# Epoch: 15/200 	Training Loss: 0.009878
# Epoch: 16/200 	Training Loss: 0.014779
# Epoch: 17/200 	Training Loss: 0.009752
# Epoch: 18/200 	Training Loss: 0.009199
# Epoch: 19/200 	Training Loss: 0.008571
# Epoch: 20/200 	Training Loss: 0.010202
# Epoch: 21/200 	Training Loss: 0.008602
# Epoch: 22/200 	Training Loss: 0.008008
# Epoch: 23/200 	Training Loss: 0.007886
# Epoch: 24/200 	Training Loss: 0.007013
# Epoch: 25/200 	Training Loss: 0.006607
# Epoch: 26/200 	Training Loss: 0.007827
# Epoch: 27/200 	Training Loss: 0.009199
# Epoch: 28/200 	Training Loss: 0.007685
# Epoch: 29/200 	Training Loss: 0.008471
# Epoch: 30/200 	Training Loss: 0.008918
# Epoch: 31/200 	Training Loss: 0.007859
# Epoch: 32/200 	Training Loss: 0.007419
# Epoch: 33/200 	Training Loss: 0.008499
# Epoch: 34/200 	Training Loss: 0.007395
# Epoch: 35/200 	Training Loss: 0.006273
# Epoch: 36/200 	Training Loss: 0.006326
# Epoch: 37/200 	Training Loss: 0.006154
# Epoch: 38/200 	Training Loss: 0.005719
# Epoch: 39/200 	Training Loss: 0.006138
# Epoch: 40/200 	Training Loss: 0.006946
# Epoch: 41/200 	Training Loss: 0.006773
# Epoch: 42/200 	Training Loss: 0.005678
# Epoch: 43/200 	Training Loss: 0.005716
# Epoch: 44/200 	Training Loss: 0.006759
# Epoch: 45/200 	Training Loss: 0.007388
# Epoch: 46/200 	Training Loss: 0.008007
# Epoch: 47/200 	Training Loss: 0.005606
# Epoch: 48/200 	Training Loss: 0.008426
# Epoch: 49/200 	Training Loss: 0.006731
# Epoch: 50/200 	Training Loss: 0.006164
# Epoch: 51/200 	Training Loss: 0.005751
# Epoch: 52/200 	Training Loss: 0.005851
# Epoch: 53/200 	Training Loss: 0.005538
# Epoch: 54/200 	Training Loss: 0.006071
# Epoch: 55/200 	Training Loss: 0.005409
# Epoch: 56/200 	Training Loss: 0.006570
# Epoch: 57/200 	Training Loss: 0.008847
# Epoch: 58/200 	Training Loss: 0.006008
# Epoch: 59/200 	Training Loss: 0.007387
# Epoch: 60/200 	Training Loss: 0.006593
# Epoch: 61/200 	Training Loss: 0.006019
# Epoch: 62/200 	Training Loss: 0.005891
# Epoch: 63/200 	Training Loss: 0.006911
# Epoch: 64/200 	Training Loss: 0.006265
# Epoch: 65/200 	Training Loss: 0.006478
# Epoch: 66/200 	Training Loss: 0.006136
# Epoch: 67/200 	Training Loss: 0.005753
# Epoch: 68/200 	Training Loss: 0.005024
# Epoch: 69/200 	Training Loss: 0.004633
# Epoch: 70/200 	Training Loss: 0.005007
# Epoch: 71/200 	Training Loss: 0.007137
# Epoch: 72/200 	Training Loss: 0.007079
# Epoch: 73/200 	Training Loss: 0.005949
# Epoch: 74/200 	Training Loss: 0.006769
# Epoch: 75/200 	Training Loss: 0.007195
# Epoch: 76/200 	Training Loss: 0.006329
# Epoch: 77/200 	Training Loss: 0.008974
# Epoch: 78/200 	Training Loss: 0.007701
# Epoch: 79/200 	Training Loss: 0.008891
# Epoch: 80/200 	Training Loss: 0.008936
# Epoch: 81/200 	Training Loss: 0.009602
# Epoch: 82/200 	Training Loss: 0.008913
# Epoch: 83/200 	Training Loss: 0.006222
# Epoch: 84/200 	Training Loss: 0.007441
# Epoch: 85/200 	Training Loss: 0.007287
# Epoch: 86/200 	Training Loss: 0.006864
# Epoch: 87/200 	Training Loss: 0.006972
# Epoch: 88/200 	Training Loss: 0.005667
# Epoch: 89/200 	Training Loss: 0.005406
# Epoch: 90/200 	Training Loss: 0.005495
# Epoch: 91/200 	Training Loss: 0.005805
# Epoch: 92/200 	Training Loss: 0.006132
# Epoch: 93/200 	Training Loss: 0.005432
# Epoch: 94/200 	Training Loss: 0.006100
# Epoch: 95/200 	Training Loss: 0.005877
# Epoch: 96/200 	Training Loss: 0.006554
# Epoch: 97/200 	Training Loss: 0.006373
# Epoch: 98/200 	Training Loss: 0.005406
# Epoch: 99/200 	Training Loss: 0.006280
# Epoch: 100/200 	Training Loss: 0.006620
# Epoch: 101/200 	Training Loss: 0.005687
# Epoch: 102/200 	Training Loss: 0.005361
# Epoch: 103/200 	Training Loss: 0.008055
# Epoch: 104/200 	Training Loss: 0.006605
# Epoch: 105/200 	Training Loss: 0.005523
# Epoch: 106/200 	Training Loss: 0.005510
# Epoch: 107/200 	Training Loss: 0.004927
# Epoch: 108/200 	Training Loss: 0.006294
# Epoch: 109/200 	Training Loss: 0.006769
# Epoch: 110/200 	Training Loss: 0.005910
# Epoch: 111/200 	Training Loss: 0.007173
# Epoch: 112/200 	Training Loss: 0.007648
# Epoch: 113/200 	Training Loss: 0.006257
# Epoch: 114/200 	Training Loss: 0.005747
# Epoch: 115/200 	Training Loss: 0.005275
# Epoch: 116/200 	Training Loss: 0.005205
# Epoch: 117/200 	Training Loss: 0.004845
# Epoch: 118/200 	Training Loss: 0.006443
# Epoch: 119/200 	Training Loss: 0.006603
# Epoch: 120/200 	Training Loss: 0.005390
# Epoch: 121/200 	Training Loss: 0.005500
# Epoch: 122/200 	Training Loss: 0.006949
# Epoch: 123/200 	Training Loss: 0.005806
# Epoch: 124/200 	Training Loss: 0.006863
# Epoch: 125/200 	Training Loss: 0.005264
# Epoch: 126/200 	Training Loss: 0.007342
# Epoch: 127/200 	Training Loss: 0.004945
# Epoch: 128/200 	Training Loss: 0.005918
# Epoch: 129/200 	Training Loss: 0.005591
# Epoch: 130/200 	Training Loss: 0.006970
# Epoch: 131/200 	Training Loss: 0.005947
# Epoch: 132/200 	Training Loss: 0.006102
# Epoch: 133/200 	Training Loss: 0.007539
# Epoch: 134/200 	Training Loss: 0.007345
# Epoch: 135/200 	Training Loss: 0.006672
# Epoch: 136/200 	Training Loss: 0.006329
# Epoch: 137/200 	Training Loss: 0.006013
# Epoch: 138/200 	Training Loss: 0.005205
# Epoch: 139/200 	Training Loss: 0.006134
# Epoch: 140/200 	Training Loss: 0.007613
# Epoch: 141/200 	Training Loss: 0.007181
# Epoch: 142/200 	Training Loss: 0.005993
# Epoch: 143/200 	Training Loss: 0.005555
# Epoch: 144/200 	Training Loss: 0.005227
# Epoch: 145/200 	Training Loss: 0.007808
# Epoch: 146/200 	Training Loss: 0.005955
# Epoch: 147/200 	Training Loss: 0.006576
# Epoch: 148/200 	Training Loss: 0.005349
# Epoch: 149/200 	Training Loss: 0.004805
# Epoch: 150/200 	Training Loss: 0.006000
# Epoch: 151/200 	Training Loss: 0.005426
# Epoch: 152/200 	Training Loss: 0.006402
# Epoch: 153/200 	Training Loss: 0.005897
# Epoch: 154/200 	Training Loss: 0.005978
# Epoch: 155/200 	Training Loss: 0.005187
# Epoch: 156/200 	Training Loss: 0.004440
# Epoch: 157/200 	Training Loss: 0.006296
# Epoch: 158/200 	Training Loss: 0.005765
# Epoch: 159/200 	Training Loss: 0.004534
# Epoch: 160/200 	Training Loss: 0.005353
# Epoch: 161/200 	Training Loss: 0.005583
# Epoch: 162/200 	Training Loss: 0.004838
# Epoch: 163/200 	Training Loss: 0.004695
# Epoch: 164/200 	Training Loss: 0.006634
# Epoch: 165/200 	Training Loss: 0.004721
# Epoch: 166/200 	Training Loss: 0.004360
# Epoch: 167/200 	Training Loss: 0.004454
# Epoch: 168/200 	Training Loss: 0.005338
# Epoch: 169/200 	Training Loss: 0.006087
# Epoch: 170/200 	Training Loss: 0.007083
# Epoch: 171/200 	Training Loss: 0.006667
# Epoch: 172/200 	Training Loss: 0.005770
# Epoch: 173/200 	Training Loss: 0.005844
# Epoch: 174/200 	Training Loss: 0.005078
# Epoch: 175/200 	Training Loss: 0.004730
# Epoch: 176/200 	Training Loss: 0.004447
# Epoch: 177/200 	Training Loss: 0.004853
# Epoch: 178/200 	Training Loss: 0.004679
# Epoch: 179/200 	Training Loss: 0.004431
# Epoch: 180/200 	Training Loss: 0.006733
# Epoch: 181/200 	Training Loss: 0.007165
# Epoch: 182/200 	Training Loss: 0.007155
# Epoch: 183/200 	Training Loss: 0.005712
# Epoch: 184/200 	Training Loss: 0.005919
# Epoch: 185/200 	Training Loss: 0.005396
# Epoch: 186/200 	Training Loss: 0.004812
# Epoch: 187/200 	Training Loss: 0.005438
# Epoch: 188/200 	Training Loss: 0.005461
# Epoch: 189/200 	Training Loss: 0.006208
# Epoch: 190/200 	Training Loss: 0.005068
# Epoch: 191/200 	Training Loss: 0.004748
# Epoch: 192/200 	Training Loss: 0.004477
# Epoch: 193/200 	Training Loss: 0.005186
# Epoch: 194/200 	Training Loss: 0.004447
# Epoch: 195/200 	Training Loss: 0.003918
# Epoch: 196/200 	Training Loss: 0.004072
# Epoch: 197/200 	Training Loss: 0.004590
# Epoch: 198/200 	Training Loss: 0.004232
# Epoch: 199/200 	Training Loss: 0.005548
# Epoch: 200/200 	Training Loss: 0.004087
# Time taken: 69.8029129

# %%
plt.plot(train_losses)

# Save the model  -- I already saved this and submitted
torch.save(model.state_dict(), 'PyTorch_Model/PosiPeakTime2_NN_mish_Drop_L2_Huber_200Epochs.pt')

# %%
model.load_state_dict(torch.load('PyTorch_Model/PosiPeakTime2_NN_mish_Drop_L2_Huber_200Epochs.pt', map_location=torch.device('cpu')))

model.eval()           # prep model for *evaluation*
model.to(device)
with torch.no_grad():  # turn off gradient to save memory
    y_predNN_torch = model(X_test_torch.to(device))

y_predNN_normal = y_predNN_torch.cpu().numpy()     # convert to numpy array
y_test_normal = y_test_torch.cpu().numpy()



print(y_predNN_normal)
# Out:
# [[-2.019474 ]
#  [-1.6720594]
#  [-1.4285383]
#  ...
#  [ 1.2284522]
#  [ 1.3731139]
#  [ 1.5364115]]

# %%
mape = mean_absolute_percentage_error(y_test_normal, y_predNN_normal)
r2 = r2_score(y_test_normal, y_predNN_normal)
rmse = np.sqrt(mean_squared_error(y_test_normal, y_predNN_normal))
print(f"Scores in normal distribution: r2 = {r2}, mape = {mape}, rmse = {rmse}")
# Out:
# Scores in normal distribution: r2 = 0.9840832625314844, mape = 0.6077567338943481, rmse = 0.12548664212226868

# %%
y_predNN = quantile1.inverse_transform(y_predNN_normal)
mape = mean_absolute_percentage_error(y_test, y_predNN)
r2 = r2_score(y_test, y_predNN)
rmse = np.sqrt(mean_squared_error(y_test, y_predNN))


print(f"Scores in actual distribution for arrival time: r2 = {r2}, mape = {mape}, rmse = {rmse}")
# Out:
# Scores in actual distribution for arrival time: r2 = 0.9959367938185688, mape = 0.04719109697034282, rmse = 0.001830722279680624
