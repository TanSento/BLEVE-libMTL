# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import timeit
#import shap
from sklearn.metrics import r2_score, mean_absolute_percentage_error, mean_squared_error
from sklearn.model_selection import cross_val_score, GridSearchCV, KFold
from sklearn.model_selection import train_test_split

# %% [markdown]
# ___

# %% [markdown]
# # Read-in and One-Hot Encoding

# %%
df = pd.read_excel("data_new/train.xlsx", sheet_name="arrival_time")

dt = pd.read_excel("data_new/test.xlsx", sheet_name="arrival_time")

# %%
# Label encoding 'Status' feature into 0 and 1 
# 0 for Subcooled and 1 for Superheated

from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()

df['Status'] = LE.fit_transform(df['Status'])
dt['Status'] = LE.fit_transform(dt['Status'])

df
# Out:
#          ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0      B291                         13.6          0.665119             1.0
# 1      B291                         13.6          0.665119             1.0
# 2      B291                         13.6          0.665119             1.0
# 3      B291                         13.6          0.665119             1.0
# 4      B291                         13.6          0.665119             1.0
# ...     ...                          ...               ...             ...
# 21595  B103                         30.7          0.181290             0.6
# 21596  B103                         30.7          0.181290             0.6
# 21597  B103                         30.7          0.181290             0.6
# 21598  B103                         30.7          0.181290             0.6
# 21599  B103                         30.7          0.181290             0.6
#
#        Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 0                  4.0              0.8                  1.8
# 1                  4.0              0.8                  1.8
# 2                  4.0              0.8                  1.8
# 3                  4.0              0.8                  1.8
# 4                  4.0              0.8                  1.8
# ...                ...              ...                  ...
# 21595              2.0              2.8                  1.2
# 21596              2.0              2.8                  1.2
# 21597              2.0              2.8                  1.2
# 21598              2.0              2.8                  1.2
# 21599              2.0              2.8                  1.2
#
#        Tank Height with Gas (m)   Vapour Temerature (K)  \
# 0                           0.4                   435.0
# 1                           0.4                   435.0
# 2                           0.4                   435.0
# 3                           0.4                   435.0
# 4                           0.4                   435.0
# ...                         ...                     ...
# 21595                       2.2                   334.7
# 21596                       2.2                   334.7
# 21597                       2.2                   334.7
# 21598                       2.2                   334.7
# 21599                       2.2                   334.7
#
#         Liquid Temerature (K)  Status  Stand-off Distance    Target
# 0                       372.5       1                   5  0.010253
# 1                       372.5       1                   6  0.012442
# 2                       372.5       1                   7  0.014733
# 3                       372.5       1                   8  0.017102
# 4                       372.5       1                   9  0.019534
# ...                       ...     ...                 ...       ...
# 21595                   404.9       0                  36  0.088987
# 21596                   404.9       0                  37  0.091772
# 21597                   404.9       0                  38  0.094563
# 21598                   404.9       0                  39  0.097352
# 21599                   404.9       0                  40  0.100150
#
# [21600 rows x 13 columns]

# %%
dt.iloc[30:50,:]
# Out:
#       ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 30  P197                     11.55904          0.602823             3.0
# 31  P197                     11.55904          0.602823             3.0
# 32  P197                     11.55904          0.602823             3.0
# 33  P197                     11.55904          0.602823             3.0
# 34  P197                     11.55904          0.602823             3.0
# 35  P197                     11.55904          0.602823             3.0
# 36  P168                     12.72223          0.648320             1.8
# 37  P168                     12.72223          0.648320             1.8
# 38  P168                     12.72223          0.648320             1.8
# 39  P168                     12.72223          0.648320             1.8
# 40  P168                     12.72223          0.648320             1.8
# 41  P168                     12.72223          0.648320             1.8
# 42  P168                     12.72223          0.648320             1.8
# 43  P168                     12.72223          0.648320             1.8
# 44  P168                     12.72223          0.648320             1.8
# 45  P168                     12.72223          0.648320             1.8
# 46  P168                     12.72223          0.648320             1.8
# 47  P168                     12.72223          0.648320             1.8
# 48  P168                     12.72223          0.648320             1.8
# 49  P168                     12.72223          0.648320             1.8
#
#     Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 30              0.8              2.2                  0.2
# 31              0.8              2.2                  0.2
# 32              0.8              2.2                  0.2
# 33              0.8              2.2                  0.2
# 34              0.8              2.2                  0.2
# 35              0.8              2.2                  0.2
# 36              8.2              0.6                  1.8
# 37              8.2              0.6                  1.8
# 38              8.2              0.6                  1.8
# 39              8.2              0.6                  1.8
# 40              8.2              0.6                  1.8
# 41              8.2              0.6                  1.8
# 42              8.2              0.6                  1.8
# 43              8.2              0.6                  1.8
# 44              8.2              0.6                  1.8
# 45              8.2              0.6                  1.8
# 46              8.2              0.6                  1.8
# 47              8.2              0.6                  1.8
# 48              8.2              0.6                  1.8
# 49              8.2              0.6                  1.8
#
#     Tank Height with Gas (m)   Vapour Temerature (K)   Liquid Temerature (K)  \
# 30                       1.0                   296.7                   328.5
# 31                       1.0                   296.7                   328.5
# 32                       1.0                   296.7                   328.5
# 33                       1.0                   296.7                   328.5
# 34                       1.0                   296.7                   328.5
# 35                       1.0                   296.7                   328.5
# 36                       0.2                   389.7                   296.4
# 37                       0.2                   389.7                   296.4
# 38                       0.2                   389.7                   296.4
# 39                       0.2                   389.7                   296.4
# 40                       0.2                   389.7                   296.4
# 41                       0.2                   389.7                   296.4
# 42                       0.2                   389.7                   296.4
# 43                       0.2                   389.7                   296.4
# 44                       0.2                   389.7                   296.4
# 45                       0.2                   389.7                   296.4
# 46                       0.2                   389.7                   296.4
# 47                       0.2                   389.7                   296.4
# 48                       0.2                   389.7                   296.4
# 49                       0.2                   389.7                   296.4
#
#     Status  Stand-off Distance    Target
# 30       1                  35  0.091514
# 31       1                  36  0.094326
# 32       1                  37  0.097138
# 33       1                  38  0.099955
# 34       1                  39  0.102774
# 35       1                  40  0.105593
# 36       0                   5  0.011512
# 37       0                   6  0.013904
# 38       0                   7  0.016363
# 39       0                   8  0.018873
# 40       0                   9  0.021419
# 41       0                  10  0.023992
# 42       0                  11  0.026597
# 43       0                  12  0.029217
# 44       0                  13  0.031857
# 45       0                  14  0.034521
# 46       0                  15  0.037198
# 47       0                  16  0.039885
# 48       0                  17  0.042588
# 49       0                  18  0.045299

# %%
X_traindf = df.drop(['ID','Target'], axis=1)
X_testdf = dt.drop(['ID','Target'], axis=1)

X_traindf
# Out:
#        Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0                             13.6          0.665119             1.0
# 1                             13.6          0.665119             1.0
# 2                             13.6          0.665119             1.0
# 3                             13.6          0.665119             1.0
# 4                             13.6          0.665119             1.0
# ...                            ...               ...             ...
# 21595                         30.7          0.181290             0.6
# 21596                         30.7          0.181290             0.6
# 21597                         30.7          0.181290             0.6
# 21598                         30.7          0.181290             0.6
# 21599                         30.7          0.181290             0.6
#
#        Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 0                  4.0              0.8                  1.8
# 1                  4.0              0.8                  1.8
# 2                  4.0              0.8                  1.8
# 3                  4.0              0.8                  1.8
# 4                  4.0              0.8                  1.8
# ...                ...              ...                  ...
# 21595              2.0              2.8                  1.2
# 21596              2.0              2.8                  1.2
# 21597              2.0              2.8                  1.2
# 21598              2.0              2.8                  1.2
# 21599              2.0              2.8                  1.2
#
#        Tank Height with Gas (m)   Vapour Temerature (K)  \
# 0                           0.4                   435.0
# 1                           0.4                   435.0
# 2                           0.4                   435.0
# 3                           0.4                   435.0
# 4                           0.4                   435.0
# ...                         ...                     ...
# 21595                       2.2                   334.7
# 21596                       2.2                   334.7
# 21597                       2.2                   334.7
# 21598                       2.2                   334.7
# 21599                       2.2                   334.7
#
#         Liquid Temerature (K)  Status  Stand-off Distance
# 0                       372.5       1                   5
# 1                       372.5       1                   6
# 2                       372.5       1                   7
# 3                       372.5       1                   8
# 4                       372.5       1                   9
# ...                       ...     ...                 ...
# 21595                   404.9       0                  36
# 21596                   404.9       0                  37
# 21597                   404.9       0                  38
# 21598                   404.9       0                  39
# 21599                   404.9       0                  40
#
# [21600 rows x 11 columns]

# %%
y_train = df['Target']
y_train
# Out:
# 0        0.010253
# 1        0.012442
# 2        0.014733
# 3        0.017102
# 4        0.019534
#            ...
# 21595    0.088987
# 21596    0.091772
# 21597    0.094563
# 21598    0.097352
# 21599    0.100150
# Name: Target, Length: 21600, dtype: float64

# %%
y_test = dt['Target']

y_test
# Out:
# 0       0.009646
# 1       0.012093
# 2       0.014611
# 3       0.017177
# 4       0.019785
#           ...
# 7195    0.087402
# 7196    0.090136
# 7197    0.092877
# 7198    0.095618
# 7199    0.098365
# Name: Target, Length: 7200, dtype: float64

# %% [markdown]
# ___

# %% [markdown]
# # Standardization and Power Transform

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import QuantileTransformer

# %%
# Processing both X_train and X_test using standardization
scaler = StandardScaler()
X_train = scaler.fit_transform(X_traindf)
X_test = scaler.transform(X_testdf)

# %%
quantile1 = QuantileTransformer(output_distribution='normal')



y_train_normal = quantile1.fit_transform(y_train.values.reshape(-1,1))
y_test_normal = quantile1.transform(y_test.values.reshape(-1,1))

# %%
# Visualize the effect of power transformation
f = plt.figure(figsize=(15, 6))

ax = f.add_subplot(121)
sns.distplot(y_train, bins=50, color='r', ax=ax)
ax.set_title('Distribution before processing')

ax=f.add_subplot(122)
sns.distplot(y_train_normal, bins=50, color='b', ax=ax)
ax.set_title('Distribution after quantile processing')
print()
# Out:
# c:\Users\buita\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\buita\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ___

# %% [markdown]
# # ANN

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt

torch.backends.cudnn.version() , torch.backends.cudnn.enabled
# Out:
# (8500, True)

# %%
# convert data to torch.FloatTensor
X_train_torch = torch.from_numpy(X_train.astype(np.float32))
X_test_torch = torch.from_numpy(X_test.astype(np.float32))



y_train_torch = torch.from_numpy(y_train_normal.astype(np.float32))
y_test_torch = torch.from_numpy(y_test_normal.astype(np.float32))

print(X_train_torch)
# Out:
# tensor([[-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.6846],
#         [-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.5883],
#         [-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.4921],
#         ...,
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.4921],
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.5883],
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.6846]])

# %%
train_data = []
for i in range(len(X_train_torch)):
   train_data.append([X_train_torch[i],
                      y_train_torch[i]
                     ])

test_data = []
for i in range(len(X_test_torch)):
   test_data.append([X_test_torch[i], 
                     y_test_torch[i]
                     ])
   
# prepare data loaders
train_loader = torch.utils.data.DataLoader(train_data, batch_size=512,               # batch_size could be smaller
    num_workers=0)                                                                   # Increasing num_workers slow down the training because it does not use GPU at all
test_loader = torch.utils.data.DataLoader(test_data, batch_size=512,
    num_workers=0)

# %%
## Define the NN architecture
## NN with 3 hidden layer, s=[11, 256, 256, 256, 128, 8]

class BleveNet(nn.Module):
    def __init__(self):
        super(BleveNet, self).__init__()
        # The first hidden layer has 256 neurons
        self.fc1 = nn.Linear(X_train_torch.shape[1], 256)
        # The second hidden layer has 256 neurons
        self.fc2 = nn.Linear(256, 256)
        # The third hidden layer has 256 neurons
        self.fc3 = nn.Linear(256, 256)
        # The fourth layer has 128 output neurons
        self.fc4 = nn.Linear(256, 128)
        # The final layer has 8 output neurons
        self.fc5 = nn.Linear(128, 1)


        # Define proportion or neurons to dropout
        self.dropout = nn.Dropout(0.1)

        # Mish activation
        self.mish = nn.Mish()


    def forward(self, x):
        # add first fully connected layer
        x = self.fc1(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add second fully connected layer
        x = self.fc2(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add third fully connected layer
        x = self.fc3(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add fourth fully connected layers
        x = self.fc4(x)
        x = self.mish(x)
        x = self.dropout(x)

        # add final output layers:
        output = self.fc5(x)
       
        return output

# initialize the NN
model = BleveNet()
print(model)
# Out:
# BleveNet(
#   (fc1): Linear(in_features=11, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=256, bias=True)
#   (fc4): Linear(in_features=256, out_features=128, bias=True)
#   (fc5): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (mish): Mish()
# )

# %%
criterion = nn.HuberLoss()        # This is the best loss function for my model
# criterion = nn.MSELoss()


optimizer = torch.optim.Adam(model.parameters(), lr=0.005, weight_decay=1e-5)     # This is the best optimizer for my model 

# Check for GPU
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
startTime = timeit.default_timer() 

n_epochs = 200 

model.to(device)    # bring the model to gpu
model.train()       # prep model for training

train_losses = []
for epoch in range(n_epochs):
    # monitor training loss
    train_loss = 0.0
    
    ###################
    # train the model #
    ###################
    for data, target in train_loader:
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        #bring data and target to gpu
        data, target = data.to(device), target.to(device)
        
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update running training loss
        train_loss += loss.item()*data.size(0)
        
    # print training statistics 
    # calculate average loss over an epoch
    train_loss = train_loss/len(train_loader.dataset)
    train_losses.append(train_loss)

    print('Epoch: {}/{} \tTraining Loss: {:.6f}'.format(
        epoch+1,
        n_epochs, 
        train_loss
        ))
    

endTime = timeit.default_timer()
runningTotal = (endTime - startTime)
print(f"Time taken: {runningTotal}")
# Out:
# Epoch: 1/200 	Training Loss: 0.067418
# Epoch: 2/200 	Training Loss: 0.020059
# Epoch: 3/200 	Training Loss: 0.016388
# Epoch: 4/200 	Training Loss: 0.013921
# Epoch: 5/200 	Training Loss: 0.013288
# Epoch: 6/200 	Training Loss: 0.019860
# Epoch: 7/200 	Training Loss: 0.015644
# Epoch: 8/200 	Training Loss: 0.012001
# Epoch: 9/200 	Training Loss: 0.009841
# Epoch: 10/200 	Training Loss: 0.007698
# Epoch: 11/200 	Training Loss: 0.009598
# Epoch: 12/200 	Training Loss: 0.011204
# Epoch: 13/200 	Training Loss: 0.008023
# Epoch: 14/200 	Training Loss: 0.008651
# Epoch: 15/200 	Training Loss: 0.007569
# Epoch: 16/200 	Training Loss: 0.007920
# Epoch: 17/200 	Training Loss: 0.009502
# Epoch: 18/200 	Training Loss: 0.008379
# Epoch: 19/200 	Training Loss: 0.007675
# Epoch: 20/200 	Training Loss: 0.008960
# Epoch: 21/200 	Training Loss: 0.007793
# Epoch: 22/200 	Training Loss: 0.007909
# Epoch: 23/200 	Training Loss: 0.008162
# Epoch: 24/200 	Training Loss: 0.010300
# Epoch: 25/200 	Training Loss: 0.008042
# Epoch: 26/200 	Training Loss: 0.006104
# Epoch: 164/200 	Training Loss: 0.005251
# Epoch: 165/200 	Training Loss: 0.004227
# Epoch: 166/200 	Training Loss: 0.009868
# Epoch: 167/200 	Training Loss: 0.007046
# Epoch: 168/200 	Training Loss: 0.005779
# Epoch: 169/200 	Training Loss: 0.004367
# Epoch: 170/200 	Training Loss: 0.004814
# Epoch: 171/200 	Training Loss: 0.004392
# Epoch: 172/200 	Training Loss: 0.004846
# Epoch: 173/200 	Training Loss: 0.006743
# Epoch: 174/200 	Training Loss: 0.004425
# Epoch: 175/200 	Training Loss: 0.004845
# Epoch: 176/200 	Training Loss: 0.005432
# Epoch: 177/200 	Training Loss: 0.004585
# Epoch: 178/200 	Training Loss: 0.005241
# Epoch: 179/200 	Training Loss: 0.005302
# Epoch: 180/200 	Training Loss: 0.005263
# Epoch: 181/200 	Training Loss: 0.004431
# Epoch: 182/200 	Training Loss: 0.004590
# Epoch: 183/200 	Training Loss: 0.005468
# Epoch: 184/200 	Training Loss: 0.005875
# Epoch: 185/200 	Training Loss: 0.005225
# Epoch: 186/200 	Training Loss: 0.004604
# Epoch: 187/200 	Training Loss: 0.003865
# Epoch: 188/200 	Training Loss: 0.005138
# Epoch: 189/200 	Training Loss: 0.005090
# Epoch: 190/200 	Training Loss: 0.007236
# Epoch: 191/200 	Training Loss: 0.010879
# Epoch: 192/200 	Training Loss: 0.007863
# Epoch: 193/200 	Training Loss: 0.004721
# Epoch: 194/200 	Training Loss: 0.005991
# Epoch: 195/200 	Training Loss: 0.006392
# Epoch: 196/200 	Training Loss: 0.005007
# Epoch: 197/200 	Training Loss: 0.005776
# Epoch: 198/200 	Training Loss: 0.005175
# Epoch: 199/200 	Training Loss: 0.004518
# Epoch: 200/200 	Training Loss: 0.005031
# Time taken: 71.25002

# %%
plt.plot(train_losses)

# Save the model  -- I already saved this and submitted
torch.save(model.state_dict(), 'PyTorch_Model/ArriTime_NN_mish_Drop_L2_Huber_200Epochs.pt')

# %%
model.load_state_dict(torch.load('PyTorch_Model/ArriTime_NN_mish_Drop_L2_Huber_200Epochs.pt', map_location=torch.device('cpu')))

model.eval()           # prep model for *evaluation*
model.to(device)
with torch.no_grad():  # turn off gradient to save memory
    y_predNN_torch = model(X_test_torch.to(device))

y_predNN_normal = y_predNN_torch.cpu().numpy()     # convert to numpy array
y_test_normal = y_test_torch.cpu().numpy()



print(y_predNN_normal)
# Out:
# [[-2.1467419]
#  [-1.7518475]
#  [-1.4842776]
#  ...
#  [ 1.1744212]
#  [ 1.3282883]
#  [ 1.5028647]]

# %%
mape = mean_absolute_percentage_error(y_test_normal, y_predNN_normal)
r2 = r2_score(y_test_normal, y_predNN_normal)
rmse = np.sqrt(mean_squared_error(y_test_normal, y_predNN_normal))
print(f"Scores in normal distribution: r2 = {r2}, mape = {mape}, rmse = {rmse}")
# Out:
# Scores in normal distribution: r2 = 0.993864730759033, mape = 0.3810582756996155, rmse = 0.07787859439849854

# %%
y_predNN = quantile1.inverse_transform(y_predNN_normal)
mape = mean_absolute_percentage_error(y_test, y_predNN)
r2 = r2_score(y_test, y_predNN)
rmse = np.sqrt(mean_squared_error(y_test, y_predNN))


print(f"Scores in actual distribution for arrival time: r2 = {r2}, mape = {mape}, rmse = {rmse}")
# Out:
# Scores in actual distribution for arrival time: r2 = 0.9960531991588721, mape = 0.03777026821935934, rmse = 0.0017416101202768588
