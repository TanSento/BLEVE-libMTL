# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import timeit
#import shap
from sklearn.metrics import r2_score, mean_absolute_percentage_error, mean_squared_error
from sklearn.model_selection import cross_val_score, GridSearchCV, KFold
from sklearn.model_selection import train_test_split

# %% [markdown]
# ___

# %% [markdown]
# # Read-in and One-Hot Encoding

# %%
df = pd.read_excel("data_new/train.xlsx", sheet_name="negative_duration")

dt = pd.read_excel("data_new/test.xlsx", sheet_name="negative_duration")

# %%
# Label encoding 'Status' feature into 0 and 1 
# 0 for Subcooled and 1 for Superheated

from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()

df['Status'] = LE.fit_transform(df['Status'])
dt['Status'] = LE.fit_transform(dt['Status'])

df
# Out:
#          ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0      B291                         13.6          0.665119             1.0
# 1      B291                         13.6          0.665119             1.0
# 2      B291                         13.6          0.665119             1.0
# 3      B291                         13.6          0.665119             1.0
# 4      B291                         13.6          0.665119             1.0
# ...     ...                          ...               ...             ...
# 21595  B103                         30.7          0.181290             0.6
# 21596  B103                         30.7          0.181290             0.6
# 21597  B103                         30.7          0.181290             0.6
# 21598  B103                         30.7          0.181290             0.6
# 21599  B103                         30.7          0.181290             0.6
#
#        Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 0                  4.0              0.8                  1.8
# 1                  4.0              0.8                  1.8
# 2                  4.0              0.8                  1.8
# 3                  4.0              0.8                  1.8
# 4                  4.0              0.8                  1.8
# ...                ...              ...                  ...
# 21595              2.0              2.8                  1.2
# 21596              2.0              2.8                  1.2
# 21597              2.0              2.8                  1.2
# 21598              2.0              2.8                  1.2
# 21599              2.0              2.8                  1.2
#
#        Tank Height with Gas (m)   Vapour Temerature (K)  \
# 0                           0.4                   435.0
# 1                           0.4                   435.0
# 2                           0.4                   435.0
# 3                           0.4                   435.0
# 4                           0.4                   435.0
# ...                         ...                     ...
# 21595                       2.2                   334.7
# 21596                       2.2                   334.7
# 21597                       2.2                   334.7
# 21598                       2.2                   334.7
# 21599                       2.2                   334.7
#
#         Liquid Temerature (K)  Status  Stand-off Distance    Target
# 0                       372.5       1                   5  0.009827
# 1                       372.5       1                   6  0.009906
# 2                       372.5       1                   7  0.009970
# 3                       372.5       1                   8  0.010039
# 4                       372.5       1                   9  0.010011
# ...                       ...     ...                 ...       ...
# 21595                   404.9       0                  36  0.017944
# 21596                   404.9       0                  37  0.017724
# 21597                   404.9       0                  38  0.017498
# 21598                   404.9       0                  39  0.017280
# 21599                   404.9       0                  40  0.017078
#
# [21600 rows x 13 columns]

# %%
dt.iloc[30:50,:]
# Out:
#       ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 30  P197                     11.55904          0.602823             3.0
# 31  P197                     11.55904          0.602823             3.0
# 32  P197                     11.55904          0.602823             3.0
# 33  P197                     11.55904          0.602823             3.0
# 34  P197                     11.55904          0.602823             3.0
# 35  P197                     11.55904          0.602823             3.0
# 36  P168                     12.72223          0.648320             1.8
# 37  P168                     12.72223          0.648320             1.8
# 38  P168                     12.72223          0.648320             1.8
# 39  P168                     12.72223          0.648320             1.8
# 40  P168                     12.72223          0.648320             1.8
# 41  P168                     12.72223          0.648320             1.8
# 42  P168                     12.72223          0.648320             1.8
# 43  P168                     12.72223          0.648320             1.8
# 44  P168                     12.72223          0.648320             1.8
# 45  P168                     12.72223          0.648320             1.8
# 46  P168                     12.72223          0.648320             1.8
# 47  P168                     12.72223          0.648320             1.8
# 48  P168                     12.72223          0.648320             1.8
# 49  P168                     12.72223          0.648320             1.8
#
#     Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 30              0.8              2.2                  0.2
# 31              0.8              2.2                  0.2
# 32              0.8              2.2                  0.2
# 33              0.8              2.2                  0.2
# 34              0.8              2.2                  0.2
# 35              0.8              2.2                  0.2
# 36              8.2              0.6                  1.8
# 37              8.2              0.6                  1.8
# 38              8.2              0.6                  1.8
# 39              8.2              0.6                  1.8
# 40              8.2              0.6                  1.8
# 41              8.2              0.6                  1.8
# 42              8.2              0.6                  1.8
# 43              8.2              0.6                  1.8
# 44              8.2              0.6                  1.8
# 45              8.2              0.6                  1.8
# 46              8.2              0.6                  1.8
# 47              8.2              0.6                  1.8
# 48              8.2              0.6                  1.8
# 49              8.2              0.6                  1.8
#
#     Tank Height with Gas (m)   Vapour Temerature (K)   Liquid Temerature (K)  \
# 30                       1.0                   296.7                   328.5
# 31                       1.0                   296.7                   328.5
# 32                       1.0                   296.7                   328.5
# 33                       1.0                   296.7                   328.5
# 34                       1.0                   296.7                   328.5
# 35                       1.0                   296.7                   328.5
# 36                       0.2                   389.7                   296.4
# 37                       0.2                   389.7                   296.4
# 38                       0.2                   389.7                   296.4
# 39                       0.2                   389.7                   296.4
# 40                       0.2                   389.7                   296.4
# 41                       0.2                   389.7                   296.4
# 42                       0.2                   389.7                   296.4
# 43                       0.2                   389.7                   296.4
# 44                       0.2                   389.7                   296.4
# 45                       0.2                   389.7                   296.4
# 46                       0.2                   389.7                   296.4
# 47                       0.2                   389.7                   296.4
# 48                       0.2                   389.7                   296.4
# 49                       0.2                   389.7                   296.4
#
#     Status  Stand-off Distance    Target
# 30       1                  35  0.015426
# 31       1                  36  0.015341
# 32       1                  37  0.015277
# 33       1                  38  0.015224
# 34       1                  39  0.015191
# 35       1                  40  0.015170
# 36       0                   5  0.009043
# 37       0                   6  0.009390
# 38       0                   7  0.009452
# 39       0                   8  0.009528
# 40       0                   9  0.009658
# 41       0                  10  0.009688
# 42       0                  11  0.009588
# 43       0                  12  0.009598
# 44       0                  13  0.009700
# 45       0                  14  0.009631
# 46       0                  15  0.009524
# 47       0                  16  0.012086
# 48       0                  17  0.012530
# 49       0                  18  0.012757

# %%
X_traindf = df.drop(['ID','Target'], axis=1)
X_testdf = dt.drop(['ID','Target'], axis=1)

X_traindf
# Out:
#        Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0                             13.6          0.665119             1.0
# 1                             13.6          0.665119             1.0
# 2                             13.6          0.665119             1.0
# 3                             13.6          0.665119             1.0
# 4                             13.6          0.665119             1.0
# ...                            ...               ...             ...
# 21595                         30.7          0.181290             0.6
# 21596                         30.7          0.181290             0.6
# 21597                         30.7          0.181290             0.6
# 21598                         30.7          0.181290             0.6
# 21599                         30.7          0.181290             0.6
#
#        Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 0                  4.0              0.8                  1.8
# 1                  4.0              0.8                  1.8
# 2                  4.0              0.8                  1.8
# 3                  4.0              0.8                  1.8
# 4                  4.0              0.8                  1.8
# ...                ...              ...                  ...
# 21595              2.0              2.8                  1.2
# 21596              2.0              2.8                  1.2
# 21597              2.0              2.8                  1.2
# 21598              2.0              2.8                  1.2
# 21599              2.0              2.8                  1.2
#
#        Tank Height with Gas (m)   Vapour Temerature (K)  \
# 0                           0.4                   435.0
# 1                           0.4                   435.0
# 2                           0.4                   435.0
# 3                           0.4                   435.0
# 4                           0.4                   435.0
# ...                         ...                     ...
# 21595                       2.2                   334.7
# 21596                       2.2                   334.7
# 21597                       2.2                   334.7
# 21598                       2.2                   334.7
# 21599                       2.2                   334.7
#
#         Liquid Temerature (K)  Status  Stand-off Distance
# 0                       372.5       1                   5
# 1                       372.5       1                   6
# 2                       372.5       1                   7
# 3                       372.5       1                   8
# 4                       372.5       1                   9
# ...                       ...     ...                 ...
# 21595                   404.9       0                  36
# 21596                   404.9       0                  37
# 21597                   404.9       0                  38
# 21598                   404.9       0                  39
# 21599                   404.9       0                  40
#
# [21600 rows x 11 columns]

# %%
y_train = df['Target']
y_train
# Out:
# 0        0.009827
# 1        0.009906
# 2        0.009970
# 3        0.010039
# 4        0.010011
#            ...
# 21595    0.017944
# 21596    0.017724
# 21597    0.017498
# 21598    0.017280
# 21599    0.017078
# Name: Target, Length: 21600, dtype: float64

# %%
y_test = dt['Target']

y_test
# Out:
# 0       0.017425
# 1       0.017031
# 2       0.016819
# 3       0.016603
# 4       0.016633
#           ...
# 7195    0.015640
# 7196    0.015677
# 7197    0.015717
# 7198    0.015774
# 7199    0.015850
# Name: Target, Length: 7200, dtype: float64

# %% [markdown]
# ___

# %% [markdown]
# # Standardization and Power Transform

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import QuantileTransformer

# %%
# Processing both X_train and X_test using standardization
scaler = StandardScaler()
X_train = scaler.fit_transform(X_traindf)
X_test = scaler.transform(X_testdf)

# %%
quantile = QuantileTransformer(output_distribution='normal', random_state=42)



y_train_normal = quantile.fit_transform(y_train.values.reshape(-1,1))
y_test_normal = quantile.transform(y_test.values.reshape(-1,1))

# %%
# Visualize the effect of power transformation
f = plt.figure(figsize=(15, 6))

ax = f.add_subplot(121)
sns.distplot(y_train, bins=50, color='r', ax=ax)
ax.set_title('Distribution before processing')

ax=f.add_subplot(122)
sns.distplot(y_train_normal, bins=50, color='b', ax=ax)
ax.set_title('Distribution after quantile processing')
print()
# Out:
# /home/tendou/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/tendou/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ___

# %% [markdown]
# # ANN

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt

torch.backends.cudnn.version() , torch.backends.cudnn.enabled
torch.manual_seed(0)

# %%
# convert data to torch.FloatTensor
X_train_torch = torch.from_numpy(X_train.astype(np.float32))
X_test_torch = torch.from_numpy(X_test.astype(np.float32))



y_train_torch = torch.from_numpy(y_train_normal.astype(np.float32))
y_test_torch = torch.from_numpy(y_test_normal.astype(np.float32))

print(X_train_torch)
# Out:
# tensor([[-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.6846],
#         [-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.5883],
#         [-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.4921],
#         ...,
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.4921],
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.5883],
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.6846]])

# %%
train_data = []
for i in range(len(X_train_torch)):
   train_data.append([X_train_torch[i],
                      y_train_torch[i]
                     ])

test_data = []
for i in range(len(X_test_torch)):
   test_data.append([X_test_torch[i], 
                     y_test_torch[i]
                     ])
   
# prepare data loaders
train_loader = torch.utils.data.DataLoader(train_data, batch_size=512,               # batch_size could be smaller
    num_workers=0, shuffle=True)                                                                   # Increasing num_workers slow down the training because it does not use GPU at all
test_loader = torch.utils.data.DataLoader(test_data, batch_size=512,
    num_workers=0)

# %%
for data, target in train_loader:
    print(data.shape[0] == data.size(0))
    break
# Out:
# True

# %%
## Define the NN architecture
## NN with 3 hidden layer, s=[11, 256, 256, 256, 1]

class BleveNet(nn.Module):
    def __init__(self):
        super(BleveNet, self).__init__()
        # The first hidden layer has 256 neurons
        self.fc1 = nn.Linear(X_train_torch.shape[1], 256)
        # The second hidden layer has 256 neurons
        self.fc2 = nn.Linear(256, 256)
        # The third hidden layer has 256 neurons
        self.fc3 = nn.Linear(256, 256)
        # The final layer has 1 output neuron
        self.fc4 = nn.Linear(256, 1)


        # Define proportion or neurons to dropout
        self.dropout = nn.Dropout(0.1)

        # Mish activation
        self.mish = nn.Mish()


    def forward(self, x):
        # add first fully connected layer
        x = self.fc1(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add second fully connected layer
        x = self.fc2(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add third fully connected layer
        x = self.fc3(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add final output layers:
        output = self.fc4(x)
       
        return output

# initialize the NN
model = BleveNet()
print(model)
# Out:
# BleveNet(
#   (fc1): Linear(in_features=11, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=256, bias=True)
#   (fc4): Linear(in_features=256, out_features=1, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (mish): Mish()
# )

# %%
criterion = nn.HuberLoss()        # This is the best loss function for my model
# criterion = nn.MSELoss()


optimizer = torch.optim.Adam(model.parameters(), lr=0.005, weight_decay=1e-5)     # This is the best optimizer for my model 

# Check for GPU
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
startTime = timeit.default_timer() 

n_epochs = 500 

model.to(device)    # bring the model to gpu

train_losses = []
lowest_mape = 100
for epoch in range(n_epochs):

    model.train()       

    # monitor training loss
    train_loss = 0.0
    
    ###################
    # train the model #
    ###################
    for data, target in train_loader:
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        #bring data and target to gpu
        data, target = data.to(device), target.to(device)
        
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update running training loss
        train_loss += loss.item()*data.size(0)
        
    # print training statistics 
    # calculate average loss over an epoch
    train_loss = train_loss/len(train_loader.dataset)
    train_losses.append(train_loss)

    print('Epoch: {}/{} \tTraining Loss: {:.6f}'.format(
        epoch+1,
        n_epochs, 
        train_loss
        ))
    

    ############################
    # Evaluate the lowest MAPE #
    ############################
    model.eval()
    with torch.no_grad():  # turn off gradient to save memory
        y_predNN_torch = model(X_test_torch.to(device))

    y_predNN = quantile.inverse_transform(y_predNN_torch.cpu().numpy())
    MAPE = mean_absolute_percentage_error(y_test, y_predNN)

    if MAPE < lowest_mape:
        lowest_mape = MAPE
        print(f'Lowest MAPE: {lowest_mape}')
        torch.save(model.state_dict(), 'PyTorch_Model/Single_NegativeDuration_lowest.pt')
    print()

endTime = timeit.default_timer()
runningTotal = (endTime - startTime)
print(f"Time taken: {runningTotal}")
# Out:
# Epoch: 1/500 	Training Loss: 0.068196
# Lowest MAPE: 0.0685507538758951
#
# Epoch: 2/500 	Training Loss: 0.030099
# Lowest MAPE: 0.06277281490209305
#
# Epoch: 3/500 	Training Loss: 0.025558
# Lowest MAPE: 0.054758544704429854
#
# Epoch: 4/500 	Training Loss: 0.023602
# Lowest MAPE: 0.05406850059991597
#
# Epoch: 5/500 	Training Loss: 0.021392
# Lowest MAPE: 0.05054597364157978
#
# Epoch: 6/500 	Training Loss: 0.019674
#
# Epoch: 7/500 	Training Loss: 0.017739
#
# Epoch: 8/500 	Training Loss: 0.016965
#
# Epoch: 9/500 	Training Loss: 0.017819
#
# Epoch: 10/500 	Training Loss: 0.016399
#
# Epoch: 11/500 	Training Loss: 0.015786
#
# Epoch: 12/500 	Training Loss: 0.015263
#
# Epoch: 13/500 	Training Loss: 0.014706
#
# Epoch: 14/500 	Training Loss: 0.014946
#
# Epoch: 15/500 	Training Loss: 0.014729
#
# Epoch: 16/500 	Training Loss: 0.013592
#
# Epoch: 17/500 	Training Loss: 0.014171
#
# Epoch: 18/500 	Training Loss: 0.013036
#
# Epoch: 19/500 	Training Loss: 0.013614
#
# Epoch: 20/500 	Training Loss: 0.013214
#
# Epoch: 21/500 	Training Loss: 0.012044
#
# Epoch: 22/500 	Training Loss: 0.012081
#
# Epoch: 23/500 	Training Loss: 0.012653
#
# Epoch: 24/500 	Training Loss: 0.014841
#
# Epoch: 25/500 	Training Loss: 0.011411
#
# Epoch: 26/500 	Training Loss: 0.011322
#
# Epoch: 27/500 	Training Loss: 0.011710
#
# Epoch: 28/500 	Training Loss: 0.010918
#
# Epoch: 29/500 	Training Loss: 0.011241
#
# Epoch: 30/500 	Training Loss: 0.010461
#
# Epoch: 31/500 	Training Loss: 0.010757
#
# Epoch: 32/500 	Training Loss: 0.011607
#
# Epoch: 33/500 	Training Loss: 0.011197
#
# Epoch: 34/500 	Training Loss: 0.011449
#
# Epoch: 35/500 	Training Loss: 0.010701
#
# Epoch: 36/500 	Training Loss: 0.010396
#
# Epoch: 37/500 	Training Loss: 0.010432
#
# Epoch: 38/500 	Training Loss: 0.009785
#
# Epoch: 39/500 	Training Loss: 0.010129
#
# Epoch: 40/500 	Training Loss: 0.009719
#
# Epoch: 41/500 	Training Loss: 0.009615
#
# Epoch: 42/500 	Training Loss: 0.010445
#
# Epoch: 43/500 	Training Loss: 0.010427
#
# Epoch: 44/500 	Training Loss: 0.010004
#
# Epoch: 45/500 	Training Loss: 0.010063
#
# Epoch: 46/500 	Training Loss: 0.009857
#
# Epoch: 47/500 	Training Loss: 0.009415
#
# Epoch: 48/500 	Training Loss: 0.013884
#
# Epoch: 49/500 	Training Loss: 0.009541
#
# Epoch: 50/500 	Training Loss: 0.009653
#
# Epoch: 51/500 	Training Loss: 0.009489
#
# Epoch: 52/500 	Training Loss: 0.009073
#
# Epoch: 53/500 	Training Loss: 0.009206
#
# Epoch: 54/500 	Training Loss: 0.009392
#
# Epoch: 55/500 	Training Loss: 0.009206
#
# Epoch: 56/500 	Training Loss: 0.011085
#
# Epoch: 57/500 	Training Loss: 0.009096
#
# Epoch: 58/500 	Training Loss: 0.010464
#
# Epoch: 59/500 	Training Loss: 0.009319
#
# Epoch: 60/500 	Training Loss: 0.008890
#
# Epoch: 61/500 	Training Loss: 0.008876
#
# Epoch: 62/500 	Training Loss: 0.009585
#
# Epoch: 63/500 	Training Loss: 0.008922
#
# Epoch: 64/500 	Training Loss: 0.009274
#
# Epoch: 65/500 	Training Loss: 0.008905
#
# Epoch: 66/500 	Training Loss: 0.010384
#
# Epoch: 67/500 	Training Loss: 0.008774
#
# Epoch: 68/500 	Training Loss: 0.009051
#
# Epoch: 69/500 	Training Loss: 0.008511
#
# Epoch: 70/500 	Training Loss: 0.009612
#
# Epoch: 71/500 	Training Loss: 0.008494
#
# Epoch: 72/500 	Training Loss: 0.008368
#
# Epoch: 73/500 	Training Loss: 0.008295
#
# Epoch: 74/500 	Training Loss: 0.009035
#
# Epoch: 75/500 	Training Loss: 0.008921
#
# Epoch: 76/500 	Training Loss: 0.009184
#
# Epoch: 77/500 	Training Loss: 0.008581
#
# Epoch: 78/500 	Training Loss: 0.008683
#
# Epoch: 79/500 	Training Loss: 0.008840
#
# Epoch: 80/500 	Training Loss: 0.008326
#
# Epoch: 81/500 	Training Loss: 0.008357
#
# Epoch: 82/500 	Training Loss: 0.008871
#
# Epoch: 83/500 	Training Loss: 0.008397
#
# Epoch: 84/500 	Training Loss: 0.008914
#
# Epoch: 85/500 	Training Loss: 0.008250
#
# Epoch: 86/500 	Training Loss: 0.008719
#
# Epoch: 87/500 	Training Loss: 0.008136
#
# Epoch: 88/500 	Training Loss: 0.009631
#
# Epoch: 89/500 	Training Loss: 0.008780
#
# Epoch: 90/500 	Training Loss: 0.009166
#
# Epoch: 91/500 	Training Loss: 0.009659
#
# Epoch: 92/500 	Training Loss: 0.008136
#
# Epoch: 93/500 	Training Loss: 0.008190
#
# Epoch: 94/500 	Training Loss: 0.008547
#
# Epoch: 95/500 	Training Loss: 0.007735
#
# Epoch: 96/500 	Training Loss: 0.008409
#
# Epoch: 97/500 	Training Loss: 0.008896
#
# Epoch: 98/500 	Training Loss: 0.008847
#
# Epoch: 99/500 	Training Loss: 0.010482
#
# Epoch: 100/500 	Training Loss: 0.008271
#
# Epoch: 101/500 	Training Loss: 0.008839
#
# Epoch: 102/500 	Training Loss: 0.008817
#
# Epoch: 103/500 	Training Loss: 0.008030
#
# Epoch: 104/500 	Training Loss: 0.007610
#
# Epoch: 105/500 	Training Loss: 0.007490
#
# Epoch: 106/500 	Training Loss: 0.007578
#
# Epoch: 107/500 	Training Loss: 0.008279
#
# Epoch: 108/500 	Training Loss: 0.008157
#
# Epoch: 109/500 	Training Loss: 0.007730
#
# Epoch: 110/500 	Training Loss: 0.007913
#
# Epoch: 111/500 	Training Loss: 0.008185
#
# Epoch: 112/500 	Training Loss: 0.008851
#
# Epoch: 113/500 	Training Loss: 0.009502
#
# Epoch: 114/500 	Training Loss: 0.008267
#
# Epoch: 115/500 	Training Loss: 0.007549
#
# Epoch: 116/500 	Training Loss: 0.007893
#
# Epoch: 117/500 	Training Loss: 0.008323
#
# Epoch: 118/500 	Training Loss: 0.007708
#
# Epoch: 119/500 	Training Loss: 0.007835
#
# Epoch: 120/500 	Training Loss: 0.009434
#
# Epoch: 121/500 	Training Loss: 0.008365
#
# Epoch: 122/500 	Training Loss: 0.008068
#
# Epoch: 123/500 	Training Loss: 0.008190
#
# Epoch: 124/500 	Training Loss: 0.009008
#
# Epoch: 125/500 	Training Loss: 0.007614
#
# Epoch: 126/500 	Training Loss: 0.009475
#
# Epoch: 127/500 	Training Loss: 0.008529
#
# Epoch: 128/500 	Training Loss: 0.008492
#
# Epoch: 129/500 	Training Loss: 0.008018
#
# Epoch: 130/500 	Training Loss: 0.008251
# Lowest MAPE: 0.05001261765106987
#
# Epoch: 131/500 	Training Loss: 0.007425
#
# Epoch: 132/500 	Training Loss: 0.007254
#
# Epoch: 133/500 	Training Loss: 0.008139
#
# Epoch: 134/500 	Training Loss: 0.008382
#
# Epoch: 135/500 	Training Loss: 0.008315
#
# Epoch: 136/500 	Training Loss: 0.007899
#
# Epoch: 137/500 	Training Loss: 0.008267
#
# Epoch: 138/500 	Training Loss: 0.008255
#
# Epoch: 139/500 	Training Loss: 0.008516
#
# Epoch: 140/500 	Training Loss: 0.008820
#
# Epoch: 141/500 	Training Loss: 0.008548
#
# Epoch: 142/500 	Training Loss: 0.007673
#
# Epoch: 143/500 	Training Loss: 0.007645
#
# Epoch: 144/500 	Training Loss: 0.007768
#
# Epoch: 145/500 	Training Loss: 0.007917
#
# Epoch: 146/500 	Training Loss: 0.009334
#
# Epoch: 147/500 	Training Loss: 0.007555
#
# Epoch: 148/500 	Training Loss: 0.007757
#
# Epoch: 149/500 	Training Loss: 0.008346
#
# Epoch: 150/500 	Training Loss: 0.008658
#
# Epoch: 151/500 	Training Loss: 0.008696
#
# Epoch: 152/500 	Training Loss: 0.008041
#
# Epoch: 153/500 	Training Loss: 0.008429
#
# Epoch: 154/500 	Training Loss: 0.008488
#
# Epoch: 155/500 	Training Loss: 0.009409
#
# Epoch: 156/500 	Training Loss: 0.007977
#
# Epoch: 157/500 	Training Loss: 0.007152
#
# Epoch: 158/500 	Training Loss: 0.007615
#
# Epoch: 159/500 	Training Loss: 0.008261
#
# Epoch: 160/500 	Training Loss: 0.007545
#
# Epoch: 161/500 	Training Loss: 0.008296
#
# Epoch: 162/500 	Training Loss: 0.007458
#
# Epoch: 163/500 	Training Loss: 0.007732
#
# Epoch: 164/500 	Training Loss: 0.007861
#
# Epoch: 165/500 	Training Loss: 0.007716
#
# Epoch: 166/500 	Training Loss: 0.008357
#
# Epoch: 167/500 	Training Loss: 0.007827
#
# Epoch: 168/500 	Training Loss: 0.007319
#
# Epoch: 169/500 	Training Loss: 0.007280
#
# Epoch: 170/500 	Training Loss: 0.007025
#
# Epoch: 171/500 	Training Loss: 0.007497
#
# Epoch: 172/500 	Training Loss: 0.007197
#
# Epoch: 173/500 	Training Loss: 0.008150
#
# Epoch: 174/500 	Training Loss: 0.008890
#
# Epoch: 175/500 	Training Loss: 0.007780
#
# Epoch: 176/500 	Training Loss: 0.008116
#
# Epoch: 177/500 	Training Loss: 0.008211
#
# Epoch: 178/500 	Training Loss: 0.008316
#
# Epoch: 179/500 	Training Loss: 0.007659
#
# Epoch: 180/500 	Training Loss: 0.007523
# Lowest MAPE: 0.04956852998581534
#
# Epoch: 181/500 	Training Loss: 0.007436
#
# Epoch: 182/500 	Training Loss: 0.007663
#
# Epoch: 183/500 	Training Loss: 0.008747
#
# Epoch: 184/500 	Training Loss: 0.009145
#
# Epoch: 185/500 	Training Loss: 0.007800
#
# Epoch: 186/500 	Training Loss: 0.007033
#
# Epoch: 187/500 	Training Loss: 0.007074
#
# Epoch: 188/500 	Training Loss: 0.009273
#
# Epoch: 189/500 	Training Loss: 0.007862
#
# Epoch: 190/500 	Training Loss: 0.007872
#
# Epoch: 191/500 	Training Loss: 0.008200
#
# Epoch: 192/500 	Training Loss: 0.007346
#
# Epoch: 193/500 	Training Loss: 0.007310
#
# Epoch: 194/500 	Training Loss: 0.008239
#
# Epoch: 195/500 	Training Loss: 0.007880
# Lowest MAPE: 0.04905432218313762
#
# Epoch: 196/500 	Training Loss: 0.007944
#
# Epoch: 197/500 	Training Loss: 0.007686
#
# Epoch: 198/500 	Training Loss: 0.007980
#
# Epoch: 199/500 	Training Loss: 0.008265
#
# Epoch: 200/500 	Training Loss: 0.007873
#
# Epoch: 201/500 	Training Loss: 0.008016
#
# Epoch: 202/500 	Training Loss: 0.007573
# Lowest MAPE: 0.04895428837995387
#
# Epoch: 203/500 	Training Loss: 0.007509
#
# Epoch: 204/500 	Training Loss: 0.008413
#
# Epoch: 205/500 	Training Loss: 0.007294
#
# Epoch: 206/500 	Training Loss: 0.007433
#
# Epoch: 207/500 	Training Loss: 0.007209
#
# Epoch: 208/500 	Training Loss: 0.008063
#
# Epoch: 209/500 	Training Loss: 0.007659
#
# Epoch: 210/500 	Training Loss: 0.007416
#
# Epoch: 211/500 	Training Loss: 0.007608
#
# Epoch: 212/500 	Training Loss: 0.007278
#
# Epoch: 213/500 	Training Loss: 0.007462
#
# Epoch: 214/500 	Training Loss: 0.008532
#
# Epoch: 215/500 	Training Loss: 0.007844
#
# Epoch: 216/500 	Training Loss: 0.012630
#
# Epoch: 217/500 	Training Loss: 0.008180
#
# Epoch: 218/500 	Training Loss: 0.007749
#
# Epoch: 219/500 	Training Loss: 0.009293
#
# Epoch: 220/500 	Training Loss: 0.008115
#
# Epoch: 221/500 	Training Loss: 0.007653
#
# Epoch: 222/500 	Training Loss: 0.007379
#
# Epoch: 223/500 	Training Loss: 0.007775
#
# Epoch: 224/500 	Training Loss: 0.008207
#
# Epoch: 225/500 	Training Loss: 0.007393
#
# Epoch: 226/500 	Training Loss: 0.008157
#
# Epoch: 227/500 	Training Loss: 0.007814
#
# Epoch: 228/500 	Training Loss: 0.007267
#
# Epoch: 229/500 	Training Loss: 0.006985
#
# Epoch: 230/500 	Training Loss: 0.007365
#
# Epoch: 231/500 	Training Loss: 0.007673
#
# Epoch: 232/500 	Training Loss: 0.007895
#
# Epoch: 233/500 	Training Loss: 0.007925
#
# Epoch: 234/500 	Training Loss: 0.009568
#
# Epoch: 235/500 	Training Loss: 0.008903
#
# Epoch: 236/500 	Training Loss: 0.007334
#
# Epoch: 237/500 	Training Loss: 0.007464
#
# Epoch: 238/500 	Training Loss: 0.007366
#
# Epoch: 239/500 	Training Loss: 0.006933
#
# Epoch: 240/500 	Training Loss: 0.007756
#
# Epoch: 241/500 	Training Loss: 0.007184
# Lowest MAPE: 0.04892732861633859
#
# Epoch: 242/500 	Training Loss: 0.007154
#
# Epoch: 243/500 	Training Loss: 0.007435
#
# Epoch: 244/500 	Training Loss: 0.008101
#
# Epoch: 245/500 	Training Loss: 0.008452
#
# Epoch: 246/500 	Training Loss: 0.007452
#
# Epoch: 247/500 	Training Loss: 0.007205
#
# Epoch: 248/500 	Training Loss: 0.007531
#
# Epoch: 249/500 	Training Loss: 0.007341
#
# Epoch: 250/500 	Training Loss: 0.007779
#
# Epoch: 251/500 	Training Loss: 0.006995
#
# Epoch: 252/500 	Training Loss: 0.008113
# Lowest MAPE: 0.048417866163566727
#
# Epoch: 253/500 	Training Loss: 0.007526
#
# Epoch: 254/500 	Training Loss: 0.008597
#
# Epoch: 255/500 	Training Loss: 0.007146
#
# Epoch: 256/500 	Training Loss: 0.007775
#
# Epoch: 257/500 	Training Loss: 0.008125
#
# Epoch: 258/500 	Training Loss: 0.007089
#
# Epoch: 259/500 	Training Loss: 0.007097
#
# Epoch: 260/500 	Training Loss: 0.008397
#
# Epoch: 261/500 	Training Loss: 0.008288
#
# Epoch: 262/500 	Training Loss: 0.007112
#
# Epoch: 263/500 	Training Loss: 0.008612
#
# Epoch: 264/500 	Training Loss: 0.007962
#
# Epoch: 265/500 	Training Loss: 0.007377
#
# Epoch: 266/500 	Training Loss: 0.007950
#
# Epoch: 267/500 	Training Loss: 0.007019
#
# Epoch: 268/500 	Training Loss: 0.007262
#
# Epoch: 269/500 	Training Loss: 0.007358
#
# Epoch: 270/500 	Training Loss: 0.007437
#
# Epoch: 271/500 	Training Loss: 0.006938
#
# Epoch: 272/500 	Training Loss: 0.007460
#
# Epoch: 273/500 	Training Loss: 0.006983
#
# Epoch: 274/500 	Training Loss: 0.008120
#
# Epoch: 275/500 	Training Loss: 0.007621
#
# Epoch: 276/500 	Training Loss: 0.007223
#
# Epoch: 277/500 	Training Loss: 0.007447
#
# Epoch: 278/500 	Training Loss: 0.009374
#
# Epoch: 279/500 	Training Loss: 0.007398
#
# Epoch: 280/500 	Training Loss: 0.007315
#
# Epoch: 281/500 	Training Loss: 0.007235
#
# Epoch: 282/500 	Training Loss: 0.006978
#
# Epoch: 283/500 	Training Loss: 0.007425
#
# Epoch: 284/500 	Training Loss: 0.007396
#
# Epoch: 285/500 	Training Loss: 0.008137
#
# Epoch: 286/500 	Training Loss: 0.007407
#
# Epoch: 287/500 	Training Loss: 0.007634
#
# Epoch: 288/500 	Training Loss: 0.009425
#
# Epoch: 289/500 	Training Loss: 0.007674
#
# Epoch: 290/500 	Training Loss: 0.007869
#
# Epoch: 291/500 	Training Loss: 0.007383
#
# Epoch: 292/500 	Training Loss: 0.007549
#
# Epoch: 293/500 	Training Loss: 0.007187
#
# Epoch: 294/500 	Training Loss: 0.007355
#
# Epoch: 295/500 	Training Loss: 0.007571
#
# Epoch: 296/500 	Training Loss: 0.008138
#
# Epoch: 297/500 	Training Loss: 0.009017
#
# Epoch: 298/500 	Training Loss: 0.007549
#
# Epoch: 299/500 	Training Loss: 0.007110
#
# Epoch: 300/500 	Training Loss: 0.007347
#
# Epoch: 301/500 	Training Loss: 0.007225
#
# Epoch: 302/500 	Training Loss: 0.007754
#
# Epoch: 303/500 	Training Loss: 0.007510
#
# Epoch: 304/500 	Training Loss: 0.006785
#
# Epoch: 305/500 	Training Loss: 0.006918
#
# Epoch: 306/500 	Training Loss: 0.007216
#
# Epoch: 307/500 	Training Loss: 0.007223
#
# Epoch: 308/500 	Training Loss: 0.007365
#
# Epoch: 309/500 	Training Loss: 0.007207
#
# Epoch: 310/500 	Training Loss: 0.007164
#
# Epoch: 311/500 	Training Loss: 0.007316
#
# Epoch: 312/500 	Training Loss: 0.007047
#
# Epoch: 313/500 	Training Loss: 0.008352
#
# Epoch: 314/500 	Training Loss: 0.008493
#
# Epoch: 315/500 	Training Loss: 0.009876
#
# Epoch: 316/500 	Training Loss: 0.007682
#
# Epoch: 317/500 	Training Loss: 0.008298
#
# Epoch: 318/500 	Training Loss: 0.007829
#
# Epoch: 319/500 	Training Loss: 0.007508
#
# Epoch: 320/500 	Training Loss: 0.007706
#
# Epoch: 321/500 	Training Loss: 0.007720
#
# Epoch: 322/500 	Training Loss: 0.007078
#
# Epoch: 323/500 	Training Loss: 0.007033
#
# Epoch: 324/500 	Training Loss: 0.007175
#
# Epoch: 325/500 	Training Loss: 0.007544
#
# Epoch: 326/500 	Training Loss: 0.007295
#
# Epoch: 327/500 	Training Loss: 0.007863
#
# Epoch: 328/500 	Training Loss: 0.007463
#
# Epoch: 329/500 	Training Loss: 0.007286
#
# Epoch: 330/500 	Training Loss: 0.007291
# Lowest MAPE: 0.04792322309120431
#
# Epoch: 331/500 	Training Loss: 0.007255
#
# Epoch: 332/500 	Training Loss: 0.007434
#
# Epoch: 333/500 	Training Loss: 0.008064
#
# Epoch: 334/500 	Training Loss: 0.007211
#
# Epoch: 335/500 	Training Loss: 0.007454
#
# Epoch: 336/500 	Training Loss: 0.007468
#
# Epoch: 337/500 	Training Loss: 0.007293
#
# Epoch: 338/500 	Training Loss: 0.007755
#
# Epoch: 339/500 	Training Loss: 0.007338
#
# Epoch: 340/500 	Training Loss: 0.007229
#
# Epoch: 341/500 	Training Loss: 0.007779
#
# Epoch: 342/500 	Training Loss: 0.007683
#
# Epoch: 343/500 	Training Loss: 0.007736
#
# Epoch: 344/500 	Training Loss: 0.009046
#
# Epoch: 345/500 	Training Loss: 0.007602
#
# Epoch: 346/500 	Training Loss: 0.007303
#
# Epoch: 347/500 	Training Loss: 0.007178
#
# Epoch: 348/500 	Training Loss: 0.008608
#
# Epoch: 349/500 	Training Loss: 0.008425
#
# Epoch: 350/500 	Training Loss: 0.007441
#
# Epoch: 351/500 	Training Loss: 0.007312
#
# Epoch: 352/500 	Training Loss: 0.007458
#
# Epoch: 353/500 	Training Loss: 0.007308
#
# Epoch: 354/500 	Training Loss: 0.007480
#
# Epoch: 355/500 	Training Loss: 0.007618
#
# Epoch: 356/500 	Training Loss: 0.008708
#
# Epoch: 357/500 	Training Loss: 0.007241
#
# Epoch: 358/500 	Training Loss: 0.006864
#
# Epoch: 359/500 	Training Loss: 0.007123
#
# Epoch: 360/500 	Training Loss: 0.007631
#
# Epoch: 361/500 	Training Loss: 0.007231
#
# Epoch: 362/500 	Training Loss: 0.007247
#
# Epoch: 363/500 	Training Loss: 0.007180
#
# Epoch: 364/500 	Training Loss: 0.007402
#
# Epoch: 365/500 	Training Loss: 0.007644
#
# Epoch: 366/500 	Training Loss: 0.008072
#
# Epoch: 367/500 	Training Loss: 0.007155
#
# Epoch: 368/500 	Training Loss: 0.006982
#
# Epoch: 369/500 	Training Loss: 0.007285
#
# Epoch: 370/500 	Training Loss: 0.007411
#
# Epoch: 371/500 	Training Loss: 0.007132
#
# Epoch: 372/500 	Training Loss: 0.008831
#
# Epoch: 373/500 	Training Loss: 0.007694
#
# Epoch: 374/500 	Training Loss: 0.007182
#
# Epoch: 375/500 	Training Loss: 0.008635
#
# Epoch: 376/500 	Training Loss: 0.007551
#
# Epoch: 377/500 	Training Loss: 0.007817
#
# Epoch: 378/500 	Training Loss: 0.007171
#
# Epoch: 379/500 	Training Loss: 0.007849
#
# Epoch: 380/500 	Training Loss: 0.007086
#
# Epoch: 381/500 	Training Loss: 0.007210
#
# Epoch: 382/500 	Training Loss: 0.008569
#
# Epoch: 383/500 	Training Loss: 0.007183
#
# Epoch: 384/500 	Training Loss: 0.007274
#
# Epoch: 385/500 	Training Loss: 0.007574
#
# Epoch: 386/500 	Training Loss: 0.006819
#
# Epoch: 387/500 	Training Loss: 0.007278
#
# Epoch: 388/500 	Training Loss: 0.007467
#
# Epoch: 389/500 	Training Loss: 0.007004
#
# Epoch: 390/500 	Training Loss: 0.007405
#
# Epoch: 391/500 	Training Loss: 0.007697
#
# Epoch: 392/500 	Training Loss: 0.008191
#
# Epoch: 393/500 	Training Loss: 0.006840
#
# Epoch: 394/500 	Training Loss: 0.007070
#
# Epoch: 395/500 	Training Loss: 0.007550
#
# Epoch: 396/500 	Training Loss: 0.007574
#
# Epoch: 397/500 	Training Loss: 0.007246
#
# Epoch: 398/500 	Training Loss: 0.007577
#
# Epoch: 399/500 	Training Loss: 0.007565
#
# Epoch: 400/500 	Training Loss: 0.007442
#
# Epoch: 401/500 	Training Loss: 0.007814
#
# Epoch: 402/500 	Training Loss: 0.007758
#
# Epoch: 403/500 	Training Loss: 0.006974
#
# Epoch: 404/500 	Training Loss: 0.006873
#
# Epoch: 405/500 	Training Loss: 0.007201
#
# Epoch: 406/500 	Training Loss: 0.007437
#
# Epoch: 407/500 	Training Loss: 0.008837
#
# Epoch: 408/500 	Training Loss: 0.007374
#
# Epoch: 409/500 	Training Loss: 0.007470
#
# Epoch: 410/500 	Training Loss: 0.008065
#
# Epoch: 411/500 	Training Loss: 0.007201
#
# Epoch: 412/500 	Training Loss: 0.007658
#
# Epoch: 413/500 	Training Loss: 0.007271
#
# Epoch: 414/500 	Training Loss: 0.007150
#
# Epoch: 415/500 	Training Loss: 0.006918
#
# Epoch: 416/500 	Training Loss: 0.008644
#
# Epoch: 417/500 	Training Loss: 0.007483
#
# Epoch: 418/500 	Training Loss: 0.006582
#
# Epoch: 419/500 	Training Loss: 0.008532
#
# Epoch: 420/500 	Training Loss: 0.007249
#
# Epoch: 421/500 	Training Loss: 0.007664
#
# Epoch: 422/500 	Training Loss: 0.006745
#
# Epoch: 423/500 	Training Loss: 0.007194
#
# Epoch: 424/500 	Training Loss: 0.006956
#
# Epoch: 425/500 	Training Loss: 0.007282
#
# Epoch: 426/500 	Training Loss: 0.006937
#
# Epoch: 427/500 	Training Loss: 0.007346
#
# Epoch: 428/500 	Training Loss: 0.007702
#
# Epoch: 429/500 	Training Loss: 0.008128
#
# Epoch: 430/500 	Training Loss: 0.007001
#
# Epoch: 431/500 	Training Loss: 0.007642
#
# Epoch: 432/500 	Training Loss: 0.007237
#
# Epoch: 433/500 	Training Loss: 0.007186
#
# Epoch: 434/500 	Training Loss: 0.007924
#
# Epoch: 435/500 	Training Loss: 0.007944
#
# Epoch: 436/500 	Training Loss: 0.007075
#
# Epoch: 437/500 	Training Loss: 0.006823
#
# Epoch: 438/500 	Training Loss: 0.006894
#
# Epoch: 439/500 	Training Loss: 0.007544
#
# Epoch: 440/500 	Training Loss: 0.007750
#
# Epoch: 441/500 	Training Loss: 0.007285
#
# Epoch: 442/500 	Training Loss: 0.007444
#
# Epoch: 443/500 	Training Loss: 0.008783
#
# Epoch: 444/500 	Training Loss: 0.007305
#
# Epoch: 445/500 	Training Loss: 0.007352
#
# Epoch: 446/500 	Training Loss: 0.007018
#
# Epoch: 447/500 	Training Loss: 0.007500
#
# Epoch: 448/500 	Training Loss: 0.007074
#
# Epoch: 449/500 	Training Loss: 0.007078
#
# Epoch: 450/500 	Training Loss: 0.006972
#
# Epoch: 451/500 	Training Loss: 0.007571
#
# Epoch: 452/500 	Training Loss: 0.007634
#
# Epoch: 453/500 	Training Loss: 0.007905
# Lowest MAPE: 0.0475621426090203
#
# Epoch: 454/500 	Training Loss: 0.007490
#
# Epoch: 455/500 	Training Loss: 0.007359
#
# Epoch: 456/500 	Training Loss: 0.006855
#
# Epoch: 457/500 	Training Loss: 0.006949
#
# Epoch: 458/500 	Training Loss: 0.007147
#
# Epoch: 459/500 	Training Loss: 0.006588
#
# Epoch: 460/500 	Training Loss: 0.007260
#
# Epoch: 461/500 	Training Loss: 0.006937
#
# Epoch: 462/500 	Training Loss: 0.008133
#
# Epoch: 463/500 	Training Loss: 0.007122
#
# Epoch: 464/500 	Training Loss: 0.007094
#
# Epoch: 465/500 	Training Loss: 0.007224
#
# Epoch: 466/500 	Training Loss: 0.007989
#
# Epoch: 467/500 	Training Loss: 0.007008
#
# Epoch: 468/500 	Training Loss: 0.007215
#
# Epoch: 469/500 	Training Loss: 0.007413
#
# Epoch: 470/500 	Training Loss: 0.006858
# Lowest MAPE: 0.04738957732064942
#
# Epoch: 471/500 	Training Loss: 0.007151
#
# Epoch: 472/500 	Training Loss: 0.007318
#
# Epoch: 473/500 	Training Loss: 0.007449
#
# Epoch: 474/500 	Training Loss: 0.007343
#
# Epoch: 475/500 	Training Loss: 0.007716
#
# Epoch: 476/500 	Training Loss: 0.006754
#
# Epoch: 477/500 	Training Loss: 0.006927
#
# Epoch: 478/500 	Training Loss: 0.007148
#
# Epoch: 479/500 	Training Loss: 0.007112
#
# Epoch: 480/500 	Training Loss: 0.007880
#
# Epoch: 481/500 	Training Loss: 0.007557
#
# Epoch: 482/500 	Training Loss: 0.007271
#
# Epoch: 483/500 	Training Loss: 0.007337
#
# Epoch: 484/500 	Training Loss: 0.006991
#
# Epoch: 485/500 	Training Loss: 0.007292
#
# Epoch: 486/500 	Training Loss: 0.008002
#
# Epoch: 487/500 	Training Loss: 0.008080
#
# Epoch: 488/500 	Training Loss: 0.007819
#
# Epoch: 489/500 	Training Loss: 0.007455
#
# Epoch: 490/500 	Training Loss: 0.007652
#
# Epoch: 491/500 	Training Loss: 0.006741
#
# Epoch: 492/500 	Training Loss: 0.007925
#
# Epoch: 493/500 	Training Loss: 0.007195
#
# Epoch: 494/500 	Training Loss: 0.007242
#
# Epoch: 495/500 	Training Loss: 0.007121
#
# Epoch: 496/500 	Training Loss: 0.007500
#
# Epoch: 497/500 	Training Loss: 0.007797
#
# Epoch: 498/500 	Training Loss: 0.007229
#
# Epoch: 499/500 	Training Loss: 0.007082
#
# Epoch: 500/500 	Training Loss: 0.007172
#
# Time taken: 99.4547079999993

# %%
plt.plot(train_losses)

# %%
model.load_state_dict(torch.load('PyTorch_Model/Single_NegativeDuration_lowest.pt', map_location=torch.device('cpu')))

model.eval()           # prep model for *evaluation*
model.to(device)
with torch.no_grad():  # turn off gradient to save memory
    y_predNN_torch = model(X_test_torch.to(device))

y_predNN_normal = y_predNN_torch.cpu().numpy()     # convert to numpy array
y_test_normal = y_test_torch.cpu().numpy()



print(y_predNN_normal)
# Out:
# [[-0.25328064]
#  [-0.27288887]
#  [-0.29128057]
#  ...
#  [-0.05918333]
#  [-0.04899295]
#  [-0.03947897]]

# %%
mape = mean_absolute_percentage_error(y_test_normal, y_predNN_normal)
r2 = r2_score(y_test_normal, y_predNN_normal)
rmse = np.sqrt(mean_squared_error(y_test_normal, y_predNN_normal))
print(f"Scores in normal distribution: r2 = {r2}, mape = {mape}, rmse = {rmse}")
# Out:
# Scores in normal distribution: r2 = 0.960635138355203, mape = 1.5291955471038818, rmse = 0.20169778168201447

# %%
y_predNN = quantile.inverse_transform(y_predNN_normal)
mape = mean_absolute_percentage_error(y_test, y_predNN)
r2 = r2_score(y_test, y_predNN)
rmse = np.sqrt(mean_squared_error(y_test, y_predNN))


print(f"Scores in actual distribution for negative duration")
print('r2:', r2*100)
print('mape:', mape*100)
print('rmse:', rmse)
print()
# Out:
# Scores in actual distribution for negative duration
# r2: 97.54875448013229
# mape: 4.738957732064942
# rmse: 0.000985544077801063
