# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import timeit
#import shap
from sklearn.metrics import r2_score, mean_absolute_percentage_error, mean_squared_error
from sklearn.model_selection import cross_val_score, GridSearchCV, KFold
from sklearn.model_selection import train_test_split

# %% [markdown]
# ___

# %% [markdown]
# # Read-in and One-Hot Encoding

# %%
df1 = pd.read_excel("data_new/train.xlsx", sheet_name="positive_peak_time")
df2 = pd.read_excel("data_new/train.xlsx", sheet_name="negative_peak_time")
df3 = pd.read_excel("data_new/train.xlsx", sheet_name="arrival_time")
df4 = pd.read_excel("data_new/train.xlsx", sheet_name="positive_duration")
df5 = pd.read_excel("data_new/train.xlsx", sheet_name="negative_duration")
df6 = pd.read_excel("data_new/train.xlsx", sheet_name="positive_pressure")
df7 = pd.read_excel("data_new/train.xlsx", sheet_name="negative_pressure")
df8 = pd.read_excel("data_new/train.xlsx", sheet_name="positive_impulse")



dt1 = pd.read_excel("data_new/test.xlsx", sheet_name="positive_peak_time")
dt2 = pd.read_excel("data_new/test.xlsx", sheet_name="negative_peak_time")
dt3 = pd.read_excel("data_new/test.xlsx", sheet_name="arrival_time")
dt4 = pd.read_excel("data_new/test.xlsx", sheet_name="positive_duration")
dt5 = pd.read_excel("data_new/test.xlsx", sheet_name="negative_duration")
dt6 = pd.read_excel("data_new/test.xlsx", sheet_name="positive_pressure")
dt7 = pd.read_excel("data_new/test.xlsx", sheet_name="negative_pressure")
dt8 = pd.read_excel("data_new/test.xlsx", sheet_name="positive_impulse")

# %%
df1
# Out:
#          ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0      B291                         13.6          0.665119             1.0
# 1      B291                         13.6          0.665119             1.0
# 2      B291                         13.6          0.665119             1.0
# 3      B291                         13.6          0.665119             1.0
# 4      B291                         13.6          0.665119             1.0
# ...     ...                          ...               ...             ...
# 21595  B103                         30.7          0.181290             0.6
# 21596  B103                         30.7          0.181290             0.6
# 21597  B103                         30.7          0.181290             0.6
# 21598  B103                         30.7          0.181290             0.6
# 21599  B103                         30.7          0.181290             0.6
#
#        Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 0                  4.0              0.8                  1.8
# 1                  4.0              0.8                  1.8
# 2                  4.0              0.8                  1.8
# 3                  4.0              0.8                  1.8
# 4                  4.0              0.8                  1.8
# ...                ...              ...                  ...
# 21595              2.0              2.8                  1.2
# 21596              2.0              2.8                  1.2
# 21597              2.0              2.8                  1.2
# 21598              2.0              2.8                  1.2
# 21599              2.0              2.8                  1.2
#
#        Tank Height with Gas (m)   Vapour Temerature (K)  \
# 0                           0.4                   435.0
# 1                           0.4                   435.0
# 2                           0.4                   435.0
# 3                           0.4                   435.0
# 4                           0.4                   435.0
# ...                         ...                     ...
# 21595                       2.2                   334.7
# 21596                       2.2                   334.7
# 21597                       2.2                   334.7
# 21598                       2.2                   334.7
# 21599                       2.2                   334.7
#
#         Liquid Temerature (K)       Status  Stand-off Distance    Target
# 0                       372.5  Superheated                   5  0.012166
# 1                       372.5  Superheated                   6  0.014556
# 2                       372.5  Superheated                   7  0.017034
# 3                       372.5  Superheated                   8  0.019576
# 4                       372.5  Superheated                   9  0.022172
# ...                       ...          ...                 ...       ...
# 21595                   404.9    Subcooled                  36  0.093782
# 21596                   404.9    Subcooled                  37  0.096635
# 21597                   404.9    Subcooled                  38  0.099487
# 21598                   404.9    Subcooled                  39  0.102341
# 21599                   404.9    Subcooled                  40  0.105201
#
# [21600 rows x 13 columns]

# %%
dt1
# Out:
#         ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0     P197                    11.559040          0.602823             3.0
# 1     P197                    11.559040          0.602823             3.0
# 2     P197                    11.559040          0.602823             3.0
# 3     P197                    11.559040          0.602823             3.0
# 4     P197                    11.559040          0.602823             3.0
# ...    ...                          ...               ...             ...
# 7195   P55                     5.970915          0.284706             0.6
# 7196   P55                     5.970915          0.284706             0.6
# 7197   P55                     5.970915          0.284706             0.6
# 7198   P55                     5.970915          0.284706             0.6
# 7199   P55                     5.970915          0.284706             0.6
#
#       Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 0                 0.8              2.2                  0.2
# 1                 0.8              2.2                  0.2
# 2                 0.8              2.2                  0.2
# 3                 0.8              2.2                  0.2
# 4                 0.8              2.2                  0.2
# ...               ...              ...                  ...
# 7195              9.8              2.8                  1.0
# 7196              9.8              2.8                  1.0
# 7197              9.8              2.8                  1.0
# 7198              9.8              2.8                  1.0
# 7199              9.8              2.8                  1.0
#
#       Tank Height with Gas (m)   Vapour Temerature (K)  \
# 0                          1.0                   296.7
# 1                          1.0                   296.7
# 2                          1.0                   296.7
# 3                          1.0                   296.7
# 4                          1.0                   296.7
# ...                        ...                     ...
# 7195                       2.2                   439.3
# 7196                       2.2                   439.3
# 7197                       2.2                   439.3
# 7198                       2.2                   439.3
# 7199                       2.2                   439.3
#
#        Liquid Temerature (K)       Status  Stand-off Distance    Target
# 0                      328.5  Superheated                   5  0.012114
# 1                      328.5  Superheated                   6  0.014798
# 2                      328.5  Superheated                   7  0.017533
# 3                      328.5  Superheated                   8  0.020293
# 4                      328.5  Superheated                   9  0.023077
# ...                      ...          ...                 ...       ...
# 7195                   349.9  Superheated                  36  0.091819
# 7196                   349.9  Superheated                  37  0.094618
# 7197                   349.9  Superheated                  38  0.097421
# 7198                   349.9  Superheated                  39  0.100227
# 7199                   349.9  Superheated                  40  0.103035
#
# [7200 rows x 13 columns]

# %%
# Label encoding 'Status' feature into 0 and 1 
# 0 for Subcooled and 1 for Superheated

from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()

df5['Status'] = LE.fit_transform(df5['Status'])
dt5['Status'] = LE.fit_transform(dt5['Status'])

df5
# Out:
#          ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0      B291                         13.6          0.665119             1.0
# 1      B291                         13.6          0.665119             1.0
# 2      B291                         13.6          0.665119             1.0
# 3      B291                         13.6          0.665119             1.0
# 4      B291                         13.6          0.665119             1.0
# ...     ...                          ...               ...             ...
# 21595  B103                         30.7          0.181290             0.6
# 21596  B103                         30.7          0.181290             0.6
# 21597  B103                         30.7          0.181290             0.6
# 21598  B103                         30.7          0.181290             0.6
# 21599  B103                         30.7          0.181290             0.6
#
#        Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 0                  4.0              0.8                  1.8
# 1                  4.0              0.8                  1.8
# 2                  4.0              0.8                  1.8
# 3                  4.0              0.8                  1.8
# 4                  4.0              0.8                  1.8
# ...                ...              ...                  ...
# 21595              2.0              2.8                  1.2
# 21596              2.0              2.8                  1.2
# 21597              2.0              2.8                  1.2
# 21598              2.0              2.8                  1.2
# 21599              2.0              2.8                  1.2
#
#        Tank Height with Gas (m)   Vapour Temerature (K)  \
# 0                           0.4                   435.0
# 1                           0.4                   435.0
# 2                           0.4                   435.0
# 3                           0.4                   435.0
# 4                           0.4                   435.0
# ...                         ...                     ...
# 21595                       2.2                   334.7
# 21596                       2.2                   334.7
# 21597                       2.2                   334.7
# 21598                       2.2                   334.7
# 21599                       2.2                   334.7
#
#         Liquid Temerature (K)  Status  Stand-off Distance    Target
# 0                       372.5       1                   5  0.009827
# 1                       372.5       1                   6  0.009906
# 2                       372.5       1                   7  0.009970
# 3                       372.5       1                   8  0.010039
# 4                       372.5       1                   9  0.010011
# ...                       ...     ...                 ...       ...
# 21595                   404.9       0                  36  0.017944
# 21596                   404.9       0                  37  0.017724
# 21597                   404.9       0                  38  0.017498
# 21598                   404.9       0                  39  0.017280
# 21599                   404.9       0                  40  0.017078
#
# [21600 rows x 13 columns]

# %%
dt5.iloc[30:50,:]
# Out:
#       ID  Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 30  P197                     11.55904          0.602823             3.0
# 31  P197                     11.55904          0.602823             3.0
# 32  P197                     11.55904          0.602823             3.0
# 33  P197                     11.55904          0.602823             3.0
# 34  P197                     11.55904          0.602823             3.0
# 35  P197                     11.55904          0.602823             3.0
# 36  P168                     12.72223          0.648320             1.8
# 37  P168                     12.72223          0.648320             1.8
# 38  P168                     12.72223          0.648320             1.8
# 39  P168                     12.72223          0.648320             1.8
# 40  P168                     12.72223          0.648320             1.8
# 41  P168                     12.72223          0.648320             1.8
# 42  P168                     12.72223          0.648320             1.8
# 43  P168                     12.72223          0.648320             1.8
# 44  P168                     12.72223          0.648320             1.8
# 45  P168                     12.72223          0.648320             1.8
# 46  P168                     12.72223          0.648320             1.8
# 47  P168                     12.72223          0.648320             1.8
# 48  P168                     12.72223          0.648320             1.8
# 49  P168                     12.72223          0.648320             1.8
#
#     Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 30              0.8              2.2                  0.2
# 31              0.8              2.2                  0.2
# 32              0.8              2.2                  0.2
# 33              0.8              2.2                  0.2
# 34              0.8              2.2                  0.2
# 35              0.8              2.2                  0.2
# 36              8.2              0.6                  1.8
# 37              8.2              0.6                  1.8
# 38              8.2              0.6                  1.8
# 39              8.2              0.6                  1.8
# 40              8.2              0.6                  1.8
# 41              8.2              0.6                  1.8
# 42              8.2              0.6                  1.8
# 43              8.2              0.6                  1.8
# 44              8.2              0.6                  1.8
# 45              8.2              0.6                  1.8
# 46              8.2              0.6                  1.8
# 47              8.2              0.6                  1.8
# 48              8.2              0.6                  1.8
# 49              8.2              0.6                  1.8
#
#     Tank Height with Gas (m)   Vapour Temerature (K)   Liquid Temerature (K)  \
# 30                       1.0                   296.7                   328.5
# 31                       1.0                   296.7                   328.5
# 32                       1.0                   296.7                   328.5
# 33                       1.0                   296.7                   328.5
# 34                       1.0                   296.7                   328.5
# 35                       1.0                   296.7                   328.5
# 36                       0.2                   389.7                   296.4
# 37                       0.2                   389.7                   296.4
# 38                       0.2                   389.7                   296.4
# 39                       0.2                   389.7                   296.4
# 40                       0.2                   389.7                   296.4
# 41                       0.2                   389.7                   296.4
# 42                       0.2                   389.7                   296.4
# 43                       0.2                   389.7                   296.4
# 44                       0.2                   389.7                   296.4
# 45                       0.2                   389.7                   296.4
# 46                       0.2                   389.7                   296.4
# 47                       0.2                   389.7                   296.4
# 48                       0.2                   389.7                   296.4
# 49                       0.2                   389.7                   296.4
#
#     Status  Stand-off Distance    Target
# 30       1                  35  0.015426
# 31       1                  36  0.015341
# 32       1                  37  0.015277
# 33       1                  38  0.015224
# 34       1                  39  0.015191
# 35       1                  40  0.015170
# 36       0                   5  0.009043
# 37       0                   6  0.009390
# 38       0                   7  0.009452
# 39       0                   8  0.009528
# 40       0                   9  0.009658
# 41       0                  10  0.009688
# 42       0                  11  0.009588
# 43       0                  12  0.009598
# 44       0                  13  0.009700
# 45       0                  14  0.009631
# 46       0                  15  0.009524
# 47       0                  16  0.012086
# 48       0                  17  0.012530
# 49       0                  18  0.012757

# %%
X_traindf = df5.drop(['ID','Target'], axis=1)
X_testdf = dt5.drop(['ID','Target'], axis=1)

X_traindf
# Out:
#        Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0                             13.6          0.665119             1.0
# 1                             13.6          0.665119             1.0
# 2                             13.6          0.665119             1.0
# 3                             13.6          0.665119             1.0
# 4                             13.6          0.665119             1.0
# ...                            ...               ...             ...
# 21595                         30.7          0.181290             0.6
# 21596                         30.7          0.181290             0.6
# 21597                         30.7          0.181290             0.6
# 21598                         30.7          0.181290             0.6
# 21599                         30.7          0.181290             0.6
#
#        Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 0                  4.0              0.8                  1.8
# 1                  4.0              0.8                  1.8
# 2                  4.0              0.8                  1.8
# 3                  4.0              0.8                  1.8
# 4                  4.0              0.8                  1.8
# ...                ...              ...                  ...
# 21595              2.0              2.8                  1.2
# 21596              2.0              2.8                  1.2
# 21597              2.0              2.8                  1.2
# 21598              2.0              2.8                  1.2
# 21599              2.0              2.8                  1.2
#
#        Tank Height with Gas (m)   Vapour Temerature (K)  \
# 0                           0.4                   435.0
# 1                           0.4                   435.0
# 2                           0.4                   435.0
# 3                           0.4                   435.0
# 4                           0.4                   435.0
# ...                         ...                     ...
# 21595                       2.2                   334.7
# 21596                       2.2                   334.7
# 21597                       2.2                   334.7
# 21598                       2.2                   334.7
# 21599                       2.2                   334.7
#
#         Liquid Temerature (K)  Status  Stand-off Distance
# 0                       372.5       1                   5
# 1                       372.5       1                   6
# 2                       372.5       1                   7
# 3                       372.5       1                   8
# 4                       372.5       1                   9
# ...                       ...     ...                 ...
# 21595                   404.9       0                  36
# 21596                   404.9       0                  37
# 21597                   404.9       0                  38
# 21598                   404.9       0                  39
# 21599                   404.9       0                  40
#
# [21600 rows x 11 columns]

# %%
X_testdf
# Out:
#       Tank Failure Pressure (bar)  Liquid Ratio (%)  Tank Width (m)  \
# 0                       11.559040          0.602823             3.0
# 1                       11.559040          0.602823             3.0
# 2                       11.559040          0.602823             3.0
# 3                       11.559040          0.602823             3.0
# 4                       11.559040          0.602823             3.0
# ...                           ...               ...             ...
# 7195                     5.970915          0.284706             0.6
# 7196                     5.970915          0.284706             0.6
# 7197                     5.970915          0.284706             0.6
# 7198                     5.970915          0.284706             0.6
# 7199                     5.970915          0.284706             0.6
#
#       Tank Length (m)  Tank Height (m)  Height of BLEVE (m)  \
# 0                 0.8              2.2                  0.2
# 1                 0.8              2.2                  0.2
# 2                 0.8              2.2                  0.2
# 3                 0.8              2.2                  0.2
# 4                 0.8              2.2                  0.2
# ...               ...              ...                  ...
# 7195              9.8              2.8                  1.0
# 7196              9.8              2.8                  1.0
# 7197              9.8              2.8                  1.0
# 7198              9.8              2.8                  1.0
# 7199              9.8              2.8                  1.0
#
#       Tank Height with Gas (m)   Vapour Temerature (K)  \
# 0                          1.0                   296.7
# 1                          1.0                   296.7
# 2                          1.0                   296.7
# 3                          1.0                   296.7
# 4                          1.0                   296.7
# ...                        ...                     ...
# 7195                       2.2                   439.3
# 7196                       2.2                   439.3
# 7197                       2.2                   439.3
# 7198                       2.2                   439.3
# 7199                       2.2                   439.3
#
#        Liquid Temerature (K)  Status  Stand-off Distance
# 0                      328.5       1                   5
# 1                      328.5       1                   6
# 2                      328.5       1                   7
# 3                      328.5       1                   8
# 4                      328.5       1                   9
# ...                      ...     ...                 ...
# 7195                   349.9       1                  36
# 7196                   349.9       1                  37
# 7197                   349.9       1                  38
# 7198                   349.9       1                  39
# 7199                   349.9       1                  40
#
# [7200 rows x 11 columns]

# %%
y5_train = df5['Target']
y5_train
# Out:
# 0        0.009827
# 1        0.009906
# 2        0.009970
# 3        0.010039
# 4        0.010011
#            ...
# 21595    0.017944
# 21596    0.017724
# 21597    0.017498
# 21598    0.017280
# 21599    0.017078
# Name: Target, Length: 21600, dtype: float64

# %%
y1_train = df1['Target']
y2_train = df2['Target']
y3_train = df3['Target']
y4_train = df4['Target']
y6_train = df6['Target']
y7_train = df7['Target']
y8_train = df8['Target']

# %%
y1_test = dt1['Target']
y2_test = dt2['Target']
y3_test = dt3['Target']
y4_test = dt4['Target']
y5_test = dt5['Target']
y6_test = dt6['Target']
y7_test = dt7['Target']
y8_test = dt8['Target']

y1_test
# Out:
# 0       0.012114
# 1       0.014798
# 2       0.017533
# 3       0.020293
# 4       0.023077
#           ...
# 7195    0.091819
# 7196    0.094618
# 7197    0.097421
# 7198    0.100227
# 7199    0.103035
# Name: Target, Length: 7200, dtype: float64

# %% [markdown]
# ___

# %% [markdown]
# # Standardization and Power Transform

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import QuantileTransformer

# %%
# Processing both X_train and X_test using standardization
scaler = StandardScaler()
X_train = scaler.fit_transform(X_traindf)
X_test = scaler.transform(X_testdf)

# %%
# Double check if it succeeded
# df_stdscal = pd.DataFrame(X_train)
# df_stdscal.hist(figsize = (20,20), bins=10)

# %%
# Exactly the same result as concatenate all targets and use only 1 quantiles

quantile1 = QuantileTransformer(output_distribution='normal', random_state=42)
quantile2 = QuantileTransformer(output_distribution='normal', random_state=42)
quantile3 = QuantileTransformer(output_distribution='normal', random_state=42)
quantile4 = QuantileTransformer(output_distribution='normal', random_state=42)
quantile5 = QuantileTransformer(output_distribution='normal', random_state=42)
quantile6 = QuantileTransformer(output_distribution='normal', random_state=42)
quantile7 = QuantileTransformer(output_distribution='normal', random_state=42)
quantile8 = QuantileTransformer(output_distribution='normal', random_state=42)


y1_train_normal = quantile1.fit_transform(y1_train.values.reshape(-1,1))
y1_test_normal = quantile1.transform(y1_test.values.reshape(-1,1))


y2_train_normal = quantile2.fit_transform(y2_train.values.reshape(-1,1))
y2_test_normal = quantile2.transform(y2_test.values.reshape(-1,1))

y3_train_normal = quantile3.fit_transform(y3_train.values.reshape(-1,1))
y3_test_normal = quantile3.transform(y3_test.values.reshape(-1,1))

y4_train_normal = quantile4.fit_transform(y4_train.values.reshape(-1,1))
y4_test_normal = quantile4.transform(y4_test.values.reshape(-1,1))

y5_train_normal = quantile5.fit_transform(y5_train.values.reshape(-1,1))
y5_test_normal = quantile5.transform(y5_test.values.reshape(-1,1))

y6_train_normal = quantile6.fit_transform(y6_train.values.reshape(-1,1))
y6_test_normal = quantile6.transform(y6_test.values.reshape(-1,1))

y7_train_normal = quantile7.fit_transform(y7_train.values.reshape(-1,1))
y7_test_normal = quantile7.transform(y7_test.values.reshape(-1,1))

y8_train_normal = quantile8.fit_transform(y8_train.values.reshape(-1,1))
y8_test_normal = quantile8.transform(y8_test.values.reshape(-1,1))

# %%
# Visualize the effect of power transformation
f = plt.figure(figsize=(15, 6))

ax = f.add_subplot(321)
sns.distplot(y1_train, bins=50, color='r', ax=ax)
ax.set_title('Distribution before processing')

ax=f.add_subplot(322)
sns.distplot(y1_train_normal, bins=50, color='b', ax=ax)
ax.set_title('Distribution after quantile processing')
print()

ax = f.add_subplot(323)
sns.distplot(y2_train, bins=50, color='r', ax=ax)
ax.set_title('Distribution before processing')

ax=f.add_subplot(324)
sns.distplot(y2_train_normal, bins=50, color='b', ax=ax)
ax.set_title('Distribution after quantile processing')
print()

ax = f.add_subplot(325)
sns.distplot(y2_test, bins=50, color='r', ax=ax)
ax.set_title('Distribution before processing')

ax=f.add_subplot(326)
sns.distplot(y2_test_normal, bins=50, color='b', ax=ax)
ax.set_title('Distribution after quantile processing')
print()

plt.tight_layout()
# Out:
# /home/tendou/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/tendou/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/tendou/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/tendou/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/tendou/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/tendou/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
y1_test_check = quantile1.inverse_transform(y1_test_normal)
y1_test_check
# Out:
# array([[0.01211439],
#        [0.01479826],
#        [0.01753254],
#        ...,
#        [0.09742104],
#        [0.1002275 ],
#        [0.10303451]])

# %%
y1_test
# Out:
# 0       0.012114
# 1       0.014798
# 2       0.017533
# 3       0.020293
# 4       0.023077
#           ...
# 7195    0.091819
# 7196    0.094618
# 7197    0.097421
# 7198    0.100227
# 7199    0.103035
# Name: Target, Length: 7200, dtype: float64

# %%
y2_test_normal
# Out:
# array([[-1.88001345],
#        [-1.5751694 ],
#        [-1.35795135],
#        ...,
#        [ 1.17679538],
#        [ 1.3282986 ],
#        [ 1.51932793]])

# %% [markdown]
# ___

# %% [markdown]
# # ANN

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset, TensorDataset


torch.backends.cudnn.version() , torch.backends.cudnn.enabled
torch.manual_seed(0)

# %%
# convert data to torch.FloatTensor
X_train_torch = torch.from_numpy(X_train.astype(np.float32))
X_test_torch = torch.from_numpy(X_test.astype(np.float32))



y1_train_torch = torch.from_numpy(y1_train_normal.astype(np.float32))
y1_test_torch = torch.from_numpy(y1_test_normal.astype(np.float32))

y2_train_torch = torch.from_numpy(y2_train_normal.astype(np.float32))
y2_test_torch = torch.from_numpy(y2_test_normal.astype(np.float32))

y3_train_torch = torch.from_numpy(y3_train_normal.astype(np.float32))
y3_test_torch = torch.from_numpy(y3_test_normal.astype(np.float32))

y4_train_torch = torch.from_numpy(y4_train_normal.astype(np.float32))
y4_test_torch = torch.from_numpy(y4_test_normal.astype(np.float32))

y5_train_torch = torch.from_numpy(y5_train_normal.astype(np.float32))
y5_test_torch = torch.from_numpy(y5_test_normal.astype(np.float32))

y6_train_torch = torch.from_numpy(y6_train_normal.astype(np.float32))
y6_test_torch = torch.from_numpy(y6_test_normal.astype(np.float32))

y7_train_torch = torch.from_numpy(y7_train_normal.astype(np.float32))
y7_test_torch = torch.from_numpy(y7_test_normal.astype(np.float32))

y8_train_torch = torch.from_numpy(y8_train_normal.astype(np.float32))
y8_test_torch = torch.from_numpy(y8_test_normal.astype(np.float32))

print(X_train_torch)
# Out:
# tensor([[-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.6846],
#         [-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.5883],
#         [-0.8024,  0.7595, -0.9898,  ...,  0.6962,  1.3190, -1.4921],
#         ...,
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.4921],
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.5883],
#         [ 0.9096, -1.3719, -1.5129,  ...,  1.5587, -0.7582,  1.6846]])

# %%
y8_train_torch
# Out:
# tensor([[ 0.6927],
#         [ 0.5174],
#         [ 0.3689],
#         ...,
#         [-0.6441],
#         [-0.6733],
#         [-0.6979]])

# %%
y8_test_torch
# Out:
# tensor([[-0.0063],
#         [-0.1328],
#         [-0.2405],
#         ...,
#         [-0.3827],
#         [-0.4098],
#         [-0.4363]])

# %%
train_data = []

# Can also just torch.cat(dim=1) for all targets first and then put into the loader
# Same as multi-class
for i in range(len(X_train_torch)):
   train_data.append([X_train_torch[i],
                      y1_train_torch[i], 
                      y2_train_torch[i],
                      y3_train_torch[i],
                      y4_train_torch[i],
                      y5_train_torch[i],
                      y6_train_torch[i],
                      y7_train_torch[i],
                      y8_train_torch[i]])    # 2D List with 21600 points

test_data = []
for i in range(len(X_test_torch)):
   test_data.append([X_test_torch[i], 
                     y1_test_torch[i],
                     y2_test_torch[i],
                     y3_test_torch[i],
                     y4_test_torch[i],
                     y5_test_torch[i],
                     y6_test_torch[i],
                     y7_test_torch[i],
                     y8_test_torch[i]])

# prepare data loaders
train_loader = DataLoader(train_data, batch_size=512,               # batch_size could be smaller
    num_workers=0, shuffle=True)                                   
test_loader = DataLoader(test_data, batch_size=512,
    num_workers=0, shuffle=False)


# dataiter = iter(train_loader)
# point, y1, y2, y3, y4, y5, y6, y7, y8 = dataiter.next()
# # print(point)
# print(torch.cat((y1,y2,y3,y4,y5,y6,y7,y8), dim=1))
# print()
# print('*'*50)

# %%
# test_data[0:2]   # The 2nd data point is the same as the 2nd row of torch.cat

# %%
test_loader_check = DataLoader(test_data, batch_size=10,
    num_workers=0, shuffle=False)

for point, y1, y2, y3, y4, y5, y6, y7, y8 in test_loader_check:
    y = torch.cat((y1,y2,y3,y4,y5,y6,y7,y8), dim=1)
    # print(y)
    print(y[:,1].reshape(-1,1))
    print()
    print(y2)
    break
# Out:
# tensor([[-1.8800],
#         [-1.5752],
#         [-1.3580],
#         [-1.1907],
#         [-1.0533],
#         [-0.9324],
#         [-0.8275],
#         [-0.7325],
#         [-0.6407],
#         [-0.5529]])
#
# tensor([[-1.8800],
#         [-1.5752],
#         [-1.3580],
#         [-1.1907],
#         [-1.0533],
#         [-0.9324],
#         [-0.8275],
#         [-0.7325],
#         [-0.6407],
#         [-0.5529]])

# %%
## Define the NN architecture
## NN with 3 hidden layer, s=[11, 256, 256] -> 8*[256,1]

class BleveNet(nn.Module):
    def __init__(self):
        super(BleveNet, self).__init__()
        # The first hidden layer has 256 neurons
        self.fc1 = nn.Linear(X_train_torch.shape[1], 256)
        # The second hidden layer has 256 neurons
        self.fc2 = nn.Linear(256, 256)
        
        # The final layer has 8 heads, each of which has 1 output neuron
        self.fc3 = nn.Linear(256, 256)
        self.fc4 = nn.Linear(256, 256)
        self.fc5 = nn.Linear(256, 256)
        self.fc6 = nn.Linear(256, 256)
        self.fc7 = nn.Linear(256, 256)
        self.fc8 = nn.Linear(256, 256)
        self.fc9 = nn.Linear(256, 256)
        self.fc10 = nn.Linear(256, 256)
        
        self.fc11 = nn.Linear(256,1)
        self.fc12 = nn.Linear(256,1)
        self.fc13 = nn.Linear(256,1)
        self.fc14 = nn.Linear(256,1)
        self.fc15 = nn.Linear(256,1)
        self.fc16 = nn.Linear(256,1)
        self.fc17 = nn.Linear(256,1)
        self.fc18 = nn.Linear(256,1)
       

        # Define proportion or neurons to dropout
        self.dropout = nn.Dropout(0.1)

        # Mish activation
        self.mish = nn.Mish()


    def forward(self, x):
        # add first fully connected layer
        x = self.fc1(x)
        x = self.mish(x)
        x = self.dropout(x)
        # add second fully connected layer
        x = self.fc2(x)
        x = self.mish(x)
        x = self.dropout(x)
       
        # separated in 8 different heads and outputs
        head1 = self.fc3(x)
        head1 = self.mish(head1)
        head1 = self.dropout(head1)
        output1 = self.fc11(head1)

        head2 = self.fc4(x)
        head2 = self.mish(head2)
        head2 = self.dropout(head2)
        output2 = self.fc12(head2)

        head3 = self.fc5(x)
        head3 = self.mish(head3)
        head3 = self.dropout(head3)
        output3 = self.fc13(head3)

        head4 = self.fc6(x)
        head4 = self.mish(head4)
        head4 = self.dropout(head4)
        output4 = self.fc14(head4)

        head5 = self.fc7(x)
        head5 = self.mish(head5)
        head5 = self.dropout(head5)
        output5 = self.fc15(head5)

        head6 = self.fc8(x)
        head6 = self.mish(head6)
        head6 = self.dropout(head6)
        output6 = self.fc16(head6)

        head7 = self.fc9(x)
        head7 = self.mish(head7)
        head7 = self.dropout(head7)
        output7 = self.fc17(head7)

        head8 = self.fc10(x)
        head8 = self.mish(head8)
        head8 = self.dropout(head8)
        output8 = self.fc18(head8)
        
       
        return [output1, output2, output3, output4, output5, output6, output7, output8]   # can also return torch.cat(dim = 1)
                                                                                          # However, this is more distinctive than Multiclass
# initialize the NN
model = BleveNet()
print(model)
# Out:
# BleveNet(
#   (fc1): Linear(in_features=11, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=256, bias=True)
#   (fc4): Linear(in_features=256, out_features=256, bias=True)
#   (fc5): Linear(in_features=256, out_features=256, bias=True)
#   (fc6): Linear(in_features=256, out_features=256, bias=True)
#   (fc7): Linear(in_features=256, out_features=256, bias=True)
#   (fc8): Linear(in_features=256, out_features=256, bias=True)
#   (fc9): Linear(in_features=256, out_features=256, bias=True)
#   (fc10): Linear(in_features=256, out_features=256, bias=True)
#   (fc11): Linear(in_features=256, out_features=1, bias=True)
#   (fc12): Linear(in_features=256, out_features=1, bias=True)
#   (fc13): Linear(in_features=256, out_features=1, bias=True)
#   (fc14): Linear(in_features=256, out_features=1, bias=True)
#   (fc15): Linear(in_features=256, out_features=1, bias=True)
#   (fc16): Linear(in_features=256, out_features=1, bias=True)
#   (fc17): Linear(in_features=256, out_features=1, bias=True)
#   (fc18): Linear(in_features=256, out_features=1, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (mish): Mish()
# )

# %%
# criterion = nn.HuberLoss() 

# for data, target1, target2, target3, target4, target5, target6, target7, target8 in test_loader_check:
#     targets = torch.cat((target1, target2, target3, target4,
#                              target5, target6, target7, target8), dim=1)
#     output = model(data)
#     print(output)
#     # print(output[1])
#     # print(targets[:,1].reshape(-1,1))
#     # # print(target2)
#     # loss = criterion(output[1], targets[:,1].reshape(-1,1))
#     # print(loss)
    
#     break

# %%
criterion = nn.HuberLoss()        # This is the best loss function for my model
# criterion = nn.MSELoss()


optimizer = torch.optim.Adam(model.parameters(), lr=0.005, weight_decay=1e-5)     # This is the best optimizer for my model 

# Check for GPU
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
startTime = timeit.default_timer() 


n_epochs = 500
T = 1

model.to(device)    # bring the model to gpu
quantiles = [quantile1, quantile2, quantile3, quantile4, quantile5, quantile6, quantile7, quantile8]
y_test = [y1_test, y2_test, y3_test, y4_test, y5_test, y6_test, y7_test, y8_test]

train_loss_buffer = torch.zeros(8, n_epochs)
train_losses = []
lowest_mape = 100


for epoch in range(n_epochs):

    model.train()       
    # monitor training loss
    train_loss = 0.0
    ###################
    # train the model #
    ###################
    for data, target1, target2, target3, target4, target5, target6, target7, target8 in train_loader:
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        #bring data and target to gpu
        data, target1 = data.to(device), target1.to(device)
        target2, target3 = target2.to(device), target3.to(device)
        target4, target5 = target4.to(device), target5.to(device)
        target6, target7 = target6.to(device), target7.to(device)
        target8 = target8.to(device)

        targets = torch.cat((target1, target2, target3, target4,
                             target5, target6, target7, target8), dim=1)
        
        
        
        # forward pass: compute predicted outputs by passing inputs to the model
        outputs = model(data)

        # calculate the loss and put into train_loss_buffer, this buffer has no grad
        # otherwise, they have to backward twice --> loss.backward(retain_graph=True) --> slow
        with torch.no_grad():
            for i in range(8):
                target = targets[:,i].reshape(-1,1)         # reshape so that they have the same shape 
                loss = criterion(outputs[i], target)        
                train_loss_buffer[i, epoch] = loss
        
        # print(train_loss_buffer)

                

        # calculate the loss which can
        losses = torch.zeros(8, dtype=torch.float32)
        for i in range(8):
            target = targets[:,i].reshape(-1,1)             # reshape so that they have the same shape 
            loss = criterion(outputs[i], target)
            losses[i] = loss
                # print(losses)
            
        # print(losses)
                
        
        # print(train_loss_buffer[:,epoch])

        
        
        if epoch > 1:
            w_i = torch.Tensor(train_loss_buffer[:,epoch-1]/train_loss_buffer[:,epoch-2])
            # print(train_loss_buffer[:,epoch-1])
            # print(train_loss_buffer[:,epoch-2])
            # print(w_i)
            # print(w_i/8)
            batch_weight = 8*F.softmax(w_i/T, dim=-1)
        else:
            batch_weight = torch.ones_like(losses)
  

        # train_loss_buffer[:,epoch].to(device)
        # print('buffer:', train_loss_buffer[:,epoch])
        # print('batch weight:', batch_weight)
        # print(batch_weight.shape)
        loss = torch.mul(losses, batch_weight).sum()


        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update running training loss
        train_loss += loss.item()*data.size(0)
        
    # print training statistics 
    # calculate average loss over an epoch
    train_loss = train_loss/len(train_loader.dataset)
    train_losses.append(train_loss)

    print('Epoch: {}/{} \tTraining Loss: {:.6f}'.format(
        epoch+1,
        n_epochs, 
        train_loss
        ))


    ############################
    # Evaluate the lowest MAPE #
    ############################
    model.eval()
    with torch.no_grad():  # turn off gradient to save memory
        y_predNN_torch = model(X_test_torch.to(device))

    
    MAPE = 0
    for i in range(8):
        y_predNN = quantiles[i].inverse_transform(y_predNN_torch[i].cpu().numpy())
        mape = mean_absolute_percentage_error(y_test[i], y_predNN)
        MAPE += mape
    
    AVG_MAPE = MAPE/8
    if AVG_MAPE < lowest_mape:
        lowest_mape = AVG_MAPE
        print(f'Lowest MAPE: {lowest_mape}')
        torch.save(model.state_dict(), 'PyTorch_Model/DWA-T1-Multitask_lowest-DoubleCheck.pt')
    print()
    
    
endTime = timeit.default_timer()
runningTotal = (endTime - startTime)
print(f"Time taken: {runningTotal}")
# Out:
# Epoch: 1/500 	Training Loss: 0.546498
# Epoch: 466/500 	Training Loss: 0.055242
#
# Epoch: 467/500 	Training Loss: 0.061895
#
# Epoch: 468/500 	Training Loss: 0.059983
#
# Epoch: 469/500 	Training Loss: 0.061955
#
# Epoch: 470/500 	Training Loss: 0.053754
#
# Epoch: 471/500 	Training Loss: 0.043969
#
# Epoch: 472/500 	Training Loss: 0.067007
#
# Epoch: 473/500 	Training Loss: 0.046867
#
# Epoch: 474/500 	Training Loss: 0.050733
#
# Epoch: 475/500 	Training Loss: 0.055683
#
# Epoch: 476/500 	Training Loss: 0.051627
#
# Epoch: 477/500 	Training Loss: 0.051342
#
# Epoch: 478/500 	Training Loss: 0.053665
#
# Epoch: 479/500 	Training Loss: 0.075245
#
# Epoch: 480/500 	Training Loss: 0.046468
#
# Epoch: 481/500 	Training Loss: 0.048719
#
# Epoch: 482/500 	Training Loss: 0.055316
#
# Epoch: 483/500 	Training Loss: 0.050336
#
# Epoch: 484/500 	Training Loss: 0.045586
#
# Epoch: 485/500 	Training Loss: 0.047031
#
# Epoch: 486/500 	Training Loss: 0.048050
#
# Epoch: 487/500 	Training Loss: 0.052381
#
# Epoch: 488/500 	Training Loss: 0.048208
#
# Epoch: 489/500 	Training Loss: 0.080624
#
# Epoch: 490/500 	Training Loss: 0.050950
#
# Epoch: 491/500 	Training Loss: 0.046427
#
# Epoch: 492/500 	Training Loss: 0.042652
#
# Epoch: 493/500 	Training Loss: 0.064899
#
# Epoch: 494/500 	Training Loss: 0.046666
#
# Epoch: 495/500 	Training Loss: 0.042417
#
# Epoch: 496/500 	Training Loss: 0.045640
#
# Epoch: 497/500 	Training Loss: 0.046479
#
# Epoch: 498/500 	Training Loss: 0.053782
#
# Epoch: 499/500 	Training Loss: 0.038619
#
# Epoch: 500/500 	Training Loss: 0.041318
#
# Time taken: 363.9351983000015

# %%
plt.plot(train_losses)  # T5 has much less spikes

# %%
# with torch.no_grad():
#     output1, output2, output3, output4, output5, output6, output7, output8 = model(X_train_torch.to(device))

# y1_predtrain = quantile1.inverse_transform(output1.cpu().numpy())
# mape = mean_absolute_percentage_error(y1_train, y1_predtrain)
# r2 = r2_score(y1_train, y1_predtrain)
# rmse = np.sqrt(mean_squared_error(y1_train, y1_predtrain))
# r2, mape

# %% [markdown]
# **Loading the saved state**

# %%
model.load_state_dict(torch.load('PyTorch_Model/DWA-T5-Multitask_lowest.pt', map_location=torch.device('cpu')))

model.eval()           # prep model for *evaluation*
model.to(device)
with torch.no_grad():  # turn off gradient to save memory
    # y1_predNN_torch, y2_predNN_torch, y3_predNN_torch, y4_predNN_torch, y5_predNN_torch, y6_predNN_torch, y7_predNN_torch, y8_predNN_torch  = model(X_test_torch.to(device))
    # you can do this instead of return a list
    y_predNN_torch = model(X_test_torch.to(device))

# print(y1_predNN_torch)
# print(y_predNN[0])

y1_predNN_normal = y_predNN_torch[0].cpu().numpy()     # convert to numpy array
y1_test_normal = y1_test_torch.cpu().numpy()           # not necessary because we used it to convert into torch tensors

y2_predNN_normal = y_predNN_torch[1].cpu().numpy()     # convert to numpy array
# y2_test_normal = y2_test_torch.cpu().numpy()

y3_predNN_normal = y_predNN_torch[2].cpu().numpy()     # convert to numpy array
# y3_test_normal = y3_test_torch.cpu().numpy()

y4_predNN_normal = y_predNN_torch[3].cpu().numpy()     # convert to numpy array
# y4_test_normal = y4_test_torch.cpu().numpy()

y5_predNN_normal = y_predNN_torch[4].cpu().numpy()     # convert to numpy array
# y5_test_normal = y5_test_torch.cpu().numpy()

y6_predNN_normal = y_predNN_torch[5].cpu().numpy()     # convert to numpy array
# y6_test_normal = y6_test_torch.cpu().numpy()

y7_predNN_normal = y_predNN_torch[6].cpu().numpy()     # convert to numpy array
# y7_test_normal = y7_test_torch.cpu().numpy()

y8_predNN_normal = y_predNN_torch[7].cpu().numpy()     # convert to numpy array
# y8_test_normal = y8_test_torch.cpu().numpy()

print(y1_predNN_normal)
print(y1_predNN_normal.shape)
# Out:
# [[-1.7718554]
#  [-1.4820942]
#  [-1.2773856]
#  ...
#  [ 1.1857154]
#  [ 1.3309104]
#  [ 1.4998993]]
# (7200, 1)

# %%
quantiles = [quantile1, quantile2, quantile3, quantile4, quantile5, quantile6, quantile7, quantile8]
y_test = [y1_test, y2_test, y3_test, y4_test, y5_test, y6_test, y7_test, y8_test]

MAPE = 0
target_name = ['Positive Peak Time', 'Negative Peak Time', "Arrival Time", 'Positive Duration',
               'Negative Duration', 'Positive Pressure', 'Negative Pressure', 'Positive Impulse']
for i in range(8):
    y_predNN = quantiles[i].inverse_transform(y_predNN_torch[i].cpu().numpy())
    r2 = r2_score(y_test[i], y_predNN)
    mape = mean_absolute_percentage_error(y_test[i], y_predNN)
    rmse = np.sqrt(mean_squared_error(y_test[i], y_predNN))

    print(target_name[i])
    print('r2:', r2*100)
    print('mape:', mape*100)
    print('rmse:', rmse)
    print()
    MAPE += mape

AVG_MAPE = MAPE/8
print(AVG_MAPE)
# Out:
# Positive Peak Time
# r2: 99.93958637990524
# mape: 1.2018007083424105
# rmse: 0.0007059199680033149
#
# Negative Peak Time
# r2: 99.84075714991508
# mape: 1.681636177380216
# rmse: 0.0011913193687616583
#
# Arrival Time
# r2: 99.93180242114204
# mape: 1.4604138009012928
# rmse: 0.0007239570671131294
#
# Positive Duration
# r2: 96.45814181115172
# mape: 4.065095039086828
# rmse: 0.0006362205483409413
#
# Negative Duration
# r2: 98.07417910986032
# mape: 4.349628043435661
# rmse: 0.0008735556817859663
#
# Positive Pressure
# r2: 98.94193139632577
# mape: 4.948887234090813
# rmse: 0.034330243488372346
#
# Negative Pressure
# r2: 99.00243553616168
# mape: 5.597395071630908
# rmse: 0.007833223418394557
#
# Positive Impulse
# r2: 96.78211456245462
# mape: 6.438875180357549
# rmse: 18.11248343560325
#
# 0.0371796640690321

# %%
mape = mean_absolute_percentage_error(y1_test_torch, y1_predNN_normal)
r2 = r2_score(y1_test_torch, y1_predNN_normal)
rmse = np.sqrt(mean_squared_error(y1_test_torch, y1_predNN_normal))
print(f"Scores in normal distribution: r2 = {r2}, mape = {mape}, rmse = {rmse}")
# Out:
# Scores in normal distribution: r2 = 0.9982121978514497, mape = 0.19426116347312927, rmse = 0.04205621778964996

# %% [markdown]
# ___

# %% [markdown]
# # Positive Peak Time

# %%
y1_predNN = quantile1.inverse_transform(y1_predNN_normal)
mape = mean_absolute_percentage_error(y1_test, y1_predNN)
r2 = r2_score(y1_test, y1_predNN)
rmse = np.sqrt(mean_squared_error(y1_test, y1_predNN))


print(f"Scores in actual distribution for positive peak time: r2 = {r2*100}, mape = {mape*100}, rmse = {rmse}")
# Out:
# Scores in actual distribution for positive peak time: r2 = 99.93958637990524, mape = 1.2018007083424105, rmse = 0.0007059199680033149

# %%
y1_test
# Out:
# 0       0.012114
# 1       0.014798
# 2       0.017533
# 3       0.020293
# 4       0.023077
#           ...
# 7195    0.091819
# 7196    0.094618
# 7197    0.097421
# 7198    0.100227
# 7199    0.103035
# Name: Target, Length: 7200, dtype: float64

# %%
y1_predNN
# Out:
# array([[0.0128759 ],
#        [0.01546114],
#        [0.0181905 ],
#        ...,
#        [0.09525672],
#        [0.09796992],
#        [0.10071054]], dtype=float32)

# %% [markdown]
# ___

# %% [markdown]
# # Negative Peak Time

# %%
y2_predNN = quantile2.inverse_transform(y2_predNN_normal)
mape = mean_absolute_percentage_error(y2_test, y2_predNN)
r2 = r2_score(y2_test, y2_predNN)
rmse = np.sqrt(mean_squared_error(y2_test, y2_predNN))


print(f"Scores in actual distribution for arrival time: r2 = {r2*100}, mape = {mape*100}, rmse = {rmse}")
# Out:
# Scores in actual distribution for arrival time: r2 = 99.84075714991508, mape = 1.681636177380216, rmse = 0.0011913193687616583

# %%
y2_test
# Out:
# 0       0.023626
# 1       0.026637
# 2       0.029588
# 3       0.032553
# 4       0.035477
#           ...
# 7195    0.105469
# 7196    0.108324
# 7197    0.111183
# 7198    0.114052
# 7199    0.116930
# Name: Target, Length: 7200, dtype: float64

# %% [markdown]
# ___

# %% [markdown]
# # Arrival Time

# %%
y3_predNN = quantile3.inverse_transform(y3_predNN_normal)
mape = mean_absolute_percentage_error(y3_test, y3_predNN.astype('float64'))
r2 = r2_score(y3_test, y3_predNN)
rmse = np.sqrt(mean_squared_error(y3_test, y3_predNN))


print(f"Scores in actual distribution for arrival time: r2 = {r2*100}, mape = {mape*100}, rmse = {rmse}")
# Out:
# Scores in actual distribution for arrival time: r2 = 99.93180242114204, mape = 1.4604138009012928, rmse = 0.0007239570671131294

# %%
y3_predNN = quantile3.inverse_transform(y3_predNN_normal)
mape = mean_absolute_percentage_error(y3_test, y3_predNN)
r2 = r2_score(y3_test, y3_predNN)
rmse = np.sqrt(mean_squared_error(y3_test, y3_predNN))


print(f"Scores in actual distribution for arrival time: r2 = {r2}, mape = {mape}, rmse = {rmse}")
# Out:
# Scores in actual distribution for arrival time: r2 = 0.9993180242114204, mape = 0.014604138009012928, rmse = 0.0007239570671131294

# %%
y3_test
# Out:
# 0       0.009646
# 1       0.012093
# 2       0.014611
# 3       0.017177
# 4       0.019785
#           ...
# 7195    0.087402
# 7196    0.090136
# 7197    0.092877
# 7198    0.095618
# 7199    0.098365
# Name: Target, Length: 7200, dtype: float64

# %% [markdown]
# ___

# %% [markdown]
# # Positive Duration

# %%
y4_predNN = quantile4.inverse_transform(y4_predNN_normal)
mape = mean_absolute_percentage_error(y4_test, y4_predNN)
r2 = r2_score(y4_test, y4_predNN)
rmse = np.sqrt(mean_squared_error(y4_test, y4_predNN))


print(f"Scores in actual distribution for arrival time: r2 = {r2*100}, mape = {mape*100}, rmse = {rmse}")
# Out:
# Scores in actual distribution for arrival time: r2 = 96.45814181115172, mape = 4.065095039086828, rmse = 0.0006362205483409413

# %%
y4_test
# Out:
# 0       0.007010
# 1       0.007732
# 2       0.008249
# 3       0.008734
# 4       0.009039
#           ...
# 7195    0.011811
# 7196    0.011917
# 7197    0.012019
# 7198    0.012124
# 7199    0.012225
# Name: Target, Length: 7200, dtype: float64

# %% [markdown]
# ___

# %% [markdown]
# # Negative Duration

# %%
y5_predNN = quantile5.inverse_transform(y5_predNN_normal)
mape = mean_absolute_percentage_error(y5_test, y5_predNN)
r2 = r2_score(y5_test, y5_predNN)
rmse = np.sqrt(mean_squared_error(y5_test, y5_predNN))


print(f"Scores in actual distribution for arrival time: r2 = {r2*100}, mape = {mape*100}, rmse = {rmse}")
# Out:
# Scores in actual distribution for arrival time: r2 = 98.07417910986032, mape = 4.349628043435661, rmse = 0.0008735556817859663

# %%
y5_test[100:120]
# Out:
# 100    0.007093
# 101    0.007088
# 102    0.007090
# 103    0.007085
# 104    0.007079
# 105    0.007068
# 106    0.007064
# 107    0.007045
# 108    0.009888
# 109    0.010129
# 110    0.010376
# 111    0.010301
# 112    0.010790
# 113    0.010871
# 114    0.010731
# 115    0.010871
# 116    0.011529
# 117    0.011713
# 118    0.012421
# 119    0.012635
# Name: Target, dtype: float64

# %%
y5_predNN[100:120]
# Out:
# array([[0.00737161],
#        [0.00737436],
#        [0.00737662],
#        [0.00737722],
#        [0.00737522],
#        [0.0073705 ],
#        [0.00736412],
#        [0.00735788],
#        [0.01107504],
#        [0.01123276],
#        [0.01136213],
#        [0.01146607],
#        [0.0115556 ],
#        [0.01162659],
#        [0.01169057],
#        [0.01174862],
#        [0.01179999],
#        [0.01183628],
#        [0.01187842],
#        [0.01192628]], dtype=float32)

# %% [markdown]
# ___

# %% [markdown]
# # Positive Pressure

# %%
y6_predNN = quantile6.inverse_transform(y6_predNN_normal)
mape = mean_absolute_percentage_error(y6_test, y6_predNN)
r2 = r2_score(y6_test, y6_predNN)
rmse = np.sqrt(mean_squared_error(y6_test, y6_predNN))


print(f"Scores in actual distribution for arrival time: r2 = {r2*100}, mape = {mape*100}, rmse = {rmse}")
# Out:
# Scores in actual distribution for arrival time: r2 = 98.94193139632577, mape = 4.948887234090813, rmse = 0.034330243488372346

# %%
y6_test
# Out:
# 0       0.250616
# 1       0.200787
# 2       0.166701
# 3       0.142053
# 4       0.123448
#           ...
# 7195    0.097647
# 7196    0.094047
# 7197    0.090670
# 7198    0.087499
# 7199    0.084514
# Name: Target, Length: 7200, dtype: float64

# %%
y6_predNN
# Out:
# array([[0.18875474],
#        [0.15623677],
#        [0.13217862],
#        ...,
#        [0.08856439],
#        [0.08560368],
#        [0.08295736]], dtype=float32)

# %% [markdown]
# ___

# %% [markdown]
# # Negative Pressure

# %%
y7_predNN = quantile7.inverse_transform(y7_predNN_normal)
mape = mean_absolute_percentage_error(y7_test, y7_predNN)
r2 = r2_score(y7_test, y7_predNN)
rmse = np.sqrt(mean_squared_error(y7_test, y7_predNN))


print(f"Scores in actual distribution for arrival time: r2 = {r2*100}, mape = {mape*100}, rmse = {rmse}")
# Out:
# Scores in actual distribution for arrival time: r2 = 99.00243553616168, mape = 5.597395071630908, rmse = 0.007833223418394557

# %%
y7_test[1010:1020]
# Out:
# 1010   -0.139212
# 1011   -0.132530
# 1012   -0.121560
# 1013   -0.108367
# 1014   -0.096830
# 1015   -0.094761
# 1016   -0.090152
# 1017   -0.083977
# 1018   -0.076700
# 1019   -0.069374
# Name: Target, dtype: float64

# %%
y7_predNN[1010:1020]
# Out:
# array([[-0.13960056],
#        [-0.12601438],
#        [-0.11412158],
#        [-0.10415473],
#        [-0.0955062 ],
#        [-0.08800204],
#        [-0.08177989],
#        [-0.07635139],
#        [-0.07145251],
#        [-0.06701434]], dtype=float32)

# %% [markdown]
# ___

# %% [markdown]
# # Positive Impulse

# %%
y8_predNN = quantile8.inverse_transform(y8_predNN_normal)
mape = mean_absolute_percentage_error(y8_test, y8_predNN)
r2 = r2_score(y8_test, y8_predNN)
rmse = np.sqrt(mean_squared_error(y8_test, y8_predNN))


print(f"Scores in actual distribution for arrival time: r2 = {r2*100}, mape = {mape*100}, rmse = {rmse}")
# Out:
# Scores in actual distribution for arrival time: r2 = 96.78211456245462, mape = 6.438875180357549, rmse = 18.11248343560325

# %%
y8_test
# Out:
# 0       52.619038
# 1       46.055485
# 2       41.131420
# 3       37.347630
# 4       34.215847
#           ...
# 7195    37.768711
# 7196    36.680138
# 7197    35.652153
# 7198    34.679951
# 7199    33.759022
# Name: Target, Length: 7200, dtype: float64

# %%
y8_predNN
# Out:
# array([[40.555313],
#        [35.851036],
#        [32.268787],
#        ...,
#        [34.78278 ],
#        [33.946976],
#        [33.210537]], dtype=float32)

# %%
y8_predNN[:10]
# Out:
# array([[40.555313],
#        [35.851036],
#        [32.268787],
#        [29.307158],
#        [27.010223],
#        [25.027554],
#        [23.349398],
#        [21.896736],
#        [20.62398 ],
#        [19.415949]], dtype=float32)

# %%
from numpy import load

# %%
test_mape_buffer = load(f'buffer/check_Test_MAPE_Buffer.npy')
test_mape_buffer
# Out:
# array([[28.60885262,  8.72471631,  7.47925118,  7.56119713,  7.21399635],
#        [23.93393219,  7.09111542,  5.46367057,  5.46166189,  5.55902421],
#        [28.61692011,  9.71555933,  7.71864057,  7.6934211 ,  7.62376934],
#        [19.66929734, 12.17941418,  9.87007245,  9.34650525,  8.87029245],
#        [23.4482795 , 13.25124502, 10.12179852,  9.48275328,  9.03234035],
#        [77.5940001 , 24.855268  , 22.93128818, 20.45512199, 18.81340742],
#        [46.7657268 , 18.68387163, 16.36225432, 15.31746984, 14.18593973],
#        [65.77277184, 28.30475271, 23.82541895, 21.86291218, 20.15381902]])
